# %% [markdown]
# ## Interactive Brokers Trading Bot
#
# An Interactive Brokers trading bot supporting both paper trading (testing) and live trading without deep reinforcement learning.

# %% [markdown]
# ### Import Dependencies and Setup

# %%
# Import required libraries
import asyncio
import logging
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from typing import Dict, List, Optional, Union
import time
import random

# Interactive Brokers imports
from ib_insync import IB, Stock, MarketOrder, LimitOrder, Contract, Ticker
from ib_insync import util

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler('trading_bot.log')
    ]
)

# Suppress ib_insync debug logs
logging.getLogger('ib_insync').setLevel(logging.WARNING)

print("✓ Dependencies imported successfully")
print("✓ Logging configured")
# Out:
# ✓ Dependencies imported successfully
# ✓ Logging configured

# %% [markdown]
# ### IB Environment Configuration

# %%
class IBEnvironment:
    """Configuration class for IB connection environments"""
    
    # Paper Trading Configuration
    PAPER_TRADING = {
        'host': '127.0.0.1',
        'port': 7497,  # Paper trading port
        'client_id': 1,
        'description': 'Paper Trading (Demo Account)'
    }
    
    # Live Trading Configuration
    LIVE_TRADING = {
        'host': '127.0.0.1',
        'port': 7496,  # Live trading port
        'client_id': 2,
        'description': 'Live Trading (Real Money)'
    }
    
    @classmethod
    def get_config(cls, environment: str = 'paper') -> Dict:
        """
        Get configuration for specified environment
        
        Args:
            environment: 'paper' for demo trading, 'live' for real money
        """
        if environment.lower() == 'paper':
            return cls.PAPER_TRADING.copy()
        elif environment.lower() == 'live':
            return cls.LIVE_TRADING.copy()
        else:
            raise ValueError("Environment must be 'paper' or 'live'")
    
    @classmethod
    def list_environments(cls):
        """List available trading environments"""
        print("Available Trading Environments:")
        print(f"  paper: {cls.PAPER_TRADING['description']} - Port {cls.PAPER_TRADING['port']}")
        print(f"  live:  {cls.LIVE_TRADING['description']} - Port {cls.LIVE_TRADING['port']}")

# Test the environment configuration
IBEnvironment.list_environments()
print("\n✓ IB Environment configuration ready")
# Out:
# Available Trading Environments:
#   paper: Paper Trading (Demo Account) - Port 7497
#   live:  Live Trading (Real Money) - Port 7496
#
# ✓ IB Environment configuration ready

# %% [markdown]
# ### IB Connection Class

# %%
class IBConnection:
    """Interactive Brokers connection handler"""
    
    def __init__(self, environment: str = 'paper'):
        """
        Initialise IB connection
        
        Args:
            environment: 'paper' for demo, 'live' for real money
        """
        self.config = IBEnvironment.get_config(environment)
        self.environment = environment
        self.ib = IB()
        self.connected = False
        self.logger = logging.getLogger(f'IBConnection-{environment}')
        
        # Connection parameters
        self.host = self.config['host']
        self.port = self.config['port']
        self.client_id = self.config['client_id']
        
        self.logger.info(f"Initialised for {self.config['description']}")
    
    async def connect(self, timeout: int = 10) -> bool:
        """Connect to Interactive Brokers TWS or Gateway"""
        try:
            self.logger.info(f"Connecting to {self.config['description']}...")
            
            await self.ib.connectAsync(
                host=self.host,
                port=self.port,
                clientId=self.client_id,
                timeout=timeout
            )
            
            self.connected = True
            self.logger.info(f"✓ Connected to IB on port {self.port}")
            
            # Get account information
            account = self.ib.managedAccounts()[0] if self.ib.managedAccounts() else "Unknown"
            self.logger.info(f"Account: {account}")
            
            return True
            
        except Exception as e:
            self.logger.error(f"Failed to connect: {e}")
            self.logger.error("Ensure TWS or IB Gateway is running and accepting connections")
            self.connected = False
            return False
    
    def connect_sync(self, timeout: int = 10) -> bool:
        """Synchronous connection method - Jupyter notebook compatible"""
        try:
            # Check if we're in a Jupyter notebook with existing event loop
            try:
                import IPython
                if IPython.get_ipython() is not None:
                    # We're in Jupyter - use util.startLoop for compatibility
                    util.startLoop()
            except ImportError:
                pass  # Not in Jupyter
            
            self.ib.connect(
                host=self.host,
                port=self.port,
                clientId=self.client_id,
                timeout=timeout
            )
            
            self.connected = True
            self.logger.info(f"✓ Connected to IB on port {self.port}")
            
            # Get account information
            try:
                account = self.ib.managedAccounts()[0] if self.ib.managedAccounts() else "Unknown"
                self.logger.info(f"Account: {account}")
            except:
                pass  # Account info not critical
            
            return True
            
        except ConnectionRefusedError as e:
            self.logger.error(f"API connection failed: {e}")
            self.logger.error("Make sure API port on TWS/IBG is open")
            self.connected = False
            return False
        except Exception as e:
            if "This event loop is already running" in str(e):
                self.logger.error("Event loop conflict - trying alternative connection method...")
                return self._connect_alternative(timeout)
            else:
                self.logger.error(f"Failed to connect: {e}")
                self.connected = False
                return False
    
    def _connect_alternative(self, timeout: int = 10) -> bool:
        """Alternative connection method for Jupyter notebooks"""
        try:
            # Create a new IB instance to avoid event loop conflicts
            self.ib = IB()
            
            # Try connecting without event loop management
            self.ib.connect(
                host=self.host,
                port=self.port,
                clientId=self.client_id,
                timeout=timeout
            )
            
            self.connected = True
            self.logger.info(f"✓ Connected to IB on port {self.port} (alternative method)")
            
            return True
            
        except ConnectionRefusedError as e:
            self.logger.error(f"API connection failed: {e}")
            self.logger.error("Make sure TWS or IB Gateway is running and API is enabled")
            self.connected = False
            return False
        except Exception as e:
            self.logger.error(f"Alternative connection failed: {e}")
            self.connected = False
            return False
    
    def disconnect(self):
        """Disconnect from Interactive Brokers"""
        try:
            if self.connected and self.ib.isConnected():
                self.ib.disconnect()
                self.logger.info("Disconnected from IB")
        except Exception as e:
            self.logger.error(f"Error during disconnect: {e}")
        finally:
            self.connected = False
    
    def is_connected(self) -> bool:
        """Check if connection is active"""
        return self.connected and self.ib.isConnected()
    
    def get_account_summary(self) -> Dict:
        """Get account summary information"""
        if not self.is_connected():
            self.logger.warning("Not connected to IB")
            return {}
        
        try:
            account = self.ib.managedAccounts()[0]
            summary = self.ib.accountSummary(account)
            
            # Convert to dictionary
            account_info = {}
            for item in summary:
                account_info[item.tag] = item.value
            
            return account_info
            
        except Exception as e:
            self.logger.error(f"Error getting account summary: {e}")
            return {}

print("✓ IB Connection class created")
# Out:
# ✓ IB Connection class created

# %% [markdown]
# ### Historical Data Handler

# %%
class HistoricalDataHandler:
    """Handle historical data retrieval from Interactive Brokers"""
    
    def __init__(self, ib_connection: IBConnection):
        """
        Initialise historical data handler
        
        Args:
            ib_connection: IBConnection instance
        """
        self.ib_conn = ib_connection
        self.ib = ib_connection.ib
        self.logger = logging.getLogger('HistoricalDataHandler')
        self.data_cache = {}
        
    def create_contract(self, symbol: str, exchange: str = 'SMART', 
                       currency: str = 'USD') -> Stock:
        """
        Create stock contract for IB
        
        Args:
            symbol: Stock symbol (e.g., 'MRK')
            exchange: Exchange (default: 'SMART')
            currency: Currency (default: 'USD')
        """
        return Stock(symbol, exchange, currency)
    
    def get_historical_data(self, symbol: str, duration: str = '1 D',
                           bar_size: str = '1 min', exchange: str = 'SMART',
                           currency: str = 'USD') -> Optional[pd.DataFrame]:
        """
        Get historical data for analysis
        
        Args:
            symbol: Stock symbol
            duration: Data duration (e.g., '1 D', '1 W', '1 M', '1 Y')
            bar_size: Bar size (e.g., '1 min', '5 mins', '1 hour', '1 day')
            exchange: Exchange (default: 'SMART')
            currency: Currency (default: 'USD')
        """
        if not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return None
        
        cache_key = f"{symbol}_{duration}_{bar_size}"
        
        try:
            contract = self.create_contract(symbol, exchange, currency)
            
            bars = self.ib.reqHistoricalData(
                contract,
                endDateTime='',
                durationStr=duration,
                barSizeSetting=bar_size,
                whatToShow='TRADES',
                useRTH=True,
                formatDate=1
            )
            
            if bars:
                df = util.df(bars)
                df['timestamp'] = pd.to_datetime(df['date'])
                df['symbol'] = symbol
                
                # Cache the data
                self.data_cache[cache_key] = {
                    'data': df,
                    'retrieved_at': datetime.now()
                }
                
                self.logger.info(f"Retrieved {len(df)} historical bars for {symbol}")
                return df
            else:
                self.logger.warning(f"No historical data for {symbol}")
                return None
                
        except Exception as e:
            self.logger.error(f"Error getting historical data for {symbol}: {e}")
            return None
    
    def get_intraday_data(self, symbol: str, days: int = 1) -> Optional[pd.DataFrame]:
        """
        Get intraday historical data (1-minute bars)
        
        Args:
            symbol: Stock symbol
            days: Number of days (max 30 for 1-min bars)
        """
        duration = f"{days} D"
        return self.get_historical_data(symbol, duration, '1 min')
    
    def get_daily_data(self, symbol: str, period: str = '1 M') -> Optional[pd.DataFrame]:
        """
        Get daily historical data
        
        Args:
            symbol: Stock symbol
            period: Time period (e.g., '1 M', '3 M', '6 M', '1 Y', '2 Y')
        """
        return self.get_historical_data(symbol, period, '1 day')
    
    def get_weekly_data(self, symbol: str, period: str = '1 Y') -> Optional[pd.DataFrame]:
        """
        Get weekly historical data
        
        Args:
            symbol: Stock symbol
            period: Time period (e.g., '1 Y', '2 Y', '5 Y')
        """
        return self.get_historical_data(symbol, period, '1 W')
    
    def get_monthly_data(self, symbol: str, period: str = '5 Y') -> Optional[pd.DataFrame]:
        """
        Get monthly historical data
        
        Args:
            symbol: Stock symbol
            period: Time period (e.g., '5 Y', '10 Y')
        """
        return self.get_historical_data(symbol, period, '1 M')
    
    def get_multiple_symbols(self, symbols: List[str], duration: str = '1 D',
                            bar_size: str = '1 min') -> Dict[str, pd.DataFrame]:
        """
        Get historical data for multiple symbols
        
        Args:
            symbols: List of stock symbols
            duration: Data duration
            bar_size: Bar size
        """
        results = {}
        
        for symbol in symbols:
            self.logger.info(f"Fetching data for {symbol}")
            data = self.get_historical_data(symbol, duration, bar_size)
            
            if data is not None:
                results[symbol] = data
            
            # Small delay to avoid rate limiting
            time.sleep(0.1)
        
        self.logger.info(f"Retrieved data for {len(results)} out of {len(symbols)} symbols")
        return results
    
    def get_cached_data(self, symbol: str, duration: str = '1 D',
                       bar_size: str = '1 min', max_age_minutes: int = 5) -> Optional[pd.DataFrame]:
        """
        Get cached historical data if available and not expired
        
        Args:
            symbol: Stock symbol
            duration: Data duration
            bar_size: Bar size
            max_age_minutes: Maximum age of cached data in minutes
        """
        cache_key = f"{symbol}_{duration}_{bar_size}"
        
        if cache_key in self.data_cache:
            cached_item = self.data_cache[cache_key]
            age_minutes = (datetime.now() - cached_item['retrieved_at']).total_seconds() / 60
            
            if age_minutes <= max_age_minutes:
                self.logger.info(f"Using cached data for {symbol} (age: {age_minutes:.1f}min)")
                return cached_item['data']
        
        # Cache miss or expired, fetch fresh data
        return self.get_historical_data(symbol, duration, bar_size)
    
    def clear_cache(self):
        """Clear the data cache"""
        self.data_cache.clear()
        self.logger.info("Data cache cleared")
    
    def get_price_at_time(self, symbol: str, target_time: datetime,
                         duration: str = '1 D') -> Optional[float]:
        """
        Get price at a specific time using historical data
        
        Args:
            symbol: Stock symbol
            target_time: Target datetime
            duration: Data duration to search in
        """
        df = self.get_historical_data(symbol, duration, '1 min')
        
        if df is None or df.empty:
            return None
        
        # Find closest time
        df['time_diff'] = abs(df['timestamp'] - target_time)
        closest_row = df.loc[df['time_diff'].idxmin()]
        
        return float(closest_row['close'])

print("✓ Historical Data Handler class created")
# Out:
# ✓ Historical Data Handler class created

# %% [markdown]
# ### Market Data Handler

# %%
class MarketDataHandler:
    """Handle real-time market data from Interactive Brokers"""
    
    def __init__(self, ib_connection: IBConnection):
        """
        Initialise market data handler
        
        Args:
            ib_connection: IBConnection instance
        """
        self.ib_conn = ib_connection
        self.ib = ib_connection.ib
        self.logger = logging.getLogger('MarketDataHandler')
        self.subscribed_tickers = {}
        self.last_prices = {}
        
    def create_contract(self, symbol: str, exchange: str = 'SMART', 
                       currency: str = 'USD') -> Stock:
        """
        Create stock contract for IB
        
        Args:
            symbol: Stock symbol (e.g., 'MRK')
            exchange: Exchange (default: 'SMART')
            currency: Currency (default: 'USD')
        """
        return Stock(symbol, exchange, currency)
    
    def get_market_data(self, symbol: str, exchange: str = 'SMART',
                       currency: str = 'USD') -> Optional[Dict]:
        """
        Get real-time market data for a symbol
        
        Args:
            symbol: Stock symbol
            exchange: Exchange
            currency: Currency
        """
        if not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return None
        
        try:
            contract = self.create_contract(symbol, exchange, currency)
            
            # Request market data
            ticker = self.ib.reqMktData(contract, '', False, False)
            self.ib.sleep(2)  # Allow time for data to arrive
            
            # Get ticker data
            if ticker and ticker.last and ticker.last > 0:
                market_data = {
                    'symbol': symbol,
                    'last': float(ticker.last),
                    'bid': float(ticker.bid) if ticker.bid and ticker.bid > 0 else None,
                    'ask': float(ticker.ask) if ticker.ask and ticker.ask > 0 else None,
                    'volume': int(ticker.volume) if ticker.volume else 0,
                    'high': float(ticker.high) if ticker.high else None,
                    'low': float(ticker.low) if ticker.low else None,
                    'close': float(ticker.close) if ticker.close else None,
                    'timestamp': datetime.now()
                }
                
                # Store last known price
                self.last_prices[symbol] = market_data['last']
                
                self.logger.info(f"Market data for {symbol}: £{market_data['last']:.2f}")
                return market_data
            else:
                self.logger.warning(f"No valid market data for {symbol}")
                return None
                
        except Exception as e:
            self.logger.error(f"Error getting market data for {symbol}: {e}")
            return None
        finally:
            # Cancel market data request to free up lines
            try:
                self.ib.cancelMktData(contract)
            except:
                pass
    
    def subscribe_to_ticker(self, symbol: str, exchange: str = 'SMART',
                           currency: str = 'USD') -> bool:
        """
        Subscribe to real-time ticker updates
        
        Args:
            symbol: Stock symbol
            exchange: Exchange
            currency: Currency
        """
        if not self.ib_conn.is_connected():
            return False
        
        try:
            contract = self.create_contract(symbol, exchange, currency)
            ticker = self.ib.reqMktData(contract, '', False, False)
            self.subscribed_tickers[symbol] = {
                'ticker': ticker,
                'contract': contract
            }
            self.logger.info(f"Subscribed to {symbol}")
            return True
        except Exception as e:
            self.logger.error(f"Error subscribing to {symbol}: {e}")
            return False
    
    def unsubscribe_from_ticker(self, symbol: str) -> bool:
        """
        Unsubscribe from ticker updates
        
        Args:
            symbol: Stock symbol
        """
        if symbol in self.subscribed_tickers:
            try:
                contract = self.subscribed_tickers[symbol]['contract']
                self.ib.cancelMktData(contract)
                del self.subscribed_tickers[symbol]
                self.logger.info(f"Unsubscribed from {symbol}")
                return True
            except Exception as e:
                self.logger.error(f"Error unsubscribing from {symbol}: {e}")
                return False
        return False
    
    def get_subscribed_data(self, symbol: str) -> Optional[Dict]:
        """
        Get current data for a subscribed ticker
        
        Args:
            symbol: Stock symbol
        """
        if symbol not in self.subscribed_tickers:
            self.logger.warning(f"Not subscribed to {symbol}")
            return None
        
        try:
            ticker = self.subscribed_tickers[symbol]['ticker']
            
            if ticker and ticker.last and ticker.last > 0:
                market_data = {
                    'symbol': symbol,
                    'last': float(ticker.last),
                    'bid': float(ticker.bid) if ticker.bid and ticker.bid > 0 else None,
                    'ask': float(ticker.ask) if ticker.ask and ticker.ask > 0 else None,
                    'volume': int(ticker.volume) if ticker.volume else 0,
                    'high': float(ticker.high) if ticker.high else None,
                    'low': float(ticker.low) if ticker.low else None,
                    'close': float(ticker.close) if ticker.close else None,
                    'timestamp': datetime.now()
                }
                
                # Store last known price
                self.last_prices[symbol] = market_data['last']
                
                return market_data
            else:
                return None
                
        except Exception as e:
            self.logger.error(f"Error getting subscribed data for {symbol}: {e}")
            return None
    
    def get_multiple_market_data(self, symbols: List[str]) -> Dict[str, Dict]:
        """
        Get market data for multiple symbols
        
        Args:
            symbols: List of stock symbols
        """
        results = {}
        
        for symbol in symbols:
            self.logger.info(f"Fetching market data for {symbol}")
            data = self.get_market_data(symbol)
            
            if data is not None:
                results[symbol] = data
            
            # Small delay to avoid overwhelming the API
            time.sleep(0.2)
        
        self.logger.info(f"Retrieved market data for {len(results)} out of {len(symbols)} symbols")
        return results
    
    def get_market_snapshot(self, symbol: str, exchange: str = 'SMART',
                           currency: str = 'USD') -> Optional[Dict]:
        """
        Get a quick market snapshot (single request)
        
        Args:
            symbol: Stock symbol
            exchange: Exchange
            currency: Currency
        """
        if not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return None
        
        try:
            contract = self.create_contract(symbol, exchange, currency)
            
            # Request snapshot data
            ticker = self.ib.reqMktData(contract, '', True, False)  # Snapshot = True
            self.ib.sleep(1)  # Shorter wait for snapshot
            
            if ticker and ticker.last and ticker.last > 0:
                snapshot_data = {
                    'symbol': symbol,
                    'last': float(ticker.last),
                    'bid': float(ticker.bid) if ticker.bid and ticker.bid > 0 else None,
                    'ask': float(ticker.ask) if ticker.ask and ticker.ask > 0 else None,
                    'timestamp': datetime.now()
                }
                
                self.logger.info(f"Snapshot for {symbol}: £{snapshot_data['last']:.2f}")
                return snapshot_data
            else:
                self.logger.warning(f"No snapshot data for {symbol}")
                return None
                
        except Exception as e:
            self.logger.error(f"Error getting snapshot for {symbol}: {e}")
            return None
        finally:
            # Cancel snapshot request
            try:
                self.ib.cancelMktData(contract)
            except:
                pass
    
    def cleanup_subscriptions(self):
        """Cancel all active subscriptions"""
        for symbol in list(self.subscribed_tickers.keys()):
            self.unsubscribe_from_ticker(symbol)
        self.logger.info("All market data subscriptions cancelled")
    
    def get_last_known_price(self, symbol: str) -> Optional[float]:
        """
        Get last known price for a symbol
        
        Args:
            symbol: Stock symbol
        """
        return self.last_prices.get(symbol)
    
    def is_market_open(self) -> bool:
        """
        Check if market is currently open (basic US market hours)
        """
        now = datetime.now()
        # Basic US market hours check (9:30 AM - 4:00 PM ET)
        market_open = now.replace(hour=9, minute=30, second=0, microsecond=0)
        market_close = now.replace(hour=16, minute=0, second=0, microsecond=0)
        
        # Check if it's a weekday and within market hours
        is_weekday = now.weekday() < 5  # Monday = 0, Friday = 4
        is_market_hours = market_open <= now <= market_close
        
        return is_weekday and is_market_hours

print("✓ Market Data Handler class created")
# Out:
# ✓ Market Data Handler class created

# %% [markdown]
# ### Order Management

# %%
class OrderManager:
    """Handle order placement and management"""
    
    def __init__(self, ib_connection: IBConnection):
        """
        Initialise order manager
        
        Args:
            ib_connection: IBConnection instance
        """
        self.ib_conn = ib_connection
        self.ib = ib_connection.ib
        self.logger = logging.getLogger('OrderManager')
        self.orders_log = []
    
    def place_market_order(self, symbol: str, action: str, quantity: int,
                          exchange: str = 'SMART', currency: str = 'USD') -> bool:
        """
        Place a market order
        
        Args:
            symbol: Stock symbol
            action: 'BUY' or 'SELL'
            quantity: Number of shares
            exchange: Exchange
            currency: Currency
        """
        if not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return False
        
        try:
            contract = Stock(symbol, exchange, currency)
            order = MarketOrder(action, quantity)
            
            # Place the order
            trade = self.ib.placeOrder(contract, order)
            
            if trade:
                order_info = {
                    'symbol': symbol,
                    'action': action,
                    'quantity': quantity,
                    'order_type': 'MARKET',
                    'status': trade.orderStatus.status,
                    'timestamp': datetime.now(),
                    'order_id': trade.order.orderId
                }
                
                self.orders_log.append(order_info)
                
                self.logger.info(f"✓ Market order placed: {action} {quantity} {symbol}")
                return True
            else:
                self.logger.error(f"Failed to place market order for {symbol}")
                return False
                
        except Exception as e:
            self.logger.error(f"Error placing market order for {symbol}: {e}")
            return False
    
    def place_limit_order(self, symbol: str, action: str, quantity: int,
                         limit_price: float, exchange: str = 'SMART',
                         currency: str = 'USD') -> bool:
        """
        Place a limit order
        
        Args:
            symbol: Stock symbol
            action: 'BUY' or 'SELL'
            quantity: Number of shares
            limit_price: Limit price
            exchange: Exchange
            currency: Currency
        """
        if not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return False
        
        try:
            contract = Stock(symbol, exchange, currency)
            order = LimitOrder(action, quantity, limit_price)
            
            # Place the order
            trade = self.ib.placeOrder(contract, order)
            
            if trade:
                order_info = {
                    'symbol': symbol,
                    'action': action,
                    'quantity': quantity,
                    'order_type': 'LIMIT',
                    'limit_price': limit_price,
                    'status': trade.orderStatus.status,
                    'timestamp': datetime.now(),
                    'order_id': trade.order.orderId
                }
                
                self.orders_log.append(order_info)
                
                self.logger.info(f"✓ Limit order placed: {action} {quantity} {symbol} @ £{limit_price:.2f}")
                return True
            else:
                self.logger.error(f"Failed to place limit order for {symbol}")
                return False
                
        except Exception as e:
            self.logger.error(f"Error placing limit order for {symbol}: {e}")
            return False
    
    def get_open_orders(self) -> List[Dict]:
        """Get list of open orders"""
        if not self.ib_conn.is_connected():
            return []
        
        try:
            trades = self.ib.openTrades()
            open_orders = []
            
            for trade in trades:
                order_info = {
                    'symbol': trade.contract.symbol,
                    'action': trade.order.action,
                    'quantity': trade.order.totalQuantity,
                    'order_type': trade.order.orderType,
                    'status': trade.orderStatus.status,
                    'order_id': trade.order.orderId,
                    'filled': trade.orderStatus.filled,
                    'remaining': trade.orderStatus.remaining
                }
                
                if hasattr(trade.order, 'lmtPrice') and trade.order.lmtPrice:
                    order_info['limit_price'] = trade.order.lmtPrice
                
                open_orders.append(order_info)
            
            return open_orders
            
        except Exception as e:
            self.logger.error(f"Error getting open orders: {e}")
            return []
    
    def cancel_order(self, order_id: int) -> bool:
        """Cancel an order by ID"""
        if not self.ib_conn.is_connected():
            return False
        
        try:
            self.ib.cancelOrder(order_id)
            self.logger.info(f"Order {order_id} cancellation requested")
            return True
        except Exception as e:
            self.logger.error(f"Error cancelling order {order_id}: {e}")
            return False
    
    def get_orders_log(self) -> List[Dict]:
        """Get log of all placed orders"""
        return self.orders_log

print("✓ Order Manager class created")
# Out:
# ✓ Order Manager class created

# %% [markdown]
# ### Trading Strategy

# %%
class TradingStrategy:
    """Advanced trading strategy using both historical and real-time market data"""
    
    def __init__(self, name: str, short_window: int = 10, long_window: int = 30,
                 historical_data_handler: HistoricalDataHandler = None,
                 market_data_handler: MarketDataHandler = None):
        """
        Initialise trading strategy
        
        Args:
            name: Strategy name
            short_window: Short moving average period
            long_window: Long moving average period
            historical_data_handler: Historical data handler instance
            market_data_handler: Market data handler instance
        """
        self.name = name
        self.short_window = short_window
        self.long_window = long_window
        self.logger = logging.getLogger(f'Strategy-{name}')
        self.historical_data = historical_data_handler
        self.market_data = market_data_handler
        
        # Strategy state
        self.positions = {}
        self.technical_indicators = {}
        self.price_history = {}
        self.signal_history = {}
        
        # Performance tracking
        self.performance_metrics = {
            'total_trades': 0,
            'profitable_trades': 0,
            'total_pnl': 0.0,
            'win_rate': 0.0,
            'max_drawdown': 0.0,
            'sharpe_ratio': 0.0
        }
        
        # Risk management parameters
        self.max_position_size = 0.20  # Maximum 20% of capital per position
        self.stop_loss_pct = 0.05      # 5% stop loss
        self.take_profit_pct = 0.15    # 15% take profit
        
    def calculate_technical_indicators(self, symbol: str, df: pd.DataFrame) -> Dict:
        """
        Calculate comprehensive technical indicators from historical data
        
        Args:
            symbol: Stock symbol
            df: Historical price DataFrame
        """
        if df is None or df.empty:
            return {}
        
        indicators = {}
        
        try:
            # Moving averages
            if len(df) >= 5:
                indicators['sma_5'] = df['close'].rolling(window=5).mean().iloc[-1]
            if len(df) >= 10:
                indicators['sma_10'] = df['close'].rolling(window=10).mean().iloc[-1]
            if len(df) >= 20:
                indicators['sma_20'] = df['close'].rolling(window=20).mean().iloc[-1]
            if len(df) >= 50:
                indicators['sma_50'] = df['close'].rolling(window=50).mean().iloc[-1]
            
            # Exponential moving averages
            if len(df) >= 12:
                indicators['ema_12'] = df['close'].ewm(span=12).mean().iloc[-1]
            if len(df) >= 26:
                indicators['ema_26'] = df['close'].ewm(span=26).mean().iloc[-1]
                
            # MACD calculation
            if 'ema_12' in indicators and 'ema_26' in indicators:
                macd_line = indicators['ema_12'] - indicators['ema_26']
                indicators['macd'] = macd_line
                
                # MACD signal line (9-period EMA of MACD)
                if len(df) >= 26:
                    macd_series = df['close'].ewm(span=12).mean() - df['close'].ewm(span=26).mean()
                    indicators['macd_signal'] = macd_series.ewm(span=9).mean().iloc[-1]
                    indicators['macd_histogram'] = macd_line - indicators['macd_signal']
            
            # RSI calculation
            if len(df) >= 14:
                delta = df['close'].diff()
                gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
                loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
                rs = gain / loss
                indicators['rsi'] = 100 - (100 / (1 + rs.iloc[-1]))
            
            # Bollinger Bands
            if len(df) >= 20:
                sma_20 = df['close'].rolling(window=20).mean()
                std_20 = df['close'].rolling(window=20).std()
                indicators['bb_upper'] = (sma_20 + (std_20 * 2)).iloc[-1]
                indicators['bb_lower'] = (sma_20 - (std_20 * 2)).iloc[-1]
                indicators['bb_middle'] = sma_20.iloc[-1]
                indicators['bb_width'] = ((indicators['bb_upper'] - indicators['bb_lower']) / indicators['bb_middle']) * 100
            
            # Volume indicators
            if len(df) >= 10:
                indicators['volume_sma'] = df['volume'].rolling(window=10).mean().iloc[-1]
                indicators['volume_ratio'] = df['volume'].iloc[-1] / indicators['volume_sma']
            
            # Volatility measures
            if len(df) >= 20:
                returns = df['close'].pct_change()
                indicators['volatility'] = returns.rolling(window=20).std().iloc[-1] * 100
                indicators['atr'] = self.calculate_atr(df, 14)
            
            # Price momentum indicators
            if len(df) >= 5:
                indicators['momentum_5'] = ((df['close'].iloc[-1] - df['close'].iloc[-5]) / df['close'].iloc[-5]) * 100
            if len(df) >= 10:
                indicators['momentum_10'] = ((df['close'].iloc[-1] - df['close'].iloc[-10]) / df['close'].iloc[-10]) * 100
            
            # Support and resistance levels
            if len(df) >= 20:
                recent_highs = df['high'].rolling(window=20).max()
                recent_lows = df['low'].rolling(window=20).min()
                indicators['resistance'] = recent_highs.iloc[-1]
                indicators['support'] = recent_lows.iloc[-1]
            
            # Market strength indicators
            if len(df) >= 14:
                # Williams %R
                highest_high = df['high'].rolling(window=14).max().iloc[-1]
                lowest_low = df['low'].rolling(window=14).min().iloc[-1]
                current_close = df['close'].iloc[-1]
                indicators['williams_r'] = ((highest_high - current_close) / (highest_high - lowest_low)) * -100
            
            self.technical_indicators[symbol] = indicators
            
        except Exception as e:
            self.logger.error(f"Error calculating indicators for {symbol}: {e}")
        
        return indicators
    
    def calculate_atr(self, df: pd.DataFrame, period: int = 14) -> float:
        """
        Calculate Average True Range
        
        Args:
            df: Historical price DataFrame
            period: ATR period
        """
        try:
            high_low = df['high'] - df['low']
            high_close = abs(df['high'] - df['close'].shift())
            low_close = abs(df['low'] - df['close'].shift())
            
            true_range = pd.concat([high_low, high_close, low_close], axis=1).max(axis=1)
            atr = true_range.rolling(window=period).mean().iloc[-1]
            
            return atr
        except:
            return 0.0
    
    def get_enhanced_market_analysis(self, symbol: str) -> Optional[Dict]:
        """
        Get comprehensive market analysis combining historical and real-time data
        
        Args:
            symbol: Stock symbol
        """
        analysis = {}
        
        try:
            # Get historical data for technical analysis
            if self.historical_data:
                df = self.historical_data.get_intraday_data(symbol, days=3)
                if df is not None and not df.empty:
                    analysis['historical_data'] = df
                    analysis['technical_indicators'] = self.calculate_technical_indicators(symbol, df)
                    
                    # Get daily data for longer-term trends
                    daily_df = self.historical_data.get_daily_data(symbol, period='1 M')
                    if daily_df is not None and not daily_df.empty:
                        analysis['daily_trend'] = self.calculate_trend_strength(daily_df)
            
            # Get real-time market data for current conditions
            if self.market_data:
                real_time_data = self.market_data.get_market_data(symbol)
                if real_time_data:
                    analysis.update(real_time_data)
                    
                    # Check market conditions
                    analysis['market_open'] = self.market_data.is_market_open()
            
            # Fallback to historical data if real-time unavailable
            if 'last' not in analysis and 'historical_data' in analysis:
                df = analysis['historical_data']
                if not df.empty:
                    analysis['last'] = float(df.iloc[-1]['close'])
                    analysis['volume'] = int(df.iloc[-1]['volume'])
                    analysis['symbol'] = symbol
                    analysis['timestamp'] = datetime.now()
            
            return analysis if analysis else None
            
        except Exception as e:
            self.logger.error(f"Error getting enhanced analysis for {symbol}: {e}")
            return None
    
    def calculate_trend_strength(self, df: pd.DataFrame) -> Dict:
        """
        Calculate trend strength from daily data
        
        Args:
            df: Daily price DataFrame
        """
        trend_data = {}
        
        try:
            if len(df) >= 20:
                sma_20 = df['close'].rolling(window=20).mean()
                current_price = df['close'].iloc[-1]
                sma_current = sma_20.iloc[-1]
                
                # Trend direction
                trend_data['direction'] = 'bullish' if current_price > sma_current else 'bearish'
                
                # Trend strength (how far from SMA)
                trend_data['strength'] = abs((current_price - sma_current) / sma_current) * 100
                
                # Price momentum over 5, 10, 20 days
                if len(df) >= 5:
                    trend_data['momentum_5d'] = ((df['close'].iloc[-1] - df['close'].iloc[-5]) / df['close'].iloc[-5]) * 100
                if len(df) >= 10:
                    trend_data['momentum_10d'] = ((df['close'].iloc[-1] - df['close'].iloc[-10]) / df['close'].iloc[-10]) * 100
                if len(df) >= 20:
                    trend_data['momentum_20d'] = ((df['close'].iloc[-1] - df['close'].iloc[-20]) / df['close'].iloc[-20]) * 100
                    
        except Exception as e:
            self.logger.error(f"Error calculating trend strength: {e}")
        
        return trend_data
    
    def update_price_history(self, symbol: str, price: float):
        """Update price history for real-time calculations"""
        if symbol not in self.price_history:
            self.price_history[symbol] = []
        
        self.price_history[symbol].append(price)
        
        # Keep only required history
        max_length = max(self.short_window, self.long_window) + 20
        if len(self.price_history[symbol]) > max_length:
            self.price_history[symbol] = self.price_history[symbol][-max_length:]
    
    def calculate_sma(self, symbol: str, window: int) -> Optional[float]:
        """Calculate simple moving average from price history"""
        if symbol not in self.price_history:
            return None
        
        prices = self.price_history[symbol]
        if len(prices) < window:
            return None
        
        return sum(prices[-window:]) / window
    
    def evaluate_buy_signals(self, symbol: str, market_data: Dict, indicators: Dict) -> List[bool]:
        """
        Evaluate multiple buy signals
        
        Args:
            symbol: Stock symbol
            market_data: Market data dictionary
            indicators: Technical indicators
        """
        signals = []
        price = market_data['last']
        
        # Signal 1: SMA crossover (traditional)
        if 'sma_10' in indicators and 'sma_20' in indicators:
            signals.append(indicators['sma_10'] > indicators['sma_20'])
        
        # Signal 2: RSI oversold
        if 'rsi' in indicators:
            signals.append(20 < indicators['rsi'] < 35)  # Slightly oversold but not extreme
        
        # Signal 3: Price above Bollinger Band lower
        if 'bb_lower' in indicators and 'bb_middle' in indicators:
            signals.append(price > indicators['bb_lower'] and price < indicators['bb_middle'])
        
        # Signal 4: MACD bullish
        if 'macd' in indicators and 'macd_signal' in indicators:
            signals.append(indicators['macd'] > indicators['macd_signal'])
        
        # Signal 5: Volume confirmation
        if 'volume_ratio' in indicators:
            signals.append(indicators['volume_ratio'] > 1.3)  # 30% above average
        
        # Signal 6: Positive momentum
        if 'momentum_5' in indicators:
            signals.append(indicators['momentum_5'] > 0.5)
        
        # Signal 7: Williams %R oversold
        if 'williams_r' in indicators:
            signals.append(-80 < indicators['williams_r'] < -50)
        
        return signals
    
    def evaluate_sell_signals(self, symbol: str, market_data: Dict, indicators: Dict) -> List[bool]:
        """
        Evaluate multiple sell signals
        
        Args:
            symbol: Stock symbol
            market_data: Market data dictionary
            indicators: Technical indicators
        """
        signals = []
        price = market_data['last']
        
        # Signal 1: SMA crossover (traditional)
        if 'sma_10' in indicators and 'sma_20' in indicators:
            signals.append(indicators['sma_10'] < indicators['sma_20'])
        
        # Signal 2: RSI overbought
        if 'rsi' in indicators:
            signals.append(indicators['rsi'] > 70)
        
        # Signal 3: Price near Bollinger Band upper
        if 'bb_upper' in indicators:
            signals.append(price > indicators['bb_upper'] * 0.98)
        
        # Signal 4: MACD bearish
        if 'macd' in indicators and 'macd_signal' in indicators:
            signals.append(indicators['macd'] < indicators['macd_signal'])
        
        # Signal 5: Negative momentum
        if 'momentum_5' in indicators:
            signals.append(indicators['momentum_5'] < -1.0)
        
        # Signal 6: Williams %R overbought
        if 'williams_r' in indicators:
            signals.append(indicators['williams_r'] > -20)
        
        # Signal 7: High volatility (risk management)
        if 'volatility' in indicators:
            signals.append(indicators['volatility'] > 5.0)  # High volatility warning
        
        return signals
    
    def check_risk_management(self, symbol: str, market_data: Dict) -> Dict:
        """
        Check risk management conditions
        
        Args:
            symbol: Stock symbol
            market_data: Market data dictionary
        """
        risk_check = {'stop_loss': False, 'take_profit': False, 'risk_level': 'normal'}
        
        position = self.get_position(symbol)
        if position['shares'] > 0:
            current_price = market_data['last']
            entry_price = position['avg_price']
            
            # Calculate P&L percentage
            pnl_pct = ((current_price - entry_price) / entry_price) * 100
            
            # Stop loss check
            if pnl_pct <= -self.stop_loss_pct * 100:
                risk_check['stop_loss'] = True
                risk_check['risk_level'] = 'high'
            
            # Take profit check
            if pnl_pct >= self.take_profit_pct * 100:
                risk_check['take_profit'] = True
            
            # Track current P&L
            risk_check['current_pnl_pct'] = pnl_pct
            
        return risk_check
    
    def should_buy(self, market_data: Dict) -> bool:
        """Enhanced buy logic using comprehensive analysis"""
        symbol = market_data['symbol']
        price = market_data['last']
        
        # Check if we already have a position
        position = self.get_position(symbol)
        if position['shares'] > 0:
            return False
        
        self.update_price_history(symbol, price)
        
        # Get enhanced analysis
        enhanced_analysis = self.get_enhanced_market_analysis(symbol)
        
        if enhanced_analysis and 'technical_indicators' in enhanced_analysis:
            indicators = enhanced_analysis['technical_indicators']
            
            # Evaluate buy signals
            buy_signals = self.evaluate_buy_signals(symbol, market_data, indicators)
            signal_count = sum(buy_signals)
            
            # Check daily trend if available
            trend_confirmation = True
            if 'daily_trend' in enhanced_analysis:
                trend = enhanced_analysis['daily_trend']
                if 'direction' in trend:
                    trend_confirmation = trend['direction'] == 'bullish'
            
            # Store signal history for analysis
            if symbol not in self.signal_history:
                self.signal_history[symbol] = []
            
            self.signal_history[symbol].append({
                'timestamp': datetime.now(),
                'signal_count': signal_count,
                'signals': buy_signals,
                'action': 'buy_evaluation',
                'price': price
            })
            
            # Buy decision: need majority of signals + trend confirmation
            required_signals = max(2, len(buy_signals) // 2)
            decision = signal_count >= required_signals and trend_confirmation
            
            if decision:
                self.logger.info(f"BUY signal for {symbol}: {signal_count}/{len(buy_signals)} signals")
            
            return decision
        
        else:
            # Fallback to simple SMA logic
            short_sma = self.calculate_sma(symbol, self.short_window)
            long_sma = self.calculate_sma(symbol, self.long_window)
            
            if short_sma and long_sma:
                return short_sma > long_sma
        
        return False
    
    def should_sell(self, symbol: str, market_data: Dict) -> bool:
        """Enhanced sell logic using comprehensive analysis and risk management"""
        price = market_data['last']
        
        # Check if we have a position to sell
        position = self.get_position(symbol)
        if position['shares'] <= 0:
            return False
        
        self.update_price_history(symbol, price)
        
        # Risk management check first
        risk_check = self.check_risk_management(symbol, market_data)
        if risk_check['stop_loss'] or risk_check['take_profit']:
            action = 'STOP_LOSS' if risk_check['stop_loss'] else 'TAKE_PROFIT'
            self.logger.info(f"{action} triggered for {symbol} at {risk_check['current_pnl_pct']:+.2f}%")
            return True
        
        # Get enhanced analysis
        enhanced_analysis = self.get_enhanced_market_analysis(symbol)
        
        if enhanced_analysis and 'technical_indicators' in enhanced_analysis:
            indicators = enhanced_analysis['technical_indicators']
            
            # Evaluate sell signals
            sell_signals = self.evaluate_sell_signals(symbol, market_data, indicators)
            signal_count = sum(sell_signals)
            
            # Store signal history
            if symbol not in self.signal_history:
                self.signal_history[symbol] = []
            
            self.signal_history[symbol].append({
                'timestamp': datetime.now(),
                'signal_count': signal_count,
                'signals': sell_signals,
                'action': 'sell_evaluation',
                'price': price
            })
            
            # Sell decision: need majority of signals
            required_signals = max(2, len(sell_signals) // 2)
            decision = signal_count >= required_signals
            
            if decision:
                self.logger.info(f"SELL signal for {symbol}: {signal_count}/{len(sell_signals)} signals")
            
            return decision
        
        else:
            # Fallback to simple SMA logic
            short_sma = self.calculate_sma(symbol, self.short_window)
            long_sma = self.calculate_sma(symbol, self.long_window)
            
            if short_sma and long_sma:
                return short_sma < long_sma
        
        return False
    
    def calculate_position_size(self, symbol: str, price: float, 
                              available_capital: float) -> int:
        """
        Calculate position size with risk management
        
        Args:
            symbol: Stock symbol
            price: Current price
            available_capital: Available capital
        """
        # Base position size (10% of capital)
        base_target_value = available_capital * 0.10
        
        # Adjust based on volatility if available
        if symbol in self.technical_indicators:
            indicators = self.technical_indicators[symbol]
            
            # Reduce position size for high volatility stocks
            if 'volatility' in indicators:
                volatility = indicators['volatility']
                if volatility > 3.0:  # High volatility
                    base_target_value *= 0.7  # Reduce by 30%
                elif volatility < 1.0:  # Low volatility
                    base_target_value *= 1.2  # Increase by 20%
            
            # Adjust based on trend strength
            if 'daily_trend' in indicators and 'strength' in indicators['daily_trend']:
                strength = indicators['daily_trend']['strength']
                if strength > 5.0:  # Strong trend
                    base_target_value *= 1.1  # Slight increase
        
        # Apply maximum position size limit
        max_target_value = available_capital * self.max_position_size
        target_value = min(base_target_value, max_target_value)
        
        shares = int(target_value / price)
        return max(1, shares)  # At least 1 share
    
    def update_position(self, symbol: str, action: str, quantity: int, price: float):
        """Update position tracking with P&L calculation"""
        if symbol not in self.positions:
            self.positions[symbol] = {'shares': 0, 'avg_price': 0.0, 'total_pnl': 0.0}
        
        position = self.positions[symbol]
        
        if action == 'BUY':
            total_cost = (position['shares'] * position['avg_price']) + (quantity * price)
            position['shares'] += quantity
            position['avg_price'] = total_cost / position['shares'] if position['shares'] > 0 else 0
            
        elif action == 'SELL':
            # Calculate P&L for this trade
            if position['shares'] > 0:
                trade_pnl = (price - position['avg_price']) * quantity
                position['total_pnl'] += trade_pnl
                
                # Update performance metrics
                self.performance_metrics['total_trades'] += 1
                if trade_pnl > 0:
                    self.performance_metrics['profitable_trades'] += 1
                
                self.performance_metrics['total_pnl'] += trade_pnl
                self.performance_metrics['win_rate'] = (
                    self.performance_metrics['profitable_trades'] / 
                    self.performance_metrics['total_trades']
                ) * 100
            
            position['shares'] -= quantity
            if position['shares'] <= 0:
                position['shares'] = 0
                position['avg_price'] = 0.0
    
    def get_position(self, symbol: str) -> Dict:
        """Get current position for symbol"""
        return self.positions.get(symbol, {'shares': 0, 'avg_price': 0.0, 'total_pnl': 0.0})
    
    def get_performance_summary(self) -> Dict:
        """Get comprehensive strategy performance summary"""
        summary = self.performance_metrics.copy()
        
        # Add current positions value
        total_position_value = 0.0
        for symbol, position in self.positions.items():
            if position['shares'] > 0:
                # Use last known price or get current price
                current_price = 0.0
                if self.market_data:
                    current_data = self.market_data.get_last_known_price(symbol)
                    if current_data:
                        current_price = current_data
                
                if current_price > 0:
                    position_value = position['shares'] * current_price
                    unrealized_pnl = (current_price - position['avg_price']) * position['shares']
                    total_position_value += position_value
                    
                    summary[f'{symbol}_position_value'] = position_value
                    summary[f'{symbol}_unrealized_pnl'] = unrealized_pnl
        
        summary['total_position_value'] = total_position_value
        
        return summary
    
    def set_data_handlers(self, historical_data_handler: HistoricalDataHandler = None,
                         market_data_handler: MarketDataHandler = None):
        """
        Set data handlers for enhanced analysis
        
        Args:
            historical_data_handler: Historical data handler instance
            market_data_handler: Market data handler instance
        """
        self.historical_data = historical_data_handler
        self.market_data = market_data_handler
        self.logger.info("Data handlers configured for enhanced analysis")
    
    def get_strategy_status(self, symbol: str) -> Dict:
        """
        Get comprehensive strategy status for a symbol
        
        Args:
            symbol: Stock symbol
        """
        status = {
            'symbol': symbol,
            'position': self.get_position(symbol),
            'technical_indicators': self.technical_indicators.get(symbol, {}),
            'price_history_length': len(self.price_history.get(symbol, [])),
            'recent_signals': self.signal_history.get(symbol, [])[-5:] if symbol in self.signal_history else []
        }
        
        return status
    
    def get_market_overview(self, symbols: List[str]) -> Dict:
        """
        Get market overview for all tracked symbols
        
        Args:
            symbols: List of symbols to analyse
        """
        overview = {
            'total_positions': 0,
            'total_value': 0.0,
            'symbols_analysis': {}
        }
        
        for symbol in symbols:
            try:
                status = self.get_strategy_status(symbol)
                overview['symbols_analysis'][symbol] = status
                
                if status['position']['shares'] > 0:
                    overview['total_positions'] += 1
                    
            except Exception as e:
                self.logger.error(f"Error getting overview for {symbol}: {e}")
        
        return overview

print("✓ Trading Strategy with Historical and Market Data created")
# Out:
# ✓ Trading Strategy with Historical and Market Data created

# %% [markdown]
# ### Trading Bot

# %%
class IBTradingBot:
    """Main Interactive Brokers trading bot with strategy integration"""
    
    def __init__(self, environment: str = 'paper', strategy: TradingStrategy = None):
        """
        Initialise trading bot
        
        Args:
            environment: 'paper' or 'live'
            strategy: Trading strategy instance
        """
        self.environment = environment
        self.logger = logging.getLogger(f'TradingBot-{environment}')
        
        # Initialize components
        self.ib_conn = IBConnection(environment)
        self.historical_data = None
        self.market_data = None
        self.order_manager = None
        self.strategy = strategy or TradingStrategy("Default_SMA", 10, 30)
        
        # Bot configuration
        self.symbols = ['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG']  # Default symbols to trade
        self.is_running = False
        self.update_interval = 10  # seconds between updates
        
        # Performance tracking
        self.start_time = None
        self.trades_executed = 0
        
        self.logger.info(f"Trading bot initialised for {environment} trading")
        self.logger.info(f"Strategy: {self.strategy.name}")
    
    def add_symbol(self, symbol: str):
        """Add symbol to trading list"""
        if symbol not in self.symbols:
            self.symbols.append(symbol)
            self.logger.info(f"Added {symbol} to trading symbols")
    
    def remove_symbol(self, symbol: str):
        """Remove symbol from trading list"""
        if symbol in self.symbols:
            self.symbols.remove(symbol)
            self.logger.info(f"Removed {symbol} from trading symbols")
    
    def set_symbols(self, symbols: List[str]):
        """Set list of symbols to trade"""
        self.symbols = symbols
        self.logger.info(f"Updated trading symbols: {symbols}")
    
    def connect(self) -> bool:
        """Connect to Interactive Brokers and initialise all handlers"""
        success = self.ib_conn.connect_sync(timeout=15)
        
        if success:
            # Initialize data handlers
            self.historical_data = HistoricalDataHandler(self.ib_conn)
            self.market_data = MarketDataHandler(self.ib_conn)
            self.order_manager = OrderManager(self.ib_conn)
            
            # Configure strategy with data handlers for enhanced analysis
            self.strategy.set_data_handlers(self.historical_data, self.market_data)
            
            self.logger.info("Trading bot connected successfully")
            
            # Display account information
            account_info = self.ib_conn.get_account_summary()
            if account_info:
                buying_power = account_info.get('BuyingPower', 'N/A')
                net_liquidation = account_info.get('NetLiquidation', 'N/A')
                self.logger.info(f"Account Net Liquidation: £{net_liquidation}")
                self.logger.info(f"Buying Power: £{buying_power}")
            
            return True
        else:
            self.logger.error("Failed to connect to IB")
            return False
    
    def disconnect(self):
        """Disconnect from Interactive Brokers and cleanup"""
        self.is_running = False
        
        # Cleanup market data subscriptions
        if self.market_data:
            self.market_data.cleanup_subscriptions()
        
        # Disconnect from IB
        if self.ib_conn:
            self.ib_conn.disconnect()
            
        self.logger.info("Trading bot disconnected")
    
    def get_enhanced_market_analysis(self, symbol: str) -> Optional[Dict]:
        """
        Get enhanced market analysis using both historical and real-time data
        
        Args:
            symbol: Stock symbol to analyse
        """
        try:
            # Use strategy's enhanced analysis method
            analysis = self.strategy.get_enhanced_market_analysis(symbol)
            
            if analysis:
                self.logger.info(
                    f"Enhanced analysis for {symbol}: £{analysis['last']:.2f} "
                    f"({analysis.get('price_change_pct', 0):+.2f}%)"
                )
                return analysis
            else:
                # Fallback to basic historical analysis
                return self.get_market_analysis(symbol)
                
        except Exception as e:
            self.logger.error(f"Error getting enhanced analysis for {symbol}: {e}")
            return self.get_market_analysis(symbol)
    
    def get_market_analysis(self, symbol: str) -> Optional[Dict]:
        """
        Get basic market analysis data for trading decisions (fallback method)
        
        Args:
            symbol: Stock symbol to analyse
        """
        try:
            # Get recent historical data for analysis
            df = self.historical_data.get_intraday_data(symbol, days=2)
            
            if df is None or df.empty:
                self.logger.warning(f"No historical data available for {symbol}")
                return None
            
            # Calculate current metrics
            latest_price = float(df.iloc[-1]['close'])
            volume = int(df.iloc[-1]['volume'])
            
            # Calculate moving averages if enough data
            if len(df) >= 20:
                ma_20 = df['close'].rolling(window=20).mean().iloc[-1]
            else:
                ma_20 = latest_price
            
            if len(df) >= 50:
                ma_50 = df['close'].rolling(window=50).mean().iloc[-1]
            else:
                ma_50 = latest_price
            
            # Price change from previous close
            if len(df) >= 2:
                price_change = latest_price - float(df.iloc[-2]['close'])
                price_change_pct = (price_change / float(df.iloc[-2]['close'])) * 100
            else:
                price_change = 0
                price_change_pct = 0
            
            analysis_data = {
                'symbol': symbol,
                'last': latest_price,
                'volume': volume,
                'price_change': price_change,
                'price_change_pct': price_change_pct,
                'ma_20': float(ma_20),
                'ma_50': float(ma_50),
                'timestamp': datetime.now(),
                'historical_data': df
            }
            
            self.logger.info(f"Analysis for {symbol}: £{latest_price:.2f} ({price_change_pct:+.2f}%)")
            return analysis_data
            
        except Exception as e:
            self.logger.error(f"Error getting market analysis for {symbol}: {e}")
            return None
    
    def execute_trade_logic(self, symbol: str, market_data: Dict) -> bool:
        """Execute enhanced trading logic using the strategy's advanced features"""
        try:
            # Get account information for position sizing
            if self.environment == 'simulator':
                # Use simulated balance
                buying_power = getattr(self, 'simulated_balance', 10000.0)
            else:
                # Get real account information
                account_info = self.ib_conn.get_account_summary()
                buying_power = float(account_info.get('BuyingPower', '0')) if account_info else 0
            
            # Check for buy signal using enhanced strategy
            if self.strategy.should_buy(market_data):
                if buying_power > 0:
                    quantity = self.strategy.calculate_position_size(
                        symbol, market_data['last'], buying_power
                    )
                    
                    if quantity > 0:
                        success = self.order_manager.place_market_order(
                            symbol, 'BUY', quantity
                        )
                        
                        if success:
                            self.strategy.update_position(
                                symbol, 'BUY', quantity, market_data['last']
                            )
                            
                            # Update simulated balance if in simulator
                            if self.environment == 'simulator':
                                trade_cost = quantity * market_data['last']
                                self.simulated_balance -= trade_cost
                            
                            self.trades_executed += 1
                            self.logger.info(f"BUY executed: {quantity} shares of {symbol}")
                            return True
            
            # Check for sell signal using enhanced strategy
            elif self.strategy.should_sell(symbol, market_data):
                position = self.strategy.get_position(symbol)
                
                if position['shares'] > 0:
                    success = self.order_manager.place_market_order(
                        symbol, 'SELL', position['shares']
                    )
                    
                    if success:
                        self.strategy.update_position(
                            symbol, 'SELL', position['shares'], market_data['last']
                        )
                        
                        # Update simulated balance if in simulator
                        if self.environment == 'simulator':
                            trade_value = position['shares'] * market_data['last']
                            self.simulated_balance += trade_value
                        
                        self.trades_executed += 1
                        self.logger.info(f"SELL executed: {position['shares']} shares of {symbol}")
                        return True
            
            return False
            
        except Exception as e:
            self.logger.error(f"Error in trade logic for {symbol}: {e}")
            return False
    
    def run_single_cycle(self):
        """Run a single enhanced trading cycle"""
        # Check connection (handle both real and simulated bots)
        if self.ib_conn and not self.ib_conn.is_connected():
            self.logger.error("Not connected to IB")
            return False
        elif not self.ib_conn and self.environment != 'simulator':
            self.logger.error("No IB connection available")
            return False
        
        trades_this_cycle = 0
        
        for symbol in self.symbols:
            try:
                # Get enhanced market analysis
                market_data = self.get_enhanced_market_analysis(symbol)
                
                if market_data:
                    # Execute trading logic using enhanced strategy
                    if self.execute_trade_logic(symbol, market_data):
                        trades_this_cycle += 1
                        
                        # Log strategy status after trade
                        status = self.strategy.get_strategy_status(symbol)
                        if status['technical_indicators']:
                            indicators = status['technical_indicators']
                            self.logger.info(
                                f"{symbol} indicators - RSI: {indicators.get('rsi', 'N/A'):.1f}, "
                                f"MACD: {indicators.get('macd', 'N/A'):.3f}, "
                                f"Volatility: {indicators.get('volatility', 'N/A'):.2f}%"
                            )
                else:
                    self.logger.warning(f"No market data available for {symbol}")
                    
            except Exception as e:
                self.logger.error(f"Error processing {symbol}: {e}")
        
        # Log cycle summary with performance metrics
        if trades_this_cycle > 0:
            self.logger.info(f"Cycle completed: {trades_this_cycle} trades executed")
            
            # Show performance summary after trades
            perf = self.strategy.get_performance_summary()
            if perf['total_trades'] > 0:
                self.logger.info(
                    f"Performance - Total Trades: {perf['total_trades']}, "
                    f"Win Rate: {perf['win_rate']:.1f}%, "
                    f"Total P&L: £{perf['total_pnl']:.2f}"
                )
        
        return True
    
    def start_trading(self, max_cycles: int = None):
        """
        Start automated trading with enhanced strategy monitoring
        
        Args:
            max_cycles: Maximum number of cycles to run (None for continuous)
        """
        # Check connection (handle both real and simulated bots)
        if self.ib_conn and not self.ib_conn.is_connected():
            self.logger.error("Must connect to IB before starting trading")
            return False
        elif not self.ib_conn and self.environment != 'simulator':
            self.logger.error("No IB connection available")
            return False
        
        self.is_running = True
        self.start_time = datetime.now()
        cycle_count = 0
        
        self.logger.info("Starting automated trading...")
        self.logger.info(f"Symbols: {self.symbols}")
        self.logger.info(f"Strategy: {self.strategy.name}")
        self.logger.info(f"Update interval: {self.update_interval} seconds")
        
        # Display strategy configuration
        self.logger.info(
            f"Strategy config - Short: {self.strategy.short_window}, "
            f"Long: {self.strategy.long_window}, "
            f"Stop Loss: {self.strategy.stop_loss_pct*100:.1f}%, "
            f"Take Profit: {self.strategy.take_profit_pct*100:.1f}%"
        )
        
        try:
            while self.is_running:
                cycle_count += 1
                
                if max_cycles and cycle_count > max_cycles:
                    self.logger.info(f"Reached maximum cycles ({max_cycles})")
                    break
                
                self.logger.info(f"--- Cycle {cycle_count} ---")
                
                # Run enhanced trading cycle
                self.run_single_cycle()
                
                # Show market overview every 5 cycles
                if cycle_count % 5 == 0:
                    try:
                        overview = self.strategy.get_market_overview(self.symbols)
                        self.logger.info(
                            f"Market Overview - Active Positions: {overview['total_positions']}, "
                            f"Symbols Tracked: {len(overview['symbols_analysis'])}"
                        )
                    except Exception as e:
                        self.logger.error(f"Error getting market overview: {e}")
                
                # Sleep before next cycle
                if self.is_running:
                    time.sleep(self.update_interval)
                
        except KeyboardInterrupt:
            self.logger.info("Trading stopped by user")
        except Exception as e:
            self.logger.error(f"Error in trading loop: {e}")
        finally:
            self.is_running = False
            self.print_enhanced_summary()
    
    def stop_trading(self):
        """Stop automated trading"""
        self.is_running = False
        self.logger.info("Trading stop requested")
    
    def print_enhanced_summary(self):
        """Print enhanced trading session summary with detailed performance metrics"""
        if self.start_time:
            duration = datetime.now() - self.start_time
            self.logger.info("="*50)
            self.logger.info("ENHANCED TRADING SESSION SUMMARY")
            self.logger.info("="*50)
            self.logger.info(f"Environment: {self.environment.upper()}")
            self.logger.info(f"Duration: {duration}")
            self.logger.info(f"Total trades executed: {self.trades_executed}")
            
            # Enhanced strategy performance
            perf = self.strategy.get_performance_summary()
            self.logger.info(f"Strategy: {self.strategy.name}")
            
            if perf['total_trades'] > 0:
                self.logger.info(f"Win Rate: {perf['win_rate']:.1f}%")
                self.logger.info(f"Total P&L: £{perf['total_pnl']:.2f}")
                self.logger.info(f"Profitable Trades: {perf['profitable_trades']}/{perf['total_trades']}")
            
            # Enhanced positions summary
            self.logger.info("Current Positions:")
            total_position_value = 0.0
            
            for symbol, position in self.strategy.positions.items():
                if position['shares'] > 0:
                    position_value = position['shares'] * position['avg_price']
                    total_position_value += position_value
                    
                    # Get current price for unrealised P&L
                    try:
                        current_data = self.get_enhanced_market_analysis(symbol)
                        if current_data:
                            current_price = current_data['last']
                            unrealised_pnl = (current_price - position['avg_price']) * position['shares']
                            unrealised_pct = (unrealised_pnl / position_value) * 100 if position_value > 0 else 0
                            
                            self.logger.info(
                                f"  {symbol}: {position['shares']} shares @ £{position['avg_price']:.2f} "
                                f"(Current: £{current_price:.2f}, P&L: £{unrealised_pnl:+.2f} {unrealised_pct:+.1f}%)"
                            )
                        else:
                            self.logger.info(f"  {symbol}: {position['shares']} shares @ £{position['avg_price']:.2f}")
                    except:
                        self.logger.info(f"  {symbol}: {position['shares']} shares @ £{position['avg_price']:.2f}")
                else:
                    self.logger.info(f"  {symbol}: No position")
            
            if total_position_value > 0:
                self.logger.info(f"Total Position Value: £{total_position_value:.2f}")
            
            # Technical indicators summary
            self.logger.info("Technical Indicators Summary:")
            for symbol in self.symbols:
                try:
                    status = self.strategy.get_strategy_status(symbol)
                    indicators = status['technical_indicators']
                    
                    if indicators:
                        summary_indicators = []
                        if 'rsi' in indicators:
                            summary_indicators.append(f"RSI: {indicators['rsi']:.1f}")
                        if 'macd' in indicators:
                            summary_indicators.append(f"MACD: {indicators['macd']:.3f}")
                        if 'volatility' in indicators:
                            summary_indicators.append(f"Vol: {indicators['volatility']:.1f}%")
                        
                        if summary_indicators:
                            self.logger.info(f"  {symbol}: {', '.join(summary_indicators)}")
                        else:
                            self.logger.info(f"  {symbol}: Calculating indicators...")
                    else:
                        self.logger.info(f"  {symbol}: No indicators available")
                        
                except Exception as e:
                    self.logger.info(f"  {symbol}: Error getting indicators - {e}")
            
            self.logger.info("="*50)
    
    def run_analysis_cycle(self, symbol: str) -> Dict:
        """
        Run a single analysis cycle for a symbol without trading
        
        Args:
            symbol: Stock symbol to analyse
        """
        try:
            # Get enhanced analysis
            analysis = self.get_enhanced_market_analysis(symbol)
            
            if analysis:
                # Get strategy status
                status = self.strategy.get_strategy_status(symbol)
                
                # Combine analysis with strategy insights
                enhanced_status = {
                    'symbol': symbol,
                    'current_price': analysis['last'],
                    'price_change_pct': analysis.get('price_change_pct', 0),
                    'position': status['position'],
                    'technical_indicators': status['technical_indicators'],
                    'buy_signals': [],
                    'sell_signals': [],
                    'risk_check': {}
                }
                
                # Evaluate signals without executing trades
                if status['technical_indicators']:
                    try:
                        buy_signals = self.strategy.evaluate_buy_signals(
                            symbol, analysis, status['technical_indicators']
                        )
                        sell_signals = self.strategy.evaluate_sell_signals(
                            symbol, analysis, status['technical_indicators']
                        )
                        
                        enhanced_status['buy_signals'] = buy_signals
                        enhanced_status['sell_signals'] = sell_signals
                        enhanced_status['buy_signal_count'] = sum(buy_signals)
                        enhanced_status['sell_signal_count'] = sum(sell_signals)
                        
                        # Risk management check
                        enhanced_status['risk_check'] = self.strategy.check_risk_management(symbol, analysis)
                        
                    except Exception as e:
                        self.logger.error(f"Error evaluating signals for {symbol}: {e}")
                
                return enhanced_status
            else:
                return {'symbol': symbol, 'error': 'No analysis data available'}
                
        except Exception as e:
            self.logger.error(f"Error in analysis cycle for {symbol}: {e}")
            return {'symbol': symbol, 'error': str(e)}
    
    def get_portfolio_summary(self) -> Dict:
        """Get comprehensive portfolio summary"""
        try:
            # Get account information
            account_info = self.ib_conn.get_account_summary()
            
            # Get strategy performance
            strategy_perf = self.strategy.get_performance_summary()
            
            # Calculate total portfolio value
            total_cash = float(account_info.get('AvailableFunds', '0')) if account_info else 0
            total_position_value = strategy_perf.get('total_position_value', 0)
            total_portfolio_value = total_cash + total_position_value
            
            portfolio_summary = {
                'account_info': account_info,
                'strategy_performance': strategy_perf,
                'total_cash': total_cash,
                'total_position_value': total_position_value,
                'total_portfolio_value': total_portfolio_value,
                'positions': self.strategy.positions.copy(),
                'trades_executed': self.trades_executed,
                'session_duration': datetime.now() - self.start_time if self.start_time else None
            }
            
            return portfolio_summary
            
        except Exception as e:
            self.logger.error(f"Error getting portfolio summary: {e}")
            return {'error': str(e)}
    
    def run_diagnostic_check(self) -> Dict:
        """Run comprehensive diagnostic check of all bot components"""
        diagnostics = {
            'connection_status': self.ib_conn.is_connected() if self.ib_conn else False,
            'components_initialised': {
                'historical_data': self.historical_data is not None,
                'market_data': self.market_data is not None,
                'order_manager': self.order_manager is not None,
                'strategy': self.strategy is not None
            },
            'strategy_config': {
                'name': self.strategy.name,
                'short_window': self.strategy.short_window,
                'long_window': self.strategy.long_window,
                'stop_loss_pct': self.strategy.stop_loss_pct * 100,
                'take_profit_pct': self.strategy.take_profit_pct * 100
            },
            'bot_config': {
                'environment': self.environment,
                'symbols': self.symbols,
                'update_interval': self.update_interval,
                'is_running': self.is_running
            },
            'data_availability': {}
        }
        
        # Test data availability for each symbol
        for symbol in self.symbols[:2]:  # Test first 2 symbols to avoid too many requests
            try:
                analysis = self.get_enhanced_market_analysis(symbol)
                diagnostics['data_availability'][symbol] = {
                    'available': analysis is not None,
                    'has_indicators': bool(analysis and analysis.get('technical_indicators')),
                    'price': analysis['last'] if analysis else None
                }
            except Exception as e:
                diagnostics['data_availability'][symbol] = {
                    'available': False,
                    'error': str(e)
                }
        
        return diagnostics

print("Trading Bot class created")
# Out:
# Trading Bot class created

# %% [markdown]
# ### Trading Bot Simulator

# %%
class IBTradingBotSimulator(IBTradingBot):
    """Simulator version of trading bot for testing without real IB connection"""
    
    def __init__(self, strategy: TradingStrategy = None):
        """Initialise enhanced trading bot simulator"""
        self.environment = 'simulator'
        self.logger = logging.getLogger('TradingBot-Simulator')
        
        # Simulated components
        self.ib_conn = None
        self.historical_data = SimulatedHistoricalData()
        self.market_data = SimulatedMarketData()
        self.order_manager = SimulatedOrderManager()
        self.strategy = strategy or TradingStrategy('Enhanced_Simulator', 10, 30)
        
        # Configure strategy with simulated data handlers
        self.strategy.set_data_handlers(self.historical_data, self.market_data)
        
        # Bot configuration
        self.symbols = ['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG']
        self.is_running = False
        self.update_interval = 5  # Faster for simulation
        
        # Performance tracking
        self.start_time = None
        self.trades_executed = 0
        self.simulated_balance = 10000.0  # Starting balance
        
        self.logger.info("Trading bot simulator initialised")
        self.logger.info(f"Strategy: {self.strategy.name}")
        self.logger.info(f"Starting balance: £{self.simulated_balance:,.2f}")
    
    def connect(self) -> bool:
        """Simulate connection with enhanced features"""
        self.logger.info("Connected to trading simulator")
        return True
    
    def disconnect(self):
        """Simulate disconnection with cleanup"""
        self.is_running = False
        self.logger.info("Disconnected from trading simulator")
    
    def get_enhanced_market_analysis(self, symbol: str) -> Optional[Dict]:
        """
        Get enhanced simulated market analysis
        
        Args:
            symbol: Stock symbol to analyse
        """
        try:
            # Use strategy's enhanced analysis with simulated data
            analysis = self.strategy.get_enhanced_market_analysis(symbol)
            
            if analysis:
                self.logger.info(
                    f"Enhanced simulated analysis for {symbol}: £{analysis['last']:.2f} "
                    f"({analysis.get('price_change_pct', 0):+.2f}%)"
                )
                return analysis
            else:
                # Fallback to basic simulated analysis
                return self.get_market_analysis(symbol)
                
        except Exception as e:
            self.logger.error(f"Error getting enhanced simulated analysis for {symbol}: {e}")
            return self.get_market_analysis(symbol)
    
    def get_market_analysis(self, symbol: str) -> Optional[Dict]:
        """
        Get simulated market analysis data for trading decisions
        
        Args:
            symbol: Stock symbol to analyse
        """
        try:
            # Get simulated historical data
            df = self.historical_data.get_intraday_data(symbol, days=2)
            
            if df is None or df.empty:
                self.logger.warning(f"No simulated historical data available for {symbol}")
                return None
            
            # Calculate current metrics
            latest_price = float(df.iloc[-1]['close'])
            volume = int(df.iloc[-1]['volume'])
            
            # Calculate moving averages if enough data
            if len(df) >= 20:
                ma_20 = df['close'].rolling(window=20).mean().iloc[-1]
            else:
                ma_20 = latest_price
            
            if len(df) >= 50:
                ma_50 = df['close'].rolling(window=50).mean().iloc[-1]
            else:
                ma_50 = latest_price
            
            # Price change from previous close
            if len(df) >= 2:
                price_change = latest_price - float(df.iloc[-2]['close'])
                price_change_pct = (price_change / float(df.iloc[-2]['close'])) * 100
            else:
                price_change = 0
                price_change_pct = 0
            
            analysis_data = {
                'symbol': symbol,
                'last': latest_price,
                'volume': volume,
                'price_change': price_change,
                'price_change_pct': price_change_pct,
                'ma_20': float(ma_20),
                'ma_50': float(ma_50),
                'timestamp': datetime.now(),
                'historical_data': df
            }
            
            self.logger.info(f"Simulated analysis for {symbol}: £{latest_price:.2f} ({price_change_pct:+.2f}%)")
            return analysis_data
            
        except Exception as e:
            self.logger.error(f"Error getting simulated market analysis for {symbol}: {e}")
            return None
    
    def execute_trade_logic(self, symbol: str, market_data: Dict) -> bool:
        """Execute enhanced simulated trading logic"""
        try:
            # Check for buy signal using enhanced strategy
            if self.strategy.should_buy(market_data):
                if self.simulated_balance > 0:
                    quantity = self.strategy.calculate_position_size(
                        symbol, market_data['last'], self.simulated_balance
                    )
                    
                    trade_value = quantity * market_data['last']
                    
                    if trade_value <= self.simulated_balance and quantity > 0:
                        # Execute simulated buy
                        self.order_manager.place_market_order(symbol, 'BUY', quantity)
                        self.strategy.update_position(
                            symbol, 'BUY', quantity, market_data['last']
                        )
                        
                        self.simulated_balance -= trade_value
                        self.trades_executed += 1
                        
                        self.logger.info(
                            f"SIMULATED BUY: {quantity} {symbol} @ £{market_data['last']:.2f} "
                            f"(Cost: £{trade_value:.2f}, Balance: £{self.simulated_balance:.2f})"
                        )
                        return True
            
            # Check for sell signal using enhanced strategy
            elif self.strategy.should_sell(symbol, market_data):
                position = self.strategy.get_position(symbol)
                
                if position['shares'] > 0:
                    # Execute simulated sell
                    self.order_manager.place_market_order(symbol, 'SELL', position['shares'])
                    
                    trade_value = position['shares'] * market_data['last']
                    
                    self.strategy.update_position(
                        symbol, 'SELL', position['shares'], market_data['last']
                    )
                    
                    self.simulated_balance += trade_value
                    self.trades_executed += 1
                    
                    # Calculate P&L
                    cost_basis = position['shares'] * position['avg_price']
                    pnl = trade_value - cost_basis
                    
                    self.logger.info(
                        f"SIMULATED SELL: {position['shares']} {symbol} @ £{market_data['last']:.2f} "
                        f"(Value: £{trade_value:.2f}, P&L: £{pnl:.2f}, Balance: £{self.simulated_balance:.2f})"
                    )
                    return True
            
            return False
            
        except Exception as e:
            self.logger.error(f"Error in simulated trade logic for {symbol}: {e}")
            return False
    
    def run_single_cycle(self):
        """Run a single enhanced simulated trading cycle"""
        trades_this_cycle = 0
        
        for symbol in self.symbols:
            try:
                # Get enhanced simulated market analysis
                market_data = self.get_enhanced_market_analysis(symbol)
                
                if market_data:
                    # Execute enhanced trading logic
                    if self.execute_trade_logic(symbol, market_data):
                        trades_this_cycle += 1
                        
                        # Log enhanced strategy status after trade
                        try:
                            status = self.strategy.get_strategy_status(symbol)
                            if status['technical_indicators']:
                                indicators = status['technical_indicators']
                                self.logger.info(
                                    f"{symbol} indicators - RSI: {indicators.get('rsi', 'N/A'):.1f}, "
                                    f"MACD: {indicators.get('macd', 'N/A'):.3f}, "
                                    f"Volatility: {indicators.get('volatility', 'N/A'):.2f}%"
                                )
                        except Exception as e:
                            self.logger.error(f"Error logging indicators for {symbol}: {e}")
                        
            except Exception as e:
                self.logger.error(f"Error processing {symbol}: {e}")
        
        # Enhanced cycle summary
        if trades_this_cycle > 0:
            self.logger.info(f"Cycle completed: {trades_this_cycle} trades executed")
            
            # Show performance summary after trades
            try:
                perf = self.strategy.get_performance_summary()
                if perf['total_trades'] > 0:
                    self.logger.info(
                        f"Performance - Total Trades: {perf['total_trades']}, "
                        f"Win Rate: {perf['win_rate']:.1f}%, "
                        f"Total P&L: £{perf['total_pnl']:.2f}"
                    )
            except Exception as e:
                self.logger.error(f"Error getting performance summary: {e}")
        
        return True
    
    def run_diagnostic_check(self) -> Dict:
        """Run comprehensive diagnostic check for simulator"""
        diagnostics = {
            'connection_status': True,  # Always true for simulator
            'components_initialised': {
                'historical_data': self.historical_data is not None,
                'market_data': self.market_data is not None,
                'order_manager': self.order_manager is not None,
                'strategy': self.strategy is not None
            },
            'strategy_config': {
                'name': self.strategy.name,
                'short_window': self.strategy.short_window,
                'long_window': self.strategy.long_window,
                'stop_loss_pct': self.strategy.stop_loss_pct * 100,
                'take_profit_pct': self.strategy.take_profit_pct * 100
            },
            'bot_config': {
                'environment': self.environment,
                'symbols': self.symbols,
                'update_interval': self.update_interval,
                'is_running': self.is_running,
                'simulated_balance': self.simulated_balance
            },
            'data_availability': {}
        }
        
        # Test data availability for each symbol
        for symbol in self.symbols[:2]:  # Test first 2 symbols
            try:
                analysis = self.get_enhanced_market_analysis(symbol)
                diagnostics['data_availability'][symbol] = {
                    'available': analysis is not None,
                    'has_indicators': bool(analysis and analysis.get('technical_indicators')),
                    'price': analysis['last'] if analysis else None
                }
            except Exception as e:
                diagnostics['data_availability'][symbol] = {
                    'available': False,
                    'error': str(e)
                }
        
        return diagnostics
    
    def get_portfolio_summary(self) -> Dict:
        """Get comprehensive simulated portfolio summary"""
        try:
            # Get strategy performance
            strategy_perf = self.strategy.get_performance_summary()
            
            # Calculate total portfolio value
            total_cash = self.simulated_balance
            total_position_value = strategy_perf.get('total_position_value', 0)
            total_portfolio_value = total_cash + total_position_value
            
            portfolio_summary = {
                'account_info': {'AvailableFunds': str(self.simulated_balance)},
                'strategy_performance': strategy_perf,
                'total_cash': total_cash,
                'total_position_value': total_position_value,
                'total_portfolio_value': total_portfolio_value,
                'positions': self.strategy.positions.copy(),
                'trades_executed': self.trades_executed,
                'session_duration': datetime.now() - self.start_time if self.start_time else None
            }
            
            return portfolio_summary
            
        except Exception as e:
            self.logger.error(f"Error getting simulated portfolio summary: {e}")
            return {'error': str(e)}


class SimulatedMarketData:
    """Simulated market data handler for testing"""
    
    def __init__(self):
        """Initialise simulated market data handler"""
        self.logger = logging.getLogger('SimulatedMarketData')
        self.subscribed_tickers = {}
        self.last_prices = {}
        
        # Base prices for simulation
        self.base_prices = {
            'MRK': 180.0, 'UNH': 850.0, 'LLY': 380.0, 'PG': 160.0, 'KO': 65.0,
            'WMT': 175.0, 'TSLA': 250.0, 'NVDA': 800.0, 'AMZN': 180.0, 
            'GOOGL': 140.0, 'META': 520.0, 'QCOM': 170.0
        }
    
    def get_market_data(self, symbol: str, exchange: str = 'SMART',
                       currency: str = 'USD') -> Optional[Dict]:
        """
        Get simulated real-time market data
        
        Args:
            symbol: Stock symbol
            exchange: Exchange (ignored in simulation)
            currency: Currency (ignored in simulation)
        """
        try:
            if symbol not in self.base_prices:
                self.base_prices[symbol] = random.uniform(50.0, 500.0)
            
            base_price = self.base_prices[symbol]
            
            # Generate realistic market data
            volatility = random.gauss(0, 0.005)  # 0.5% volatility
            current_price = base_price * (1 + volatility)
            
            # Generate bid/ask spread
            spread_pct = random.uniform(0.001, 0.003)  # 0.1-0.3% spread
            spread = current_price * spread_pct
            
            market_data = {
                'symbol': symbol,
                'last': round(current_price, 2),
                'bid': round(current_price - spread/2, 2),
                'ask': round(current_price + spread/2, 2),
                'volume': random.randint(1000, 50000),
                'high': round(current_price * 1.01, 2),
                'low': round(current_price * 0.99, 2),
                'close': round(current_price, 2),
                'timestamp': datetime.now()
            }
            
            # Update base price for next call
            self.base_prices[symbol] = current_price
            self.last_prices[symbol] = current_price
            
            return market_data
            
        except Exception as e:
            self.logger.error(f"Error getting simulated market data for {symbol}: {e}")
            return None
    
    def get_market_snapshot(self, symbol: str, exchange: str = 'SMART',
                           currency: str = 'USD') -> Optional[Dict]:
        """Get simulated market snapshot"""
        return self.get_market_data(symbol, exchange, currency)
    
    def subscribe_to_ticker(self, symbol: str, exchange: str = 'SMART',
                           currency: str = 'USD') -> bool:
        """Simulate ticker subscription"""
        self.subscribed_tickers[symbol] = {'symbol': symbol}
        self.logger.info(f"Subscribed to simulated {symbol}")
        return True
    
    def unsubscribe_from_ticker(self, symbol: str) -> bool:
        """Simulate ticker unsubscription"""
        if symbol in self.subscribed_tickers:
            del self.subscribed_tickers[symbol]
            self.logger.info(f"Unsubscribed from simulated {symbol}")
            return True
        return False
    
    def get_subscribed_data(self, symbol: str) -> Optional[Dict]:
        """Get simulated subscribed data"""
        if symbol in self.subscribed_tickers:
            return self.get_market_data(symbol)
        return None
    
    def cleanup_subscriptions(self):
        """Cancel all simulated subscriptions"""
        for symbol in list(self.subscribed_tickers.keys()):
            self.unsubscribe_from_ticker(symbol)
        self.logger.info("All simulated market data subscriptions cancelled")
    
    def get_last_known_price(self, symbol: str) -> Optional[float]:
        """Get last known simulated price"""
        return self.last_prices.get(symbol)
    
    def is_market_open(self) -> bool:
        """Simulate market hours (always open for testing)"""
        return True


class SimulatedHistoricalData:
    """Enhanced simulated historical data generator for testing"""
    
    def __init__(self):
        """Initialise with realistic starting prices and enhanced data history"""
        self.base_prices = {
            'MRK': 180.0, 'UNH': 850.0, 'LLY': 380.0, 'PG': 160.0, 'KO': 65.0,
            'WMT': 175.0, 'TSLA': 250.0, 'NVDA': 800.0, 'AMZN': 180.0, 
            'GOOGL': 140.0, 'META': 520.0, 'QCOM': 170.0
        }
        self.volatility = 0.002  # 0.2% volatility per minute
        self.trend = 0.0001  # Small upward trend
        self.data_cache = {}
        self.time_counter = {}
        self.logger = logging.getLogger('SimulatedHistoricalData')
    
    def generate_enhanced_historical_data(self, symbol: str, periods: int) -> pd.DataFrame:
        """
        Generate realistic historical price data with enhanced features
        
        Args:
            symbol: Stock symbol
            periods: Number of periods to generate
        """
        if symbol not in self.base_prices:
            self.base_prices[symbol] = random.uniform(50.0, 500.0)
        
        base_price = self.base_prices[symbol]
        prices = []
        
        current_price = base_price
        start_time = datetime.now() - timedelta(minutes=periods)
        
        # Add some market regime changes for more realistic testing
        regime_changes = random.choices([True, False], weights=[0.1, 0.9], k=periods)
        trend_strength = 1.0
        
        for i in range(periods):
            # Simulate market regime changes
            if regime_changes[i]:
                trend_strength *= random.uniform(0.5, 1.5)
                trend_strength = max(0.2, min(2.0, trend_strength))  # Keep within bounds
            
            # Generate realistic price movement with enhanced volatility patterns
            trend_component = self.trend * trend_strength * random.uniform(0.5, 1.5)
            
            # Add volatility clustering (periods of high/low volatility)
            vol_multiplier = random.uniform(0.5, 2.0) if i % 50 == 0 else random.uniform(0.8, 1.2)
            volatility_component = random.gauss(0, self.volatility * vol_multiplier)
            
            price_change = trend_component + volatility_component
            current_price = current_price * (1 + price_change)
            
            # Ensure reasonable price bounds with some drift allowance
            min_price = base_price * 0.7  # Allow 30% down
            max_price = base_price * 1.4  # Allow 40% up
            current_price = max(current_price, min_price)
            current_price = min(current_price, max_price)
            
            # Generate realistic OHLC data with proper relationships
            daily_range = current_price * random.uniform(0.005, 0.03)  # 0.5-3% daily range
            
            open_price = current_price * random.uniform(0.995, 1.005)
            high = current_price + (daily_range * random.uniform(0.3, 1.0))
            low = current_price - (daily_range * random.uniform(0.3, 1.0))
            close_price = current_price
            
            # Ensure OHLC relationships are valid
            high = max(high, open_price, close_price)
            low = min(low, open_price, close_price)
            
            # Generate realistic volume with patterns
            base_volume = random.randint(5000, 50000)
            volume_multiplier = 2.0 if abs(price_change) > 0.01 else 1.0  # Higher volume on big moves
            volume = int(base_volume * volume_multiplier * random.uniform(0.7, 1.3))
            
            prices.append({
                'date': start_time + timedelta(minutes=i),
                'open': round(open_price, 2),
                'high': round(high, 2),
                'low': round(low, 2),
                'close': round(close_price, 2),
                'volume': volume
            })
        
        # Update current price for this symbol
        self.base_prices[symbol] = current_price
        
        df = pd.DataFrame(prices)
        df['timestamp'] = df['date']
        df['symbol'] = symbol
        
        return df
    
    def get_intraday_data(self, symbol: str, days: int = 1) -> Optional[pd.DataFrame]:
        """
        Get enhanced simulated intraday data
        
        Args:
            symbol: Stock symbol
            days: Number of days
        """
        periods = days * 390  # Approximate trading minutes per day
        return self.generate_enhanced_historical_data(symbol, periods)
    
    def get_daily_data(self, symbol: str, period: str = '1 M') -> Optional[pd.DataFrame]:
        """
        Get enhanced simulated daily data
        
        Args:
            symbol: Stock symbol
            period: Time period
        """
        # Convert period to number of days
        period_map = {'1 M': 30, '3 M': 90, '6 M': 180, '1 Y': 365, '2 Y': 730}
        days = period_map.get(period, 30)
        
        return self.generate_enhanced_historical_data(symbol, days)
    
    def get_historical_data(self, symbol: str, duration: str = '1 D',
                           bar_size: str = '1 min', exchange: str = 'SMART',
                           currency: str = 'USD') -> Optional[pd.DataFrame]:
        """
        Get enhanced simulated historical data with IB-like parameters
        
        Args:
            symbol: Stock symbol
            duration: Data duration
            bar_size: Bar size
            exchange: Exchange (ignored in simulation)
            currency: Currency (ignored in simulation)
        """
        # Parse duration to get number of periods
        try:
            if 'D' in duration:
                days = int(duration.replace(' D', ''))
                if '1 min' in bar_size:
                    periods = days * 390  # Trading minutes per day
                elif '1 hour' in bar_size:
                    periods = int(days * 6.5)  # Trading hours per day
                else:  # Daily bars
                    periods = days
            elif 'W' in duration:
                weeks = int(duration.replace(' W', ''))
                periods = weeks * 5  # Trading days per week
            elif 'M' in duration:
                months = int(duration.replace(' M', ''))
                periods = months * 22  # Trading days per month
            else:
                periods = 390  # Default to 1 day
            
            return self.generate_enhanced_historical_data(symbol, int(periods))
            
        except Exception as e:
            self.logger.error(f"Error parsing duration '{duration}': {e}")
            return self.generate_enhanced_historical_data(symbol, 390)
    
    def get_cached_data(self, symbol: str, duration: str = '1 D',
                       bar_size: str = '1 min', max_age_minutes: int = 5) -> Optional[pd.DataFrame]:
        """
        Simulate enhanced cached data behaviour
        """
        # In simulation, always return fresh data with some caching simulation
        cache_key = f"{symbol}_{duration}_{bar_size}"
        
        if cache_key in self.data_cache:
            cached_item = self.data_cache[cache_key]
            age_minutes = (datetime.now() - cached_item['retrieved_at']).total_seconds() / 60
            
            if age_minutes <= max_age_minutes:
                self.logger.info(f"Using simulated cached data for {symbol} (age: {age_minutes:.1f}min)")
                return cached_item['data']
        
        # Generate fresh data and cache it
        fresh_data = self.get_historical_data(symbol, duration, bar_size)
        if fresh_data is not None:
            self.data_cache[cache_key] = {
                'data': fresh_data,
                'retrieved_at': datetime.now()
            }
        
        return fresh_data
    
    def clear_cache(self):
        """Clear simulated cache"""
        self.data_cache.clear()
        self.logger.info("Simulated data cache cleared")
    
    def get_multiple_symbols(self, symbols: List[str], duration: str = '1 D',
                            bar_size: str = '1 min') -> Dict[str, pd.DataFrame]:
        """
        Get enhanced simulated data for multiple symbols
        
        Args:
            symbols: List of stock symbols
            duration: Data duration
            bar_size: Bar size
        """
        results = {}
        
        for symbol in symbols:
            self.logger.info(f"Fetching simulated data for {symbol}")
            data = self.get_historical_data(symbol, duration, bar_size)
            
            if data is not None:
                results[symbol] = data
            
            # Simulate small delay
            time.sleep(0.05)
        
        self.logger.info(f"Retrieved simulated data for {len(results)} out of {len(symbols)} symbols")
        return results


class SimulatedOrderManager:
    """Enhanced simulated order manager for testing"""
    
    def __init__(self):
        """Initialise enhanced simulated order manager"""
        self.orders_log = []
        self.order_id_counter = 1000
        self.logger = logging.getLogger('SimulatedOrderManager')
        self.open_orders = []
    
    def place_market_order(self, symbol: str, action: str, quantity: int,
                          exchange: str = 'SMART', currency: str = 'USD') -> bool:
        """Simulate placing a market order with enhanced logging"""
        order = {
            'order_id': self.order_id_counter,
            'symbol': symbol,
            'action': action,
            'quantity': quantity,
            'order_type': 'MARKET',
            'status': 'FILLED',
            'timestamp': datetime.now(),
            'exchange': exchange,
            'currency': currency
        }
        
        self.orders_log.append(order)
        self.order_id_counter += 1
        
        self.logger.info(f"Simulated {action} order placed: {quantity} {symbol}")
        return True
    
    def place_limit_order(self, symbol: str, action: str, quantity: int,
                         limit_price: float, exchange: str = 'SMART',
                         currency: str = 'USD') -> bool:
        """Simulate placing a limit order"""
        order = {
            'order_id': self.order_id_counter,
            'symbol': symbol,
            'action': action,
            'quantity': quantity,
            'order_type': 'LIMIT',
            'limit_price': limit_price,
            'status': 'SUBMITTED',
            'timestamp': datetime.now(),
            'exchange': exchange,
            'currency': currency
        }
        
        self.orders_log.append(order)
        self.open_orders.append(order)
        self.order_id_counter += 1
        
        self.logger.info(f"Simulated limit order placed: {action} {quantity} {symbol} @ £{limit_price:.2f}")
        return True
    
    def get_open_orders(self) -> List[Dict]:
        """Get simulated open orders"""
        return self.open_orders.copy()
    
    def cancel_order(self, order_id: int) -> bool:
        """Simulate order cancellation"""
        for order in self.open_orders:
            if order['order_id'] == order_id:
                order['status'] = 'CANCELLED'
                self.open_orders.remove(order)
                self.logger.info(f"Simulated order {order_id} cancelled")
                return True
        return False
    
    def get_orders_log(self) -> List[Dict]:
        """Get enhanced simulated orders log"""
        return self.orders_log


print("Trading Bot Simulator created")
# Out:
# Trading Bot Simulator created

# %% [markdown]
# ### Configuration and Testing Functions

# %%
def create_trading_bot(environment: str = 'paper', 
                      strategy_type: str = 'enhanced',
                      **strategy_params) -> IBTradingBot:
    """
    Create a trading bot with specified configuration
    
    Args:
        environment: 'paper', 'live', or 'simulator'
        strategy_type: 'enhanced' for Enhanced Trading Strategy, 'sma' for legacy
        **strategy_params: Strategy-specific parameters
    """
    
    # Create enhanced strategy with proper configuration
    if strategy_type.lower() == 'enhanced':
        short_window = strategy_params.get('short_window', 10)
        long_window = strategy_params.get('long_window', 30)
        strategy_name = strategy_params.get('name', f'Enhanced_{short_window}_{long_window}')
        strategy = TradingStrategy(strategy_name, short_window, long_window)
        
        # Configure risk management parameters
        strategy.stop_loss_pct = strategy_params.get('stop_loss_pct', 0.05)
        strategy.take_profit_pct = strategy_params.get('take_profit_pct', 0.15)
        strategy.max_position_size = strategy_params.get('max_position_size', 0.20)
        
    elif strategy_type.lower() == 'sma':
        # Legacy simple strategy for backwards compatibility
        short_window = strategy_params.get('short_window', 10)
        long_window = strategy_params.get('long_window', 30)
        strategy_name = f'SMA_{short_window}_{long_window}'
        strategy = TradingStrategy(strategy_name, short_window, long_window)
    else:
        # Default to enhanced strategy
        strategy = TradingStrategy('Enhanced_Default', 10, 30)
    
    # Create appropriate bot
    if environment.lower() == 'simulator':
        bot = IBTradingBotSimulator(strategy)
    else:
        bot = IBTradingBot(environment, strategy)
    
    return bot


def test_bot_connection(environment: str = 'paper') -> bool:
    """
    Test bot connection with enhanced diagnostics
    
    Args:
        environment: 'paper', 'live', or 'simulator'
    """
    print(f"Testing {environment} trading connection...")
    
    if environment == 'simulator':
        bot = create_trading_bot('simulator')
        success = bot.connect()
        if success:
            print("Simulator connection test passed")
            
            # Test enhanced strategy features
            print("\nTesting enhanced strategy features:")
            for symbol in ['MRK', 'UNH'][:1]:  # Test one symbol
                try:
                    analysis = bot.get_enhanced_market_analysis(symbol)
                    if analysis and analysis.get('technical_indicators'):
                        indicators = analysis['technical_indicators']
                        print(f"  {symbol} Indicators:")
                        print(f"    RSI: {indicators.get('rsi', 'N/A'):.1f}")
                        print(f"    MACD: {indicators.get('macd', 'N/A'):.3f}")
                        print(f"    Volatility: {indicators.get('volatility', 'N/A'):.1f}%")
                        print(f"    Bollinger Band Width: {indicators.get('bb_width', 'N/A'):.1f}%")
                    else:
                        print(f"  {symbol}: Basic analysis available")
                except Exception as e:
                    print(f"  {symbol}: Error testing indicators - {e}")
        
        bot.disconnect()
        return success
    
    bot = create_trading_bot(environment)
    
    try:
        success = bot.connect()
        
        if success:
            print(f"Connection to {environment} trading successful")
            
            # Test enhanced historical data and analysis
            print("\nTesting enhanced analysis capabilities...")
            test_symbols = ['MRK', 'UNH']
            
            for symbol in test_symbols:
                try:
                    # Test enhanced market analysis
                    analysis = bot.get_enhanced_market_analysis(symbol)
                    if analysis:
                        print(f"  {symbol}: £{analysis['last']:.2f}")
                        
                        # Show technical indicators if available
                        if analysis.get('technical_indicators'):
                            indicators = analysis['technical_indicators']
                            indicator_summary = []
                            
                            if 'rsi' in indicators:
                                indicator_summary.append(f"RSI: {indicators['rsi']:.1f}")
                            if 'macd' in indicators:
                                indicator_summary.append(f"MACD: {indicators['macd']:.3f}")
                            if 'volatility' in indicators:
                                indicator_summary.append(f"Vol: {indicators['volatility']:.1f}%")
                            
                            if indicator_summary:
                                print(f"    Indicators: {', '.join(indicator_summary)}")
                            
                        # Test signal evaluation
                        if analysis.get('technical_indicators'):
                            try:
                                buy_signals = bot.strategy.evaluate_buy_signals(
                                    symbol, analysis, analysis['technical_indicators']
                                )
                                sell_signals = bot.strategy.evaluate_sell_signals(
                                    symbol, analysis, analysis['technical_indicators']
                                )
                                
                                print(f"    Buy Signals: {sum(buy_signals)}/{len(buy_signals)}")
                                print(f"    Sell Signals: {sum(sell_signals)}/{len(sell_signals)}")
                                
                            except Exception as e:
                                print(f"    Signal evaluation error: {e}")
                    else:
                        print(f"  {symbol}: No enhanced analysis available")
                        
                except Exception as e:
                    print(f"  {symbol}: Error getting enhanced analysis - {e}")
            
            # Test account info with enhanced display
            print("\nAccount Information:")
            try:
                account_info = bot.ib_conn.get_account_summary()
                if account_info:
                    net_liq = account_info.get('NetLiquidation', 'N/A')
                    buying_power = account_info.get('BuyingPower', 'N/A')
                    available_funds = account_info.get('AvailableFunds', 'N/A')
                    print(f"  Net Liquidation: £{net_liq}")
                    print(f"  Buying Power: £{buying_power}")
                    print(f"  Available Funds: £{available_funds}")
                else:
                    print("  Account info not available")
            except Exception as e:
                print(f"  Error getting account info: {e}")
            
            # Run diagnostic check
            print("\nDiagnostic Check:")
            try:
                diagnostics = bot.run_diagnostic_check()
                print(f"  Connection: {'Connected' if diagnostics['connection_status'] else 'Disconnected'}")
                print(f"  Components: {sum(diagnostics['components_initialised'].values())}/4 initialised")
                print(f"  Strategy: {diagnostics['strategy_config']['name']}")
                print(f"  Risk Management: Stop Loss {diagnostics['strategy_config']['stop_loss_pct']:.1f}%, Take Profit {diagnostics['strategy_config']['take_profit_pct']:.1f}%")
            except Exception as e:
                print(f"  Diagnostic error: {e}")
            
        else:
            print(f"Failed to connect to {environment} trading")
            if environment == 'paper':
                print("\nTroubleshooting tips:")
                print("• Ensure TWS or IB Gateway is running")
                print("• Check it's configured for paper trading (port 7497)")
                print("• Enable API connections: Configure > API > Enable ActiveX and Socket Clients")
                print("• Check if 'Read-Only API' is disabled")
                print("• Verify no other API clients are connected with the same client ID")
                print("• Check your IP address is whitelisted in TWS API settings")
            
    except Exception as e:
        print(f"Connection test failed: {e}")
        success = False
    finally:
        try:
            bot.disconnect()
        except:
            pass
    
    return success


def run_strategy_backtest(symbols: List[str] = None, 
                         duration_minutes: int = 5,
                         strategy_config: Dict = None) -> Dict:
    """
    Run enhanced backtest using the simulator with configurable strategy
    
    Args:
        symbols: List of symbols to test
        duration_minutes: How long to run the test
        strategy_config: Strategy configuration parameters
    """
    print("Running enhanced strategy backtest simulation...")
    
    # Configure strategy
    config = strategy_config or {}
    
    # Create simulator bot with enhanced strategy
    bot = create_trading_bot(
        'simulator',
        strategy_type='enhanced',
        short_window=config.get('short_window', 10),
        long_window=config.get('long_window', 30),
        stop_loss_pct=config.get('stop_loss_pct', 0.05),
        take_profit_pct=config.get('take_profit_pct', 0.15),
        name=config.get('name', 'Backtest_Enhanced')
    )
    
    if symbols:
        bot.set_symbols(symbols)
    
    # Connect and run
    if bot.connect():
        # Calculate max cycles based on duration
        max_cycles = (duration_minutes * 60) // bot.update_interval
        
        print(f"Running {max_cycles} cycles over {duration_minutes} minutes...")
        print(f"Testing symbols: {bot.symbols}")
        print(f"Strategy: {bot.strategy.name}")
        print(f"Starting balance: £{bot.simulated_balance:,.2f}")
        print(f"Risk Management: Stop Loss {bot.strategy.stop_loss_pct*100:.1f}%, Take Profit {bot.strategy.take_profit_pct*100:.1f}%")
        
        bot.start_trading(max_cycles=max_cycles)
        
        # Calculate enhanced portfolio metrics
        portfolio_value = bot.simulated_balance
        total_unrealised_pnl = 0.0
        
        for symbol, position in bot.strategy.positions.items():
            if position['shares'] > 0:
                try:
                    analysis = bot.get_enhanced_market_analysis(symbol)
                    if analysis:
                        current_value = position['shares'] * analysis['last']
                        cost_basis = position['shares'] * position['avg_price']
                        unrealised_pnl = current_value - cost_basis
                        
                        portfolio_value += current_value
                        total_unrealised_pnl += unrealised_pnl
                except:
                    # Fallback to cost basis if current price unavailable
                    portfolio_value += position['shares'] * position['avg_price']
        
        # Get enhanced results
        strategy_performance = bot.strategy.get_performance_summary()
        
        results = {
            'total_trades': bot.trades_executed,
            'final_balance': bot.simulated_balance,
            'portfolio_value': portfolio_value,
            'total_return': portfolio_value - 10000.0,
            'return_percentage': ((portfolio_value - 10000.0) / 10000.0) * 100,
            'total_unrealised_pnl': total_unrealised_pnl,
            'strategy_performance': strategy_performance,
            'positions': bot.strategy.positions.copy(),
            'orders_log': bot.order_manager.get_orders_log(),
            'technical_indicators': bot.strategy.technical_indicators.copy(),
            'signal_history': {k: v[-10:] for k, v in bot.strategy.signal_history.items()}  # Last 10 signals per symbol
        }
        
        # Display enhanced results
        print(f"\nEnhanced Backtest Results:")
        print(f"Total Trades: {results['total_trades']}")
        print(f"Cash Balance: £{results['final_balance']:.2f}")
        print(f"Portfolio Value: £{results['portfolio_value']:.2f}")
        print(f"Total Return: £{results['total_return']:.2f} ({results['return_percentage']:+.2f}%)")
        
        if results['strategy_performance']['total_trades'] > 0:
            perf = results['strategy_performance']
            print(f"Win Rate: {perf['win_rate']:.1f}%")
            print(f"Profitable Trades: {perf['profitable_trades']}/{perf['total_trades']}")
            print(f"Realised P&L: £{perf['total_pnl']:.2f}")
        
        if total_unrealised_pnl != 0:
            print(f"Unrealised P&L: £{total_unrealised_pnl:+.2f}")
        
        if results['total_trades'] > 0:
            print(f"\nFinal Positions:")
            for symbol, position in results['positions'].items():
                if position['shares'] > 0:
                    cost_basis = position['shares'] * position['avg_price']
                    print(f"  {symbol}: {position['shares']} shares @ £{position['avg_price']:.2f} (Cost: £{cost_basis:.2f})")
        
        # Show technical analysis summary
        print(f"\nTechnical Analysis Summary:")
        for symbol, indicators in results['technical_indicators'].items():
            if indicators:
                summary_parts = []
                if 'rsi' in indicators:
                    rsi_status = "Oversold" if indicators['rsi'] < 30 else "Overbought" if indicators['rsi'] > 70 else "Neutral"
                    summary_parts.append(f"RSI: {indicators['rsi']:.1f} ({rsi_status})")
                if 'macd' in indicators and 'macd_signal' in indicators:
                    macd_status = "Bullish" if indicators['macd'] > indicators['macd_signal'] else "Bearish"
                    summary_parts.append(f"MACD: {macd_status}")
                if 'volatility' in indicators:
                    vol_status = "High" if indicators['volatility'] > 3.0 else "Low" if indicators['volatility'] < 1.0 else "Normal"
                    summary_parts.append(f"Volatility: {vol_status} ({indicators['volatility']:.1f}%)")
                
                if summary_parts:
                    print(f"  {symbol}: {', '.join(summary_parts)}")
                else:
                    print(f"  {symbol}: Basic indicators calculated")
        
        bot.disconnect()
        return results
    else:
        print("Failed to connect to simulator")
        return {}


def test_historical_data(symbol: str = 'MRK', environment: str = 'paper'):
    """
    Test enhanced historical data retrieval and analysis
    
    Args:
        symbol: Symbol to test
        environment: Trading environment
    """
    print(f"Testing enhanced historical data for {symbol} in {environment} environment...")
    
    bot = create_trading_bot(environment, strategy_type='enhanced')
    
    if bot.connect():
        try:
            # Test enhanced analysis capabilities
            print(f"\n1. Enhanced Market Analysis:")
            analysis = bot.get_enhanced_market_analysis(symbol)
            if analysis:
                print(f"   Current price: £{analysis['last']:.2f}")
                print(f"   Price change: {analysis.get('price_change_pct', 0):+.2f}%")
                
                # Display technical indicators
                if analysis.get('technical_indicators'):
                    indicators = analysis['technical_indicators']
                    print(f"   Technical Indicators:")
                    
                    if 'rsi' in indicators:
                        rsi_level = "Oversold" if indicators['rsi'] < 30 else "Overbought" if indicators['rsi'] > 70 else "Neutral"
                        print(f"     RSI: {indicators['rsi']:.1f} ({rsi_level})")
                    
                    if 'macd' in indicators and 'macd_signal' in indicators:
                        macd_trend = "Bullish" if indicators['macd'] > indicators['macd_signal'] else "Bearish"
                        print(f"     MACD: {indicators['macd']:.3f} vs Signal: {indicators['macd_signal']:.3f} ({macd_trend})")
                    
                    if 'bb_upper' in indicators and 'bb_lower' in indicators:
                        bb_position = "Above Upper" if analysis['last'] > indicators['bb_upper'] else \
                                     "Below Lower" if analysis['last'] < indicators['bb_lower'] else "Within Bands"
                        print(f"     Bollinger Bands: £{indicators['bb_lower']:.2f} - £{indicators['bb_upper']:.2f} ({bb_position})")
                    
                    if 'volatility' in indicators:
                        vol_level = "High" if indicators['volatility'] > 3.0 else "Low" if indicators['volatility'] < 1.0 else "Normal"
                        print(f"     Volatility: {indicators['volatility']:.2f}% ({vol_level})")
                    
                    if 'volume_ratio' in indicators:
                        vol_activity = "High" if indicators['volume_ratio'] > 1.5 else "Low" if indicators['volume_ratio'] < 0.7 else "Normal"
                        print(f"     Volume Activity: {indicators['volume_ratio']:.1f}x average ({vol_activity})")
                    
                    # Test signal evaluation
                    print(f"   Signal Evaluation:")
                    try:
                        buy_signals = bot.strategy.evaluate_buy_signals(symbol, analysis, indicators)
                        sell_signals = bot.strategy.evaluate_sell_signals(symbol, analysis, indicators)
                        
                        print(f"     Buy Signals: {sum(buy_signals)}/{len(buy_signals)} active")
                        print(f"     Sell Signals: {sum(sell_signals)}/{len(sell_signals)} active")
                        
                        # Show which specific signals are active
                        if any(buy_signals):
                            active_buy = [i for i, signal in enumerate(buy_signals) if signal]
                            print(f"     Active Buy Signal Types: {active_buy}")
                        
                        if any(sell_signals):
                            active_sell = [i for i, signal in enumerate(sell_signals) if signal]
                            print(f"     Active Sell Signal Types: {active_sell}")
                            
                    except Exception as e:
                        print(f"     Error evaluating signals: {e}")
                
                # Test daily trend analysis
                if analysis.get('daily_trend'):
                    trend = analysis['daily_trend']
                    print(f"   Daily Trend: {trend.get('direction', 'Unknown')} (Strength: {trend.get('strength', 0):.1f}%)")
                    
                    if 'momentum_5d' in trend:
                        print(f"   5-Day Momentum: {trend['momentum_5d']:+.2f}%")
                    if 'momentum_20d' in trend:
                        print(f"   20-Day Momentum: {trend['momentum_20d']:+.2f}%")
                        
            else:
                print(f"   No enhanced analysis data available")
            
            # Test multiple data timeframes
            print(f"\n2. Historical Data Timeframes:")
            
            # Test intraday data
            intraday = bot.historical_data.get_intraday_data(symbol, days=1)
            if intraday is not None and not intraday.empty:
                print(f"   Intraday (1 day): {len(intraday)} data points")
                print(f"   Latest price: £{intraday.iloc[-1]['close']:.2f}")
                print(f"   Date range: {intraday.iloc[0]['date']} to {intraday.iloc[-1]['date']}")
            else:
                print(f"   Intraday: No data available")
            
            # Test daily data
            daily = bot.historical_data.get_daily_data(symbol, period='1 M')
            if daily is not None and not daily.empty:
                print(f"   Daily (1 month): {len(daily)} data points")
                monthly_return = ((daily.iloc[-1]['close'] - daily.iloc[0]['close']) / daily.iloc[0]['close']) * 100
                print(f"   Monthly return: {monthly_return:+.2f}%")
            else:
                print(f"   Daily: No data available")
            
            # Test strategy status
            print(f"\n3. Strategy Status:")
            try:
                status = bot.strategy.get_strategy_status(symbol)
                print(f"   Position: {status['position']['shares']} shares")
                print(f"   Price History Length: {status['price_history_length']}")
                print(f"   Technical Indicators Count: {len(status['technical_indicators'])}")
                print(f"   Recent Signals: {len(status['recent_signals'])}")
            except Exception as e:
                print(f"   Error getting strategy status: {e}")
                
        except Exception as e:
            print(f"Error testing enhanced historical data: {e}")
        finally:
            bot.disconnect()
    else:
        print(f"Failed to connect to {environment} environment")


def run_enhanced_analysis_test(symbols: List[str] = None) -> Dict:
    """
    Run comprehensive analysis test without trading
    
    Args:
        symbols: List of symbols to analyse
    """
    symbols = symbols or ['MRK', 'UNH', 'LLY']
    print(f"Running enhanced analysis test for: {symbols}")
    
    bot = create_trading_bot('simulator', strategy_type='enhanced')
    
    analysis_results = {}
    
    if bot.connect():
        try:
            for symbol in symbols:
                print(f"\n--- Analysing {symbol} ---")
                
                # Run analysis cycle (no trading)
                cycle_result = bot.run_analysis_cycle(symbol)
                analysis_results[symbol] = cycle_result
                
                if 'error' not in cycle_result:
                    print(f"Current Price: £{cycle_result['current_price']:.2f}")
                    print(f"Price Change: {cycle_result['price_change_pct']:+.2f}%")
                    print(f"Position: {cycle_result['position']['shares']} shares")
                    
                    # Technical indicators summary
                    if cycle_result['technical_indicators']:
                        indicators = cycle_result['technical_indicators']
                        print(f"Technical Analysis:")
                        
                        for indicator_name, value in indicators.items():
                            if isinstance(value, (int, float)):
                                if indicator_name == 'rsi':
                                    level = "Oversold" if value < 30 else "Overbought" if value > 70 else "Neutral"
                                    print(f"  {indicator_name.upper()}: {value:.1f} ({level})")
                                elif 'volatility' in indicator_name.lower():
                                    level = "High" if value > 3.0 else "Low" if value < 1.0 else "Normal"
                                    print(f"  {indicator_name}: {value:.2f}% ({level})")
                                elif 'volume' in indicator_name.lower() and 'ratio' in indicator_name.lower():
                                    level = "High" if value > 1.5 else "Low" if value < 0.7 else "Normal"
                                    print(f"  Volume Activity: {value:.1f}x ({level})")
                    
                    # Signal analysis
                    if cycle_result['buy_signals'] and cycle_result['sell_signals']:
                        print(f"Signal Analysis:")
                        print(f"  Buy Signals: {cycle_result['buy_signal_count']}/{len(cycle_result['buy_signals'])}")
                        print(f"  Sell Signals: {cycle_result['sell_signal_count']}/{len(cycle_result['sell_signals'])}")
                        
                        # Determine overall signal
                        if cycle_result['buy_signal_count'] >= len(cycle_result['buy_signals']) // 2:
                            print(f"  Overall Signal: BUY (Strength: {cycle_result['buy_signal_count']}/{len(cycle_result['buy_signals'])})")
                        elif cycle_result['sell_signal_count'] >= len(cycle_result['sell_signals']) // 2:
                            print(f"  Overall Signal: SELL (Strength: {cycle_result['sell_signal_count']}/{len(cycle_result['sell_signals'])})")
                        else:
                            print(f"  Overall Signal: HOLD")
                    
                    # Risk assessment
                    if cycle_result['risk_check']:
                        risk = cycle_result['risk_check']
                        if risk.get('current_pnl_pct'):
                            print(f"  Current P&L: {risk['current_pnl_pct']:+.2f}%")
                        if risk.get('stop_loss'):
                            print(f"  Risk Alert: Stop Loss Triggered")
                        if risk.get('take_profit'):
                            print(f"  Profit Alert: Take Profit Triggered")
                
                else:
                    print(f"Analysis Error: {cycle_result['error']}")
                    
        except Exception as e:
            print(f"Error in enhanced analysis test: {e}")
        finally:
            bot.disconnect()
    else:
        print("Failed to connect to simulator")
    
    return analysis_results


def display_trading_help():
    """Display comprehensive help information for using the enhanced trading bot"""
    help_text = """
    ╔═══════════════════════════════════════════════════════════════════════════════════════╗
                          ENHANCED INTERACTIVE BROKERS TRADING BOT GUIDE
    ╚═══════════════════════════════════════════════════════════════════════════════════════╝

    ENVIRONMENTS:
    • 'paper'     - Paper trading (demo account, port 7497)
    • 'live'      - Live trading (real money, port 7496) 
    • 'simulator' - Enhanced simulator for testing (no IB connection needed)

    ENHANCED QUICK START:

    1. Test Enhanced Connection:
       test_bot_connection('paper')     # Test paper trading with enhanced features
       test_bot_connection('simulator') # Test enhanced simulator

    2. Test Enhanced Historical Data:
       test_historical_data('MRK', 'paper')      # Test real enhanced data
       test_historical_data('MRK', 'simulator')  # Test simulated enhanced data

    3. Run Enhanced Analysis (No Trading):
       results = run_enhanced_analysis_test(['MRK', 'UNH'])  # Comprehensive analysis

    4. Create Enhanced Trading Bot:
       bot = create_trading_bot('paper', 'enhanced')                           # Enhanced strategy
       bot = create_trading_bot('simulator', 'enhanced', short_window=5, long_window=20)
       bot = create_trading_bot('paper', 'enhanced', stop_loss_pct=0.03, take_profit_pct=0.10)

    5. Configure Enhanced Bot:
       bot.set_symbols(['MRK', 'UNH', 'LLY', 'PG'])        # Set symbols
       bot.update_interval = 30                             # Update every 30 seconds
       bot.strategy.stop_loss_pct = 0.05                    # 5% stop loss
       bot.strategy.take_profit_pct = 0.15                  # 15% take profit

    6. Run Enhanced Bot:
       bot.connect()                                        # Connect with enhanced features
       bot.start_trading(max_cycles=10)                     # Run with enhanced monitoring
       bot.disconnect()                                     # Clean disconnect

    7. Enhanced Backtest:
       config = {'short_window': 5, 'long_window': 15, 'stop_loss_pct': 0.03}
       results = run_strategy_backtest(['MRK', 'UNH'], duration_minutes=5, strategy_config=config)

    ENHANCED FEATURES:

    Technical Indicators:
    • RSI (Relative Strength Index) - Momentum oscillator
    • MACD (Moving Average Convergence Divergence) - Trend following
    • Bollinger Bands - Volatility and support/resistance
    • ATR (Average True Range) - Volatility measurement
    • Williams %R - Momentum indicator
    • Volume Analysis - Trading activity assessment
    • Support/Resistance Levels - Key price levels

    Advanced Signal Evaluation:
    • Multi-signal buy/sell decisions (7 different signal types)
    • Trend confirmation using daily data
    • Volume confirmation for signal strength
    • Momentum analysis across multiple timeframes

    Risk Management:
    • Automatic stop loss triggers (default 5%)
    • Take profit targets (default 15%)
    • Position sizing based on volatility
    • Maximum position size limits (default 20% of capital)
    • Real-time P&L monitoring

    Performance Tracking:
    • Win rate calculation
    • Realised and unrealised P&L
    • Trade history and signal logging
    • Comprehensive performance metrics
    • Portfolio value tracking

    Market Analysis:
    • Intraday data: 1-minute bars for up to 30 days
    • Daily data: Daily bars for months/years of history
    • Real-time market data integration
    • Enhanced caching to reduce API calls
    • Multiple symbol bulk analysis

    STRATEGY CONFIGURATION:

    Risk Parameters:
    bot.strategy.stop_loss_pct = 0.05      # 5% stop loss
    bot.strategy.take_profit_pct = 0.15    # 15% take profit  
    bot.strategy.max_position_size = 0.20  # 20% max position size

    Technical Parameters:
    short_window = 10    # Fast moving average period
    long_window = 30     # Slow moving average period

    IMPORTANT SAFETY NOTES:
    • Always test with 'simulator' first for strategy validation
    • Use 'paper' trading for realistic testing without risk
    • Enhanced risk management protects against large losses
    • Monitor technical indicators for market conditions
    • The enhanced strategy uses multiple confirmation signals
    • Real-time P&L tracking helps manage positions actively

    DIAGNOSTIC TOOLS:
    • bot.run_diagnostic_check() - Comprehensive system check
    • bot.get_portfolio_summary() - Detailed portfolio analysis
    • bot.strategy.get_market_overview(symbols) - Multi-symbol analysis
    • run_enhanced_analysis_test() - Strategy testing without trading

    ╔═══════════════════════════════════════════════════════════════════════════════════════╗
    """
    print(help_text)


def create_conservative_bot(environment: str = 'paper') -> IBTradingBot:
    """
    Create a conservative trading bot with enhanced risk management
    
    Args:
        environment: Trading environment
    """
    bot = create_trading_bot(
        environment=environment,
        strategy_type='enhanced',
        short_window=20,
        long_window=50,
        stop_loss_pct=0.03,      # Tight 3% stop loss
        take_profit_pct=0.08,    # Conservative 8% take profit
        max_position_size=0.10,  # Conservative 10% max position size
        name='Conservative_Enhanced'
    )
    
    # Set conservative symbols (large cap, stable stocks)
    bot.set_symbols(['MRK', 'UNH', 'PG', 'KO', 'WMT'])
    bot.update_interval = 60  # Conservative 1-minute updates
    
    return bot


def create_aggressive_bot(environment: str = 'paper') -> IBTradingBot:
    """
    Create an aggressive trading bot for higher risk/reward
    
    Args:
        environment: Trading environment
    """
    bot = create_trading_bot(
        environment=environment,
        strategy_type='enhanced',
        short_window=5,
        long_window=15,
        stop_loss_pct=0.08,      # Wider 8% stop loss
        take_profit_pct=0.25,    # Higher 25% take profit
        max_position_size=0.30,  # Larger 30% max position size
        name='Aggressive_Enhanced'
    )
    
    # Set growth/volatile symbols
    bot.set_symbols(['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG'])
    bot.update_interval = 30  # Faster 30-second updates
    
    return bot


def run_strategy_comparison(symbols: List[str] = None, duration_minutes: int = 10) -> Dict:
    """
    Compare conservative vs aggressive strategies
    
    Args:
        symbols: List of symbols to test
        duration_minutes: Test duration
    """
    print("Running strategy comparison test...")
    
    symbols = symbols or ['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG']
    
    # Conservative strategy configuration
    conservative_config = {
        'short_window': 20,
        'long_window': 50,
        'stop_loss_pct': 0.03,
        'take_profit_pct': 0.08,
        'name': 'Conservative_Test'
    }
    
    # Aggressive strategy configuration
    aggressive_config = {
        'short_window': 5,
        'long_window': 15,
        'stop_loss_pct': 0.08,
        'take_profit_pct': 0.25,
        'name': 'Aggressive_Test'
    }
    
    print(f"Testing {len(symbols)} symbols over {duration_minutes} minutes")
    print(f"Symbols: {symbols}")
    
    # Run both strategies
    print("\n--- Conservative Strategy ---")
    conservative_results = run_strategy_backtest(
        symbols, duration_minutes, conservative_config
    )
    
    print("\n--- Aggressive Strategy ---")
    aggressive_results = run_strategy_backtest(
        symbols, duration_minutes, aggressive_config
    )
    
    # Compare results
    if conservative_results and aggressive_results:
        print("\n" + "="*60)
        print("STRATEGY COMPARISON RESULTS")
        print("="*60)
        
        comparison = {
            'conservative': {
                'return_pct': conservative_results['return_percentage'],
                'trades': conservative_results['total_trades'],
                'win_rate': conservative_results['strategy_performance'].get('win_rate', 0),
                'final_value': conservative_results['portfolio_value']
            },
            'aggressive': {
                'return_pct': aggressive_results['return_percentage'],
                'trades': aggressive_results['total_trades'],
                'win_rate': aggressive_results['strategy_performance'].get('win_rate', 0),
                'final_value': aggressive_results['portfolio_value']
            }
        }
        
        print(f"Conservative Strategy:")
        print(f"  Return: {comparison['conservative']['return_pct']:+.2f}%")
        print(f"  Trades: {comparison['conservative']['trades']}")
        print(f"  Win Rate: {comparison['conservative']['win_rate']:.1f}%")
        print(f"  Final Value: £{comparison['conservative']['final_value']:.2f}")
        
        print(f"\nAggressive Strategy:")
        print(f"  Return: {comparison['aggressive']['return_pct']:+.2f}%")
        print(f"  Trades: {comparison['aggressive']['trades']}")
        print(f"  Win Rate: {comparison['aggressive']['win_rate']:.1f}%")
        print(f"  Final Value: £{comparison['aggressive']['final_value']:.2f}")
        
        # Determine winner
        conservative_score = comparison['conservative']['return_pct']
        aggressive_score = comparison['aggressive']['return_pct']
        
        if conservative_score > aggressive_score:
            winner = "Conservative"
            margin = conservative_score - aggressive_score
        elif aggressive_score > conservative_score:
            winner = "Aggressive"
            margin = aggressive_score - conservative_score
        else:
            winner = "Tie"
            margin = 0
        
        print(f"\nWinner: {winner} Strategy" + (f" (by {margin:.2f}%)" if margin > 0 else ""))
        print("="*60)
        
        return {
            'comparison': comparison,
            'winner': winner,
            'margin': margin,
            'conservative_results': conservative_results,
            'aggressive_results': aggressive_results
        }
    
    return {}


def run_multi_symbol_analysis(symbols: List[str] = None) -> Dict:
    """
    Run multi-symbol market analysis
    
    Args:
        symbols: List of symbols to analyse
    """
    symbols = symbols or ['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG']
    print(f"Running multi-symbol enhanced analysis for {len(symbols)} symbols...")
    
    bot = create_trading_bot('simulator', strategy_type='enhanced')
    
    if bot.connect():
        try:
            # Get market overview
            overview = bot.strategy.get_market_overview(symbols)
            
            print(f"\nMarket Overview:")
            print(f"Symbols Analysed: {len(overview['symbols_analysis'])}")
            print(f"Active Positions: {overview['total_positions']}")
            
            # Analyse each symbol
            market_conditions = {
                'bullish_signals': [],
                'bearish_signals': [],
                'neutral_signals': [],
                'high_volatility': [],
                'oversold': [],
                'overbought': []
            }
            
            for symbol in symbols:
                try:
                    cycle_result = bot.run_analysis_cycle(symbol)
                    
                    if 'error' not in cycle_result:
                        # Categorise market signals
                        buy_strength = cycle_result.get('buy_signal_count', 0)
                        sell_strength = cycle_result.get('sell_signal_count', 0)
                        buy_total = len(cycle_result.get('buy_signals', []))
                        sell_total = len(cycle_result.get('sell_signals', []))
                        
                        if buy_total > 0 and buy_strength >= buy_total // 2:
                            market_conditions['bullish_signals'].append(symbol)
                        elif sell_total > 0 and sell_strength >= sell_total // 2:
                            market_conditions['bearish_signals'].append(symbol)
                        else:
                            market_conditions['neutral_signals'].append(symbol)
                        
                        # Check technical conditions
                        indicators = cycle_result.get('technical_indicators', {})
                        if indicators:
                            if indicators.get('volatility', 0) > 3.0:
                                market_conditions['high_volatility'].append(symbol)
                            if indicators.get('rsi', 50) < 30:
                                market_conditions['oversold'].append(symbol)
                            elif indicators.get('rsi', 50) > 70:
                                market_conditions['overbought'].append(symbol)
                        
                        print(f"  {symbol}: £{cycle_result['current_price']:.2f} "
                              f"({cycle_result['price_change_pct']:+.2f}%) - "
                              f"Buy: {buy_strength}/{buy_total}, Sell: {sell_strength}/{sell_total}")
                        
                except Exception as e:
                    print(f"  {symbol}: Analysis error - {e}")
            
            # Display market conditions summary
            print(f"\nMarket Conditions Summary:")
            print(f"  Bullish Signals: {market_conditions['bullish_signals']}")
            print(f"  Bearish Signals: {market_conditions['bearish_signals']}")
            print(f"  Neutral/Hold: {market_conditions['neutral_signals']}")
            print(f"  High Volatility: {market_conditions['high_volatility']}")
            print(f"  Oversold (RSI < 30): {market_conditions['oversold']}")
            print(f"  Overbought (RSI > 70): {market_conditions['overbought']}")
            
            bot.disconnect()
            return market_conditions
            
        except Exception as e:
            print(f"Error in multi-symbol analysis: {e}")
            bot.disconnect()
            return {}
    else:
        print("Failed to connect to simulator")
        return {}


print("Enhanced Configuration and Testing Functions created")

print("\nAvailable Commands:")
print("• test_bot_connection('simulator')                    # Test enhanced simulator")
print("• test_historical_data('MRK', 'simulator')            # Test enhanced data analysis")
print("• run_enhanced_analysis_test(['MRK', 'UNH'])          # Analysis without trading")
print("• run_strategy_backtest(symbols, duration, config)    # Enhanced backtest")
print("• run_strategy_comparison(['MRK', 'UNH'], 10)         # Compare strategies")
print("• run_multi_symbol_analysis(['MRK', 'UNH', 'LLY'])    # Multi-symbol analysis")
print("• create_conservative_bot('simulator')                # Conservative strategy")
print("• create_aggressive_bot('simulator')                  # Aggressive strategy")

print("\nStrategy Types:")
print("• 'enhanced' - Advanced multi-indicator strategy (recommended)")
print("• 'sma'      - Simple moving average strategy (legacy)")

print("\nSafety Reminder: Always test with simulator and paper trading before live trading!")
# Out:
# Enhanced Configuration and Testing Functions created
#
# Available Commands:
# • test_bot_connection('simulator')                    # Test enhanced simulator
# • test_historical_data('MRK', 'simulator')            # Test enhanced data analysis
# • run_enhanced_analysis_test(['MRK', 'UNH'])          # Analysis without trading
# • run_strategy_backtest(symbols, duration, config)    # Enhanced backtest
# • run_strategy_comparison(['MRK', 'UNH'], 10)         # Compare strategies
# • run_multi_symbol_analysis(['MRK', 'UNH', 'LLY'])    # Multi-symbol analysis
# • create_conservative_bot('simulator')                # Conservative strategy
# • create_aggressive_bot('simulator')                  # Aggressive strategy
#
# Strategy Types:
# • 'enhanced' - Advanced multi-indicator strategy (recommended)
# • 'sma'      - Simple moving average strategy (legacy)
#
# Safety Reminder: Always test with simulator and paper trading before live trading!

# %% [markdown]
# ### Test Simulator Connection

# %%
print("="*60)
print("Enhanced Simulator Connection Test")
print("="*60)

# Test basic simulator connection
print("1. Testing Basic Simulator Connection:")
basic_connection_success = test_bot_connection('simulator')

if basic_connection_success:
    print("\n2. Testing Enhanced Analysis Features:")
    
    # Test enhanced analysis without trading
    analysis_results = run_enhanced_analysis_test(['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG'])
    
    if analysis_results:
        print(f"\nAnalysis completed for {len(analysis_results)} symbols")
        
        # Show summary of analysis results
        for symbol, result in analysis_results.items():
            if 'error' not in result:
                print(f"\n{symbol} Analysis Summary:")
                print(f"  Current Price: £{result['current_price']:.2f}")
                print(f"  Price Change: {result['price_change_pct']:+.2f}%")
                
                # Signal summary
                if result.get('buy_signals') and result.get('sell_signals'):
                    buy_count = result['buy_signal_count']
                    sell_count = result['sell_signal_count']
                    buy_total = len(result['buy_signals'])
                    sell_total = len(result['sell_signals'])
                    
                    signal_interpretation = "BUY" if buy_count >= buy_total//2 else \
                                          "SELL" if sell_count >= sell_total//2 else "HOLD"
                    
                    print(f"  Trading Signal: {signal_interpretation} (Buy: {buy_count}/{buy_total}, Sell: {sell_count}/{sell_total})")
                
                # Technical indicators summary
                if result.get('technical_indicators'):
                    indicators = result['technical_indicators']
                    tech_summary = []
                    
                    if 'rsi' in indicators:
                        rsi_level = "Oversold" if indicators['rsi'] < 30 else \
                                   "Overbought" if indicators['rsi'] > 70 else "Neutral"
                        tech_summary.append(f"RSI: {rsi_level}")
                    
                    if 'volatility' in indicators:
                        vol_level = "High" if indicators['volatility'] > 3.0 else \
                                   "Low" if indicators['volatility'] < 1.0 else "Normal"
                        tech_summary.append(f"Volatility: {vol_level}")
                    
                    if tech_summary:
                        print(f"  Market Conditions: {', '.join(tech_summary)}")
            else:
                print(f"\n{symbol}: Analysis Error - {result['error']}")

print("\n3. Testing Multi-Symbol Market Analysis:")

# Test multi-symbol analysis
market_conditions = run_multi_symbol_analysis(['MRK', 'UNH', 'LLY', 'PG'])

if market_conditions:
    print(f"\nMarket Sentiment Analysis:")
    total_symbols = len(market_conditions['bullish_signals']) + \
                   len(market_conditions['bearish_signals']) + \
                   len(market_conditions['neutral_signals'])
    
    if total_symbols > 0:
        bullish_pct = (len(market_conditions['bullish_signals']) / total_symbols) * 100
        bearish_pct = (len(market_conditions['bearish_signals']) / total_symbols) * 100
        neutral_pct = (len(market_conditions['neutral_signals']) / total_symbols) * 100
        
        print(f"  Bullish: {bullish_pct:.0f}% ({len(market_conditions['bullish_signals'])} symbols)")
        print(f"  Bearish: {bearish_pct:.0f}% ({len(market_conditions['bearish_signals'])} symbols)")
        print(f"  Neutral: {neutral_pct:.0f}% ({len(market_conditions['neutral_signals'])} symbols)")
        
        if market_conditions['high_volatility']:
            print(f"  High Volatility Warning: {market_conditions['high_volatility']}")

print("\n4. Testing Strategy Configuration:")

# Test different strategy configurations
print("\nTesting Conservative Strategy Configuration:")
conservative_bot = create_conservative_bot('simulator')
if conservative_bot.connect():
    print(f"  Strategy: {conservative_bot.strategy.name}")
    print(f"  Risk Management: Stop Loss {conservative_bot.strategy.stop_loss_pct*100:.1f}%, Take Profit {conservative_bot.strategy.take_profit_pct*100:.1f}%")
    print(f"  Position Sizing: Max {conservative_bot.strategy.max_position_size*100:.0f}% per position")
    print(f"  Symbols: {conservative_bot.symbols}")
    conservative_bot.disconnect()

print("\nTesting Aggressive Strategy Configuration:")
aggressive_bot = create_aggressive_bot('simulator')
if aggressive_bot.connect():
    print(f"  Strategy: {aggressive_bot.strategy.name}")
    print(f"  Risk Management: Stop Loss {aggressive_bot.strategy.stop_loss_pct*100:.1f}%, Take Profit {aggressive_bot.strategy.take_profit_pct*100:.1f}%")
    print(f"  Position Sizing: Max {aggressive_bot.strategy.max_position_size*100:.0f}% per position")
    print(f"  Symbols: {aggressive_bot.symbols}")
    aggressive_bot.disconnect()

print("\n5. Testing Custom Strategy Configuration:")

# Test custom strategy with specific parameters
custom_strategy_config = {
    'short_window': 8,
    'long_window': 21,
    'stop_loss_pct': 0.04,
    'take_profit_pct': 0.12,
    'max_position_size': 0.15,
    'name': 'Custom_Test_Strategy'
}

custom_bot = create_trading_bot(
    'simulator',
    strategy_type='enhanced',
    **custom_strategy_config
)

if custom_bot.connect():
    print(f"  Custom Strategy: {custom_bot.strategy.name}")
    print(f"  Moving Averages: {custom_bot.strategy.short_window}/{custom_bot.strategy.long_window}")
    print(f"  Risk Parameters: SL {custom_bot.strategy.stop_loss_pct*100:.1f}%, TP {custom_bot.strategy.take_profit_pct*100:.1f}%")
    
    # Test diagnostic check
    print(f"\n  Running Diagnostic Check:")
    diagnostics = custom_bot.run_diagnostic_check()
    
    if diagnostics:
        print(f"    Connection Status: {'Connected' if diagnostics['connection_status'] else 'Disconnected'}")
        
        components = diagnostics['components_initialised']
        initialised_count = sum(components.values())
        print(f"    Components Initialised: {initialised_count}/4")
        
        if diagnostics.get('data_availability'):
            available_data = sum(1 for symbol_data in diagnostics['data_availability'].values() 
                               if symbol_data.get('available', False))
            total_tested = len(diagnostics['data_availability'])
            print(f"    Data Availability: {available_data}/{total_tested} symbols")
    
    custom_bot.disconnect()

print("\n6. Testing Signal Evaluation System:")

# Create a bot specifically for signal testing
signal_test_bot = create_trading_bot('simulator', strategy_type='enhanced', short_window=5, long_window=15)

if signal_test_bot.connect():
    test_symbol = 'MRK'
    print(f"\nTesting signal evaluation for {test_symbol}:")
    
    try:
        # Get enhanced analysis
        analysis = signal_test_bot.get_enhanced_market_analysis(test_symbol)
        
        if analysis and analysis.get('technical_indicators'):
            indicators = analysis['technical_indicators']
            
            # Test buy signals
            buy_signals = signal_test_bot.strategy.evaluate_buy_signals(test_symbol, analysis, indicators)
            sell_signals = signal_test_bot.strategy.evaluate_sell_signals(test_symbol, analysis, indicators)
            
            print(f"  Current Price: £{analysis['last']:.2f}")
            print(f"  Buy Signal Types Active: {sum(buy_signals)}/{len(buy_signals)}")
            print(f"  Sell Signal Types Active: {sum(sell_signals)}/{len(sell_signals)}")
            
            # Show which specific signal types are active
            signal_names = [
                "SMA Crossover", "RSI Level", "Bollinger Position", 
                "MACD Trend", "Volume Confirmation", "Momentum", "Williams %R"
            ]
            
            active_buy_signals = [signal_names[i] for i, active in enumerate(buy_signals) if active]
            active_sell_signals = [signal_names[i] for i, active in enumerate(sell_signals) if active]
            
            if active_buy_signals:
                print(f"  Active Buy Signals: {', '.join(active_buy_signals)}")
            if active_sell_signals:
                print(f"  Active Sell Signals: {', '.join(active_sell_signals)}")
            
            # Test risk management
            risk_check = signal_test_bot.strategy.check_risk_management(test_symbol, analysis)
            print(f"  Risk Level: {risk_check.get('risk_level', 'Normal')}")
            
        else:
            print(f"  Enhanced analysis not available for {test_symbol}")
            
    except Exception as e:
        print(f"  Signal evaluation error: {e}")
    
    signal_test_bot.disconnect()

print("\n" + "="*60)
print("Enhanced Simulator Tests Completed")
print("="*60)
print("All enhanced features tested successfully!")
print("\nNext Steps:")
print("• Run enhanced backtest: run_strategy_backtest(['MRK', 'UNH'], 5)")
print("• Compare strategies: run_strategy_comparison(['MRK', 'UNH'], 5)")
print("• Test paper trading: test_bot_connection('paper')")
print("="*60)
# Out:
# 2025-09-01 12:48:36,444 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,446 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,446 - INFO - Strategy: Enhanced_10_30
# 2025-09-01 12:48:36,447 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,447 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,462 - INFO - Enhanced simulated analysis for MRK: £181.43 (+0.00%)
# 2025-09-01 12:48:36,463 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,464 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,464 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,464 - INFO - Strategy: Enhanced_10_30
# 2025-09-01 12:48:36,465 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,465 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,476 - INFO - Enhanced simulated analysis for ABCL: £380.75 (+0.00%)
# 2025-09-01 12:48:36,483 - INFO - Enhanced simulated analysis for ALLO: £123.95 (+0.00%)
# 2025-09-01 12:48:36,491 - INFO - Enhanced simulated analysis for ANNX: £456.84 (+0.00%)
# 2025-09-01 12:48:36,498 - INFO - Enhanced simulated analysis for ANRO: £73.79 (+0.00%)
# 2025-09-01 12:48:36,504 - INFO - Enhanced simulated analysis for ANVS: £487.85 (+0.00%)
# 2025-09-01 12:48:36,511 - INFO - Enhanced simulated analysis for APLM: £440.95 (+0.00%)
# 2025-09-01 12:48:36,518 - INFO - Enhanced simulated analysis for APLT: £301.14 (+0.00%)
# 2025-09-01 12:48:36,524 - INFO - Enhanced simulated analysis for APVO: £390.16 (+0.00%)
# 2025-09-01 12:48:36,530 - INFO - Enhanced simulated analysis for ARAY: £253.33 (+0.00%)
# 2025-09-01 12:48:36,537 - INFO - Enhanced simulated analysis for ARBE: £364.22 (+0.00%)
# 2025-09-01 12:48:36,543 - INFO - Enhanced simulated analysis for ATEN: £486.65 (+0.00%)
# 2025-09-01 12:48:36,549 - INFO - Enhanced simulated analysis for ATAI: £486.11 (+0.00%)
# 2025-09-01 12:48:36,555 - INFO - Enhanced simulated analysis for ATHA: £390.79 (+0.00%)
# 2025-09-01 12:48:36,561 - INFO - Enhanced simulated analysis for AUTL: £423.17 (+0.00%)
# 2025-09-01 12:48:36,567 - INFO - Enhanced simulated analysis for AVIR: £463.10 (+0.00%)
# 2025-09-01 12:48:36,573 - INFO - Enhanced simulated analysis for CABA: £229.44 (+0.00%)
# 2025-09-01 12:48:36,579 - INFO - Enhanced simulated analysis for CAMP: £183.98 (+0.00%)
# 2025-09-01 12:48:36,585 - INFO - Enhanced simulated analysis for CARM: £291.33 (+0.00%)
# 2025-09-01 12:48:36,591 - INFO - Enhanced simulated analysis for CATX: £168.28 (+0.00%)
# 2025-09-01 12:48:36,598 - INFO - Enhanced simulated analysis for CCCC: £420.78 (+0.00%)
# 2025-09-01 12:48:36,604 - INFO - Enhanced simulated analysis for CELU: £368.85 (+0.00%)
# 2025-09-01 12:48:36,610 - INFO - Enhanced simulated analysis for CERS: £137.52 (+0.00%)
# 2025-09-01 12:48:36,616 - INFO - Enhanced simulated analysis for CGTX: £250.10 (+0.00%)
# 2025-09-01 12:48:36,622 - INFO - Enhanced simulated analysis for CHRS: £198.35 (+0.00%)
# 2025-09-01 12:48:36,629 - INFO - Enhanced simulated analysis for CLDI: £347.40 (+0.00%)
# 2025-09-01 12:48:36,635 - INFO - Enhanced simulated analysis for CLLS: £301.06 (+0.00%)
# 2025-09-01 12:48:36,641 - INFO - Enhanced simulated analysis for CLRB: £98.49 (+0.00%)
# ============================================================
# Enhanced Simulator Connection Test
# ============================================================
# 1. Testing Basic Simulator Connection:
# Testing simulator trading connection...
# Simulator connection test passed
#
# Testing enhanced strategy features:
#   MRK Indicators:
#     RSI: 41.1
#     MACD: 0.274
#     Volatility: 0.2%
#     Bollinger Band Width: 1.3%
#
# 2. Testing Enhanced Analysis Features:
# Running enhanced analysis test for: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
#
# --- Analysing ABCL ---
# Current Price: £380.75
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 49.3 (Neutral)
#   Volume Activity: 1.1x (Normal)
#   volatility: 0.25% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing ALLO ---
# Current Price: £123.95
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 48.5 (Neutral)
#   Volume Activity: 0.2x (Low)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing ANNX ---
# Current Price: £456.84
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 56.9 (Neutral)
#   Volume Activity: 0.9x (Normal)
#   volatility: 0.25% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing ANRO ---
# Current Price: £73.79
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 72.7 (Overbought)
#   Volume Activity: 0.6x (Low)
#   volatility: 0.25% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing ANVS ---
# Current Price: £487.85
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 51.7 (Neutral)
#   Volume Activity: 0.7x (Normal)
#   volatility: 0.24% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing APLM ---
# Current Price: £440.95
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 26.9 (Oversold)
#   Volume Activity: 1.5x (High)
#   volatility: 0.27% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 3/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing APLT ---
# Current Price: £301.14
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 62.2 (Neutral)
#   Volume Activity: 1.4x (Normal)
#   volatility: 0.21% (Low)
# Signal Analysis:
#   Buy Signals: 4/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 4/7)
#
# --- Analysing APVO ---
# Current Price: £390.16
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 83.7 (Overbought)
#   Volume Activity: 1.6x (High)
#   volatility: 0.11% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing ARAY ---
# Current Price: £253.33
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 76.1 (Overbought)
#   Volume Activity: 1.9x (High)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing ARBE ---
# Current Price: £364.22
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 48.7 (Neutral)
#   Volume Activity: 1.3x (Normal)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 3/7
#   Overall Signal: SELL (Strength: 3/7)
#
# --- Analysing ATEN ---
# Current Price: £486.65
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 58.7 (Neutral)
#   Volume Activity: 1.0x (Normal)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing ATAI ---
# Current Price: £486.11
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 74.5 (Overbought)
#   Volume Activity: 1.6x (High)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 4/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 4/7)
#
# --- Analysing ATHA ---
# Current Price: £390.79
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 55.8 (Neutral)
#   Volume Activity: 1.1x (Normal)
#   volatility: 0.26% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing AUTL ---
# Current Price: £423.17
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 64.3 (Neutral)
#   Volume Activity: 1.5x (High)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing AVIR ---
# Current Price: £463.10
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 70.4 (Overbought)
#   Volume Activity: 0.5x (Low)
#   volatility: 0.15% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CABA ---
# Current Price: £229.44
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 81.3 (Overbought)
#   Volume Activity: 0.5x (Low)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CAMP ---
# Current Price: £183.98
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 55.5 (Neutral)
#   Volume Activity: 1.9x (High)
#   volatility: 0.21% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 0/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CARM ---
# Current Price: £291.33
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 45.4 (Neutral)
#   Volume Activity: 1.2x (Normal)
#   volatility: 0.24% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CATX ---
# Current Price: £168.28
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 40.5 (Neutral)
#   Volume Activity: 2.3x (High)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CCCC ---
# Current Price: £420.78
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 56.2 (Neutral)
#   Volume Activity: 0.3x (Low)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CELU ---
# Current Price: £368.85
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 66.1 (Neutral)
#   Volume Activity: 1.2x (Normal)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CERS ---
# Current Price: £137.52
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 59.6 (Neutral)
#   Volume Activity: 1.8x (High)
#   volatility: 0.23% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CGTX ---
# Current Price: £250.10
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 56.5 (Neutral)
#   Volume Activity: 0.4x (Low)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CHRS ---
# Current Price: £198.35
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 59.0 (Neutral)
#   Volume Activity: 0.5x (Low)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CLDI ---
# Current Price: £347.40
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 38.7 (Neutral)
#   Volume Activity: 0.3x (Low)
#   volatility: 0.24% (Low)
# Signal Analysis:
#   Buy Signals: 0/7
#   Sell Signals: 3/7
#   Overall Signal: SELL (Strength: 3/7)
#
# --- Analysing CLLS ---
# Current Price: £301.06
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 67.9 (Neutral)
#   Volume Activity: 0.5x (Low)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 0/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CLRB ---
# Current Price: £98.49
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 69.6 (Neutral)
#   Volume Activity: 1.8x (High)
#   volatility: 0.21% (Low)
# Signal Analysis:
#   Buy Signals: 4/7
#   Sell Signals: 0/7
#   Overall Signal: BUY (Strength: 4/7)
#
# --- Analysing CLSD ---
# 2025-09-01 12:48:36,648 - INFO - Enhanced simulated analysis for CLSD: £214.04 (+0.00%)
# 2025-09-01 12:48:36,674 - INFO - Enhanced simulated analysis for CLYM: £367.16 (+0.00%)
# 2025-09-01 12:48:36,686 - INFO - Enhanced simulated analysis for CMPS: £59.83 (+0.00%)
# 2025-09-01 12:48:36,695 - INFO - Enhanced simulated analysis for CMPX: £495.00 (+0.00%)
# 2025-09-01 12:48:36,702 - INFO - Enhanced simulated analysis for CMTL: £211.22 (+0.00%)
# 2025-09-01 12:48:36,708 - INFO - Enhanced simulated analysis for COCP: £274.76 (+0.00%)
# 2025-09-01 12:48:36,715 - INFO - Enhanced simulated analysis for CRBU: £131.13 (+0.00%)
# 2025-09-01 12:48:36,721 - INFO - Enhanced simulated analysis for CRDF: £58.42 (+0.00%)
# 2025-09-01 12:48:36,728 - INFO - Enhanced simulated analysis for CRDL: £483.59 (+0.00%)
# 2025-09-01 12:48:36,734 - INFO - Enhanced simulated analysis for CRIS: £77.98 (+0.00%)
# 2025-09-01 12:48:36,740 - INFO - Enhanced simulated analysis for CTMX: £316.97 (+0.00%)
# 2025-09-01 12:48:36,746 - INFO - Enhanced simulated analysis for CTOR: £346.83 (+0.00%)
# 2025-09-01 12:48:36,753 - INFO - Enhanced simulated analysis for CTXR: £252.58 (+0.00%)
# 2025-09-01 12:48:36,759 - INFO - Enhanced simulated analysis for CUE: £308.04 (+0.00%)
# 2025-09-01 12:48:36,765 - INFO - Enhanced simulated analysis for CURR: £466.35 (+0.00%)
# 2025-09-01 12:48:36,771 - INFO - Enhanced simulated analysis for DARE: £213.26 (+0.00%)
# 2025-09-01 12:48:36,777 - INFO - Enhanced simulated analysis for DTIL: £253.32 (+0.00%)
# 2025-09-01 12:48:36,783 - INFO - Enhanced simulated analysis for EDIT: £384.28 (+0.00%)
# 2025-09-01 12:48:36,789 - INFO - Enhanced simulated analysis for ELDN: £270.65 (+0.00%)
# 2025-09-01 12:48:36,795 - INFO - Enhanced simulated analysis for EQ: £466.26 (+0.00%)
# 2025-09-01 12:48:36,801 - INFO - Enhanced simulated analysis for ERAS: £203.95 (+0.00%)
# 2025-09-01 12:48:36,808 - INFO - Enhanced simulated analysis for ERNA: £297.34 (+0.00%)
# 2025-09-01 12:48:36,814 - INFO - Enhanced simulated analysis for ESLA: £119.29 (+0.00%)
# 2025-09-01 12:48:36,820 - INFO - Enhanced simulated analysis for ESPR: £80.55 (+0.00%)
# 2025-09-01 12:48:36,826 - INFO - Enhanced simulated analysis for EVGN: £376.66 (+0.00%)
# 2025-09-01 12:48:36,832 - INFO - Enhanced simulated analysis for FATE: £168.46 (+0.00%)
# 2025-09-01 12:48:36,839 - INFO - Enhanced simulated analysis for FBLG: £445.59 (+0.00%)
# 2025-09-01 12:48:36,839 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,840 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,840 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,841 - INFO - Strategy: Enhanced_10_30
# 2025-09-01 12:48:36,841 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,842 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,849 - INFO - Enhanced simulated analysis for MRK: £181.55 (+0.00%)
# 2025-09-01 12:48:36,855 - INFO - Enhanced simulated analysis for UNH: £855.63 (+0.00%)
# 2025-09-01 12:48:36,861 - INFO - Enhanced simulated analysis for LLY: £375.74 (+0.00%)
# Current Price: £214.04
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 72.0 (Overbought)
#   Volume Activity: 0.8x (Normal)
#   volatility: 0.26% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CLYM ---
# Current Price: £367.16
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 63.9 (Neutral)
#   Volume Activity: 0.6x (Low)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CMPS ---
# Current Price: £59.83
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 49.0 (Neutral)
#   Volume Activity: 0.8x (Normal)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CMPX ---
# Current Price: £495.00
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 56.6 (Neutral)
#   Volume Activity: 0.9x (Normal)
#   volatility: 0.26% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CMTL ---
# Current Price: £211.22
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 54.4 (Neutral)
#   Volume Activity: 1.4x (Normal)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing COCP ---
# Current Price: £274.76
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 36.8 (Neutral)
#   Volume Activity: 1.3x (Normal)
#   volatility: 0.16% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CRBU ---
# Current Price: £131.13
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 54.4 (Neutral)
#   Volume Activity: 0.6x (Low)
#   volatility: 0.30% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CRDF ---
# Current Price: £58.42
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 68.7 (Neutral)
#   Volume Activity: 1.6x (High)
#   volatility: 0.24% (Low)
# Signal Analysis:
#   Buy Signals: 4/7
#   Sell Signals: 0/7
#   Overall Signal: BUY (Strength: 4/7)
#
# --- Analysing CRDL ---
# Current Price: £483.59
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 18.8 (Oversold)
#   Volume Activity: 0.4x (Low)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 4/7
#   Overall Signal: SELL (Strength: 4/7)
#
# --- Analysing CRIS ---
# Current Price: £77.98
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 42.0 (Neutral)
#   Volume Activity: 1.8x (High)
#   volatility: 0.16% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing CTMX ---
# Current Price: £316.97
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 80.5 (Overbought)
#   Volume Activity: 0.6x (Low)
#   volatility: 0.15% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CTOR ---
# Current Price: £346.83
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 80.2 (Overbought)
#   Volume Activity: 0.3x (Low)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing CTXR ---
# Current Price: £252.58
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 45.3 (Neutral)
#   Volume Activity: 1.2x (Normal)
#   volatility: 0.17% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing CUE ---
# Current Price: £308.04
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 41.9 (Neutral)
#   Volume Activity: 0.5x (Low)
#   volatility: 0.16% (Low)
# Signal Analysis:
#   Buy Signals: 0/7
#   Sell Signals: 3/7
#   Overall Signal: SELL (Strength: 3/7)
#
# --- Analysing CURR ---
# Current Price: £466.35
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 69.4 (Neutral)
#   Volume Activity: 0.2x (Low)
#   volatility: 0.15% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing DARE ---
# Current Price: £213.26
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 33.4 (Neutral)
#   Volume Activity: 1.6x (High)
#   volatility: 0.24% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 2/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing DTIL ---
# Current Price: £253.32
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 55.1 (Neutral)
#   Volume Activity: 0.9x (Normal)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing EDIT ---
# Current Price: £384.28
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 40.1 (Neutral)
#   Volume Activity: 0.9x (Normal)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing ELDN ---
# Current Price: £270.65
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 39.8 (Neutral)
#   Volume Activity: 0.6x (Low)
#   volatility: 0.17% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing EQ ---
# Current Price: £466.26
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 44.2 (Neutral)
#   Volume Activity: 1.1x (Normal)
#   volatility: 0.23% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 1/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing ERAS ---
# Current Price: £203.95
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 38.8 (Neutral)
#   Volume Activity: 2.3x (High)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing ERNA ---
# Current Price: £297.34
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 39.9 (Neutral)
#   Volume Activity: 0.3x (Low)
#   volatility: 0.18% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing ESLA ---
# Current Price: £119.29
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 48.3 (Neutral)
#   Volume Activity: 0.9x (Normal)
#   volatility: 0.20% (Low)
# Signal Analysis:
#   Buy Signals: 3/7
#   Sell Signals: 0/7
#   Overall Signal: BUY (Strength: 3/7)
#
# --- Analysing ESPR ---
# Current Price: £80.55
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 43.9 (Neutral)
#   Volume Activity: 0.8x (Normal)
#   volatility: 0.22% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 1/7
#   Overall Signal: HOLD
#
# --- Analysing EVGN ---
# Current Price: £376.66
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 37.6 (Neutral)
#   Volume Activity: 0.7x (Normal)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 3/7
#   Overall Signal: SELL (Strength: 3/7)
#
# --- Analysing FATE ---
# Current Price: £168.46
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 35.4 (Neutral)
#   Volume Activity: 1.1x (Normal)
#   volatility: 0.16% (Low)
# Signal Analysis:
#   Buy Signals: 1/7
#   Sell Signals: 2/7
#   Overall Signal: HOLD
#
# --- Analysing FBLG ---
# Current Price: £445.59
# Price Change: +0.00%
# Position: 0 shares
# Technical Analysis:
#   RSI: 25.1 (Oversold)
#   Volume Activity: 1.1x (Normal)
#   volatility: 0.19% (Low)
# Signal Analysis:
#   Buy Signals: 2/7
#   Sell Signals: 3/7
#   Overall Signal: SELL (Strength: 3/7)
#
# Analysis completed for 54 symbols
#
# ABCL Analysis Summary:
#   Current Price: £380.75
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ALLO Analysis Summary:
#   Current Price: £123.95
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ANNX Analysis Summary:
#   Current Price: £456.84
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ANRO Analysis Summary:
#   Current Price: £73.79
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# ANVS Analysis Summary:
#   Current Price: £487.85
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# APLM Analysis Summary:
#   Current Price: £440.95
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 3/7)
#   Market Conditions: RSI: Oversold, Volatility: Low
#
# APLT Analysis Summary:
#   Current Price: £301.14
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 4/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# APVO Analysis Summary:
#   Current Price: £390.16
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# ARAY Analysis Summary:
#   Current Price: £253.33
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# ARBE Analysis Summary:
#   Current Price: £364.22
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 1/7, Sell: 3/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ATEN Analysis Summary:
#   Current Price: £486.65
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ATAI Analysis Summary:
#   Current Price: £486.11
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 4/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# ATHA Analysis Summary:
#   Current Price: £390.79
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# AUTL Analysis Summary:
#   Current Price: £423.17
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# AVIR Analysis Summary:
#   Current Price: £463.10
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# CABA Analysis Summary:
#   Current Price: £229.44
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# CAMP Analysis Summary:
#   Current Price: £183.98
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 0/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CARM Analysis Summary:
#   Current Price: £291.33
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CATX Analysis Summary:
#   Current Price: £168.28
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CCCC Analysis Summary:
#   Current Price: £420.78
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CELU Analysis Summary:
#   Current Price: £368.85
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CERS Analysis Summary:
#   Current Price: £137.52
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CGTX Analysis Summary:
#   Current Price: £250.10
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CHRS Analysis Summary:
#   Current Price: £198.35
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CLDI Analysis Summary:
#   Current Price: £347.40
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 0/7, Sell: 3/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CLLS Analysis Summary:
#   Current Price: £301.06
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 0/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CLRB Analysis Summary:
#   Current Price: £98.49
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 4/7, Sell: 0/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CLSD Analysis Summary:
#   Current Price: £214.04
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# CLYM Analysis Summary:
#   Current Price: £367.16
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CMPS Analysis Summary:
#   Current Price: £59.83
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CMPX Analysis Summary:
#   Current Price: £495.00
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CMTL Analysis Summary:
#   Current Price: £211.22
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# COCP Analysis Summary:
#   Current Price: £274.76
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CRBU Analysis Summary:
#   Current Price: £131.13
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CRDF Analysis Summary:
#   Current Price: £58.42
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 4/7, Sell: 0/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CRDL Analysis Summary:
#   Current Price: £483.59
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 1/7, Sell: 4/7)
#   Market Conditions: RSI: Oversold, Volatility: Low
#
# CRIS Analysis Summary:
#   Current Price: £77.98
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CTMX Analysis Summary:
#   Current Price: £316.97
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# CTOR Analysis Summary:
#   Current Price: £346.83
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 2/7)
#   Market Conditions: RSI: Overbought, Volatility: Low
#
# CTXR Analysis Summary:
#   Current Price: £252.58
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CUE Analysis Summary:
#   Current Price: £308.04
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 0/7, Sell: 3/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# CURR Analysis Summary:
#   Current Price: £466.35
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# DARE Analysis Summary:
#   Current Price: £213.26
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# DTIL Analysis Summary:
#   Current Price: £253.32
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# EDIT Analysis Summary:
#   Current Price: £384.28
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ELDN Analysis Summary:
#   Current Price: £270.65
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# EQ Analysis Summary:
#   Current Price: £466.26
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ERAS Analysis Summary:
#   Current Price: £203.95
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ERNA Analysis Summary:
#   Current Price: £297.34
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ESLA Analysis Summary:
#   Current Price: £119.29
#   Price Change: +0.00%
#   Trading Signal: BUY (Buy: 3/7, Sell: 0/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# ESPR Analysis Summary:
#   Current Price: £80.55
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 2/7, Sell: 1/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# EVGN Analysis Summary:
#   Current Price: £376.66
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 1/7, Sell: 3/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# FATE Analysis Summary:
#   Current Price: £168.46
#   Price Change: +0.00%
#   Trading Signal: HOLD (Buy: 1/7, Sell: 2/7)
#   Market Conditions: RSI: Neutral, Volatility: Low
#
# FBLG Analysis Summary:
#   Current Price: £445.59
#   Price Change: +0.00%
#   Trading Signal: SELL (Buy: 2/7, Sell: 3/7)
#   Market Conditions: RSI: Oversold, Volatility: Low
#
# 3. Testing Multi-Symbol Market Analysis:
# Running multi-symbol enhanced analysis for 4 symbols...
#
# Market Overview:
# Symbols Analysed: 4
# Active Positions: 0
#   MRK: £181.55 (+0.00%) - Buy: 2/7, Sell: 1/7
#   UNH: £855.63 (+0.00%) - Buy: 1/7, Sell: 2/7
#   LLY: £375.74 (+0.00%) - Buy: 2/7, Sell: 1/7
# 2025-09-01 12:48:36,868 - INFO - Enhanced simulated analysis for PG: £159.53 (+0.00%)
# 2025-09-01 12:48:36,868 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,869 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,869 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,870 - INFO - Strategy: Conservative_Enhanced
# 2025-09-01 12:48:36,870 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,870 - INFO - Updated trading symbols: ['MRK', 'UNH', 'PG', 'KO', 'WMT']
# 2025-09-01 12:48:36,871 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,871 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,871 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,872 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,872 - INFO - Strategy: Aggressive_Enhanced
# 2025-09-01 12:48:36,872 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,873 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:48:36,873 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,873 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,874 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,874 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,874 - INFO - Strategy: Custom_Test_Strategy
# 2025-09-01 12:48:36,875 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,875 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,883 - INFO - Enhanced simulated analysis for ABCL: £370.33 (+0.00%)
# 2025-09-01 12:48:36,890 - INFO - Enhanced simulated analysis for ALLO: £225.07 (+0.00%)
# 2025-09-01 12:48:36,891 - INFO - Disconnected from trading simulator
# 2025-09-01 12:48:36,891 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:36,891 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:36,892 - INFO - Strategy: Enhanced_5_15
# 2025-09-01 12:48:36,892 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:36,892 - INFO - Connected to trading simulator
# 2025-09-01 12:48:36,900 - INFO - Enhanced simulated analysis for MRK: £180.33 (+0.00%)
# 2025-09-01 12:48:36,900 - INFO - Disconnected from trading simulator
#   PG: £159.53 (+0.00%) - Buy: 2/7, Sell: 1/7
#
# Market Conditions Summary:
#   Bullish Signals: []
#   Bearish Signals: []
#   Neutral/Hold: ['MRK', 'UNH', 'LLY', 'PG']
#   High Volatility: []
#   Oversold (RSI < 30): ['UNH']
#   Overbought (RSI > 70): ['MRK', 'PG']
#
# Market Sentiment Analysis:
#   Bullish: 0% (0 symbols)
#   Bearish: 0% (0 symbols)
#   Neutral: 100% (4 symbols)
#
# 4. Testing Strategy Configuration:
#
# Testing Conservative Strategy Configuration:
#   Strategy: Conservative_Enhanced
#   Risk Management: Stop Loss 3.0%, Take Profit 8.0%
#   Position Sizing: Max 10% per position
#   Symbols: ['MRK', 'UNH', 'PG', 'KO', 'WMT']
#
# Testing Aggressive Strategy Configuration:
#   Strategy: Aggressive_Enhanced
#   Risk Management: Stop Loss 8.0%, Take Profit 25.0%
#   Position Sizing: Max 30% per position
#   Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
#
# 5. Testing Custom Strategy Configuration:
#   Custom Strategy: Custom_Test_Strategy
#   Moving Averages: 8/21
#   Risk Parameters: SL 4.0%, TP 12.0%
#
#   Running Diagnostic Check:
#     Connection Status: Connected
#     Components Initialised: 4/4
#     Data Availability: 2/2 symbols
#
# 6. Testing Signal Evaluation System:
#
# Testing signal evaluation for MRK:
#   Current Price: £180.33
#   Buy Signal Types Active: 2/7
#   Sell Signal Types Active: 2/7
#   Active Buy Signals: RSI Level, Williams %R
#   Active Sell Signals: SMA Crossover, MACD Trend
#   Risk Level: normal
#
# ============================================================
# Enhanced Simulator Tests Completed
# ============================================================
# All enhanced features tested successfully!
#
# Next Steps:
# • Run enhanced backtest: run_strategy_backtest(['MRK', 'UNH'], 5)
# • Compare strategies: run_strategy_comparison(['MRK', 'UNH'], 5)
# • Test paper trading: test_bot_connection('paper')
# ============================================================

# %% [markdown]
# ### Backtest Simulation

# %%
print("="*60)
print("Enhanced Backtest Simulation")
print("="*60)

# Simple enhanced backtest - 3 minutes on simulator
results = run_strategy_backtest(['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG'], duration_minutes=3)

if results:
    print(f"\nSimple Backtest Results:")
    print(f"Trades: {results['total_trades']}")
    print(f"Final Balance: £{results['final_balance']:,.2f}")
    print(f"Portfolio Value: £{results['portfolio_value']:,.2f}")
    print(f"Return: £{results['total_return']:+.2f} ({results['return_percentage']:+.2f}%)")
    
    # Show trades if any occurred
    if results['total_trades'] > 0:
        perf = results['strategy_performance']
        print(f"Win Rate: {perf['win_rate']:.1f}%")
        
        # Show positions
        for symbol, position in results['positions'].items():
            if position['shares'] > 0:
                print(f"{symbol}: {position['shares']} shares @ £{position['avg_price']:.2f}")
    else:
        print("No trades executed")
else:
    print("Backtest failed")
# Out:
# 2025-09-01 12:48:39,294 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:48:39,295 - INFO - Trading bot simulator initialised
# 2025-09-01 12:48:39,296 - INFO - Strategy: Backtest_Enhanced
# 2025-09-01 12:48:39,297 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:48:39,297 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:48:39,298 - INFO - Connected to trading simulator
# 2025-09-01 12:48:39,298 - INFO - Starting automated trading...
# 2025-09-01 12:48:39,299 - INFO - Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:48:39,299 - INFO - Strategy: Backtest_Enhanced
# 2025-09-01 12:48:39,300 - INFO - Update interval: 5 seconds
# 2025-09-01 12:48:39,300 - INFO - Strategy config - Short: 10, Long: 30, Stop Loss: 5.0%, Take Profit: 15.0%
# 2025-09-01 12:48:39,301 - INFO - --- Cycle 1 ---
# 2025-09-01 12:48:39,319 - INFO - Enhanced simulated analysis for ABCL: £463.00 (+0.00%)
# 2025-09-01 12:48:39,336 - INFO - Enhanced simulated analysis for ALLO: £91.42 (+0.00%)
# 2025-09-01 12:48:39,351 - INFO - Enhanced simulated analysis for ANNX: £404.23 (+0.00%)
# 2025-09-01 12:48:39,358 - INFO - BUY signal for ANNX: 4/7 signals
# 2025-09-01 12:48:39,359 - INFO - Simulated BUY order placed: 2 ANNX
# 2025-09-01 12:48:39,359 - INFO - SIMULATED BUY: 2 ANNX @ £404.23 (Cost: £808.46, Balance: £9191.54)
# 2025-09-01 12:48:39,359 - INFO - ANNX indicators - RSI: 95.7, MACD: 1.511, Volatility: 0.15%
# 2025-09-01 12:48:39,367 - INFO - Enhanced simulated analysis for ANRO: £141.59 (+0.00%)
# 2025-09-01 12:48:39,379 - INFO - Enhanced simulated analysis for ANVS: £268.14 (+0.00%)
# 2025-09-01 12:48:39,391 - INFO - Enhanced simulated analysis for APLM: £476.65 (+0.00%)
# 2025-09-01 12:48:39,403 - INFO - Enhanced simulated analysis for APLT: £383.63 (+0.00%)
# 2025-09-01 12:48:39,415 - INFO - Enhanced simulated analysis for APVO: £138.66 (+0.00%)
# 2025-09-01 12:48:39,426 - INFO - Enhanced simulated analysis for ARAY: £389.34 (+0.00%)
# 2025-09-01 12:48:39,437 - INFO - Enhanced simulated analysis for ARBE: £97.26 (+0.00%)
# 2025-09-01 12:48:39,448 - INFO - Enhanced simulated analysis for ATEN: £263.61 (+0.00%)
# 2025-09-01 12:48:39,460 - INFO - Enhanced simulated analysis for ATAI: £355.04 (+0.00%)
# 2025-09-01 12:48:39,471 - INFO - Enhanced simulated analysis for ATHA: £126.13 (+0.00%)
# 2025-09-01 12:48:39,483 - INFO - Enhanced simulated analysis for AUTL: £190.77 (+0.00%)
# 2025-09-01 12:48:39,494 - INFO - Enhanced simulated analysis for AVIR: £481.95 (+0.00%)
# ============================================================
# Enhanced Backtest Simulation
# ============================================================
# Running enhanced strategy backtest simulation...
# Running 36 cycles over 3 minutes...
# Testing symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# Strategy: Backtest_Enhanced
# Starting balance: £10,000.00
# Risk Management: Stop Loss 5.0%, Take Profit 15.0%
# 2025-09-01 12:48:39,506 - INFO - Enhanced simulated analysis for CABA: £147.95 (+0.00%)
# 2025-09-01 12:48:39,518 - INFO - Enhanced simulated analysis for CAMP: £278.88 (+0.00%)
# 2025-09-01 12:48:39,529 - INFO - Enhanced simulated analysis for CARM: £483.60 (+0.00%)
# 2025-09-01 12:48:39,540 - INFO - Enhanced simulated analysis for CATX: £296.95 (+0.00%)
# 2025-09-01 12:48:39,552 - INFO - Enhanced simulated analysis for CCCC: £197.27 (+0.00%)
# 2025-09-01 12:48:39,563 - INFO - Enhanced simulated analysis for CELU: £428.48 (+0.00%)
# 2025-09-01 12:48:39,575 - INFO - Enhanced simulated analysis for CERS: £296.49 (+0.00%)
# 2025-09-01 12:48:39,586 - INFO - Enhanced simulated analysis for CGTX: £245.02 (+0.00%)
# 2025-09-01 12:48:39,593 - INFO - BUY signal for CGTX: 3/7 signals
# 2025-09-01 12:48:39,593 - INFO - Simulated BUY order placed: 4 CGTX
# 2025-09-01 12:48:39,593 - INFO - SIMULATED BUY: 4 CGTX @ £245.02 (Cost: £980.08, Balance: £8211.46)
# 2025-09-01 12:48:39,594 - INFO - CGTX indicators - RSI: 51.5, MACD: -0.544, Volatility: 0.25%
# 2025-09-01 12:48:39,600 - INFO - Enhanced simulated analysis for CHRS: £145.31 (+0.00%)
# 2025-09-01 12:48:39,606 - INFO - BUY signal for CHRS: 3/7 signals
# 2025-09-01 12:48:39,607 - INFO - Simulated BUY order placed: 6 CHRS
# 2025-09-01 12:48:39,607 - INFO - SIMULATED BUY: 6 CHRS @ £145.31 (Cost: £871.86, Balance: £7339.60)
# 2025-09-01 12:48:39,607 - INFO - CHRS indicators - RSI: 48.1, MACD: -0.062, Volatility: 0.21%
# 2025-09-01 12:48:39,627 - INFO - Enhanced simulated analysis for CLDI: £197.93 (+0.00%)
# 2025-09-01 12:48:39,652 - INFO - Enhanced simulated analysis for CLLS: £194.79 (+0.00%)
# 2025-09-01 12:48:39,664 - INFO - Enhanced simulated analysis for CLRB: £338.01 (+0.00%)
# 2025-09-01 12:48:39,675 - INFO - Enhanced simulated analysis for CLSD: £146.86 (+0.00%)
# 2025-09-01 12:48:39,681 - INFO - BUY signal for CLSD: 3/7 signals
# 2025-09-01 12:48:39,682 - INFO - Simulated BUY order placed: 5 CLSD
# 2025-09-01 12:48:39,682 - INFO - SIMULATED BUY: 5 CLSD @ £146.86 (Cost: £734.30, Balance: £6605.30)
# 2025-09-01 12:48:39,682 - INFO - CLSD indicators - RSI: 65.5, MACD: 2.322, Volatility: 0.17%
# 2025-09-01 12:48:39,689 - INFO - Enhanced simulated analysis for CLYM: £476.61 (+0.00%)
# 2025-09-01 12:48:39,700 - INFO - Enhanced simulated analysis for CMPS: £194.19 (+0.00%)
# 2025-09-01 12:48:39,706 - INFO - BUY signal for CMPS: 3/7 signals
# 2025-09-01 12:48:39,707 - INFO - Simulated BUY order placed: 4 CMPS
# 2025-09-01 12:48:39,707 - INFO - SIMULATED BUY: 4 CMPS @ £194.19 (Cost: £776.76, Balance: £5828.54)
# 2025-09-01 12:48:39,707 - INFO - CMPS indicators - RSI: 74.6, MACD: 0.985, Volatility: 0.18%
# 2025-09-01 12:48:39,714 - INFO - Enhanced simulated analysis for CMPX: £382.39 (+0.00%)
# 2025-09-01 12:48:39,725 - INFO - Enhanced simulated analysis for CMTL: £308.54 (+0.00%)
# 2025-09-01 12:48:39,732 - INFO - BUY signal for CMTL: 3/7 signals
# 2025-09-01 12:48:39,732 - INFO - Simulated BUY order placed: 2 CMTL
# 2025-09-01 12:48:39,732 - INFO - SIMULATED BUY: 2 CMTL @ £308.54 (Cost: £617.08, Balance: £5211.46)
# 2025-09-01 12:48:39,733 - INFO - CMTL indicators - RSI: 25.8, MACD: -0.812, Volatility: 0.14%
# 2025-09-01 12:48:39,739 - INFO - Enhanced simulated analysis for COCP: £358.47 (+0.00%)
# 2025-09-01 12:48:39,751 - INFO - Enhanced simulated analysis for CRBU: £300.83 (+0.00%)
# 2025-09-01 12:48:39,762 - INFO - Enhanced simulated analysis for CRDF: £195.25 (+0.00%)
# 2025-09-01 12:48:39,774 - INFO - Enhanced simulated analysis for CRDL: £113.01 (+0.00%)
# 2025-09-01 12:48:39,785 - INFO - Enhanced simulated analysis for CRIS: £332.55 (+0.00%)
# 2025-09-01 12:48:39,797 - INFO - Enhanced simulated analysis for CTMX: £90.07 (+0.00%)
# 2025-09-01 12:48:39,808 - INFO - Enhanced simulated analysis for CTOR: £161.13 (+0.00%)
# 2025-09-01 12:48:39,820 - INFO - Enhanced simulated analysis for CTXR: £195.15 (+0.00%)
# 2025-09-01 12:48:39,832 - INFO - Enhanced simulated analysis for CUE: £302.20 (+0.00%)
# 2025-09-01 12:48:39,843 - INFO - Enhanced simulated analysis for CURR: £196.71 (+0.00%)
# 2025-09-01 12:48:39,855 - INFO - Enhanced simulated analysis for DARE: £355.27 (+0.00%)
# 2025-09-01 12:48:39,866 - INFO - Enhanced simulated analysis for DTIL: £406.24 (+0.00%)
# 2025-09-01 12:48:39,878 - INFO - Enhanced simulated analysis for EDIT: £435.69 (+0.00%)
# 2025-09-01 12:48:39,889 - INFO - Enhanced simulated analysis for ELDN: £234.84 (+0.00%)
# 2025-09-01 12:48:39,901 - INFO - Enhanced simulated analysis for EQ: £167.73 (+0.00%)
# 2025-09-01 12:48:39,912 - INFO - Enhanced simulated analysis for ERAS: £494.65 (+0.00%)
# 2025-09-01 12:48:39,924 - INFO - Enhanced simulated analysis for ERNA: £382.95 (+0.00%)
# 2025-09-01 12:48:39,931 - INFO - BUY signal for ERNA: 3/7 signals
# 2025-09-01 12:48:39,931 - INFO - Simulated BUY order placed: 1 ERNA
# 2025-09-01 12:48:39,931 - INFO - SIMULATED BUY: 1 ERNA @ £382.95 (Cost: £382.95, Balance: £4828.51)
# 2025-09-01 12:48:39,931 - INFO - ERNA indicators - RSI: 64.9, MACD: 0.686, Volatility: 0.10%
# 2025-09-01 12:48:39,938 - INFO - Enhanced simulated analysis for ESLA: £339.84 (+0.00%)
# 2025-09-01 12:48:39,950 - INFO - Enhanced simulated analysis for ESPR: £450.09 (+0.00%)
# 2025-09-01 12:48:39,961 - INFO - Enhanced simulated analysis for EVGN: £417.44 (+0.00%)
# 2025-09-01 12:48:39,972 - INFO - Enhanced simulated analysis for FATE: £151.02 (+0.00%)
# 2025-09-01 12:48:39,984 - INFO - Enhanced simulated analysis for FBLG: £241.59 (+0.00%)
# 2025-09-01 12:48:39,990 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 12:48:44,995 - INFO - --- Cycle 2 ---
# 2025-09-01 12:48:45,019 - INFO - Enhanced simulated analysis for ABCL: £471.17 (+0.00%)
# 2025-09-01 12:48:45,042 - INFO - Enhanced simulated analysis for ALLO: £92.47 (+0.00%)
# 2025-09-01 12:48:45,059 - INFO - Enhanced simulated analysis for ANNX: £402.11 (+0.00%)
# 2025-09-01 12:48:45,073 - INFO - Enhanced simulated analysis for ANRO: £141.55 (+0.00%)
# 2025-09-01 12:48:45,086 - INFO - Enhanced simulated analysis for ANVS: £265.90 (+0.00%)
# 2025-09-01 12:48:45,099 - INFO - Enhanced simulated analysis for APLM: £479.56 (+0.00%)
# 2025-09-01 12:48:45,105 - INFO - BUY signal for APLM: 3/7 signals
# 2025-09-01 12:48:45,106 - INFO - Simulated BUY order placed: 1 APLM
# 2025-09-01 12:48:45,106 - INFO - SIMULATED BUY: 1 APLM @ £479.56 (Cost: £479.56, Balance: £4348.95)
# 2025-09-01 12:48:45,106 - INFO - APLM indicators - RSI: 62.1, MACD: -0.004, Volatility: 0.23%
# 2025-09-01 12:48:45,114 - INFO - Enhanced simulated analysis for APLT: £385.21 (+0.00%)
# 2025-09-01 12:48:45,125 - INFO - Enhanced simulated analysis for APVO: £138.71 (+0.00%)
# 2025-09-01 12:48:45,137 - INFO - Enhanced simulated analysis for ARAY: £388.64 (+0.00%)
# 2025-09-01 12:48:45,143 - INFO - BUY signal for ARAY: 3/7 signals
# 2025-09-01 12:48:45,143 - INFO - Simulated BUY order placed: 1 ARAY
# 2025-09-01 12:48:45,143 - INFO - SIMULATED BUY: 1 ARAY @ £388.64 (Cost: £388.64, Balance: £3960.31)
# 2025-09-01 12:48:45,144 - INFO - ARAY indicators - RSI: 71.6, MACD: 0.636, Volatility: 0.13%
# 2025-09-01 12:48:45,151 - INFO - Enhanced simulated analysis for ARBE: £95.36 (+0.00%)
# 2025-09-01 12:48:45,163 - INFO - Enhanced simulated analysis for ATEN: £263.12 (+0.00%)
# 2025-09-01 12:48:45,174 - INFO - Enhanced simulated analysis for ATAI: £358.33 (+0.00%)
# 2025-09-01 12:48:45,186 - INFO - Enhanced simulated analysis for ATHA: £125.08 (+0.00%)
# 2025-09-01 12:48:45,198 - INFO - Enhanced simulated analysis for AUTL: £188.66 (+0.00%)
# 2025-09-01 12:48:45,209 - INFO - Enhanced simulated analysis for AVIR: £479.84 (+0.00%)
# 2025-09-01 12:48:45,216 - INFO - BUY signal for AVIR: 3/7 signals
# 2025-09-01 12:48:45,216 - INFO - Simulated BUY order placed: 1 AVIR
# 2025-09-01 12:48:45,216 - INFO - SIMULATED BUY: 1 AVIR @ £479.84 (Cost: £479.84, Balance: £3480.47)
# 2025-09-01 12:48:45,217 - INFO - AVIR indicators - RSI: 61.1, MACD: 0.173, Volatility: 0.18%
# 2025-09-01 12:48:45,223 - INFO - Enhanced simulated analysis for CABA: £147.96 (+0.00%)
# 2025-09-01 12:48:45,230 - INFO - BUY signal for CABA: 3/7 signals
# 2025-09-01 12:48:45,230 - INFO - Simulated BUY order placed: 2 CABA
# 2025-09-01 12:48:45,230 - INFO - SIMULATED BUY: 2 CABA @ £147.96 (Cost: £295.92, Balance: £3184.55)
# 2025-09-01 12:48:45,231 - INFO - CABA indicators - RSI: 52.1, MACD: -0.120, Volatility: 0.19%
# 2025-09-01 12:48:45,238 - INFO - Enhanced simulated analysis for CAMP: £280.54 (+0.00%)
# 2025-09-01 12:48:45,250 - INFO - Enhanced simulated analysis for CARM: £478.69 (+0.00%)
# 2025-09-01 12:48:45,256 - INFO - BUY signal for CARM: 3/7 signals
# 2025-09-01 12:48:45,256 - INFO - Simulated BUY order placed: 1 CARM
# 2025-09-01 12:48:45,257 - INFO - SIMULATED BUY: 1 CARM @ £478.69 (Cost: £478.69, Balance: £2705.86)
# 2025-09-01 12:48:45,257 - INFO - CARM indicators - RSI: 30.8, MACD: -0.231, Volatility: 0.17%
# 2025-09-01 12:48:45,274 - INFO - Enhanced simulated analysis for CATX: £296.83 (+0.00%)
# 2025-09-01 12:48:45,301 - INFO - Enhanced simulated analysis for CCCC: £197.24 (+0.00%)
# 2025-09-01 12:48:45,313 - INFO - Enhanced simulated analysis for CELU: £432.65 (+0.00%)
# 2025-09-01 12:48:45,325 - INFO - Enhanced simulated analysis for CERS: £296.06 (+0.00%)
# 2025-09-01 12:48:45,336 - INFO - Enhanced simulated analysis for CGTX: £246.17 (+0.00%)
# 2025-09-01 12:48:45,348 - INFO - Enhanced simulated analysis for CHRS: £146.31 (+0.00%)
# 2025-09-01 12:48:45,355 - INFO - SELL signal for CHRS: 3/7 signals
# 2025-09-01 12:48:45,355 - INFO - Simulated SELL order placed: 6 CHRS
# 2025-09-01 12:48:45,355 - INFO - SIMULATED SELL: 0 CHRS @ £146.31 (Value: £877.86, P&L: £877.86, Balance: £3583.72)
# 2025-09-01 12:48:45,356 - INFO - CHRS indicators - RSI: 40.3, MACD: -0.146, Volatility: 0.18%
# 2025-09-01 12:48:45,362 - INFO - Enhanced simulated analysis for CLDI: £194.79 (+0.00%)
# 2025-09-01 12:48:45,378 - INFO - Enhanced simulated analysis for CLLS: £195.99 (+0.00%)
# 2025-09-01 12:48:45,390 - INFO - Enhanced simulated analysis for CLRB: £339.28 (+0.00%)
# 2025-09-01 12:48:45,402 - INFO - Enhanced simulated analysis for CLSD: £146.90 (+0.00%)
# 2025-09-01 12:48:45,414 - INFO - Enhanced simulated analysis for CLYM: £478.02 (+0.00%)
# 2025-09-01 12:48:45,426 - INFO - Enhanced simulated analysis for CMPS: £195.49 (+0.00%)
# 2025-09-01 12:48:45,437 - INFO - Enhanced simulated analysis for CMPX: £381.66 (+0.00%)
# 2025-09-01 12:48:45,449 - INFO - Enhanced simulated analysis for CMTL: £309.15 (+0.00%)
# 2025-09-01 12:48:45,461 - INFO - Enhanced simulated analysis for COCP: £357.42 (+0.00%)
# 2025-09-01 12:48:45,472 - INFO - Enhanced simulated analysis for CRBU: £300.32 (+0.00%)
# 2025-09-01 12:48:45,485 - INFO - Enhanced simulated analysis for CRDF: £196.03 (+0.00%)
# 2025-09-01 12:48:45,496 - INFO - Enhanced simulated analysis for CRDL: £113.21 (+0.00%)
# 2025-09-01 12:48:45,508 - INFO - Enhanced simulated analysis for CRIS: £332.67 (+0.00%)
# 2025-09-01 12:48:45,519 - INFO - Enhanced simulated analysis for CTMX: £90.67 (+0.00%)
# 2025-09-01 12:48:45,532 - INFO - Enhanced simulated analysis for CTOR: £161.23 (+0.00%)
# 2025-09-01 12:48:45,543 - INFO - Enhanced simulated analysis for CTXR: £194.63 (+0.00%)
# 2025-09-01 12:48:45,555 - INFO - Enhanced simulated analysis for CUE: £303.03 (+0.00%)
# 2025-09-01 12:48:45,567 - INFO - Enhanced simulated analysis for CURR: £197.45 (+0.00%)
# 2025-09-01 12:48:45,578 - INFO - Enhanced simulated analysis for DARE: £355.12 (+0.00%)
# 2025-09-01 12:48:45,590 - INFO - Enhanced simulated analysis for DTIL: £408.27 (+0.00%)
# 2025-09-01 12:48:45,602 - INFO - Enhanced simulated analysis for EDIT: £432.00 (+0.00%)
# 2025-09-01 12:48:45,614 - INFO - Enhanced simulated analysis for ELDN: £236.64 (+0.00%)
# 2025-09-01 12:48:45,625 - INFO - Enhanced simulated analysis for EQ: £167.34 (+0.00%)
# 2025-09-01 12:48:45,631 - INFO - BUY signal for EQ: 4/7 signals
# 2025-09-01 12:48:45,632 - INFO - Simulated BUY order placed: 2 EQ
# 2025-09-01 12:48:45,632 - INFO - SIMULATED BUY: 2 EQ @ £167.34 (Cost: £334.68, Balance: £3249.04)
# 2025-09-01 12:48:45,632 - INFO - EQ indicators - RSI: 32.2, MACD: -0.212, Volatility: 0.17%
# 2025-09-01 12:48:45,639 - INFO - Enhanced simulated analysis for ERAS: £493.80 (+0.00%)
# 2025-09-01 12:48:45,651 - INFO - Enhanced simulated analysis for ERNA: £379.41 (+0.00%)
# 2025-09-01 12:48:45,662 - INFO - Enhanced simulated analysis for ESLA: £342.18 (+0.00%)
# 2025-09-01 12:48:45,673 - INFO - Enhanced simulated analysis for ESPR: £448.24 (+0.00%)
# 2025-09-01 12:48:45,685 - INFO - Enhanced simulated analysis for EVGN: £419.15 (+0.00%)
# 2025-09-01 12:48:45,691 - INFO - BUY signal for EVGN: 4/7 signals
# 2025-09-01 12:48:45,691 - INFO - Simulated BUY order placed: 1 EVGN
# 2025-09-01 12:48:45,691 - INFO - SIMULATED BUY: 1 EVGN @ £419.15 (Cost: £419.15, Balance: £2829.89)
# 2025-09-01 12:48:45,692 - INFO - EVGN indicators - RSI: 33.9, MACD: -0.468, Volatility: 0.21%
# 2025-09-01 12:48:45,698 - INFO - Enhanced simulated analysis for FATE: £149.41 (+0.00%)
# 2025-09-01 12:48:45,710 - INFO - Enhanced simulated analysis for FBLG: £243.15 (+0.00%)
# 2025-09-01 12:48:45,717 - INFO - Cycle completed: 8 trades executed
# 2025-09-01 12:48:45,717 - INFO - Performance - Total Trades: 1, Win Rate: 100.0%, Total P&L: £6.00
# 2025-09-01 12:48:50,719 - INFO - --- Cycle 3 ---
# 2025-09-01 12:48:50,740 - INFO - Enhanced simulated analysis for ABCL: £473.23 (+0.00%)
# 2025-09-01 12:48:50,762 - INFO - Enhanced simulated analysis for ALLO: £92.72 (+0.00%)
# 2025-09-01 12:48:50,779 - INFO - Enhanced simulated analysis for ANNX: £400.48 (+0.00%)
# 2025-09-01 12:48:50,794 - INFO - Enhanced simulated analysis for ANRO: £142.65 (+0.00%)
# 2025-09-01 12:48:50,807 - INFO - Enhanced simulated analysis for ANVS: £265.51 (+0.00%)
# 2025-09-01 12:48:50,819 - INFO - Enhanced simulated analysis for APLM: £479.84 (+0.00%)
# 2025-09-01 12:48:50,832 - INFO - Enhanced simulated analysis for APLT: £388.13 (+0.00%)
# 2025-09-01 12:48:50,838 - INFO - BUY signal for APLT: 3/7 signals
# 2025-09-01 12:48:50,838 - INFO - Simulated BUY order placed: 1 APLT
# 2025-09-01 12:48:50,839 - INFO - SIMULATED BUY: 1 APLT @ £388.13 (Cost: £388.13, Balance: £2441.76)
# 2025-09-01 12:48:50,839 - INFO - APLT indicators - RSI: 81.3, MACD: 2.731, Volatility: 0.23%
# 2025-09-01 12:48:50,846 - INFO - Enhanced simulated analysis for APVO: £139.93 (+0.00%)
# 2025-09-01 12:48:50,857 - INFO - Enhanced simulated analysis for ARAY: £388.68 (+0.00%)
# 2025-09-01 12:48:50,869 - INFO - Enhanced simulated analysis for ARBE: £96.20 (+0.00%)
# 2025-09-01 12:48:50,880 - INFO - Enhanced simulated analysis for ATEN: £264.52 (+0.00%)
# 2025-09-01 12:48:50,887 - INFO - BUY signal for ATEN: 3/7 signals
# 2025-09-01 12:48:50,887 - INFO - Simulated BUY order placed: 1 ATEN
# 2025-09-01 12:48:50,888 - INFO - SIMULATED BUY: 1 ATEN @ £264.52 (Cost: £264.52, Balance: £2177.24)
# 2025-09-01 12:48:50,888 - INFO - ATEN indicators - RSI: 75.2, MACD: 0.835, Volatility: 0.23%
# 2025-09-01 12:48:50,895 - INFO - Enhanced simulated analysis for ATAI: £358.92 (+0.00%)
# 2025-09-01 12:48:50,906 - INFO - Enhanced simulated analysis for ATHA: £124.33 (+0.00%)
# 2025-09-01 12:48:50,918 - INFO - Enhanced simulated analysis for AUTL: £189.08 (+0.00%)
# 2025-09-01 12:48:50,930 - INFO - Enhanced simulated analysis for AVIR: £481.10 (+0.00%)
# 2025-09-01 12:48:50,941 - INFO - Enhanced simulated analysis for CABA: £149.38 (+0.00%)
# 2025-09-01 12:48:50,952 - INFO - Enhanced simulated analysis for CAMP: £281.83 (+0.00%)
# 2025-09-01 12:48:50,964 - INFO - Enhanced simulated analysis for CARM: £479.62 (+0.00%)
# 2025-09-01 12:48:50,975 - INFO - Enhanced simulated analysis for CATX: £292.67 (+0.00%)
# 2025-09-01 12:48:50,987 - INFO - Enhanced simulated analysis for CCCC: £197.88 (+0.00%)
# 2025-09-01 12:48:50,999 - INFO - Enhanced simulated analysis for CELU: £433.58 (+0.00%)
# 2025-09-01 12:48:51,010 - INFO - Enhanced simulated analysis for CERS: £298.20 (+0.00%)
# 2025-09-01 12:48:51,021 - INFO - Enhanced simulated analysis for CGTX: £246.18 (+0.00%)
# 2025-09-01 12:48:51,033 - INFO - Enhanced simulated analysis for CHRS: £147.17 (+0.00%)
# 2025-09-01 12:48:51,044 - INFO - Enhanced simulated analysis for CLDI: £191.49 (+0.00%)
# 2025-09-01 12:48:51,050 - INFO - BUY signal for CLDI: 4/7 signals
# 2025-09-01 12:48:51,051 - INFO - Simulated BUY order placed: 1 CLDI
# 2025-09-01 12:48:51,051 - INFO - SIMULATED BUY: 1 CLDI @ £191.49 (Cost: £191.49, Balance: £1985.75)
# 2025-09-01 12:48:51,051 - INFO - CLDI indicators - RSI: 65.7, MACD: 0.445, Volatility: 0.24%
# 2025-09-01 12:48:51,058 - INFO - Enhanced simulated analysis for CLLS: £195.79 (+0.00%)
# 2025-09-01 12:48:51,069 - INFO - Enhanced simulated analysis for CLRB: £336.63 (+0.00%)
# 2025-09-01 12:48:51,075 - INFO - BUY signal for CLRB: 4/7 signals
# 2025-09-01 12:48:51,076 - INFO - Simulated BUY order placed: 1 CLRB
# 2025-09-01 12:48:51,076 - INFO - SIMULATED BUY: 1 CLRB @ £336.63 (Cost: £336.63, Balance: £1649.12)
# 2025-09-01 12:48:51,076 - INFO - CLRB indicators - RSI: 64.0, MACD: 1.129, Volatility: 0.29%
# 2025-09-01 12:48:51,083 - INFO - Enhanced simulated analysis for CLSD: £146.13 (+0.00%)
# 2025-09-01 12:48:51,095 - INFO - Enhanced simulated analysis for CLYM: £478.11 (+0.00%)
# 2025-09-01 12:48:51,107 - INFO - Enhanced simulated analysis for CMPS: £196.74 (+0.00%)
# 2025-09-01 12:48:51,119 - INFO - Enhanced simulated analysis for CMPX: £385.53 (+0.00%)
# 2025-09-01 12:48:51,130 - INFO - Enhanced simulated analysis for CMTL: £309.71 (+0.00%)
# 2025-09-01 12:48:51,142 - INFO - Enhanced simulated analysis for COCP: £355.67 (+0.00%)
# 2025-09-01 12:48:51,153 - INFO - Enhanced simulated analysis for CRBU: £295.68 (+0.00%)
# 2025-09-01 12:48:51,165 - INFO - Enhanced simulated analysis for CRDF: £198.20 (+0.00%)
# 2025-09-01 12:48:51,176 - INFO - Enhanced simulated analysis for CRDL: £113.08 (+0.00%)
# 2025-09-01 12:48:51,188 - INFO - Enhanced simulated analysis for CRIS: £331.02 (+0.00%)
# 2025-09-01 12:48:51,200 - INFO - Enhanced simulated analysis for CTMX: £90.44 (+0.00%)
# 2025-09-01 12:48:51,211 - INFO - Enhanced simulated analysis for CTOR: £162.24 (+0.00%)
# 2025-09-01 12:48:51,218 - INFO - BUY signal for CTOR: 3/7 signals
# 2025-09-01 12:48:51,218 - INFO - Simulated BUY order placed: 1 CTOR
# 2025-09-01 12:48:51,218 - INFO - SIMULATED BUY: 1 CTOR @ £162.24 (Cost: £162.24, Balance: £1486.88)
# 2025-09-01 12:48:51,219 - INFO - CTOR indicators - RSI: 81.0, MACD: 1.759, Volatility: 0.21%
# 2025-09-01 12:48:51,225 - INFO - Enhanced simulated analysis for CTXR: £196.02 (+0.00%)
# 2025-09-01 12:48:51,264 - INFO - Enhanced simulated analysis for CUE: £301.45 (+0.00%)
# 2025-09-01 12:48:51,277 - INFO - Enhanced simulated analysis for CURR: £196.65 (+0.00%)
# 2025-09-01 12:48:51,289 - INFO - Enhanced simulated analysis for DARE: £355.69 (+0.00%)
# 2025-09-01 12:48:51,301 - INFO - Enhanced simulated analysis for DTIL: £410.45 (+0.00%)
# 2025-09-01 12:48:51,313 - INFO - Enhanced simulated analysis for EDIT: £432.63 (+0.00%)
# 2025-09-01 12:48:51,324 - INFO - Enhanced simulated analysis for ELDN: £236.78 (+0.00%)
# 2025-09-01 12:48:51,331 - INFO - BUY signal for ELDN: 4/7 signals
# 2025-09-01 12:48:51,331 - INFO - Simulated BUY order placed: 1 ELDN
# 2025-09-01 12:48:51,331 - INFO - SIMULATED BUY: 1 ELDN @ £236.78 (Cost: £236.78, Balance: £1250.10)
# 2025-09-01 12:48:51,332 - INFO - ELDN indicators - RSI: 39.7, MACD: -1.219, Volatility: 0.22%
# 2025-09-01 12:48:51,342 - INFO - Enhanced simulated analysis for EQ: £167.91 (+0.00%)
# 2025-09-01 12:48:51,354 - INFO - Enhanced simulated analysis for ERAS: £496.21 (+0.00%)
# 2025-09-01 12:48:51,366 - INFO - Enhanced simulated analysis for ERNA: £378.97 (+0.00%)
# 2025-09-01 12:48:51,377 - INFO - Enhanced simulated analysis for ESLA: £341.04 (+0.00%)
# 2025-09-01 12:48:51,389 - INFO - Enhanced simulated analysis for ESPR: £445.88 (+0.00%)
# 2025-09-01 12:48:51,400 - INFO - Enhanced simulated analysis for EVGN: £414.17 (+0.00%)
# 2025-09-01 12:48:51,413 - INFO - Enhanced simulated analysis for FATE: £150.89 (+0.00%)
# 2025-09-01 12:48:51,419 - INFO - BUY signal for FATE: 3/7 signals
# 2025-09-01 12:48:51,419 - INFO - Simulated BUY order placed: 1 FATE
# 2025-09-01 12:48:51,419 - INFO - SIMULATED BUY: 1 FATE @ £150.89 (Cost: £150.89, Balance: £1099.21)
# 2025-09-01 12:48:51,420 - INFO - FATE indicators - RSI: 70.2, MACD: 0.319, Volatility: 0.14%
# 2025-09-01 12:48:51,427 - INFO - Enhanced simulated analysis for FBLG: £242.21 (+0.00%)
# 2025-09-01 12:48:51,433 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 12:48:51,433 - INFO - Performance - Total Trades: 1, Win Rate: 100.0%, Total P&L: £6.00
# 2025-09-01 12:48:56,439 - INFO - --- Cycle 4 ---
# 2025-09-01 12:48:56,462 - INFO - Enhanced simulated analysis for ABCL: £475.38 (+0.00%)
# 2025-09-01 12:48:56,483 - INFO - Enhanced simulated analysis for ALLO: £92.08 (+0.00%)
# 2025-09-01 12:48:56,500 - INFO - Enhanced simulated analysis for ANNX: £402.40 (+0.00%)
# 2025-09-01 12:48:56,515 - INFO - Enhanced simulated analysis for ANRO: £144.63 (+0.00%)
# 2025-09-01 12:48:56,528 - INFO - Enhanced simulated analysis for ANVS: £264.33 (+0.00%)
# 2025-09-01 12:48:56,541 - INFO - Enhanced simulated analysis for APLM: £473.86 (+0.00%)
# 2025-09-01 12:48:56,553 - INFO - Enhanced simulated analysis for APLT: £393.34 (+0.00%)
# 2025-09-01 12:48:56,565 - INFO - Enhanced simulated analysis for APVO: £140.24 (+0.00%)
# 2025-09-01 12:48:56,577 - INFO - Enhanced simulated analysis for ARAY: £386.47 (+0.00%)
# 2025-09-01 12:48:56,588 - INFO - Enhanced simulated analysis for ARBE: £96.19 (+0.00%)
# 2025-09-01 12:48:56,600 - INFO - Enhanced simulated analysis for ATEN: £264.81 (+0.00%)
# 2025-09-01 12:48:56,611 - INFO - Enhanced simulated analysis for ATAI: £359.94 (+0.00%)
# 2025-09-01 12:48:56,618 - INFO - BUY signal for ATAI: 3/7 signals
# 2025-09-01 12:48:56,618 - INFO - Simulated BUY order placed: 1 ATAI
# 2025-09-01 12:48:56,618 - INFO - SIMULATED BUY: 1 ATAI @ £359.94 (Cost: £359.94, Balance: £739.27)
# 2025-09-01 12:48:56,619 - INFO - ATAI indicators - RSI: 72.4, MACD: 0.970, Volatility: 0.20%
# 2025-09-01 12:48:56,625 - INFO - Enhanced simulated analysis for ATHA: £123.62 (+0.00%)
# 2025-09-01 12:48:56,637 - INFO - Enhanced simulated analysis for AUTL: £190.81 (+0.00%)
# 2025-09-01 12:48:56,648 - INFO - Enhanced simulated analysis for AVIR: £481.98 (+0.00%)
# 2025-09-01 12:48:56,681 - INFO - Enhanced simulated analysis for CABA: £149.21 (+0.00%)
# 2025-09-01 12:48:56,698 - INFO - Enhanced simulated analysis for CAMP: £283.47 (+0.00%)
# 2025-09-01 12:48:56,709 - INFO - Enhanced simulated analysis for CARM: £478.79 (+0.00%)
# 2025-09-01 12:48:56,721 - INFO - Enhanced simulated analysis for CATX: £295.35 (+0.00%)
# 2025-09-01 12:48:56,733 - INFO - Enhanced simulated analysis for CCCC: £198.29 (+0.00%)
# 2025-09-01 12:48:56,744 - INFO - Enhanced simulated analysis for CELU: £438.46 (+0.00%)
# 2025-09-01 12:48:56,756 - INFO - Enhanced simulated analysis for CERS: £299.09 (+0.00%)
# 2025-09-01 12:48:56,767 - INFO - Enhanced simulated analysis for CGTX: £245.92 (+0.00%)
# 2025-09-01 12:48:56,779 - INFO - Enhanced simulated analysis for CHRS: £145.92 (+0.00%)
# 2025-09-01 12:48:56,790 - INFO - Enhanced simulated analysis for CLDI: £191.14 (+0.00%)
# 2025-09-01 12:48:56,802 - INFO - Enhanced simulated analysis for CLLS: £196.07 (+0.00%)
# 2025-09-01 12:48:56,813 - INFO - Enhanced simulated analysis for CLRB: £336.36 (+0.00%)
# 2025-09-01 12:48:56,825 - INFO - Enhanced simulated analysis for CLSD: £144.09 (+0.00%)
# 2025-09-01 12:48:56,837 - INFO - Enhanced simulated analysis for CLYM: £477.95 (+0.00%)
# 2025-09-01 12:48:56,848 - INFO - Enhanced simulated analysis for CMPS: £198.14 (+0.00%)
# 2025-09-01 12:48:56,860 - INFO - Enhanced simulated analysis for CMPX: £388.59 (+0.00%)
# 2025-09-01 12:48:56,871 - INFO - Enhanced simulated analysis for CMTL: £308.50 (+0.00%)
# 2025-09-01 12:48:56,883 - INFO - Enhanced simulated analysis for COCP: £353.44 (+0.00%)
# 2025-09-01 12:48:56,894 - INFO - Enhanced simulated analysis for CRBU: £297.79 (+0.00%)
# 2025-09-01 12:48:56,906 - INFO - Enhanced simulated analysis for CRDF: £200.14 (+0.00%)
# 2025-09-01 12:48:56,912 - INFO - BUY signal for CRDF: 3/7 signals
# 2025-09-01 12:48:56,913 - INFO - Simulated BUY order placed: 1 CRDF
# 2025-09-01 12:48:56,913 - INFO - SIMULATED BUY: 1 CRDF @ £200.14 (Cost: £200.14, Balance: £539.13)
# 2025-09-01 12:48:56,913 - INFO - CRDF indicators - RSI: 61.4, MACD: 0.667, Volatility: 0.20%
# 2025-09-01 12:48:56,920 - INFO - Enhanced simulated analysis for CRDL: £113.26 (+0.00%)
# 2025-09-01 12:48:56,926 - INFO - BUY signal for CRDL: 3/7 signals
# 2025-09-01 12:48:56,926 - INFO - Simulated BUY order placed: 1 CRDL
# 2025-09-01 12:48:56,927 - INFO - SIMULATED BUY: 1 CRDL @ £113.26 (Cost: £113.26, Balance: £425.87)
# 2025-09-01 12:48:56,927 - INFO - CRDL indicators - RSI: 63.3, MACD: -0.710, Volatility: 0.27%
# 2025-09-01 12:48:56,934 - INFO - Enhanced simulated analysis for CRIS: £331.21 (+0.00%)
# 2025-09-01 12:48:56,946 - INFO - Enhanced simulated analysis for CTMX: £90.23 (+0.00%)
# 2025-09-01 12:48:56,957 - INFO - Enhanced simulated analysis for CTOR: £162.10 (+0.00%)
# 2025-09-01 12:48:56,969 - INFO - Enhanced simulated analysis for CTXR: £195.82 (+0.00%)
# 2025-09-01 12:48:56,980 - INFO - Enhanced simulated analysis for CUE: £300.14 (+0.00%)
# 2025-09-01 12:48:56,992 - INFO - Enhanced simulated analysis for CURR: £195.30 (+0.00%)
# 2025-09-01 12:48:56,998 - INFO - BUY signal for CURR: 4/7 signals
# 2025-09-01 12:48:56,999 - INFO - Simulated BUY order placed: 1 CURR
# 2025-09-01 12:48:56,999 - INFO - SIMULATED BUY: 1 CURR @ £195.30 (Cost: £195.30, Balance: £230.57)
# 2025-09-01 12:48:56,999 - INFO - CURR indicators - RSI: 46.2, MACD: -0.217, Volatility: 0.26%
# 2025-09-01 12:48:57,006 - INFO - Enhanced simulated analysis for DARE: £357.14 (+0.00%)
# 2025-09-01 12:48:57,018 - INFO - Enhanced simulated analysis for DTIL: £407.30 (+0.00%)
# 2025-09-01 12:48:57,030 - INFO - Enhanced simulated analysis for EDIT: £428.44 (+0.00%)
# 2025-09-01 12:48:57,036 - INFO - BUY signal for EDIT: 3/7 signals
# 2025-09-01 12:48:57,042 - INFO - Enhanced simulated analysis for ELDN: £236.26 (+0.00%)
# 2025-09-01 12:48:57,054 - INFO - Enhanced simulated analysis for EQ: £169.93 (+0.00%)
# 2025-09-01 12:48:57,066 - INFO - Enhanced simulated analysis for ERAS: £489.87 (+0.00%)
# 2025-09-01 12:48:57,072 - INFO - BUY signal for ERAS: 3/7 signals
# 2025-09-01 12:48:57,078 - INFO - Enhanced simulated analysis for ERNA: £373.12 (+0.00%)
# 2025-09-01 12:48:57,090 - INFO - Enhanced simulated analysis for ESLA: £342.65 (+0.00%)
# 2025-09-01 12:48:57,102 - INFO - Enhanced simulated analysis for ESPR: £446.84 (+0.00%)
# 2025-09-01 12:48:57,114 - INFO - Enhanced simulated analysis for EVGN: £412.55 (+0.00%)
# 2025-09-01 12:48:57,120 - INFO - SELL signal for EVGN: 3/7 signals
# 2025-09-01 12:48:57,120 - INFO - Simulated SELL order placed: 1 EVGN
# 2025-09-01 12:48:57,120 - INFO - SIMULATED SELL: 0 EVGN @ £412.55 (Value: £412.55, P&L: £412.55, Balance: £643.12)
# 2025-09-01 12:48:57,121 - INFO - EVGN indicators - RSI: 47.6, MACD: -0.049, Volatility: 0.21%
# 2025-09-01 12:48:57,128 - INFO - Enhanced simulated analysis for FATE: £152.01 (+0.00%)
# 2025-09-01 12:48:57,139 - INFO - Enhanced simulated analysis for FBLG: £243.57 (+0.00%)
# 2025-09-01 12:48:57,152 - INFO - BUY signal for FBLG: 3/7 signals
# 2025-09-01 12:48:57,153 - INFO - Simulated BUY order placed: 1 FBLG
# 2025-09-01 12:48:57,155 - INFO - SIMULATED BUY: 1 FBLG @ £243.57 (Cost: £243.57, Balance: £399.55)
# 2025-09-01 12:48:57,156 - INFO - FBLG indicators - RSI: 23.5, MACD: -0.213, Volatility: 0.19%
# 2025-09-01 12:48:57,157 - INFO - Cycle completed: 6 trades executed
# 2025-09-01 12:48:57,158 - INFO - Performance - Total Trades: 2, Win Rate: 50.0%, Total P&L: £-0.60
# 2025-09-01 12:49:02,161 - INFO - --- Cycle 5 ---
# 2025-09-01 12:49:02,187 - INFO - Enhanced simulated analysis for ABCL: £477.54 (+0.00%)
# 2025-09-01 12:49:02,208 - INFO - Enhanced simulated analysis for ALLO: £92.10 (+0.00%)
# 2025-09-01 12:49:02,225 - INFO - Enhanced simulated analysis for ANNX: £402.00 (+0.00%)
# 2025-09-01 12:49:02,239 - INFO - Enhanced simulated analysis for ANRO: £145.44 (+0.00%)
# 2025-09-01 12:49:02,252 - INFO - Enhanced simulated analysis for ANVS: £264.21 (+0.00%)
# 2025-09-01 12:49:02,264 - INFO - Enhanced simulated analysis for APLM: £476.34 (+0.00%)
# 2025-09-01 12:49:02,276 - INFO - Enhanced simulated analysis for APLT: £387.66 (+0.00%)
# 2025-09-01 12:49:02,288 - INFO - Enhanced simulated analysis for APVO: £142.47 (+0.00%)
# 2025-09-01 12:49:02,294 - INFO - BUY signal for APVO: 4/7 signals
# 2025-09-01 12:49:02,294 - INFO - Simulated BUY order placed: 1 APVO
# 2025-09-01 12:49:02,295 - INFO - SIMULATED BUY: 1 APVO @ £142.47 (Cost: £142.47, Balance: £257.08)
# 2025-09-01 12:49:02,295 - INFO - APVO indicators - RSI: 82.8, MACD: 4.942, Volatility: 0.24%
# 2025-09-01 12:49:02,302 - INFO - Enhanced simulated analysis for ARAY: £383.86 (+0.00%)
# 2025-09-01 12:49:02,313 - INFO - Enhanced simulated analysis for ARBE: £96.76 (+0.00%)
# 2025-09-01 12:49:02,324 - INFO - Enhanced simulated analysis for ATEN: £266.67 (+0.00%)
# 2025-09-01 12:49:02,336 - INFO - Enhanced simulated analysis for ATAI: £358.98 (+0.00%)
# 2025-09-01 12:49:02,347 - INFO - Enhanced simulated analysis for ATHA: £124.58 (+0.00%)
# 2025-09-01 12:49:02,359 - INFO - Enhanced simulated analysis for AUTL: £191.96 (+0.00%)
# 2025-09-01 12:49:02,371 - INFO - Enhanced simulated analysis for AVIR: £485.19 (+0.00%)
# 2025-09-01 12:49:02,382 - INFO - Enhanced simulated analysis for CABA: £149.96 (+0.00%)
# 2025-09-01 12:49:02,394 - INFO - Enhanced simulated analysis for CAMP: £282.99 (+0.00%)
# 2025-09-01 12:49:02,400 - INFO - BUY signal for CAMP: 3/7 signals
# 2025-09-01 12:49:02,406 - INFO - Enhanced simulated analysis for CARM: £477.23 (+0.00%)
# 2025-09-01 12:49:02,418 - INFO - Enhanced simulated analysis for CATX: £297.29 (+0.00%)
# 2025-09-01 12:49:02,429 - INFO - Enhanced simulated analysis for CCCC: £200.69 (+0.00%)
# 2025-09-01 12:49:02,441 - INFO - Enhanced simulated analysis for CELU: £437.09 (+0.00%)
# 2025-09-01 12:49:02,452 - INFO - Enhanced simulated analysis for CERS: £302.85 (+0.00%)
# 2025-09-01 12:49:02,464 - INFO - Enhanced simulated analysis for CGTX: £244.10 (+0.00%)
# 2025-09-01 12:49:02,475 - INFO - Enhanced simulated analysis for CHRS: £144.46 (+0.00%)
# 2025-09-01 12:49:02,486 - INFO - Enhanced simulated analysis for CLDI: £191.08 (+0.00%)
# 2025-09-01 12:49:02,498 - INFO - Enhanced simulated analysis for CLLS: £199.14 (+0.00%)
# 2025-09-01 12:49:02,504 - INFO - BUY signal for CLLS: 3/7 signals
# 2025-09-01 12:49:02,504 - INFO - Simulated BUY order placed: 1 CLLS
# 2025-09-01 12:49:02,505 - INFO - SIMULATED BUY: 1 CLLS @ £199.14 (Cost: £199.14, Balance: £57.94)
# 2025-09-01 12:49:02,505 - INFO - CLLS indicators - RSI: 58.0, MACD: 0.559, Volatility: 0.27%
# 2025-09-01 12:49:02,512 - INFO - Enhanced simulated analysis for CLRB: £335.30 (+0.00%)
# 2025-09-01 12:49:02,524 - INFO - Enhanced simulated analysis for CLSD: £143.50 (+0.00%)
# 2025-09-01 12:49:02,535 - INFO - Enhanced simulated analysis for CLYM: £479.64 (+0.00%)
# 2025-09-01 12:49:02,547 - INFO - Enhanced simulated analysis for CMPS: £198.22 (+0.00%)
# 2025-09-01 12:49:02,558 - INFO - Enhanced simulated analysis for CMPX: £387.97 (+0.00%)
# 2025-09-01 12:49:02,570 - INFO - Enhanced simulated analysis for CMTL: £308.06 (+0.00%)
# 2025-09-01 12:49:02,603 - INFO - Enhanced simulated analysis for COCP: £351.56 (+0.00%)
# 2025-09-01 12:49:02,613 - INFO - BUY signal for COCP: 3/7 signals
# 2025-09-01 12:49:02,619 - INFO - Enhanced simulated analysis for CRBU: £299.11 (+0.00%)
# 2025-09-01 12:49:02,631 - INFO - Enhanced simulated analysis for CRDF: £202.30 (+0.00%)
# 2025-09-01 12:49:02,643 - INFO - Enhanced simulated analysis for CRDL: £113.97 (+0.00%)
# 2025-09-01 12:49:02,654 - INFO - Enhanced simulated analysis for CRIS: £329.99 (+0.00%)
# 2025-09-01 12:49:02,666 - INFO - Enhanced simulated analysis for CTMX: £91.22 (+0.00%)
# 2025-09-01 12:49:02,677 - INFO - Enhanced simulated analysis for CTOR: £162.93 (+0.00%)
# 2025-09-01 12:49:02,689 - INFO - Enhanced simulated analysis for CTXR: £195.06 (+0.00%)
# 2025-09-01 12:49:02,700 - INFO - Enhanced simulated analysis for CUE: £298.76 (+0.00%)
# 2025-09-01 12:49:02,712 - INFO - Enhanced simulated analysis for CURR: £193.93 (+0.00%)
# 2025-09-01 12:49:02,723 - INFO - Enhanced simulated analysis for DARE: £362.39 (+0.00%)
# 2025-09-01 12:49:02,735 - INFO - Enhanced simulated analysis for DTIL: £407.94 (+0.00%)
# 2025-09-01 12:49:02,746 - INFO - Enhanced simulated analysis for EDIT: £430.39 (+0.00%)
# 2025-09-01 12:49:02,752 - INFO - BUY signal for EDIT: 3/7 signals
# 2025-09-01 12:49:02,758 - INFO - Enhanced simulated analysis for ELDN: £235.01 (+0.00%)
# 2025-09-01 12:49:02,770 - INFO - Enhanced simulated analysis for EQ: £168.35 (+0.00%)
# 2025-09-01 12:49:02,781 - INFO - Enhanced simulated analysis for ERAS: £490.89 (+0.00%)
# 2025-09-01 12:49:02,793 - INFO - Enhanced simulated analysis for ERNA: £375.36 (+0.00%)
# 2025-09-01 12:49:02,805 - INFO - Enhanced simulated analysis for ESLA: £345.16 (+0.00%)
# 2025-09-01 12:49:02,816 - INFO - Enhanced simulated analysis for ESPR: £446.51 (+0.00%)
# 2025-09-01 12:49:02,827 - INFO - Enhanced simulated analysis for EVGN: £419.03 (+0.00%)
# 2025-09-01 12:49:02,839 - INFO - Enhanced simulated analysis for FATE: £150.78 (+0.00%)
# 2025-09-01 12:49:02,851 - INFO - Enhanced simulated analysis for FBLG: £242.80 (+0.00%)
# 2025-09-01 12:49:02,856 - INFO - Cycle completed: 2 trades executed
# 2025-09-01 12:49:02,857 - INFO - Performance - Total Trades: 2, Win Rate: 50.0%, Total P&L: £-0.60
# 2025-09-01 12:49:02,857 - INFO - Market Overview - Active Positions: 26, Symbols Tracked: 54
# 2025-09-01 12:49:07,858 - INFO - --- Cycle 6 ---
# 2025-09-01 12:49:07,877 - INFO - Enhanced simulated analysis for ABCL: £475.41 (+0.00%)
# 2025-09-01 12:49:07,898 - INFO - Enhanced simulated analysis for ALLO: £91.40 (+0.00%)
# 2025-09-01 12:49:07,907 - INFO - BUY signal for ALLO: 3/7 signals
# 2025-09-01 12:49:07,915 - INFO - Enhanced simulated analysis for ANNX: £402.34 (+0.00%)
# 2025-09-01 12:49:07,929 - INFO - Enhanced simulated analysis for ANRO: £145.29 (+0.00%)
# 2025-09-01 12:49:07,942 - INFO - Enhanced simulated analysis for ANVS: £264.13 (+0.00%)
# 2025-09-01 12:49:07,955 - INFO - Enhanced simulated analysis for APLM: £472.45 (+0.00%)
# 2025-09-01 12:49:07,966 - INFO - Enhanced simulated analysis for APLT: £393.79 (+0.00%)
# 2025-09-01 12:49:07,978 - INFO - Enhanced simulated analysis for APVO: £142.50 (+0.00%)
# 2025-09-01 12:49:07,990 - INFO - Enhanced simulated analysis for ARAY: £385.40 (+0.00%)
# 2025-09-01 12:49:08,001 - INFO - Enhanced simulated analysis for ARBE: £96.94 (+0.00%)
# 2025-09-01 12:49:08,013 - INFO - Enhanced simulated analysis for ATEN: £267.23 (+0.00%)
# 2025-09-01 12:49:08,029 - INFO - Enhanced simulated analysis for ATAI: £360.58 (+0.00%)
# 2025-09-01 12:49:08,041 - INFO - Enhanced simulated analysis for ATHA: £125.65 (+0.00%)
# 2025-09-01 12:49:08,047 - INFO - BUY signal for ATHA: 3/7 signals
# 2025-09-01 12:49:08,053 - INFO - Enhanced simulated analysis for AUTL: £191.31 (+0.00%)
# 2025-09-01 12:49:08,065 - INFO - Enhanced simulated analysis for AVIR: £485.31 (+0.00%)
# 2025-09-01 12:49:08,077 - INFO - Enhanced simulated analysis for CABA: £149.41 (+0.00%)
# 2025-09-01 12:49:08,089 - INFO - Enhanced simulated analysis for CAMP: £281.92 (+0.00%)
# 2025-09-01 12:49:08,100 - INFO - Enhanced simulated analysis for CARM: £474.15 (+0.00%)
# 2025-09-01 12:49:08,112 - INFO - Enhanced simulated analysis for CATX: £296.10 (+0.00%)
# 2025-09-01 12:49:08,123 - INFO - Enhanced simulated analysis for CCCC: £202.24 (+0.00%)
# 2025-09-01 12:49:08,135 - INFO - Enhanced simulated analysis for CELU: £436.93 (+0.00%)
# 2025-09-01 12:49:08,159 - INFO - Enhanced simulated analysis for CERS: £304.44 (+0.00%)
# 2025-09-01 12:49:08,184 - INFO - Enhanced simulated analysis for CGTX: £246.40 (+0.00%)
# 2025-09-01 12:49:08,196 - INFO - Enhanced simulated analysis for CHRS: £146.59 (+0.00%)
# 2025-09-01 12:49:08,202 - INFO - BUY signal for CHRS: 3/7 signals
# 2025-09-01 12:49:08,208 - INFO - Enhanced simulated analysis for CLDI: £193.03 (+0.00%)
# 2025-09-01 12:49:08,220 - INFO - Enhanced simulated analysis for CLLS: £198.83 (+0.00%)
# 2025-09-01 12:49:08,232 - INFO - Enhanced simulated analysis for CLRB: £333.13 (+0.00%)
# 2025-09-01 12:49:08,243 - INFO - Enhanced simulated analysis for CLSD: £142.98 (+0.00%)
# 2025-09-01 12:49:08,255 - INFO - Enhanced simulated analysis for CLYM: £476.68 (+0.00%)
# 2025-09-01 12:49:08,267 - INFO - Enhanced simulated analysis for CMPS: £196.25 (+0.00%)
# 2025-09-01 12:49:08,279 - INFO - Enhanced simulated analysis for CMPX: £390.27 (+0.00%)
# 2025-09-01 12:49:08,291 - INFO - Enhanced simulated analysis for CMTL: £310.23 (+0.00%)
# 2025-09-01 12:49:08,302 - INFO - Enhanced simulated analysis for COCP: £354.31 (+0.00%)
# 2025-09-01 12:49:08,314 - INFO - Enhanced simulated analysis for CRBU: £299.99 (+0.00%)
# 2025-09-01 12:49:08,325 - INFO - Enhanced simulated analysis for CRDF: £203.79 (+0.00%)
# 2025-09-01 12:49:08,337 - INFO - Enhanced simulated analysis for CRDL: £116.11 (+0.00%)
# 2025-09-01 12:49:08,348 - INFO - Enhanced simulated analysis for CRIS: £325.08 (+0.00%)
# 2025-09-01 12:49:08,360 - INFO - Enhanced simulated analysis for CTMX: £90.98 (+0.00%)
# 2025-09-01 12:49:08,371 - INFO - Enhanced simulated analysis for CTOR: £163.94 (+0.00%)
# 2025-09-01 12:49:08,383 - INFO - Enhanced simulated analysis for CTXR: £193.79 (+0.00%)
# 2025-09-01 12:49:08,395 - INFO - Enhanced simulated analysis for CUE: £300.05 (+0.00%)
# 2025-09-01 12:49:08,406 - INFO - Enhanced simulated analysis for CURR: £195.59 (+0.00%)
# 2025-09-01 12:49:08,418 - INFO - Enhanced simulated analysis for DARE: £364.33 (+0.00%)
# 2025-09-01 12:49:08,424 - INFO - BUY signal for DARE: 3/7 signals
# 2025-09-01 12:49:08,431 - INFO - Enhanced simulated analysis for DTIL: £414.04 (+0.00%)
# 2025-09-01 12:49:08,442 - INFO - Enhanced simulated analysis for EDIT: £433.36 (+0.00%)
# 2025-09-01 12:49:08,453 - INFO - Enhanced simulated analysis for ELDN: £235.63 (+0.00%)
# 2025-09-01 12:49:08,465 - INFO - Enhanced simulated analysis for EQ: £170.20 (+0.00%)
# 2025-09-01 12:49:08,477 - INFO - Enhanced simulated analysis for ERAS: £490.20 (+0.00%)
# 2025-09-01 12:49:08,489 - INFO - Enhanced simulated analysis for ERNA: £377.35 (+0.00%)
# 2025-09-01 12:49:08,500 - INFO - Enhanced simulated analysis for ESLA: £342.88 (+0.00%)
# 2025-09-01 12:49:08,512 - INFO - Enhanced simulated analysis for ESPR: £445.80 (+0.00%)
# 2025-09-01 12:49:08,523 - INFO - Enhanced simulated analysis for EVGN: £416.38 (+0.00%)
# 2025-09-01 12:49:08,535 - INFO - Enhanced simulated analysis for FATE: £150.48 (+0.00%)
# 2025-09-01 12:49:08,547 - INFO - Enhanced simulated analysis for FBLG: £242.05 (+0.00%)
# 2025-09-01 12:49:13,559 - INFO - --- Cycle 7 ---
# 2025-09-01 12:49:13,576 - INFO - Enhanced simulated analysis for ABCL: £470.08 (+0.00%)
# 2025-09-01 12:49:13,597 - INFO - Enhanced simulated analysis for ALLO: £90.94 (+0.00%)
# 2025-09-01 12:49:13,613 - INFO - Enhanced simulated analysis for ANNX: £402.49 (+0.00%)
# 2025-09-01 12:49:13,627 - INFO - Enhanced simulated analysis for ANRO: £145.41 (+0.00%)
# 2025-09-01 12:49:13,634 - INFO - BUY signal for ANRO: 3/7 signals
# 2025-09-01 12:49:13,640 - INFO - Enhanced simulated analysis for ANVS: £267.41 (+0.00%)
# 2025-09-01 12:49:13,653 - INFO - Enhanced simulated analysis for APLM: £478.03 (+0.00%)
# 2025-09-01 12:49:13,665 - INFO - Enhanced simulated analysis for APLT: £396.99 (+0.00%)
# 2025-09-01 12:49:13,677 - INFO - Enhanced simulated analysis for APVO: £143.45 (+0.00%)
# 2025-09-01 12:49:13,688 - INFO - Enhanced simulated analysis for ARAY: £383.63 (+0.00%)
# 2025-09-01 12:49:13,700 - INFO - Enhanced simulated analysis for ARBE: £96.51 (+0.00%)
# 2025-09-01 12:49:13,712 - INFO - Enhanced simulated analysis for ATEN: £265.52 (+0.00%)
# 2025-09-01 12:49:13,747 - INFO - Enhanced simulated analysis for ATAI: £357.26 (+0.00%)
# 2025-09-01 12:49:13,763 - INFO - Enhanced simulated analysis for ATHA: £125.00 (+0.00%)
# 2025-09-01 12:49:13,769 - INFO - BUY signal for ATHA: 3/7 signals
# 2025-09-01 12:49:13,775 - INFO - Enhanced simulated analysis for AUTL: £192.64 (+0.00%)
# 2025-09-01 12:49:13,787 - INFO - Enhanced simulated analysis for AVIR: £482.67 (+0.00%)
# 2025-09-01 12:49:13,799 - INFO - Enhanced simulated analysis for CABA: £150.12 (+0.00%)
# 2025-09-01 12:49:13,810 - INFO - Enhanced simulated analysis for CAMP: £283.69 (+0.00%)
# 2025-09-01 12:49:13,822 - INFO - Enhanced simulated analysis for CARM: £474.30 (+0.00%)
# 2025-09-01 12:49:13,834 - INFO - Enhanced simulated analysis for CATX: £296.71 (+0.00%)
# 2025-09-01 12:49:13,846 - INFO - Enhanced simulated analysis for CCCC: £201.69 (+0.00%)
# 2025-09-01 12:49:13,857 - INFO - Enhanced simulated analysis for CELU: £436.19 (+0.00%)
# 2025-09-01 12:49:13,869 - INFO - Enhanced simulated analysis for CERS: £302.69 (+0.00%)
# 2025-09-01 12:49:13,881 - INFO - Enhanced simulated analysis for CGTX: £248.33 (+0.00%)
# 2025-09-01 12:49:13,893 - INFO - Enhanced simulated analysis for CHRS: £146.80 (+0.00%)
# 2025-09-01 12:49:13,905 - INFO - Enhanced simulated analysis for CLDI: £195.09 (+0.00%)
# 2025-09-01 12:49:13,917 - INFO - Enhanced simulated analysis for CLLS: £199.69 (+0.00%)
# 2025-09-01 12:49:13,923 - INFO - SELL signal for CLLS: 3/7 signals
# 2025-09-01 12:49:13,923 - INFO - Simulated SELL order placed: 1 CLLS
# 2025-09-01 12:49:13,923 - INFO - SIMULATED SELL: 0 CLLS @ £199.69 (Value: £199.69, P&L: £199.69, Balance: £257.63)
# 2025-09-01 12:49:13,924 - INFO - CLLS indicators - RSI: 40.9, MACD: 0.081, Volatility: 0.13%
# 2025-09-01 12:49:13,931 - INFO - Enhanced simulated analysis for CLRB: £332.98 (+0.00%)
# 2025-09-01 12:49:13,943 - INFO - Enhanced simulated analysis for CLSD: £143.94 (+0.00%)
# 2025-09-01 12:49:13,954 - INFO - Enhanced simulated analysis for CLYM: £477.31 (+0.00%)
# 2025-09-01 12:49:13,961 - INFO - BUY signal for CLYM: 3/7 signals
# 2025-09-01 12:49:13,967 - INFO - Enhanced simulated analysis for CMPS: £195.57 (+0.00%)
# 2025-09-01 12:49:13,978 - INFO - Enhanced simulated analysis for CMPX: £393.13 (+0.00%)
# 2025-09-01 12:49:13,990 - INFO - Enhanced simulated analysis for CMTL: £308.29 (+0.00%)
# 2025-09-01 12:49:14,001 - INFO - Enhanced simulated analysis for COCP: £351.51 (+0.00%)
# 2025-09-01 12:49:14,013 - INFO - Enhanced simulated analysis for CRBU: £297.08 (+0.00%)
# 2025-09-01 12:49:14,025 - INFO - Enhanced simulated analysis for CRDF: £202.08 (+0.00%)
# 2025-09-01 12:49:14,037 - INFO - Enhanced simulated analysis for CRDL: £116.83 (+0.00%)
# 2025-09-01 12:49:14,048 - INFO - Enhanced simulated analysis for CRIS: £324.07 (+0.00%)
# 2025-09-01 12:49:14,060 - INFO - Enhanced simulated analysis for CTMX: £90.39 (+0.00%)
# 2025-09-01 12:49:14,071 - INFO - Enhanced simulated analysis for CTOR: £162.70 (+0.00%)
# 2025-09-01 12:49:14,083 - INFO - Enhanced simulated analysis for CTXR: £192.77 (+0.00%)
# 2025-09-01 12:49:14,095 - INFO - Enhanced simulated analysis for CUE: £301.83 (+0.00%)
# 2025-09-01 12:49:14,101 - INFO - BUY signal for CUE: 3/7 signals
# 2025-09-01 12:49:14,107 - INFO - Enhanced simulated analysis for CURR: £195.90 (+0.00%)
# 2025-09-01 12:49:14,119 - INFO - Enhanced simulated analysis for DARE: £368.74 (+0.00%)
# 2025-09-01 12:49:14,131 - INFO - Enhanced simulated analysis for DTIL: £419.44 (+0.00%)
# 2025-09-01 12:49:14,142 - INFO - Enhanced simulated analysis for EDIT: £433.37 (+0.00%)
# 2025-09-01 12:49:14,149 - INFO - BUY signal for EDIT: 3/7 signals
# 2025-09-01 12:49:14,154 - INFO - Enhanced simulated analysis for ELDN: £234.43 (+0.00%)
# 2025-09-01 12:49:14,166 - INFO - Enhanced simulated analysis for EQ: £171.06 (+0.00%)
# 2025-09-01 12:49:14,177 - INFO - Enhanced simulated analysis for ERAS: £488.97 (+0.00%)
# 2025-09-01 12:49:14,189 - INFO - Enhanced simulated analysis for ERNA: £378.67 (+0.00%)
# 2025-09-01 12:49:14,201 - INFO - Enhanced simulated analysis for ESLA: £343.41 (+0.00%)
# 2025-09-01 12:49:14,212 - INFO - Enhanced simulated analysis for ESPR: £449.87 (+0.00%)
# 2025-09-01 12:49:14,223 - INFO - Enhanced simulated analysis for EVGN: £418.17 (+0.00%)
# 2025-09-01 12:49:14,230 - INFO - BUY signal for EVGN: 3/7 signals
# 2025-09-01 12:49:14,236 - INFO - Enhanced simulated analysis for FATE: £149.96 (+0.00%)
# 2025-09-01 12:49:14,247 - INFO - Enhanced simulated analysis for FBLG: £241.39 (+0.00%)
# ...
# 2025-09-01 12:52:04,989 - INFO -   ELDN: No position
# 2025-09-01 12:52:04,996 - INFO - Enhanced simulated analysis for FATE: £158.30 (+0.00%)
# 2025-09-01 12:52:04,996 - INFO -   FATE: 1 shares @ £150.89 (Current: £158.30, P&L: £+7.41 +4.9%)
# 2025-09-01 12:52:04,997 - INFO -   ATAI: No position
# 2025-09-01 12:52:05,003 - INFO - Enhanced simulated analysis for CRDF: £216.23 (+0.00%)
# 2025-09-01 12:52:05,004 - INFO -   CRDF: 1 shares @ £200.14 (Current: £216.23, P&L: £+16.09 +8.0%)
# 2025-09-01 12:52:05,010 - INFO - Enhanced simulated analysis for CRDL: £118.25 (+0.00%)
# 2025-09-01 12:52:05,011 - INFO -   CRDL: 1 shares @ £113.26 (Current: £118.25, P&L: £+4.99 +4.4%)
# 2025-09-01 12:52:05,011 - INFO -   CURR: No position
# 2025-09-01 12:52:05,011 - INFO -   FBLG: No position
# 2025-09-01 12:52:05,012 - INFO -   APVO: No position
# 2025-09-01 12:52:05,018 - INFO - Enhanced simulated analysis for CLLS: £195.04 (+0.00%)
# 2025-09-01 12:52:05,019 - INFO -   CLLS: 1 shares @ £200.38 (Current: £195.04, P&L: £-5.34 -2.7%)
# 2025-09-01 12:52:05,025 - INFO - Enhanced simulated analysis for ANRO: £143.61 (+0.00%)
# 2025-09-01 12:52:05,026 - INFO -   ANRO: 1 shares @ £145.45 (Current: £143.61, P&L: £-1.84 -1.3%)
# 2025-09-01 12:52:05,026 - INFO -   CELU: No position
# 2025-09-01 12:52:05,033 - INFO - Enhanced simulated analysis for ANVS: £266.97 (+0.00%)
# 2025-09-01 12:52:05,033 - INFO -   ANVS: 1 shares @ £267.83 (Current: £266.97, P&L: £-0.86 -0.3%)
# 2025-09-01 12:52:05,040 - INFO - Enhanced simulated analysis for AUTL: £200.61 (+0.00%)
# 2025-09-01 12:52:05,040 - INFO -   AUTL: 1 shares @ £190.68 (Current: £200.61, P&L: £+9.93 +5.2%)
# 2025-09-01 12:52:05,040 - INFO -   COCP: No position
# 2025-09-01 12:52:05,041 - INFO -   ATHA: No position
# 2025-09-01 12:52:05,048 - INFO - Enhanced simulated analysis for CCCC: £197.22 (+0.00%)
# 2025-09-01 12:52:05,048 - INFO -   CCCC: 1 shares @ £199.05 (Current: £197.22, P&L: £-1.83 -0.9%)
# 2025-09-01 12:52:05,055 - INFO - Enhanced simulated analysis for ESPR: £432.72 (+0.00%)
# 2025-09-01 12:52:05,055 - INFO -   ESPR: 1 shares @ £433.15 (Current: £432.72, P&L: £-0.43 -0.1%)
# 2025-09-01 12:52:05,062 - INFO - Enhanced simulated analysis for ALLO: £90.12 (+0.00%)
# 2025-09-01 12:52:05,062 - INFO -   ALLO: 1 shares @ £87.99 (Current: £90.12, P&L: £+2.13 +2.4%)
# 2025-09-01 12:52:05,079 - INFO - Enhanced simulated analysis for CTXR: £193.16 (+0.00%)
# 2025-09-01 12:52:05,080 - INFO -   CTXR: 1 shares @ £191.28 (Current: £193.16, P&L: £+1.88 +1.0%)
# 2025-09-01 12:52:05,104 - INFO - Enhanced simulated analysis for ARBE: £96.94 (+0.00%)
# 2025-09-01 12:52:05,105 - INFO -   ARBE: 1 shares @ £96.51 (Current: £96.94, P&L: £+0.43 +0.4%)
# 2025-09-01 12:52:05,113 - INFO - Enhanced simulated analysis for CRBU: £293.43 (+0.00%)
# 2025-09-01 12:52:05,113 - INFO -   CRBU: 1 shares @ £291.82 (Current: £293.43, P&L: £+1.61 +0.6%)
# 2025-09-01 12:52:05,120 - INFO - Enhanced simulated analysis for CTMX: £83.26 (+0.00%)
# 2025-09-01 12:52:05,120 - INFO -   CTMX: 1 shares @ £83.95 (Current: £83.26, P&L: £-0.69 -0.8%)
# 2025-09-01 12:52:05,121 - INFO - Total Position Value: £9542.73
# 2025-09-01 12:52:05,121 - INFO - Technical Indicators Summary:
# 2025-09-01 12:52:05,121 - INFO -   ABCL: RSI: 34.6, MACD: -98.142, Vol: 0.2%
# 2025-09-01 12:52:05,122 - INFO -   ALLO: RSI: 52.5, MACD: 8.608, Vol: 0.2%
# 2025-09-01 12:52:05,122 - INFO -   ANNX: RSI: 80.4, MACD: 144.582, Vol: 0.2%
# 2025-09-01 12:52:05,122 - INFO -   ANRO: RSI: 45.6, MACD: -141.552, Vol: 0.2%
# 2025-09-01 12:52:05,122 - INFO -   ANVS: RSI: 77.5, MACD: 195.018, Vol: 0.2%
# 2025-09-01 12:52:05,123 - INFO -   APLM: RSI: 54.4, MACD: 9.962, Vol: 0.1%
# 2025-09-01 12:52:05,123 - INFO -   APLT: RSI: 27.7, MACD: -259.786, Vol: 0.2%
# 2025-09-01 12:52:05,123 - INFO -   APVO: RSI: 31.7, MACD: -87.976, Vol: 0.2%
# 2025-09-01 12:52:05,123 - INFO -   ARAY: RSI: 53.3, MACD: 78.420, Vol: 0.2%
# 2025-09-01 12:52:05,124 - INFO -   ARBE: RSI: 46.7, MACD: -42.596, Vol: 0.1%
# 2025-09-01 12:52:05,124 - INFO -   ATEN: RSI: 59.0, MACD: 75.506, Vol: 0.2%
# 2025-09-01 12:52:05,124 - INFO -   ATAI: RSI: 65.1, MACD: 91.718, Vol: 0.2%
# 2025-09-01 12:52:05,125 - INFO -   ATHA: RSI: 40.0, MACD: -63.897, Vol: 0.1%
# 2025-09-01 12:52:05,125 - INFO -   AUTL: RSI: 47.7, MACD: 48.051, Vol: 0.2%
# 2025-09-01 12:52:05,125 - INFO -   AVIR: RSI: 20.7, MACD: 0.638, Vol: 0.2%
# 2025-09-01 12:52:05,125 - INFO -   CABA: RSI: 47.9, MACD: -104.932, Vol: 0.2%
# 2025-09-01 12:52:05,125 - INFO -   CAMP: RSI: 41.1, MACD: -76.911, Vol: 0.2%
# 2025-09-01 12:52:05,126 - INFO -   CARM: RSI: 39.3, MACD: -16.766, Vol: 0.3%
# 2025-09-01 12:52:05,126 - INFO -   CATX: RSI: 56.1, MACD: 18.368, Vol: 0.2%
# 2025-09-01 12:52:05,126 - INFO -   CCCC: RSI: 54.1, MACD: -67.548, Vol: 0.2%
# 2025-09-01 12:52:05,127 - INFO -   CELU: RSI: 55.8, MACD: 5.441, Vol: 0.2%
# 2025-09-01 12:52:05,127 - INFO -   CERS: RSI: 56.9, MACD: 75.910, Vol: 0.2%
# 2025-09-01 12:52:05,127 - INFO -   CGTX: RSI: 58.2, MACD: 61.028, Vol: 0.2%
# 2025-09-01 12:52:05,127 - INFO -   CHRS: RSI: 70.5, MACD: 10.063, Vol: 0.2%
# 2025-09-01 12:52:05,128 - INFO -   CLDI: RSI: 47.6, MACD: -16.188, Vol: 0.3%
# 2025-09-01 12:52:05,129 - INFO -   CLLS: RSI: 66.8, MACD: 5.966, Vol: 0.2%
# 2025-09-01 12:52:05,129 - INFO -   CLRB: RSI: 46.1, MACD: 114.799, Vol: 0.2%
# 2025-09-01 12:52:05,129 - INFO -   CLSD: RSI: 50.1, MACD: -328.526, Vol: 0.2%
# 2025-09-01 12:52:05,130 - INFO -   CLYM: RSI: 30.7, MACD: -14.269, Vol: 0.2%
# 2025-09-01 12:52:05,130 - INFO -   CMPS: RSI: 47.6, MACD: -38.154, Vol: 0.2%
# 2025-09-01 12:52:05,130 - INFO -   CMPX: RSI: 58.4, MACD: 26.363, Vol: 0.2%
# 2025-09-01 12:52:05,131 - INFO -   CMTL: RSI: 25.7, MACD: -213.325, Vol: 0.2%
# 2025-09-01 12:52:05,131 - INFO -   COCP: RSI: 31.0, MACD: -109.395, Vol: 0.2%
# 2025-09-01 12:52:05,131 - INFO -   CRBU: RSI: 74.1, MACD: 719.180, Vol: 0.2%
# 2025-09-01 12:52:05,131 - INFO -   CRDF: RSI: 50.9, MACD: -45.750, Vol: 0.2%
# 2025-09-01 12:52:05,132 - INFO -   CRDL: RSI: 30.3, MACD: -107.801, Vol: 0.2%
# 2025-09-01 12:52:05,132 - INFO -   CRIS: RSI: 45.6, MACD: -73.339, Vol: 0.2%
# 2025-09-01 12:52:05,132 - INFO -   CTMX: RSI: 51.9, MACD: 312.289, Vol: 0.3%
# 2025-09-01 12:52:05,133 - INFO -   CTOR: RSI: 32.5, MACD: -27.690, Vol: 0.2%
# 2025-09-01 12:52:05,133 - INFO -   CTXR: RSI: 81.4, MACD: 52.849, Vol: 0.3%
# 2025-09-01 12:52:05,133 - INFO -   CUE: RSI: 37.3, MACD: -2.676, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   CURR: RSI: 46.4, MACD: 0.687, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   DARE: RSI: 56.9, MACD: 74.924, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   DTIL: RSI: 59.4, MACD: 104.275, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   EDIT: RSI: 68.7, MACD: 14.610, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   ELDN: RSI: 49.2, MACD: 114.029, Vol: 0.2%
# 2025-09-01 12:52:05,134 - INFO -   EQ: RSI: 31.4, MACD: -68.234, Vol: 0.2%
# 2025-09-01 12:52:05,135 - INFO -   ERAS: RSI: 56.5, MACD: 24.532, Vol: 0.2%
# 2025-09-01 12:52:05,135 - INFO -   ERNA: RSI: 46.5, MACD: 22.152, Vol: 0.2%
# 2025-09-01 12:52:05,135 - INFO -   ESLA: RSI: 81.5, MACD: 98.761, Vol: 0.2%
# 2025-09-01 12:52:05,135 - INFO -   ESPR: RSI: 18.7, MACD: -37.994, Vol: 0.1%
# 2025-09-01 12:52:05,135 - INFO -   EVGN: RSI: 52.1, MACD: -65.942, Vol: 0.2%
# 2025-09-01 12:52:05,135 - INFO -   FATE: RSI: 57.0, MACD: -9.798, Vol: 0.2%
# 2025-09-01 12:52:05,136 - INFO -   FBLG: RSI: 55.5, MACD: -2.567, Vol: 0.1%
# 2025-09-01 12:52:05,136 - INFO - ==================================================
# 2025-09-01 12:52:05,149 - INFO - Enhanced simulated analysis for ANNX: £394.36 (+0.00%)
# 2025-09-01 12:52:05,176 - INFO - Enhanced simulated analysis for CGTX: £251.54 (+0.00%)
# 2025-09-01 12:52:05,188 - INFO - Enhanced simulated analysis for CHRS: £144.05 (+0.00%)
# 2025-09-01 12:52:05,196 - INFO - Enhanced simulated analysis for CLSD: £145.10 (+0.00%)
# 2025-09-01 12:52:05,204 - INFO - Enhanced simulated analysis for CMPS: £189.11 (+0.00%)
# 2025-09-01 12:52:05,213 - INFO - Enhanced simulated analysis for CMTL: £311.82 (+0.00%)
# 2025-09-01 12:52:05,223 - INFO - Enhanced simulated analysis for APLM: £474.46 (+0.00%)
# 2025-09-01 12:52:05,229 - INFO - Enhanced simulated analysis for ARAY: £411.66 (+0.00%)
# 2025-09-01 12:52:05,236 - INFO - Enhanced simulated analysis for CABA: £143.47 (+0.00%)
# 2025-09-01 12:52:05,242 - INFO - Enhanced simulated analysis for EQ: £175.16 (+0.00%)
# 2025-09-01 12:52:05,249 - INFO - Enhanced simulated analysis for APLT: £374.23 (+0.00%)
# 2025-09-01 12:52:05,255 - INFO - Enhanced simulated analysis for ATEN: £263.99 (+0.00%)
# 2025-09-01 12:52:05,262 - INFO - Enhanced simulated analysis for CLDI: £192.01 (+0.00%)
# 2025-09-01 12:52:05,268 - INFO - Enhanced simulated analysis for CLRB: £330.18 (+0.00%)
# 2025-09-01 12:52:05,274 - INFO - Enhanced simulated analysis for CTOR: £147.80 (+0.00%)
# 2025-09-01 12:52:05,281 - INFO - Enhanced simulated analysis for FATE: £157.12 (+0.00%)
# 2025-09-01 12:52:05,287 - INFO - Enhanced simulated analysis for CRDF: £216.89 (+0.00%)
# 2025-09-01 12:52:05,294 - INFO - Enhanced simulated analysis for CRDL: £117.52 (+0.00%)
# 2025-09-01 12:52:05,300 - INFO - Enhanced simulated analysis for CLLS: £195.92 (+0.00%)
# 2025-09-01 12:52:05,305 - INFO - Enhanced simulated analysis for ANRO: £143.86 (+0.00%)
# 2025-09-01 12:52:05,312 - INFO - Enhanced simulated analysis for ANVS: £266.14 (+0.00%)
# 2025-09-01 12:52:05,318 - INFO - Enhanced simulated analysis for AUTL: £200.64 (+0.00%)
# 2025-09-01 12:52:05,324 - INFO - Enhanced simulated analysis for CCCC: £196.17 (+0.00%)
# 2025-09-01 12:52:05,331 - INFO - Enhanced simulated analysis for ESPR: £434.29 (+0.00%)
# 2025-09-01 12:52:05,338 - INFO - Enhanced simulated analysis for ALLO: £89.95 (+0.00%)
# 2025-09-01 12:52:05,344 - INFO - Enhanced simulated analysis for CTXR: £193.27 (+0.00%)
# 2025-09-01 12:52:05,354 - INFO - Enhanced simulated analysis for ARBE: £97.63 (+0.00%)
# 2025-09-01 12:52:05,360 - INFO - Enhanced simulated analysis for CRBU: £291.61 (+0.00%)
# 2025-09-01 12:52:05,367 - INFO - Enhanced simulated analysis for CTMX: £82.73 (+0.00%)
# 2025-09-01 12:52:05,367 - INFO - Disconnected from trading simulator
# Enhanced Backtest Results:
# Total Trades: 61
# Cash Balance: £378.99
# Portfolio Value: £9938.83
# Total Return: £-61.17 (-0.61%)
# Win Rate: 25.0%
# Profitable Trades: 4/16
# Realised P&L: £-78.28
# Unrealised P&L: £+17.11
#
# Final Positions:
#   ANNX: 2 shares @ £404.23 (Cost: £808.46)
#   CGTX: 4 shares @ £245.02 (Cost: £980.08)
#   CHRS: 1 shares @ £146.10 (Cost: £146.10)
#   CLSD: 5 shares @ £146.86 (Cost: £734.30)
#   CMPS: 4 shares @ £194.19 (Cost: £776.76)
#   CMTL: 2 shares @ £308.54 (Cost: £617.08)
#   APLM: 1 shares @ £479.56 (Cost: £479.56)
#   ARAY: 1 shares @ £388.64 (Cost: £388.64)
#   CABA: 2 shares @ £147.96 (Cost: £295.92)
#   EQ: 2 shares @ £167.34 (Cost: £334.68)
#   APLT: 1 shares @ £388.13 (Cost: £388.13)
#   ATEN: 1 shares @ £264.52 (Cost: £264.52)
#   CLDI: 1 shares @ £191.49 (Cost: £191.49)
#   CLRB: 1 shares @ £336.63 (Cost: £336.63)
#   CTOR: 1 shares @ £148.00 (Cost: £148.00)
#   FATE: 1 shares @ £150.89 (Cost: £150.89)
#   CRDF: 1 shares @ £200.14 (Cost: £200.14)
#   CRDL: 1 shares @ £113.26 (Cost: £113.26)
#   CLLS: 1 shares @ £200.38 (Cost: £200.38)
#   ANRO: 1 shares @ £145.45 (Cost: £145.45)
#   ANVS: 1 shares @ £267.83 (Cost: £267.83)
#   AUTL: 1 shares @ £190.68 (Cost: £190.68)
#   CCCC: 1 shares @ £199.05 (Cost: £199.05)
#   ESPR: 1 shares @ £433.15 (Cost: £433.15)
#   ALLO: 1 shares @ £87.99 (Cost: £87.99)
#   CTXR: 1 shares @ £191.28 (Cost: £191.28)
#   ARBE: 1 shares @ £96.51 (Cost: £96.51)
#   CRBU: 1 shares @ £291.82 (Cost: £291.82)
#   CTMX: 1 shares @ £83.95 (Cost: £83.95)
#
# Technical Analysis Summary:
#   ABCL: RSI: 34.6 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ALLO: RSI: 51.4 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   ANNX: RSI: 95.7 (Overbought), MACD: Bullish, Volatility: Low (0.2%)
#   ANRO: RSI: 74.4 (Overbought), MACD: Bullish, Volatility: Low (0.2%)
#   ANVS: RSI: 63.0 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   APLM: RSI: 48.3 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   APLT: RSI: 46.4 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   APVO: RSI: 31.7 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ARAY: RSI: 33.2 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ARBE: RSI: 68.7 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   ATEN: RSI: 62.6 (Neutral), MACD: Bearish, Volatility: Low (0.3%)
#   ATAI: RSI: 65.1 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ATHA: RSI: 40.0 (Neutral), MACD: Bullish, Volatility: Low (0.1%)
#   AUTL: RSI: 57.3 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   AVIR: RSI: 20.7 (Oversold), MACD: Bearish, Volatility: Low (0.2%)
#   CABA: RSI: 53.7 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CAMP: RSI: 41.1 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CARM: RSI: 39.3 (Neutral), MACD: Bearish, Volatility: Low (0.3%)
#   CATX: RSI: 56.1 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CCCC: RSI: 62.0 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CELU: RSI: 55.8 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CERS: RSI: 56.9 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CGTX: RSI: 50.8 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CHRS: RSI: 60.3 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CLDI: RSI: 49.7 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CLLS: RSI: 75.4 (Overbought), MACD: Bullish, Volatility: Low (0.2%)
#   CLRB: RSI: 55.7 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CLSD: RSI: 49.4 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CLYM: RSI: 30.7 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CMPS: RSI: 22.7 (Oversold), MACD: Bearish, Volatility: Low (0.2%)
#   CMPX: RSI: 58.4 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CMTL: RSI: 58.3 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   COCP: RSI: 31.0 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CRBU: RSI: 63.1 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CRDF: RSI: 56.5 (Neutral), MACD: Bullish, Volatility: Low (0.1%)
#   CRDL: RSI: 30.6 (Neutral), MACD: Bearish, Volatility: Low (0.3%)
#   CRIS: RSI: 45.6 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   CTMX: RSI: 38.4 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CTOR: RSI: 50.7 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CTXR: RSI: 78.2 (Overbought), MACD: Bullish, Volatility: Low (0.1%)
#   CUE: RSI: 37.3 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   CURR: RSI: 46.4 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   DARE: RSI: 56.9 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   DTIL: RSI: 59.4 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   EDIT: RSI: 68.7 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   ELDN: RSI: 49.2 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   EQ: RSI: 53.4 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   ERAS: RSI: 56.5 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ERNA: RSI: 46.5 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   ESLA: RSI: 81.5 (Overbought), MACD: Bullish, Volatility: Low (0.2%)
#   ESPR: RSI: 53.8 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   EVGN: RSI: 52.1 (Neutral), MACD: Bullish, Volatility: Low (0.2%)
#   FATE: RSI: 51.9 (Neutral), MACD: Bearish, Volatility: Low (0.2%)
#   FBLG: RSI: 55.5 (Neutral), MACD: Bullish, Volatility: Low (0.1%)
#
# Simple Backtest Results:
# Trades: 61
# Final Balance: £378.99
# Portfolio Value: £9,938.83
# Return: £-61.17 (-0.61%)
# Win Rate: 25.0%
# ANNX: 2 shares @ £404.23
# CGTX: 4 shares @ £245.02
# CHRS: 1 shares @ £146.10
# CLSD: 5 shares @ £146.86
# CMPS: 4 shares @ £194.19
# CMTL: 2 shares @ £308.54
# APLM: 1 shares @ £479.56
# ARAY: 1 shares @ £388.64
# CABA: 2 shares @ £147.96
# EQ: 2 shares @ £167.34
# APLT: 1 shares @ £388.13
# ATEN: 1 shares @ £264.52
# CLDI: 1 shares @ £191.49
# CLRB: 1 shares @ £336.63
# CTOR: 1 shares @ £148.00
# FATE: 1 shares @ £150.89
# CRDF: 1 shares @ £200.14
# CRDL: 1 shares @ £113.26
# CLLS: 1 shares @ £200.38
# ANRO: 1 shares @ £145.45
# ANVS: 1 shares @ £267.83
# AUTL: 1 shares @ £190.68
# CCCC: 1 shares @ £199.05
# ESPR: 1 shares @ £433.15
# ALLO: 1 shares @ £87.99
# CTXR: 1 shares @ £191.28
# ARBE: 1 shares @ £96.51
# CRBU: 1 shares @ £291.82
# CTMX: 1 shares @ £83.95

# %% [markdown]
# ### Paper Trading Test (Requires IB connection)

# %%
print("="*60)
print("Paper Trading Test")
print("="*60)
print("NOTE: Requires TWS or IB Gateway running on port 7497")

# Simple paper trading connection test
success = test_bot_connection('paper')

if success:
    print("\nPaper trading connection successful")
    
    # Test one symbol with enhanced analysis
    print("\nTesting enhanced analysis on paper trading:")
    test_historical_data('MRK', 'paper')
    
else:
    print("\nPaper trading connection failed")
    print("\nSetup Instructions:")
    print("1. Start TWS or IB Gateway")
    print("2. Switch to Paper Trading mode")
    print("3. Configure API settings:")
    print("   - Enable 'ActiveX and Socket Clients'")
    print("   - Set Socket port to 7497")
    print("   - Disable 'Read-Only API'")
    print("   - Add 127.0.0.1 to trusted IPs")
    print("4. Restart TWS/Gateway")
    
    print("\nAlternative: Use simulator for testing")
    print("test_bot_connection('simulator')")
# Out:
# 2025-09-01 12:52:50,721 - INFO - Initialised for Paper Trading (Demo Account)
# 2025-09-01 12:52:50,722 - INFO - Trading bot initialised for paper trading
# 2025-09-01 12:52:50,722 - INFO - Strategy: Enhanced_10_30
# ============================================================
# Paper Trading Test
# ============================================================
# NOTE: Requires TWS or IB Gateway running on port 7497
# Testing paper trading connection...
# 2025-09-01 12:52:51,263 - INFO - ✓ Connected to IB on port 7497
# 2025-09-01 12:52:51,264 - INFO - Account: DUM797459
# 2025-09-01 12:52:51,265 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:52:51,266 - INFO - Trading bot connected successfully
# 2025-09-01 12:52:51,491 - INFO - Account Net Liquidation: £1000093.76
# 2025-09-01 12:52:51,491 - INFO - Buying Power: £4000000.00
# Connection to paper trading successful
#
# Testing enhanced analysis capabilities...
# 2025-09-01 12:52:53,017 - INFO - Retrieved 1170 historical bars for MRK
# 2025-09-01 12:52:53,384 - INFO - Retrieved 22 historical bars for MRK
# 2025-09-01 12:52:55,386 - WARNING - No valid market data for MRK
# 2025-09-01 12:52:55,389 - INFO - Enhanced analysis for MRK: £84.14 (+0.00%)
#   MRK: £84.14
#     Indicators: RSI: 71.2, MACD: 0.036, Vol: 0.1%
#     Buy Signals: 3/7
#     Sell Signals: 3/7
# 2025-09-01 12:52:55,922 - INFO - Retrieved 1170 historical bars for UNH
# 2025-09-01 12:52:56,269 - INFO - Retrieved 22 historical bars for UNH
# 2025-09-01 12:52:58,272 - WARNING - No valid market data for UNH
# 2025-09-01 12:52:58,276 - INFO - Enhanced analysis for UNH: £309.98 (+0.00%)
#   UNH: £309.98
#     Indicators: RSI: 68.1, MACD: 0.334, Vol: 0.1%
#     Buy Signals: 3/7
#     Sell Signals: 2/7
#
# Account Information:
#   Net Liquidation: £1000093.76
#   Buying Power: £4000000.00
#   Available Funds: £1000000.00
#
# Diagnostic Check:
# 2025-09-01 12:52:59,060 - INFO - Retrieved 1170 historical bars for ABCL
# 2025-09-01 12:52:59,496 - INFO - Retrieved 22 historical bars for ABCL
# 2025-09-01 12:53:01,499 - WARNING - No valid market data for ABCL
# 2025-09-01 12:53:01,501 - INFO - Enhanced analysis for ABCL: £4.17 (+0.00%)
# 2025-09-01 12:53:02,247 - INFO - Retrieved 1170 historical bars for ALLO
# 2025-09-01 12:53:02,582 - INFO - Retrieved 22 historical bars for ALLO
# 2025-09-01 12:53:04,586 - WARNING - No valid market data for ALLO
# 2025-09-01 12:53:04,588 - INFO - Enhanced analysis for ALLO: £1.14 (+0.00%)
# 2025-09-01 12:53:04,589 - INFO - All market data subscriptions cancelled
# 2025-09-01 12:53:04,591 - INFO - Disconnected from IB
# 2025-09-01 12:53:04,592 - INFO - Trading bot disconnected
# 2025-09-01 12:53:04,595 - INFO - Initialised for Paper Trading (Demo Account)
# 2025-09-01 12:53:04,597 - INFO - Trading bot initialised for paper trading
# 2025-09-01 12:53:04,598 - INFO - Strategy: Enhanced_10_30
#   Connection: Connected
#   Components: 4/4 initialised
#   Strategy: Enhanced_10_30
#   Risk Management: Stop Loss 5.0%, Take Profit 15.0%
#
# Paper trading connection successful
#
# Testing enhanced analysis on paper trading:
# Testing enhanced historical data for MRK in paper environment...
# 2025-09-01 12:53:05,144 - INFO - ✓ Connected to IB on port 7497
# 2025-09-01 12:53:05,145 - INFO - Account: DUM797459
# 2025-09-01 12:53:05,145 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:53:05,146 - INFO - Trading bot connected successfully
# 2025-09-01 12:53:05,354 - INFO - Account Net Liquidation: £1000093.76
# 2025-09-01 12:53:05,355 - INFO - Buying Power: £4000000.00
# 1. Enhanced Market Analysis:
# 2025-09-01 12:53:05,880 - INFO - Retrieved 1170 historical bars for MRK
# 2025-09-01 12:53:06,215 - INFO - Retrieved 22 historical bars for MRK
# 2025-09-01 12:53:08,219 - WARNING - No valid market data for MRK
# 2025-09-01 12:53:08,221 - INFO - Enhanced analysis for MRK: £84.14 (+0.00%)
#    Current price: £84.14
#    Price change: +0.00%
#    Technical Indicators:
#      RSI: 71.2 (Overbought)
#      MACD: 0.036 vs Signal: 0.012 (Bullish)
#      Bollinger Bands: £83.83 - £84.16 (Within Bands)
#      Volatility: 0.05% (Low)
#      Volume Activity: 4.8x average (High)
#    Signal Evaluation:
#      Buy Signals: 3/7 active
#      Sell Signals: 3/7 active
#      Active Buy Signal Types: [0, 3, 4]
#      Active Sell Signal Types: [1, 2, 5]
#    Daily Trend: bullish (Strength: 1.3%)
#    5-Day Momentum: -1.39%
#    20-Day Momentum: +5.33%
#
# 2. Historical Data Timeframes:
# 2025-09-01 12:53:08,681 - INFO - Retrieved 390 historical bars for MRK
#    Intraday (1 day): 390 data points
#    Latest price: £84.14
#    Date range: 2025-08-29 09:30:00-04:00 to 2025-08-29 15:59:00-04:00
# 2025-09-01 12:53:09,012 - INFO - Retrieved 22 historical bars for MRK
# 2025-09-01 12:53:09,014 - INFO - All market data subscriptions cancelled
# 2025-09-01 12:53:09,015 - INFO - Disconnected from IB
# 2025-09-01 12:53:09,016 - INFO - Trading bot disconnected
#    Daily (1 month): 22 data points
#    Monthly return: +7.68%
#
# 3. Strategy Status:
#    Position: 0 shares
#    Price History Length: 0
#    Technical Indicators Count: 23
#    Recent Signals: 0

# %% [markdown]
# ### Advanced Trading Bot

# %%
print("="*60)
print("Advanced Trading Bot Test")
print("="*60)

# Create enhanced bot with custom settings
bot = create_trading_bot(
    environment='simulator',
    strategy_type='enhanced',
    short_window=5,
    long_window=15,
    stop_loss_pct=0.04,
    take_profit_pct=0.12
)

# Configure symbols and update speed
# Set the bot's tracked symbols
bot.set_symbols([
    'ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG'
])
bot.update_interval = 3  # Fast updates for demo

print(f"Bot Environment: {bot.environment}")
print(f"Strategy: {bot.strategy.name}")
print(f"Symbols: {bot.symbols}")
print(f"Risk Management: SL {bot.strategy.stop_loss_pct*100:.1f}%, TP {bot.strategy.take_profit_pct*100:.1f}%")

# Connect and run
if bot.connect():
    print("\nRunning 5 cycles...")
    
    try:
        bot.start_trading(max_cycles=5)
        
        # Show results
        print(f"\nResults:")
        print(f"Trades: {bot.trades_executed}")
        print(f"Balance: £{bot.simulated_balance:,.2f}")
        
        # Show positions
        for symbol, position in bot.strategy.positions.items():
            if position['shares'] > 0:
                value = position['shares'] * position['avg_price']
                print(f"{symbol}: {position['shares']} shares @ £{position['avg_price']:.2f} (£{value:.2f})")
                
    finally:
        bot.disconnect()
else:
    print("Failed to connect")
# Out:
# 2025-09-01 12:53:25,653 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:53:25,655 - INFO - Trading bot simulator initialised
# 2025-09-01 12:53:25,655 - INFO - Strategy: Enhanced_5_15
# 2025-09-01 12:53:25,658 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:53:25,660 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:53:25,663 - INFO - Connected to trading simulator
# 2025-09-01 12:53:25,663 - INFO - Starting automated trading...
# 2025-09-01 12:53:25,664 - INFO - Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:53:25,665 - INFO - Strategy: Enhanced_5_15
# 2025-09-01 12:53:25,666 - INFO - Update interval: 3 seconds
# 2025-09-01 12:53:25,666 - INFO - Strategy config - Short: 5, Long: 15, Stop Loss: 4.0%, Take Profit: 12.0%
# 2025-09-01 12:53:25,671 - INFO - --- Cycle 1 ---
# 2025-09-01 12:53:25,695 - INFO - Enhanced simulated analysis for ABCL: £100.48 (+0.00%)
# 2025-09-01 12:53:25,710 - INFO - Enhanced simulated analysis for ALLO: £124.51 (+0.00%)
# 2025-09-01 12:53:25,722 - INFO - Enhanced simulated analysis for ANNX: £218.38 (+0.00%)
# 2025-09-01 12:53:25,729 - INFO - BUY signal for ANNX: 3/7 signals
# 2025-09-01 12:53:25,729 - INFO - Simulated BUY order placed: 5 ANNX
# 2025-09-01 12:53:25,729 - INFO - SIMULATED BUY: 5 ANNX @ £218.38 (Cost: £1091.90, Balance: £8908.10)
# 2025-09-01 12:53:25,730 - INFO - ANNX indicators - RSI: 61.1, MACD: -0.213, Volatility: 0.21%
# 2025-09-01 12:53:25,736 - INFO - Enhanced simulated analysis for ANRO: £272.28 (+0.00%)
# 2025-09-01 12:53:25,748 - INFO - Enhanced simulated analysis for ANVS: £88.03 (+0.00%)
# 2025-09-01 12:53:25,759 - INFO - Enhanced simulated analysis for APLM: £201.27 (+0.00%)
# 2025-09-01 12:53:25,771 - INFO - Enhanced simulated analysis for APLT: £331.22 (+0.00%)
# 2025-09-01 12:53:25,783 - INFO - Enhanced simulated analysis for APVO: £232.04 (+0.00%)
# 2025-09-01 12:53:25,794 - INFO - Enhanced simulated analysis for ARAY: £106.58 (+0.00%)
# 2025-09-01 12:53:25,805 - INFO - Enhanced simulated analysis for ARBE: £284.53 (+0.00%)
# 2025-09-01 12:53:25,817 - INFO - Enhanced simulated analysis for ATEN: £280.91 (+0.00%)
# 2025-09-01 12:53:25,823 - INFO - BUY signal for ATEN: 3/7 signals
# 2025-09-01 12:53:25,823 - INFO - Simulated BUY order placed: 3 ATEN
# 2025-09-01 12:53:25,823 - INFO - SIMULATED BUY: 3 ATEN @ £280.91 (Cost: £842.73, Balance: £8065.37)
# 2025-09-01 12:53:25,824 - INFO - ATEN indicators - RSI: 34.7, MACD: -0.602, Volatility: 0.19%
# 2025-09-01 12:53:25,831 - INFO - Enhanced simulated analysis for ATAI: £356.33 (+0.00%)
# 2025-09-01 12:53:25,843 - INFO - Enhanced simulated analysis for ATHA: £60.56 (+0.00%)
# 2025-09-01 12:53:25,854 - INFO - Enhanced simulated analysis for AUTL: £486.73 (+0.00%)
# ============================================================
# Advanced Trading Bot Test
# ============================================================
# Bot Environment: simulator
# Strategy: Enhanced_5_15
# Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# Risk Management: SL 4.0%, TP 12.0%
#
# Running 5 cycles...
# 2025-09-01 12:53:25,861 - INFO - BUY signal for AUTL: 4/7 signals
# 2025-09-01 12:53:25,862 - INFO - Simulated BUY order placed: 1 AUTL
# 2025-09-01 12:53:25,862 - INFO - SIMULATED BUY: 1 AUTL @ £486.73 (Cost: £486.73, Balance: £7578.64)
# 2025-09-01 12:53:25,862 - INFO - AUTL indicators - RSI: 46.4, MACD: -0.440, Volatility: 0.17%
# 2025-09-01 12:53:25,869 - INFO - Enhanced simulated analysis for AVIR: £417.95 (+0.00%)
# 2025-09-01 12:53:25,882 - INFO - Enhanced simulated analysis for CABA: £185.60 (+0.00%)
# 2025-09-01 12:53:25,894 - INFO - Enhanced simulated analysis for CAMP: £147.28 (+0.00%)
# 2025-09-01 12:53:25,900 - INFO - BUY signal for CAMP: 3/7 signals
# 2025-09-01 12:53:25,900 - INFO - Simulated BUY order placed: 6 CAMP
# 2025-09-01 12:53:25,900 - INFO - SIMULATED BUY: 6 CAMP @ £147.28 (Cost: £883.68, Balance: £6694.96)
# 2025-09-01 12:53:25,901 - INFO - CAMP indicators - RSI: 73.8, MACD: 1.302, Volatility: 0.19%
# 2025-09-01 12:53:25,907 - INFO - Enhanced simulated analysis for CARM: £349.73 (+0.00%)
# 2025-09-01 12:53:25,914 - INFO - BUY signal for CARM: 3/7 signals
# 2025-09-01 12:53:25,914 - INFO - Simulated BUY order placed: 2 CARM
# 2025-09-01 12:53:25,914 - INFO - SIMULATED BUY: 2 CARM @ £349.73 (Cost: £699.46, Balance: £5995.50)
# 2025-09-01 12:53:25,915 - INFO - CARM indicators - RSI: 67.8, MACD: 0.711, Volatility: 0.20%
# 2025-09-01 12:53:25,921 - INFO - Enhanced simulated analysis for CATX: £77.01 (+0.00%)
# 2025-09-01 12:53:25,933 - INFO - Enhanced simulated analysis for CCCC: £478.43 (+0.00%)
# 2025-09-01 12:53:25,945 - INFO - Enhanced simulated analysis for CELU: £150.95 (+0.00%)
# 2025-09-01 12:53:25,951 - INFO - BUY signal for CELU: 3/7 signals
# 2025-09-01 12:53:25,951 - INFO - Simulated BUY order placed: 4 CELU
# 2025-09-01 12:53:25,952 - INFO - SIMULATED BUY: 4 CELU @ £150.95 (Cost: £603.80, Balance: £5391.70)
# 2025-09-01 12:53:25,952 - INFO - CELU indicators - RSI: 40.7, MACD: -0.137, Volatility: 0.27%
# 2025-09-01 12:53:25,959 - INFO - Enhanced simulated analysis for CERS: £488.08 (+0.00%)
# 2025-09-01 12:53:25,970 - INFO - Enhanced simulated analysis for CGTX: £58.96 (+0.00%)
# 2025-09-01 12:53:25,982 - INFO - Enhanced simulated analysis for CHRS: £449.35 (+0.00%)
# 2025-09-01 12:53:25,994 - INFO - Enhanced simulated analysis for CLDI: £386.56 (+0.00%)
# 2025-09-01 12:53:26,005 - INFO - Enhanced simulated analysis for CLLS: £126.20 (+0.00%)
# 2025-09-01 12:53:26,016 - INFO - Enhanced simulated analysis for CLRB: £431.32 (+0.00%)
# 2025-09-01 12:53:26,023 - INFO - BUY signal for CLRB: 4/7 signals
# 2025-09-01 12:53:26,023 - INFO - Simulated BUY order placed: 1 CLRB
# 2025-09-01 12:53:26,023 - INFO - SIMULATED BUY: 1 CLRB @ £431.32 (Cost: £431.32, Balance: £4960.38)
# 2025-09-01 12:53:26,024 - INFO - CLRB indicators - RSI: 79.0, MACD: 2.082, Volatility: 0.18%
# 2025-09-01 12:53:26,031 - INFO - Enhanced simulated analysis for CLSD: £497.07 (+0.00%)
# 2025-09-01 12:53:26,037 - INFO - BUY signal for CLSD: 3/7 signals
# 2025-09-01 12:53:26,037 - INFO - Simulated BUY order placed: 1 CLSD
# 2025-09-01 12:53:26,037 - INFO - SIMULATED BUY: 1 CLSD @ £497.07 (Cost: £497.07, Balance: £4463.31)
# 2025-09-01 12:53:26,038 - INFO - CLSD indicators - RSI: 57.7, MACD: 0.504, Volatility: 0.16%
# 2025-09-01 12:53:26,045 - INFO - Enhanced simulated analysis for CLYM: £135.42 (+0.00%)
# 2025-09-01 12:53:26,068 - INFO - BUY signal for CLYM: 3/7 signals
# 2025-09-01 12:53:26,071 - INFO - Simulated BUY order placed: 3 CLYM
# 2025-09-01 12:53:26,072 - INFO - SIMULATED BUY: 3 CLYM @ £135.42 (Cost: £406.26, Balance: £4057.05)
# 2025-09-01 12:53:26,073 - INFO - CLYM indicators - RSI: 58.5, MACD: -0.039, Volatility: 0.23%
# 2025-09-01 12:53:26,087 - INFO - Enhanced simulated analysis for CMPS: £292.34 (+0.00%)
# 2025-09-01 12:53:26,099 - INFO - Enhanced simulated analysis for CMPX: £477.45 (+0.00%)
# 2025-09-01 12:53:26,111 - INFO - Enhanced simulated analysis for CMTL: £167.29 (+0.00%)
# 2025-09-01 12:53:26,123 - INFO - Enhanced simulated analysis for COCP: £374.77 (+0.00%)
# 2025-09-01 12:53:26,134 - INFO - Enhanced simulated analysis for CRBU: £331.95 (+0.00%)
# 2025-09-01 12:53:26,146 - INFO - Enhanced simulated analysis for CRDF: £55.05 (+0.00%)
# 2025-09-01 12:53:26,157 - INFO - Enhanced simulated analysis for CRDL: £81.03 (+0.00%)
# 2025-09-01 12:53:26,169 - INFO - Enhanced simulated analysis for CRIS: £162.14 (+0.00%)
# 2025-09-01 12:53:26,182 - INFO - Enhanced simulated analysis for CTMX: £97.03 (+0.00%)
# 2025-09-01 12:53:26,188 - INFO - BUY signal for CTMX: 3/7 signals
# 2025-09-01 12:53:26,188 - INFO - Simulated BUY order placed: 5 CTMX
# 2025-09-01 12:53:26,189 - INFO - SIMULATED BUY: 5 CTMX @ £97.03 (Cost: £485.15, Balance: £3571.90)
# 2025-09-01 12:53:26,189 - INFO - CTMX indicators - RSI: 72.6, MACD: 0.548, Volatility: 0.17%
# 2025-09-01 12:53:26,196 - INFO - Enhanced simulated analysis for CTOR: £73.72 (+0.00%)
# 2025-09-01 12:53:26,203 - INFO - BUY signal for CTOR: 4/7 signals
# 2025-09-01 12:53:26,203 - INFO - Simulated BUY order placed: 5 CTOR
# 2025-09-01 12:53:26,203 - INFO - SIMULATED BUY: 5 CTOR @ £73.72 (Cost: £368.60, Balance: £3203.30)
# 2025-09-01 12:53:26,204 - INFO - CTOR indicators - RSI: 70.6, MACD: 0.815, Volatility: 0.18%
# 2025-09-01 12:53:26,211 - INFO - Enhanced simulated analysis for CTXR: £203.19 (+0.00%)
# 2025-09-01 12:53:26,222 - INFO - Enhanced simulated analysis for CUE: £329.09 (+0.00%)
# 2025-09-01 12:53:26,235 - INFO - Enhanced simulated analysis for CURR: £414.81 (+0.00%)
# 2025-09-01 12:53:26,247 - INFO - Enhanced simulated analysis for DARE: £137.87 (+0.00%)
# 2025-09-01 12:53:26,258 - INFO - Enhanced simulated analysis for DTIL: £99.14 (+0.00%)
# 2025-09-01 12:53:26,270 - INFO - Enhanced simulated analysis for EDIT: £370.41 (+0.00%)
# 2025-09-01 12:53:26,282 - INFO - Enhanced simulated analysis for ELDN: £413.46 (+0.00%)
# 2025-09-01 12:53:26,294 - INFO - Enhanced simulated analysis for EQ: £57.24 (+0.00%)
# 2025-09-01 12:53:26,305 - INFO - Enhanced simulated analysis for ERAS: £185.34 (+0.00%)
# 2025-09-01 12:53:26,317 - INFO - Enhanced simulated analysis for ERNA: £106.26 (+0.00%)
# 2025-09-01 12:53:26,329 - INFO - Enhanced simulated analysis for ESLA: £220.90 (+0.00%)
# 2025-09-01 12:53:26,335 - INFO - BUY signal for ESLA: 3/7 signals
# 2025-09-01 12:53:26,335 - INFO - Simulated BUY order placed: 1 ESLA
# 2025-09-01 12:53:26,336 - INFO - SIMULATED BUY: 1 ESLA @ £220.90 (Cost: £220.90, Balance: £2982.40)
# 2025-09-01 12:53:26,336 - INFO - ESLA indicators - RSI: 72.7, MACD: 0.617, Volatility: 0.27%
# 2025-09-01 12:53:26,343 - INFO - Enhanced simulated analysis for ESPR: £270.82 (+0.00%)
# 2025-09-01 12:53:26,354 - INFO - Enhanced simulated analysis for EVGN: £77.14 (+0.00%)
# 2025-09-01 12:53:26,366 - INFO - Enhanced simulated analysis for FATE: £450.17 (+0.00%)
# 2025-09-01 12:53:26,378 - INFO - Enhanced simulated analysis for FBLG: £327.54 (+0.00%)
# 2025-09-01 12:53:26,384 - INFO - Cycle completed: 12 trades executed
# 2025-09-01 12:53:29,386 - INFO - --- Cycle 2 ---
# 2025-09-01 12:53:29,404 - INFO - Enhanced simulated analysis for ABCL: £99.94 (+0.00%)
# 2025-09-01 12:53:29,427 - INFO - Enhanced simulated analysis for ALLO: £124.91 (+0.00%)
# 2025-09-01 12:53:29,443 - INFO - Enhanced simulated analysis for ANNX: £219.10 (+0.00%)
# 2025-09-01 12:53:29,457 - INFO - Enhanced simulated analysis for ANRO: £269.18 (+0.00%)
# 2025-09-01 12:53:29,470 - INFO - Enhanced simulated analysis for ANVS: £88.99 (+0.00%)
# 2025-09-01 12:53:29,477 - INFO - BUY signal for ANVS: 3/7 signals
# 2025-09-01 12:53:29,477 - INFO - Simulated BUY order placed: 4 ANVS
# 2025-09-01 12:53:29,478 - INFO - SIMULATED BUY: 4 ANVS @ £88.99 (Cost: £355.96, Balance: £2626.44)
# 2025-09-01 12:53:29,478 - INFO - ANVS indicators - RSI: 69.7, MACD: 0.512, Volatility: 0.23%
# 2025-09-01 12:53:29,485 - INFO - Enhanced simulated analysis for APLM: £200.85 (+0.00%)
# 2025-09-01 12:53:29,497 - INFO - Enhanced simulated analysis for APLT: £334.26 (+0.00%)
# 2025-09-01 12:53:29,509 - INFO - Enhanced simulated analysis for APVO: £233.27 (+0.00%)
# 2025-09-01 12:53:29,520 - INFO - Enhanced simulated analysis for ARAY: £107.09 (+0.00%)
# 2025-09-01 12:53:29,532 - INFO - Enhanced simulated analysis for ARBE: £282.60 (+0.00%)
# 2025-09-01 12:53:29,543 - INFO - Enhanced simulated analysis for ATEN: £282.61 (+0.00%)
# 2025-09-01 12:53:29,555 - INFO - Enhanced simulated analysis for ATAI: £357.12 (+0.00%)
# 2025-09-01 12:53:29,567 - INFO - Enhanced simulated analysis for ATHA: £61.46 (+0.00%)
# 2025-09-01 12:53:29,578 - INFO - Enhanced simulated analysis for AUTL: £483.36 (+0.00%)
# 2025-09-01 12:53:29,585 - INFO - SELL signal for AUTL: 3/7 signals
# 2025-09-01 12:53:29,585 - INFO - Simulated SELL order placed: 1 AUTL
# 2025-09-01 12:53:29,586 - INFO - SIMULATED SELL: 0 AUTL @ £483.36 (Value: £483.36, P&L: £483.36, Balance: £3109.80)
# 2025-09-01 12:53:29,586 - INFO - AUTL indicators - RSI: 36.5, MACD: -1.565, Volatility: 0.20%
# 2025-09-01 12:53:29,593 - INFO - Enhanced simulated analysis for AVIR: £416.34 (+0.00%)
# 2025-09-01 12:53:29,605 - INFO - Enhanced simulated analysis for CABA: £185.43 (+0.00%)
# 2025-09-01 12:53:29,617 - INFO - Enhanced simulated analysis for CAMP: £147.31 (+0.00%)
# 2025-09-01 12:53:29,628 - INFO - Enhanced simulated analysis for CARM: £348.23 (+0.00%)
# 2025-09-01 12:53:29,640 - INFO - Enhanced simulated analysis for CATX: £76.44 (+0.00%)
# 2025-09-01 12:53:29,651 - INFO - Enhanced simulated analysis for CCCC: £477.84 (+0.00%)
# 2025-09-01 12:53:29,663 - INFO - Enhanced simulated analysis for CELU: £152.09 (+0.00%)
# 2025-09-01 12:53:29,669 - INFO - SELL signal for CELU: 3/7 signals
# 2025-09-01 12:53:29,670 - INFO - Simulated SELL order placed: 4 CELU
# 2025-09-01 12:53:29,670 - INFO - SIMULATED SELL: 0 CELU @ £152.09 (Value: £608.36, P&L: £608.36, Balance: £3718.16)
# 2025-09-01 12:53:29,670 - INFO - CELU indicators - RSI: 27.3, MACD: 0.096, Volatility: 0.13%
# 2025-09-01 12:53:29,677 - INFO - Enhanced simulated analysis for CERS: £495.61 (+0.00%)
# 2025-09-01 12:53:29,684 - INFO - BUY signal for CERS: 3/7 signals
# 2025-09-01 12:53:29,684 - INFO - Simulated BUY order placed: 1 CERS
# 2025-09-01 12:53:29,684 - INFO - SIMULATED BUY: 1 CERS @ £495.61 (Cost: £495.61, Balance: £3222.55)
# 2025-09-01 12:53:29,684 - INFO - CERS indicators - RSI: 72.0, MACD: 1.232, Volatility: 0.21%
# 2025-09-01 12:53:29,692 - INFO - Enhanced simulated analysis for CGTX: £58.78 (+0.00%)
# 2025-09-01 12:53:29,704 - INFO - Enhanced simulated analysis for CHRS: £446.41 (+0.00%)
# 2025-09-01 12:53:29,716 - INFO - Enhanced simulated analysis for CLDI: £388.11 (+0.00%)
# 2025-09-01 12:53:29,727 - INFO - Enhanced simulated analysis for CLLS: £125.91 (+0.00%)
# 2025-09-01 12:53:29,740 - INFO - Enhanced simulated analysis for CLRB: £429.61 (+0.00%)
# 2025-09-01 12:53:29,752 - INFO - Enhanced simulated analysis for CLSD: £498.92 (+0.00%)
# 2025-09-01 12:53:29,758 - INFO - SELL signal for CLSD: 3/7 signals
# 2025-09-01 12:53:29,758 - INFO - Simulated SELL order placed: 1 CLSD
# 2025-09-01 12:53:29,758 - INFO - SIMULATED SELL: 0 CLSD @ £498.92 (Value: £498.92, P&L: £498.92, Balance: £3721.47)
# 2025-09-01 12:53:29,758 - INFO - CLSD indicators - RSI: 8.9, MACD: -0.886, Volatility: 0.13%
# 2025-09-01 12:53:29,765 - INFO - Enhanced simulated analysis for CLYM: £135.19 (+0.00%)
# 2025-09-01 12:53:29,777 - INFO - Enhanced simulated analysis for CMPS: £293.94 (+0.00%)
# 2025-09-01 12:53:29,789 - INFO - Enhanced simulated analysis for CMPX: £478.27 (+0.00%)
# 2025-09-01 12:53:29,801 - INFO - Enhanced simulated analysis for CMTL: £167.35 (+0.00%)
# 2025-09-01 12:53:29,834 - INFO - Enhanced simulated analysis for COCP: £372.58 (+0.00%)
# 2025-09-01 12:53:29,845 - INFO - BUY signal for COCP: 3/7 signals
# 2025-09-01 12:53:29,845 - INFO - Simulated BUY order placed: 1 COCP
# 2025-09-01 12:53:29,845 - INFO - SIMULATED BUY: 1 COCP @ £372.58 (Cost: £372.58, Balance: £3348.89)
# 2025-09-01 12:53:29,846 - INFO - COCP indicators - RSI: 67.0, MACD: 0.814, Volatility: 0.23%
# 2025-09-01 12:53:29,853 - INFO - Enhanced simulated analysis for CRBU: £329.15 (+0.00%)
# 2025-09-01 12:53:29,864 - INFO - Enhanced simulated analysis for CRDF: £55.67 (+0.00%)
# 2025-09-01 12:53:29,876 - INFO - Enhanced simulated analysis for CRDL: £80.51 (+0.00%)
# 2025-09-01 12:53:29,888 - INFO - Enhanced simulated analysis for CRIS: £162.18 (+0.00%)
# 2025-09-01 12:53:29,900 - INFO - Enhanced simulated analysis for CTMX: £97.49 (+0.00%)
# 2025-09-01 12:53:29,911 - INFO - Enhanced simulated analysis for CTOR: £72.95 (+0.00%)
# 2025-09-01 12:53:29,923 - INFO - Enhanced simulated analysis for CTXR: £203.00 (+0.00%)
# 2025-09-01 12:53:29,934 - INFO - Enhanced simulated analysis for CUE: £331.25 (+0.00%)
# 2025-09-01 12:53:29,946 - INFO - Enhanced simulated analysis for CURR: £419.51 (+0.00%)
# 2025-09-01 12:53:29,957 - INFO - Enhanced simulated analysis for DARE: £139.42 (+0.00%)
# 2025-09-01 12:53:29,969 - INFO - Enhanced simulated analysis for DTIL: £99.83 (+0.00%)
# 2025-09-01 12:53:29,980 - INFO - Enhanced simulated analysis for EDIT: £375.09 (+0.00%)
# 2025-09-01 12:53:29,992 - INFO - Enhanced simulated analysis for ELDN: £413.15 (+0.00%)
# 2025-09-01 12:53:30,003 - INFO - Enhanced simulated analysis for EQ: £56.49 (+0.00%)
# 2025-09-01 12:53:30,015 - INFO - Enhanced simulated analysis for ERAS: £186.60 (+0.00%)
# 2025-09-01 12:53:30,026 - INFO - Enhanced simulated analysis for ERNA: £106.77 (+0.00%)
# 2025-09-01 12:53:30,033 - INFO - BUY signal for ERNA: 3/7 signals
# 2025-09-01 12:53:30,033 - INFO - Simulated BUY order placed: 3 ERNA
# 2025-09-01 12:53:30,034 - INFO - SIMULATED BUY: 3 ERNA @ £106.77 (Cost: £320.31, Balance: £3028.58)
# 2025-09-01 12:53:30,034 - INFO - ERNA indicators - RSI: 58.4, MACD: -0.085, Volatility: 0.24%
# 2025-09-01 12:53:30,041 - INFO - Enhanced simulated analysis for ESLA: £221.22 (+0.00%)
# 2025-09-01 12:53:30,052 - INFO - Enhanced simulated analysis for ESPR: £274.33 (+0.00%)
# 2025-09-01 12:53:30,064 - INFO - Enhanced simulated analysis for EVGN: £77.22 (+0.00%)
# 2025-09-01 12:53:30,075 - INFO - Enhanced simulated analysis for FATE: £449.23 (+0.00%)
# 2025-09-01 12:53:30,082 - INFO - BUY signal for FATE: 3/7 signals
# 2025-09-01 12:53:30,082 - INFO - Simulated BUY order placed: 1 FATE
# 2025-09-01 12:53:30,082 - INFO - SIMULATED BUY: 1 FATE @ £449.23 (Cost: £449.23, Balance: £2579.35)
# 2025-09-01 12:53:30,083 - INFO - FATE indicators - RSI: 58.7, MACD: 0.931, Volatility: 0.20%
# 2025-09-01 12:53:30,089 - INFO - Enhanced simulated analysis for FBLG: £330.05 (+0.00%)
# 2025-09-01 12:53:30,096 - INFO - Cycle completed: 8 trades executed
# 2025-09-01 12:53:30,096 - INFO - Performance - Total Trades: 3, Win Rate: 66.7%, Total P&L: £3.04
# 2025-09-01 12:53:33,098 - INFO - --- Cycle 3 ---
# 2025-09-01 12:53:33,119 - INFO - Enhanced simulated analysis for ABCL: £101.56 (+0.00%)
# 2025-09-01 12:53:33,131 - INFO - BUY signal for ABCL: 3/7 signals
# 2025-09-01 12:53:33,132 - INFO - Simulated BUY order placed: 3 ABCL
# 2025-09-01 12:53:33,132 - INFO - SIMULATED BUY: 3 ABCL @ £101.56 (Cost: £304.68, Balance: £2274.67)
# 2025-09-01 12:53:33,133 - INFO - ABCL indicators - RSI: 94.4, MACD: 1.872, Volatility: 0.15%
# 2025-09-01 12:53:33,143 - INFO - Enhanced simulated analysis for ALLO: £125.96 (+0.00%)
# 2025-09-01 12:53:33,160 - INFO - Enhanced simulated analysis for ANNX: £214.62 (+0.00%)
# 2025-09-01 12:53:33,174 - INFO - Enhanced simulated analysis for ANRO: £271.31 (+0.00%)
# 2025-09-01 12:53:33,181 - INFO - BUY signal for ANRO: 3/7 signals
# 2025-09-01 12:53:33,181 - INFO - Simulated BUY order placed: 1 ANRO
# 2025-09-01 12:53:33,182 - INFO - SIMULATED BUY: 1 ANRO @ £271.31 (Cost: £271.31, Balance: £2003.36)
# 2025-09-01 12:53:33,182 - INFO - ANRO indicators - RSI: 28.8, MACD: -0.080, Volatility: 0.22%
# 2025-09-01 12:53:33,189 - INFO - Enhanced simulated analysis for ANVS: £88.14 (+0.00%)
# 2025-09-01 12:53:33,202 - INFO - Enhanced simulated analysis for APLM: £201.83 (+0.00%)
# 2025-09-01 12:53:33,214 - INFO - Enhanced simulated analysis for APLT: £333.91 (+0.00%)
# 2025-09-01 12:53:33,226 - INFO - Enhanced simulated analysis for APVO: £233.82 (+0.00%)
# 2025-09-01 12:53:33,237 - INFO - Enhanced simulated analysis for ARAY: £106.07 (+0.00%)
# 2025-09-01 12:53:33,249 - INFO - Enhanced simulated analysis for ARBE: £284.79 (+0.00%)
# 2025-09-01 12:53:33,261 - INFO - Enhanced simulated analysis for ATEN: £282.43 (+0.00%)
# 2025-09-01 12:53:33,272 - INFO - Enhanced simulated analysis for ATAI: £355.80 (+0.00%)
# 2025-09-01 12:53:33,278 - INFO - BUY signal for ATAI: 3/7 signals
# 2025-09-01 12:53:33,279 - INFO - Simulated BUY order placed: 1 ATAI
# 2025-09-01 12:53:33,279 - INFO - SIMULATED BUY: 1 ATAI @ £355.80 (Cost: £355.80, Balance: £1647.56)
# 2025-09-01 12:53:33,279 - INFO - ATAI indicators - RSI: 31.3, MACD: -0.618, Volatility: 0.18%
# 2025-09-01 12:53:33,286 - INFO - Enhanced simulated analysis for ATHA: £61.41 (+0.00%)
# 2025-09-01 12:53:33,298 - INFO - Enhanced simulated analysis for AUTL: £485.08 (+0.00%)
# 2025-09-01 12:53:33,304 - INFO - BUY signal for AUTL: 3/7 signals
# 2025-09-01 12:53:33,304 - INFO - Simulated BUY order placed: 1 AUTL
# 2025-09-01 12:53:33,305 - INFO - SIMULATED BUY: 1 AUTL @ £485.08 (Cost: £485.08, Balance: £1162.48)
# 2025-09-01 12:53:33,305 - INFO - AUTL indicators - RSI: 51.7, MACD: 0.191, Volatility: 0.19%
# 2025-09-01 12:53:33,312 - INFO - Enhanced simulated analysis for AVIR: £418.06 (+0.00%)
# 2025-09-01 12:53:33,324 - INFO - Enhanced simulated analysis for CABA: £187.31 (+0.00%)
# 2025-09-01 12:53:33,330 - INFO - BUY signal for CABA: 4/7 signals
# 2025-09-01 12:53:33,330 - INFO - Simulated BUY order placed: 1 CABA
# 2025-09-01 12:53:33,331 - INFO - SIMULATED BUY: 1 CABA @ £187.31 (Cost: £187.31, Balance: £975.17)
# 2025-09-01 12:53:33,331 - INFO - CABA indicators - RSI: 69.2, MACD: 1.665, Volatility: 0.22%
# 2025-09-01 12:53:33,338 - INFO - Enhanced simulated analysis for CAMP: £146.69 (+0.00%)
# 2025-09-01 12:53:33,354 - INFO - Enhanced simulated analysis for CARM: £350.50 (+0.00%)
# 2025-09-01 12:53:33,366 - INFO - Enhanced simulated analysis for CATX: £76.81 (+0.00%)
# 2025-09-01 12:53:33,378 - INFO - Enhanced simulated analysis for CCCC: £475.25 (+0.00%)
# 2025-09-01 12:53:33,389 - INFO - Enhanced simulated analysis for CELU: £154.38 (+0.00%)
# 2025-09-01 12:53:33,403 - INFO - Enhanced simulated analysis for CERS: £493.41 (+0.00%)
# 2025-09-01 12:53:33,415 - INFO - Enhanced simulated analysis for CGTX: £58.65 (+0.00%)
# 2025-09-01 12:53:33,427 - INFO - Enhanced simulated analysis for CHRS: £450.56 (+0.00%)
# 2025-09-01 12:53:33,439 - INFO - Enhanced simulated analysis for CLDI: £387.24 (+0.00%)
# 2025-09-01 12:53:33,445 - INFO - BUY signal for CLDI: 3/7 signals
# 2025-09-01 12:53:33,445 - INFO - Simulated BUY order placed: 1 CLDI
# 2025-09-01 12:53:33,446 - INFO - SIMULATED BUY: 1 CLDI @ £387.24 (Cost: £387.24, Balance: £587.93)
# 2025-09-01 12:53:33,446 - INFO - CLDI indicators - RSI: 30.8, MACD: -0.147, Volatility: 0.17%
# 2025-09-01 12:53:33,453 - INFO - Enhanced simulated analysis for CLLS: £126.18 (+0.00%)
# 2025-09-01 12:53:33,465 - INFO - Enhanced simulated analysis for CLRB: £432.54 (+0.00%)
# 2025-09-01 12:53:33,477 - INFO - Enhanced simulated analysis for CLSD: £495.32 (+0.00%)
# 2025-09-01 12:53:33,489 - INFO - Enhanced simulated analysis for CLYM: £136.53 (+0.00%)
# 2025-09-01 12:53:33,500 - INFO - Enhanced simulated analysis for CMPS: £293.70 (+0.00%)
# 2025-09-01 12:53:33,534 - INFO - Enhanced simulated analysis for CMPX: £477.90 (+0.00%)
# 2025-09-01 12:53:33,548 - INFO - Enhanced simulated analysis for CMTL: £169.50 (+0.00%)
# 2025-09-01 12:53:33,559 - INFO - Enhanced simulated analysis for COCP: £375.09 (+0.00%)
# 2025-09-01 12:53:33,572 - INFO - Enhanced simulated analysis for CRBU: £326.46 (+0.00%)
# 2025-09-01 12:53:33,584 - INFO - Enhanced simulated analysis for CRDF: £55.47 (+0.00%)
# 2025-09-01 12:53:33,595 - INFO - Enhanced simulated analysis for CRDL: £80.18 (+0.00%)
# 2025-09-01 12:53:33,607 - INFO - Enhanced simulated analysis for CRIS: £159.29 (+0.00%)
# 2025-09-01 12:53:33,619 - INFO - Enhanced simulated analysis for CTMX: £98.24 (+0.00%)
# 2025-09-01 12:53:33,630 - INFO - Enhanced simulated analysis for CTOR: £73.14 (+0.00%)
# 2025-09-01 12:53:33,642 - INFO - Enhanced simulated analysis for CTXR: £203.81 (+0.00%)
# 2025-09-01 12:53:33,654 - INFO - Enhanced simulated analysis for CUE: £330.45 (+0.00%)
# 2025-09-01 12:53:33,665 - INFO - Enhanced simulated analysis for CURR: £418.23 (+0.00%)
# 2025-09-01 12:53:33,677 - INFO - Enhanced simulated analysis for DARE: £139.95 (+0.00%)
# 2025-09-01 12:53:33,684 - INFO - BUY signal for DARE: 3/7 signals
# 2025-09-01 12:53:33,684 - INFO - Simulated BUY order placed: 1 DARE
# 2025-09-01 12:53:33,684 - INFO - SIMULATED BUY: 1 DARE @ £139.95 (Cost: £139.95, Balance: £447.98)
# 2025-09-01 12:53:33,685 - INFO - DARE indicators - RSI: 52.5, MACD: 0.095, Volatility: 0.17%
# 2025-09-01 12:53:33,691 - INFO - Enhanced simulated analysis for DTIL: £99.30 (+0.00%)
# 2025-09-01 12:53:33,703 - INFO - Enhanced simulated analysis for EDIT: £374.91 (+0.00%)
# 2025-09-01 12:53:33,714 - INFO - Enhanced simulated analysis for ELDN: £415.74 (+0.00%)
# 2025-09-01 12:53:33,726 - INFO - Enhanced simulated analysis for EQ: £56.16 (+0.00%)
# 2025-09-01 12:53:33,738 - INFO - Enhanced simulated analysis for ERAS: £186.59 (+0.00%)
# 2025-09-01 12:53:33,750 - INFO - Enhanced simulated analysis for ERNA: £105.51 (+0.00%)
# 2025-09-01 12:53:33,761 - INFO - Enhanced simulated analysis for ESLA: £221.64 (+0.00%)
# 2025-09-01 12:53:33,774 - INFO - Enhanced simulated analysis for ESPR: £273.75 (+0.00%)
# 2025-09-01 12:53:33,786 - INFO - Enhanced simulated analysis for EVGN: £77.80 (+0.00%)
# 2025-09-01 12:53:33,797 - INFO - Enhanced simulated analysis for FATE: £446.73 (+0.00%)
# 2025-09-01 12:53:33,809 - INFO - Enhanced simulated analysis for FBLG: £328.94 (+0.00%)
# 2025-09-01 12:53:33,815 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 12:53:33,816 - INFO - Performance - Total Trades: 3, Win Rate: 66.7%, Total P&L: £3.04
# 2025-09-01 12:53:36,819 - INFO - --- Cycle 4 ---
# 2025-09-01 12:53:36,838 - INFO - Enhanced simulated analysis for ABCL: £102.22 (+0.00%)
# 2025-09-01 12:53:36,858 - INFO - Enhanced simulated analysis for ALLO: £125.44 (+0.00%)
# 2025-09-01 12:53:36,874 - INFO - Enhanced simulated analysis for ANNX: £212.20 (+0.00%)
# 2025-09-01 12:53:36,888 - INFO - Enhanced simulated analysis for ANRO: £273.89 (+0.00%)
# 2025-09-01 12:53:36,901 - INFO - Enhanced simulated analysis for ANVS: £88.49 (+0.00%)
# 2025-09-01 12:53:36,914 - INFO - Enhanced simulated analysis for APLM: £202.85 (+0.00%)
# 2025-09-01 12:53:36,926 - INFO - Enhanced simulated analysis for APLT: £333.19 (+0.00%)
# 2025-09-01 12:53:36,937 - INFO - Enhanced simulated analysis for APVO: £234.26 (+0.00%)
# 2025-09-01 12:53:36,949 - INFO - Enhanced simulated analysis for ARAY: £104.93 (+0.00%)
# 2025-09-01 12:53:36,960 - INFO - Enhanced simulated analysis for ARBE: £284.64 (+0.00%)
# 2025-09-01 12:53:36,971 - INFO - Enhanced simulated analysis for ATEN: £284.49 (+0.00%)
# 2025-09-01 12:53:36,983 - INFO - Enhanced simulated analysis for ATAI: £355.44 (+0.00%)
# 2025-09-01 12:53:36,994 - INFO - Enhanced simulated analysis for ATHA: £60.80 (+0.00%)
# 2025-09-01 12:53:37,005 - INFO - Enhanced simulated analysis for AUTL: £482.30 (+0.00%)
# 2025-09-01 12:53:37,043 - INFO - Enhanced simulated analysis for AVIR: £418.70 (+0.00%)
# 2025-09-01 12:53:37,055 - INFO - Enhanced simulated analysis for CABA: £187.90 (+0.00%)
# 2025-09-01 12:53:37,067 - INFO - Enhanced simulated analysis for CAMP: £149.20 (+0.00%)
# 2025-09-01 12:53:37,078 - INFO - Enhanced simulated analysis for CARM: £350.20 (+0.00%)
# 2025-09-01 12:53:37,090 - INFO - Enhanced simulated analysis for CATX: £76.57 (+0.00%)
# 2025-09-01 12:53:37,101 - INFO - Enhanced simulated analysis for CCCC: £476.41 (+0.00%)
# 2025-09-01 12:53:37,113 - INFO - Enhanced simulated analysis for CELU: £154.48 (+0.00%)
# 2025-09-01 12:53:37,124 - INFO - Enhanced simulated analysis for CERS: £490.05 (+0.00%)
# 2025-09-01 12:53:37,136 - INFO - Enhanced simulated analysis for CGTX: £58.71 (+0.00%)
# 2025-09-01 12:53:37,147 - INFO - Enhanced simulated analysis for CHRS: £448.77 (+0.00%)
# 2025-09-01 12:53:37,159 - INFO - Enhanced simulated analysis for CLDI: £389.31 (+0.00%)
# 2025-09-01 12:53:37,166 - INFO - SELL signal for CLDI: 3/7 signals
# 2025-09-01 12:53:37,166 - INFO - Simulated SELL order placed: 1 CLDI
# 2025-09-01 12:53:37,166 - INFO - SIMULATED SELL: 0 CLDI @ £389.31 (Value: £389.31, P&L: £389.31, Balance: £837.29)
# 2025-09-01 12:53:37,167 - INFO - CLDI indicators - RSI: 19.2, MACD: -0.134, Volatility: 0.15%
# 2025-09-01 12:53:37,173 - INFO - Enhanced simulated analysis for CLLS: £125.61 (+0.00%)
# 2025-09-01 12:53:37,180 - INFO - BUY signal for CLLS: 4/7 signals
# 2025-09-01 12:53:37,181 - INFO - Simulated BUY order placed: 1 CLLS
# 2025-09-01 12:53:37,181 - INFO - SIMULATED BUY: 1 CLLS @ £125.61 (Cost: £125.61, Balance: £711.68)
# 2025-09-01 12:53:37,181 - INFO - CLLS indicators - RSI: 56.2, MACD: -0.187, Volatility: 0.11%
# 2025-09-01 12:53:37,188 - INFO - Enhanced simulated analysis for CLRB: £431.98 (+0.00%)
# 2025-09-01 12:53:37,201 - INFO - Enhanced simulated analysis for CLSD: £494.75 (+0.00%)
# 2025-09-01 12:53:37,214 - INFO - Enhanced simulated analysis for CLYM: £135.24 (+0.00%)
# 2025-09-01 12:53:37,225 - INFO - Enhanced simulated analysis for CMPS: £289.89 (+0.00%)
# 2025-09-01 12:53:37,238 - INFO - Enhanced simulated analysis for CMPX: £474.38 (+0.00%)
# 2025-09-01 12:53:37,251 - INFO - Enhanced simulated analysis for CMTL: £170.80 (+0.00%)
# 2025-09-01 12:53:37,263 - INFO - Enhanced simulated analysis for COCP: £372.81 (+0.00%)
# 2025-09-01 12:53:37,275 - INFO - Enhanced simulated analysis for CRBU: £327.36 (+0.00%)
# 2025-09-01 12:53:37,285 - INFO - BUY signal for CRBU: 3/7 signals
# 2025-09-01 12:53:37,285 - INFO - Simulated BUY order placed: 1 CRBU
# 2025-09-01 12:53:37,285 - INFO - SIMULATED BUY: 1 CRBU @ £327.36 (Cost: £327.36, Balance: £384.32)
# 2025-09-01 12:53:37,286 - INFO - CRBU indicators - RSI: 20.2, MACD: -1.263, Volatility: 0.21%
# 2025-09-01 12:53:37,293 - INFO - Enhanced simulated analysis for CRDF: £55.46 (+0.00%)
# 2025-09-01 12:53:37,300 - INFO - BUY signal for CRDF: 3/7 signals
# 2025-09-01 12:53:37,300 - INFO - Simulated BUY order placed: 1 CRDF
# 2025-09-01 12:53:37,300 - INFO - SIMULATED BUY: 1 CRDF @ £55.46 (Cost: £55.46, Balance: £328.86)
# 2025-09-01 12:53:37,301 - INFO - CRDF indicators - RSI: 74.2, MACD: 1.881, Volatility: 0.21%
# 2025-09-01 12:53:37,308 - INFO - Enhanced simulated analysis for CRDL: £80.22 (+0.00%)
# 2025-09-01 12:53:37,320 - INFO - Enhanced simulated analysis for CRIS: £158.82 (+0.00%)
# 2025-09-01 12:53:37,357 - INFO - Enhanced simulated analysis for CTMX: £97.96 (+0.00%)
# 2025-09-01 12:53:37,374 - INFO - Enhanced simulated analysis for CTOR: £73.83 (+0.00%)
# 2025-09-01 12:53:37,387 - INFO - Enhanced simulated analysis for CTXR: £209.45 (+0.00%)
# 2025-09-01 12:53:37,394 - INFO - BUY signal for CTXR: 3/7 signals
# 2025-09-01 12:53:37,394 - INFO - Simulated BUY order placed: 1 CTXR
# 2025-09-01 12:53:37,394 - INFO - SIMULATED BUY: 1 CTXR @ £209.45 (Cost: £209.45, Balance: £119.41)
# 2025-09-01 12:53:37,395 - INFO - CTXR indicators - RSI: 67.4, MACD: -0.219, Volatility: 0.17%
# 2025-09-01 12:53:37,403 - INFO - Enhanced simulated analysis for CUE: £329.53 (+0.00%)
# 2025-09-01 12:53:37,411 - INFO - BUY signal for CUE: 3/7 signals
# 2025-09-01 12:53:37,417 - INFO - Enhanced simulated analysis for CURR: £412.76 (+0.00%)
# 2025-09-01 12:53:37,429 - INFO - Enhanced simulated analysis for DARE: £138.55 (+0.00%)
# 2025-09-01 12:53:37,444 - INFO - Enhanced simulated analysis for DTIL: £99.26 (+0.00%)
# 2025-09-01 12:53:37,456 - INFO - Enhanced simulated analysis for EDIT: £374.05 (+0.00%)
# 2025-09-01 12:53:37,470 - INFO - Enhanced simulated analysis for ELDN: £418.29 (+0.00%)
# 2025-09-01 12:53:37,482 - INFO - Enhanced simulated analysis for EQ: £56.01 (+0.00%)
# 2025-09-01 12:53:37,494 - INFO - Enhanced simulated analysis for ERAS: £183.91 (+0.00%)
# 2025-09-01 12:53:37,506 - INFO - Enhanced simulated analysis for ERNA: £105.94 (+0.00%)
# 2025-09-01 12:53:37,520 - INFO - Enhanced simulated analysis for ESLA: £222.66 (+0.00%)
# 2025-09-01 12:53:37,532 - INFO - Enhanced simulated analysis for ESPR: £275.03 (+0.00%)
# 2025-09-01 12:53:37,545 - INFO - Enhanced simulated analysis for EVGN: £77.08 (+0.00%)
# 2025-09-01 12:53:37,558 - INFO - Enhanced simulated analysis for FATE: £447.81 (+0.00%)
# 2025-09-01 12:53:37,570 - INFO - Enhanced simulated analysis for FBLG: £326.09 (+0.00%)
# 2025-09-01 12:53:37,577 - INFO - BUY signal for FBLG: 3/7 signals
# 2025-09-01 12:53:37,577 - INFO - Cycle completed: 5 trades executed
# 2025-09-01 12:53:37,578 - INFO - Performance - Total Trades: 4, Win Rate: 75.0%, Total P&L: £5.11
# 2025-09-01 12:53:40,583 - INFO - --- Cycle 5 ---
# 2025-09-01 12:53:40,593 - INFO - Enhanced simulated analysis for ABCL: £102.85 (+0.00%)
# 2025-09-01 12:53:40,609 - INFO - Enhanced simulated analysis for ALLO: £124.67 (+0.00%)
# 2025-09-01 12:53:40,623 - INFO - Enhanced simulated analysis for ANNX: £211.29 (+0.00%)
# 2025-09-01 12:53:40,636 - INFO - Enhanced simulated analysis for ANRO: £276.44 (+0.00%)
# 2025-09-01 12:53:40,649 - INFO - Enhanced simulated analysis for ANVS: £87.83 (+0.00%)
# 2025-09-01 12:53:40,661 - INFO - Enhanced simulated analysis for APLM: £202.56 (+0.00%)
# 2025-09-01 12:53:40,672 - INFO - Enhanced simulated analysis for APLT: £334.53 (+0.00%)
# 2025-09-01 12:53:40,685 - INFO - Enhanced simulated analysis for APVO: £235.43 (+0.00%)
# 2025-09-01 12:53:40,696 - INFO - Enhanced simulated analysis for ARAY: £105.08 (+0.00%)
# 2025-09-01 12:53:40,707 - INFO - Enhanced simulated analysis for ARBE: £284.45 (+0.00%)
# 2025-09-01 12:53:40,719 - INFO - Enhanced simulated analysis for ATEN: £280.69 (+0.00%)
# 2025-09-01 12:53:40,731 - INFO - Enhanced simulated analysis for ATAI: £357.00 (+0.00%)
# 2025-09-01 12:53:40,742 - INFO - Enhanced simulated analysis for ATHA: £60.46 (+0.00%)
# 2025-09-01 12:53:40,754 - INFO - Enhanced simulated analysis for AUTL: £481.82 (+0.00%)
# 2025-09-01 12:53:40,766 - INFO - Enhanced simulated analysis for AVIR: £419.17 (+0.00%)
# 2025-09-01 12:53:40,777 - INFO - Enhanced simulated analysis for CABA: £186.82 (+0.00%)
# 2025-09-01 12:53:40,789 - INFO - Enhanced simulated analysis for CAMP: £148.29 (+0.00%)
# 2025-09-01 12:53:40,801 - INFO - Enhanced simulated analysis for CARM: £348.29 (+0.00%)
# 2025-09-01 12:53:40,812 - INFO - Enhanced simulated analysis for CATX: £77.36 (+0.00%)
# 2025-09-01 12:53:40,824 - INFO - Enhanced simulated analysis for CCCC: £471.12 (+0.00%)
# 2025-09-01 12:53:40,835 - INFO - Enhanced simulated analysis for CELU: £154.09 (+0.00%)
# 2025-09-01 12:53:40,848 - INFO - Enhanced simulated analysis for CERS: £492.07 (+0.00%)
# 2025-09-01 12:53:40,859 - INFO - Enhanced simulated analysis for CGTX: £58.68 (+0.00%)
# 2025-09-01 12:53:40,866 - INFO - BUY signal for CGTX: 3/7 signals
# 2025-09-01 12:53:40,866 - INFO - Simulated BUY order placed: 1 CGTX
# 2025-09-01 12:53:40,866 - INFO - SIMULATED BUY: 1 CGTX @ £58.68 (Cost: £58.68, Balance: £60.73)
# 2025-09-01 12:53:40,867 - INFO - CGTX indicators - RSI: 68.8, MACD: 0.471, Volatility: 0.19%
# 2025-09-01 12:53:40,873 - INFO - Enhanced simulated analysis for CHRS: £443.51 (+0.00%)
# 2025-09-01 12:53:40,885 - INFO - Enhanced simulated analysis for CLDI: £388.13 (+0.00%)
# 2025-09-01 12:53:40,897 - INFO - Enhanced simulated analysis for CLLS: £125.17 (+0.00%)
# 2025-09-01 12:53:40,910 - INFO - Enhanced simulated analysis for CLRB: £431.66 (+0.00%)
# 2025-09-01 12:53:40,921 - INFO - Enhanced simulated analysis for CLSD: £492.32 (+0.00%)
# 2025-09-01 12:53:40,933 - INFO - Enhanced simulated analysis for CLYM: £134.46 (+0.00%)
# 2025-09-01 12:53:40,944 - INFO - Enhanced simulated analysis for CMPS: £293.97 (+0.00%)
# 2025-09-01 12:53:40,956 - INFO - Enhanced simulated analysis for CMPX: £471.68 (+0.00%)
# 2025-09-01 12:53:40,968 - INFO - Enhanced simulated analysis for CMTL: £171.00 (+0.00%)
# 2025-09-01 12:53:40,980 - INFO - Enhanced simulated analysis for COCP: £374.83 (+0.00%)
# 2025-09-01 12:53:40,992 - INFO - Enhanced simulated analysis for CRBU: £325.60 (+0.00%)
# 2025-09-01 12:53:41,004 - INFO - Enhanced simulated analysis for CRDF: £55.44 (+0.00%)
# 2025-09-01 12:53:41,017 - INFO - Enhanced simulated analysis for CRDL: £80.99 (+0.00%)
# 2025-09-01 12:53:41,024 - INFO - BUY signal for CRDL: 3/7 signals
# 2025-09-01 12:53:41,031 - INFO - Enhanced simulated analysis for CRIS: £158.63 (+0.00%)
# 2025-09-01 12:53:41,042 - INFO - Enhanced simulated analysis for CTMX: £98.01 (+0.00%)
# 2025-09-01 12:53:41,057 - INFO - Enhanced simulated analysis for CTOR: £74.73 (+0.00%)
# 2025-09-01 12:53:41,070 - INFO - Enhanced simulated analysis for CTXR: £208.49 (+0.00%)
# 2025-09-01 12:53:41,081 - INFO - Enhanced simulated analysis for CUE: £333.02 (+0.00%)
# 2025-09-01 12:53:41,097 - INFO - Enhanced simulated analysis for CURR: £413.72 (+0.00%)
# 2025-09-01 12:53:41,130 - INFO - Enhanced simulated analysis for DARE: £138.48 (+0.00%)
# 2025-09-01 12:53:41,141 - INFO - Enhanced simulated analysis for DTIL: £100.55 (+0.00%)
# 2025-09-01 12:53:41,154 - INFO - Enhanced simulated analysis for EDIT: £369.50 (+0.00%)
# 2025-09-01 12:53:41,165 - INFO - Enhanced simulated analysis for ELDN: £418.07 (+0.00%)
# 2025-09-01 12:53:41,177 - INFO - Enhanced simulated analysis for EQ: £56.67 (+0.00%)
# 2025-09-01 12:53:41,189 - INFO - Enhanced simulated analysis for ERAS: £182.53 (+0.00%)
# 2025-09-01 12:53:41,200 - INFO - Enhanced simulated analysis for ERNA: £105.27 (+0.00%)
# 2025-09-01 12:53:41,212 - INFO - Enhanced simulated analysis for ESLA: £220.84 (+0.00%)
# 2025-09-01 12:53:41,224 - INFO - Enhanced simulated analysis for ESPR: £273.48 (+0.00%)
# 2025-09-01 12:53:41,235 - INFO - Enhanced simulated analysis for EVGN: £77.21 (+0.00%)
# 2025-09-01 12:53:41,248 - INFO - Enhanced simulated analysis for FATE: £443.59 (+0.00%)
# 2025-09-01 12:53:41,259 - INFO - Enhanced simulated analysis for FBLG: £329.89 (+0.00%)
# 2025-09-01 12:53:41,266 - INFO - Cycle completed: 1 trades executed
# 2025-09-01 12:53:41,266 - INFO - Performance - Total Trades: 4, Win Rate: 75.0%, Total P&L: £5.11
# 2025-09-01 12:53:41,266 - INFO - Market Overview - Active Positions: 25, Symbols Tracked: 54
# 2025-09-01 12:53:44,272 - INFO - Reached maximum cycles (5)
# 2025-09-01 12:53:44,276 - INFO - ==================================================
# 2025-09-01 12:53:44,277 - INFO - ENHANCED TRADING SESSION SUMMARY
# 2025-09-01 12:53:44,277 - INFO - ==================================================
# 2025-09-01 12:53:44,278 - INFO - Environment: SIMULATOR
# 2025-09-01 12:53:44,279 - INFO - Duration: 0:00:18.612601
# 2025-09-01 12:53:44,279 - INFO - Total trades executed: 33
# 2025-09-01 12:53:44,280 - INFO - Strategy: Enhanced_5_15
# 2025-09-01 12:53:44,281 - INFO - Win Rate: 75.0%
# 2025-09-01 12:53:44,281 - INFO - Total P&L: £5.11
# 2025-09-01 12:53:44,282 - INFO - Profitable Trades: 3/4
# 2025-09-01 12:53:44,285 - INFO - Current Positions:
# 2025-09-01 12:53:44,313 - INFO - Enhanced simulated analysis for ANNX: £214.73 (+0.00%)
# 2025-09-01 12:53:44,314 - INFO -   ANNX: 5 shares @ £218.38 (Current: £214.73, P&L: £-18.25 -1.7%)
# 2025-09-01 12:53:44,336 - INFO - Enhanced simulated analysis for ATEN: £283.86 (+0.00%)
# 2025-09-01 12:53:44,336 - INFO -   ATEN: 3 shares @ £280.91 (Current: £283.86, P&L: £+8.85 +1.1%)
# 2025-09-01 12:53:44,347 - INFO - Enhanced simulated analysis for AUTL: £482.27 (+0.00%)
# 2025-09-01 12:53:44,347 - INFO -   AUTL: 1 shares @ £485.08 (Current: £482.27, P&L: £-2.81 -0.6%)
# 2025-09-01 12:53:44,355 - INFO - Enhanced simulated analysis for CAMP: £147.47 (+0.00%)
# 2025-09-01 12:53:44,355 - INFO -   CAMP: 6 shares @ £147.28 (Current: £147.47, P&L: £+1.14 +0.1%)
# 2025-09-01 12:53:44,362 - INFO - Enhanced simulated analysis for CARM: £347.12 (+0.00%)
# 2025-09-01 12:53:44,363 - INFO -   CARM: 2 shares @ £349.73 (Current: £347.12, P&L: £-5.22 -0.7%)
# 2025-09-01 12:53:44,363 - INFO -   CELU: No position
# 2025-09-01 12:53:44,370 - INFO - Enhanced simulated analysis for CLRB: £428.03 (+0.00%)
# 2025-09-01 12:53:44,370 - INFO -   CLRB: 1 shares @ £431.32 (Current: £428.03, P&L: £-3.29 -0.8%)
# 2025-09-01 12:53:44,370 - INFO -   CLSD: No position
# 2025-09-01 12:53:44,378 - INFO - Enhanced simulated analysis for CLYM: £135.57 (+0.00%)
# 2025-09-01 12:53:44,378 - INFO -   CLYM: 3 shares @ £135.42 (Current: £135.57, P&L: £+0.45 +0.1%)
# 2025-09-01 12:53:44,384 - INFO - Enhanced simulated analysis for CTMX: £98.21 (+0.00%)
# 2025-09-01 12:53:44,384 - INFO -   CTMX: 5 shares @ £97.03 (Current: £98.21, P&L: £+5.90 +1.2%)
# 2025-09-01 12:53:44,391 - INFO - Enhanced simulated analysis for CTOR: £74.48 (+0.00%)
# 2025-09-01 12:53:44,391 - INFO -   CTOR: 5 shares @ £73.72 (Current: £74.48, P&L: £+3.80 +1.0%)
# 2025-09-01 12:53:44,398 - INFO - Enhanced simulated analysis for ESLA: £221.24 (+0.00%)
# 2025-09-01 12:53:44,399 - INFO -   ESLA: 1 shares @ £220.90 (Current: £221.24, P&L: £+0.34 +0.2%)
# 2025-09-01 12:53:44,405 - INFO - Enhanced simulated analysis for ANVS: £88.06 (+0.00%)
# 2025-09-01 12:53:44,405 - INFO -   ANVS: 4 shares @ £88.99 (Current: £88.06, P&L: £-3.72 -1.0%)
# 2025-09-01 12:53:44,413 - INFO - Enhanced simulated analysis for CERS: £492.01 (+0.00%)
# 2025-09-01 12:53:44,413 - INFO -   CERS: 1 shares @ £495.61 (Current: £492.01, P&L: £-3.60 -0.7%)
# 2025-09-01 12:53:44,420 - INFO - Enhanced simulated analysis for COCP: £375.83 (+0.00%)
# 2025-09-01 12:53:44,420 - INFO -   COCP: 1 shares @ £372.58 (Current: £375.83, P&L: £+3.25 +0.9%)
# 2025-09-01 12:53:44,426 - INFO - Enhanced simulated analysis for ERNA: £104.97 (+0.00%)
# 2025-09-01 12:53:44,427 - INFO -   ERNA: 3 shares @ £106.77 (Current: £104.97, P&L: £-5.40 -1.7%)
# 2025-09-01 12:53:44,433 - INFO - Enhanced simulated analysis for FATE: £441.69 (+0.00%)
# 2025-09-01 12:53:44,434 - INFO -   FATE: 1 shares @ £449.23 (Current: £441.69, P&L: £-7.54 -1.7%)
# 2025-09-01 12:53:44,440 - INFO - Enhanced simulated analysis for ABCL: £102.76 (+0.00%)
# 2025-09-01 12:53:44,440 - INFO -   ABCL: 3 shares @ £101.56 (Current: £102.76, P&L: £+3.60 +1.2%)
# 2025-09-01 12:53:44,447 - INFO - Enhanced simulated analysis for ANRO: £276.43 (+0.00%)
# 2025-09-01 12:53:44,448 - INFO -   ANRO: 1 shares @ £271.31 (Current: £276.43, P&L: £+5.12 +1.9%)
# 2025-09-01 12:53:44,454 - INFO - Enhanced simulated analysis for ATAI: £357.87 (+0.00%)
# 2025-09-01 12:53:44,454 - INFO -   ATAI: 1 shares @ £355.80 (Current: £357.87, P&L: £+2.07 +0.6%)
# 2025-09-01 12:53:44,461 - INFO - Enhanced simulated analysis for CABA: £187.34 (+0.00%)
# 2025-09-01 12:53:44,461 - INFO -   CABA: 1 shares @ £187.31 (Current: £187.34, P&L: £+0.03 +0.0%)
# 2025-09-01 12:53:44,462 - INFO -   CLDI: No position
# 2025-09-01 12:53:44,468 - INFO - Enhanced simulated analysis for DARE: £138.63 (+0.00%)
# 2025-09-01 12:53:44,468 - INFO -   DARE: 1 shares @ £139.95 (Current: £138.63, P&L: £-1.32 -0.9%)
# 2025-09-01 12:53:44,475 - INFO - Enhanced simulated analysis for CLLS: £124.88 (+0.00%)
# 2025-09-01 12:53:44,476 - INFO -   CLLS: 1 shares @ £125.61 (Current: £124.88, P&L: £-0.73 -0.6%)
# 2025-09-01 12:53:44,482 - INFO - Enhanced simulated analysis for CRBU: £325.78 (+0.00%)
# 2025-09-01 12:53:44,482 - INFO -   CRBU: 1 shares @ £327.36 (Current: £325.78, P&L: £-1.58 -0.5%)
# 2025-09-01 12:53:44,489 - INFO - Enhanced simulated analysis for CRDF: £55.08 (+0.00%)
# 2025-09-01 12:53:44,489 - INFO -   CRDF: 1 shares @ £55.46 (Current: £55.08, P&L: £-0.38 -0.7%)
# 2025-09-01 12:53:44,497 - INFO - Enhanced simulated analysis for CTXR: £206.26 (+0.00%)
# 2025-09-01 12:53:44,497 - INFO -   CTXR: 1 shares @ £209.45 (Current: £206.26, P&L: £-3.19 -1.5%)
# 2025-09-01 12:53:44,503 - INFO - Enhanced simulated analysis for CGTX: £58.69 (+0.00%)
# 2025-09-01 12:53:44,503 - INFO -   CGTX: 1 shares @ £58.68 (Current: £58.69, P&L: £+0.01 +0.0%)
# 2025-09-01 12:53:44,504 - INFO - Total Position Value: £9944.38
# 2025-09-01 12:53:44,504 - INFO - Technical Indicators Summary:
# 2025-09-01 12:53:44,504 - INFO -   ABCL: RSI: 63.4, MACD: 0.951, Vol: 0.2%
# 2025-09-01 12:53:44,505 - INFO -   ALLO: RSI: 76.1, MACD: 1.082, Vol: 0.2%
# 2025-09-01 12:53:44,505 - INFO -   ANNX: RSI: 85.3, MACD: 5.356, Vol: 0.2%
# 2025-09-01 12:53:44,505 - INFO -   ANRO: RSI: 30.1, MACD: -1.936, Vol: 0.2%
# 2025-09-01 12:53:44,506 - INFO -   ANVS: RSI: 39.8, MACD: -0.589, Vol: 0.2%
# 2025-09-01 12:53:44,506 - INFO -   APLM: RSI: 37.8, MACD: 0.206, Vol: 0.2%
# 2025-09-01 12:53:44,506 - INFO -   APLT: RSI: 48.5, MACD: -0.002, Vol: 0.2%
# 2025-09-01 12:53:44,507 - INFO -   APVO: RSI: 63.3, MACD: -0.028, Vol: 0.2%
# 2025-09-01 12:53:44,509 - INFO -   ARAY: RSI: 28.2, MACD: -0.380, Vol: 0.2%
# 2025-09-01 12:53:44,510 - INFO -   ARBE: RSI: 65.6, MACD: 0.631, Vol: 0.2%
# 2025-09-01 12:53:44,511 - INFO -   ATEN: RSI: 58.5, MACD: -0.384, Vol: 0.1%
# 2025-09-01 12:53:44,512 - INFO -   ATAI: RSI: 22.2, MACD: -1.394, Vol: 0.2%
# 2025-09-01 12:53:44,512 - INFO -   ATHA: RSI: 55.1, MACD: -0.410, Vol: 0.2%
# 2025-09-01 12:53:44,513 - INFO -   AUTL: RSI: 63.5, MACD: 1.417, Vol: 0.3%
# 2025-09-01 12:53:44,514 - INFO -   AVIR: RSI: 69.4, MACD: 0.407, Vol: 0.2%
# 2025-09-01 12:53:44,515 - INFO -   CABA: RSI: 66.4, MACD: 1.317, Vol: 0.2%
# 2025-09-01 12:53:44,516 - INFO -   CAMP: RSI: 65.3, MACD: 0.536, Vol: 0.2%
# 2025-09-01 12:53:44,516 - INFO -   CARM: RSI: 29.7, MACD: -2.238, Vol: 0.2%
# 2025-09-01 12:53:44,516 - INFO -   CATX: RSI: 46.7, MACD: -0.332, Vol: 0.2%
# 2025-09-01 12:53:44,518 - INFO -   CCCC: RSI: 56.1, MACD: 0.622, Vol: 0.3%
# 2025-09-01 12:53:44,519 - INFO -   CELU: RSI: 49.7, MACD: -0.271, Vol: 0.2%
# 2025-09-01 12:53:44,521 - INFO -   CERS: RSI: 42.9, MACD: -0.004, Vol: 0.2%
# 2025-09-01 12:53:44,522 - INFO -   CGTX: RSI: 34.8, MACD: -0.475, Vol: 0.2%
# 2025-09-01 12:53:44,522 - INFO -   CHRS: RSI: 61.1, MACD: 1.300, Vol: 0.2%
# 2025-09-01 12:53:44,523 - INFO -   CLDI: RSI: 32.2, MACD: -0.236, Vol: 0.2%
# 2025-09-01 12:53:44,525 - INFO -   CLLS: RSI: 30.9, MACD: -4.191, Vol: 0.2%
# 2025-09-01 12:53:44,526 - INFO -   CLRB: RSI: 56.0, MACD: -0.904, Vol: 0.2%
# 2025-09-01 12:53:44,527 - INFO -   CLSD: RSI: 80.8, MACD: 1.495, Vol: 0.3%
# 2025-09-01 12:53:44,528 - INFO -   CLYM: RSI: 36.1, MACD: -0.270, Vol: 0.2%
# 2025-09-01 12:53:44,530 - INFO -   CMPS: RSI: 32.9, MACD: -0.914, Vol: 0.2%
# 2025-09-01 12:53:44,531 - INFO -   CMPX: RSI: 71.0, MACD: 1.002, Vol: 0.2%
# 2025-09-01 12:53:44,532 - INFO -   CMTL: RSI: 32.3, MACD: -0.461, Vol: 0.3%
# 2025-09-01 12:53:44,533 - INFO -   COCP: RSI: 41.9, MACD: -1.412, Vol: 0.3%
# 2025-09-01 12:53:44,534 - INFO -   CRBU: RSI: 68.8, MACD: -0.255, Vol: 0.2%
# 2025-09-01 12:53:44,535 - INFO -   CRDF: RSI: 51.0, MACD: -2.150, Vol: 0.2%
# 2025-09-01 12:53:44,536 - INFO -   CRDL: RSI: 48.8, MACD: -0.055, Vol: 0.3%
# 2025-09-01 12:53:44,537 - INFO -   CRIS: RSI: 49.9, MACD: 0.156, Vol: 0.1%
# 2025-09-01 12:53:44,537 - INFO -   CTMX: RSI: 56.4, MACD: 0.369, Vol: 0.2%
# 2025-09-01 12:53:44,538 - INFO -   CTOR: RSI: 70.4, MACD: 1.661, Vol: 0.3%
# 2025-09-01 12:53:44,539 - INFO -   CTXR: RSI: 42.0, MACD: -0.531, Vol: 0.2%
# 2025-09-01 12:53:44,539 - INFO -   CUE: RSI: 39.6, MACD: -0.579, Vol: 0.2%
# 2025-09-01 12:53:44,539 - INFO -   CURR: RSI: 33.2, MACD: -0.069, Vol: 0.2%
# 2025-09-01 12:53:44,539 - INFO -   DARE: RSI: 36.5, MACD: -0.612, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   DTIL: RSI: 57.1, MACD: 0.780, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   EDIT: RSI: 34.0, MACD: -1.772, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   ELDN: RSI: 59.0, MACD: -0.577, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   EQ: RSI: 47.5, MACD: -0.047, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   ERAS: RSI: 69.2, MACD: 1.785, Vol: 0.2%
# 2025-09-01 12:53:44,540 - INFO -   ERNA: RSI: 48.8, MACD: -0.495, Vol: 0.2%
# 2025-09-01 12:53:44,541 - INFO -   ESLA: RSI: 66.9, MACD: 0.125, Vol: 0.2%
# 2025-09-01 12:53:44,541 - INFO -   ESPR: RSI: 64.2, MACD: 0.840, Vol: 0.2%
# 2025-09-01 12:53:44,542 - INFO -   EVGN: RSI: 65.2, MACD: 0.303, Vol: 0.2%
# 2025-09-01 12:53:44,542 - INFO -   FATE: RSI: 59.3, MACD: -0.026, Vol: 0.2%
# 2025-09-01 12:53:44,542 - INFO -   FBLG: RSI: 52.8, MACD: 0.933, Vol: 0.2%
# 2025-09-01 12:53:44,542 - INFO - ==================================================
# 2025-09-01 12:53:44,543 - INFO - Disconnected from trading simulator
# Results:
# Trades: 33
# Balance: £60.73
# ANNX: 5 shares @ £218.38 (£1091.90)
# ATEN: 3 shares @ £280.91 (£842.73)
# AUTL: 1 shares @ £485.08 (£485.08)
# CAMP: 6 shares @ £147.28 (£883.68)
# CARM: 2 shares @ £349.73 (£699.46)
# CLRB: 1 shares @ £431.32 (£431.32)
# CLYM: 3 shares @ £135.42 (£406.26)
# CTMX: 5 shares @ £97.03 (£485.15)
# CTOR: 5 shares @ £73.72 (£368.60)
# ESLA: 1 shares @ £220.90 (£220.90)
# ANVS: 4 shares @ £88.99 (£355.96)
# CERS: 1 shares @ £495.61 (£495.61)
# COCP: 1 shares @ £372.58 (£372.58)
# ERNA: 3 shares @ £106.77 (£320.31)
# FATE: 1 shares @ £449.23 (£449.23)
# ABCL: 3 shares @ £101.56 (£304.68)
# ANRO: 1 shares @ £271.31 (£271.31)
# ATAI: 1 shares @ £355.80 (£355.80)
# CABA: 1 shares @ £187.31 (£187.31)
# DARE: 1 shares @ £139.95 (£139.95)
# CLLS: 1 shares @ £125.61 (£125.61)
# CRBU: 1 shares @ £327.36 (£327.36)
# CRDF: 1 shares @ £55.46 (£55.46)
# CTXR: 1 shares @ £209.45 (£209.45)
# CGTX: 1 shares @ £58.68 (£58.68)

# %% [markdown]
# ### Production-Ready Bot

# %%
def create_production_bot(environment: str = 'paper') -> IBTradingBot:
    """
    Create a production-ready trading bot with conservative settings
    
    Args:
        environment: 'paper', 'live', or 'simulator'
    """
    
    # Create bot with conservative enhanced strategy
    bot = create_trading_bot(
        environment=environment,
        strategy_type='enhanced',
        short_window=20,
        long_window=50,
        stop_loss_pct=0.05,
        take_profit_pct=0.15,
        name='Production_Enhanced'
    )
    
    # Set stable symbols
    bot.set_symbols(['ABCL','ALLO','ANNX','ANRO','ANVS','APLM','APLT','APVO','ARAY','ARBE',
    'ATEN','ATAI','ATHA','AUTL','AVIR','CABA','CAMP','CARM','CATX','CCCC',
    'CELU','CERS','CGTX','CHRS','CLDI','CLLS','CLRB','CLSD','CLYM','CMPS',
    'CMPX','CMTL','COCP','CRBU','CRDF','CRDL','CRIS','CTMX','CTOR','CTXR',
    'CUE','CURR','DARE','DTIL','EDIT','ELDN','EQ','ERAS','ERNA','ESLA',
    'ESPR','EVGN','FATE','FBLG'])
    bot.update_interval = 60  # 1-minute updates
    
    return bot


def run_production_session(environment: str = 'simulator', max_cycles: int = 10):
    """
    Run a simple production trading session
    
    Args:
        environment: 'simulator', 'paper', or 'live'
        max_cycles: Number of cycles to run
    """
    
    bot = create_production_bot(environment)
    
    try:
        if not bot.connect():
            print(f"Failed to connect to {environment}")
            return False
        
        print("="*50)
        print("PRODUCTION SESSION STARTED")
        print("="*50)
        print(f"Environment: {bot.environment.upper()}")
        print(f"Strategy: {bot.strategy.name}")
        print(f"Symbols: {bot.symbols}")
        print(f"Cycles: {max_cycles}")
        print("="*50)
        
        # Start trading
        bot.start_trading(max_cycles=max_cycles)
        
        # Show results
        print(f"\nSession Results:")
        print(f"Trades: {bot.trades_executed}")
        
        if environment == 'simulator':
            print(f"Final Balance: £{bot.simulated_balance:,.2f}")
        
        # Show positions
        any_positions = False
        for symbol, position in bot.strategy.positions.items():
            if position['shares'] > 0:
                print(f"{symbol}: {position['shares']} shares @ £{position['avg_price']:.2f}")
                any_positions = True
        
        if not any_positions:
            print("No positions")
        
        return True
        
    except KeyboardInterrupt:
        print("\nSession stopped by user")
        return True
    except Exception as e:
        print(f"Session error: {e}")
        return False
    finally:
        try:
            bot.disconnect()
        except:
            pass
        print("\nSession ended")


def run_quick_demo():
    """Run a quick 5-cycle demo"""
    print("Quick Demo (5 cycles, simulator)")
    success = run_production_session('simulator', max_cycles=5)
    
    if success:
        print("\nDemo completed")
        print("Next: Try run_production_session('paper', 10) with TWS running")
    else:
        print("Demo failed")


print("Production-ready bot functions created")
print("\nAvailable commands:")
print("• run_quick_demo()")
print("• run_production_session('simulator', 10)")
print("• run_production_session('paper', 10)")

print("\nWarning: Test extensively before live trading")
# Out:
# Production-ready bot functions created
#
# Available commands:
# • run_quick_demo()
# • run_production_session('simulator', 10)
# • run_production_session('paper', 10)
#
# Warning: Test extensively before live trading

# %% [markdown]
# ### Execute IB Trading Bot Simulator (Quick Demo)

# %%
print("="*60)
print("Quick Demo - Enhanced Trading Bot")
print("="*60)

# Simple 5-cycle demo
print("Running quick demo...")
run_quick_demo()

print("="*60)
# Out:
# 2025-09-01 12:54:09,163 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 12:54:09,165 - INFO - Trading bot simulator initialised
# 2025-09-01 12:54:09,165 - INFO - Strategy: Production_Enhanced
# 2025-09-01 12:54:09,166 - INFO - Starting balance: £10,000.00
# 2025-09-01 12:54:09,166 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:54:09,167 - INFO - Connected to trading simulator
# 2025-09-01 12:54:09,167 - INFO - Starting automated trading...
# 2025-09-01 12:54:09,168 - INFO - Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 12:54:09,168 - INFO - Strategy: Production_Enhanced
# 2025-09-01 12:54:09,168 - INFO - Update interval: 60 seconds
# 2025-09-01 12:54:09,168 - INFO - Strategy config - Short: 20, Long: 50, Stop Loss: 5.0%, Take Profit: 15.0%
# 2025-09-01 12:54:09,169 - INFO - --- Cycle 1 ---
# 2025-09-01 12:54:09,185 - INFO - Enhanced simulated analysis for ABCL: £354.33 (+0.00%)
# 2025-09-01 12:54:09,201 - INFO - Enhanced simulated analysis for ALLO: £459.72 (+0.00%)
# 2025-09-01 12:54:09,215 - INFO - Enhanced simulated analysis for ANNX: £396.52 (+0.00%)
# 2025-09-01 12:54:09,222 - INFO - BUY signal for ANNX: 3/7 signals
# 2025-09-01 12:54:09,222 - INFO - Simulated BUY order placed: 3 ANNX
# 2025-09-01 12:54:09,222 - INFO - SIMULATED BUY: 3 ANNX @ £396.52 (Cost: £1189.56, Balance: £8810.44)
# 2025-09-01 12:54:09,223 - INFO - ANNX indicators - RSI: 92.6, MACD: 1.105, Volatility: 0.21%
# 2025-09-01 12:54:09,230 - INFO - Enhanced simulated analysis for ANRO: £211.92 (+0.00%)
# 2025-09-01 12:54:09,243 - INFO - Enhanced simulated analysis for ANVS: £258.48 (+0.00%)
# 2025-09-01 12:54:09,249 - INFO - BUY signal for ANVS: 3/7 signals
# 2025-09-01 12:54:09,249 - INFO - Simulated BUY order placed: 4 ANVS
# 2025-09-01 12:54:09,250 - INFO - SIMULATED BUY: 4 ANVS @ £258.48 (Cost: £1033.92, Balance: £7776.52)
# 2025-09-01 12:54:09,250 - INFO - ANVS indicators - RSI: 49.6, MACD: -0.395, Volatility: 0.26%
# 2025-09-01 12:54:09,257 - INFO - Enhanced simulated analysis for APLM: £360.42 (+0.00%)
# 2025-09-01 12:54:09,264 - INFO - BUY signal for APLM: 3/7 signals
# 2025-09-01 12:54:09,265 - INFO - Simulated BUY order placed: 2 APLM
# 2025-09-01 12:54:09,265 - INFO - SIMULATED BUY: 2 APLM @ £360.42 (Cost: £720.84, Balance: £7055.68)
# 2025-09-01 12:54:09,265 - INFO - APLM indicators - RSI: 76.1, MACD: 0.329, Volatility: 0.15%
# 2025-09-01 12:54:09,272 - INFO - Enhanced simulated analysis for APLT: £106.91 (+0.00%)
# 2025-09-01 12:54:09,280 - INFO - BUY signal for APLT: 3/7 signals
# 2025-09-01 12:54:09,280 - INFO - Simulated BUY order placed: 7 APLT
# 2025-09-01 12:54:09,281 - INFO - SIMULATED BUY: 7 APLT @ £106.91 (Cost: £748.37, Balance: £6307.31)
# 2025-09-01 12:54:09,281 - INFO - APLT indicators - RSI: 38.2, MACD: 0.012, Volatility: 0.21%
# 2025-09-01 12:54:09,288 - INFO - Enhanced simulated analysis for APVO: £291.31 (+0.00%)
# 2025-09-01 12:54:09,301 - INFO - Enhanced simulated analysis for ARAY: £69.65 (+0.00%)
# 2025-09-01 12:54:09,313 - INFO - Enhanced simulated analysis for ARBE: £440.00 (+0.00%)
# 2025-09-01 12:54:09,326 - INFO - Enhanced simulated analysis for ATEN: £188.26 (+0.00%)
# 2025-09-01 12:54:09,337 - INFO - Enhanced simulated analysis for ATAI: £319.41 (+0.00%)
# 2025-09-01 12:54:09,350 - INFO - Enhanced simulated analysis for ATHA: £119.69 (+0.00%)
# 2025-09-01 12:54:09,362 - INFO - Enhanced simulated analysis for AUTL: £383.80 (+0.00%)
# ============================================================
# Quick Demo - Enhanced Trading Bot
# ============================================================
# Running quick demo...
# Quick Demo (5 cycles, simulator)
# ==================================================
# PRODUCTION SESSION STARTED
# ==================================================
# Environment: SIMULATOR
# Strategy: Production_Enhanced
# Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# Cycles: 5
# ==================================================
# 2025-09-01 12:54:09,369 - INFO - BUY signal for AUTL: 3/7 signals
# 2025-09-01 12:54:09,370 - INFO - Simulated BUY order placed: 1 AUTL
# 2025-09-01 12:54:09,370 - INFO - SIMULATED BUY: 1 AUTL @ £383.80 (Cost: £383.80, Balance: £5923.51)
# 2025-09-01 12:54:09,370 - INFO - AUTL indicators - RSI: 45.1, MACD: 0.772, Volatility: 0.18%
# 2025-09-01 12:54:09,379 - INFO - Enhanced simulated analysis for AVIR: £479.72 (+0.00%)
# 2025-09-01 12:54:09,391 - INFO - Enhanced simulated analysis for CABA: £150.25 (+0.00%)
# 2025-09-01 12:54:09,403 - INFO - Enhanced simulated analysis for CAMP: £55.65 (+0.00%)
# 2025-09-01 12:54:09,437 - INFO - Enhanced simulated analysis for CARM: £119.39 (+0.00%)
# 2025-09-01 12:54:09,453 - INFO - Enhanced simulated analysis for CATX: £436.41 (+0.00%)
# 2025-09-01 12:54:09,460 - INFO - BUY signal for CATX: 3/7 signals
# 2025-09-01 12:54:09,460 - INFO - Simulated BUY order placed: 1 CATX
# 2025-09-01 12:54:09,461 - INFO - SIMULATED BUY: 1 CATX @ £436.41 (Cost: £436.41, Balance: £5487.10)
# 2025-09-01 12:54:09,461 - INFO - CATX indicators - RSI: 61.4, MACD: -0.092, Volatility: 0.25%
# 2025-09-01 12:54:09,467 - INFO - Enhanced simulated analysis for CCCC: £458.45 (+0.00%)
# 2025-09-01 12:54:09,480 - INFO - Enhanced simulated analysis for CELU: £101.69 (+0.00%)
# 2025-09-01 12:54:09,491 - INFO - Enhanced simulated analysis for CERS: £354.27 (+0.00%)
# 2025-09-01 12:54:09,503 - INFO - Enhanced simulated analysis for CGTX: £319.38 (+0.00%)
# 2025-09-01 12:54:09,515 - INFO - Enhanced simulated analysis for CHRS: £214.52 (+0.00%)
# 2025-09-01 12:54:09,526 - INFO - Enhanced simulated analysis for CLDI: £374.18 (+0.00%)
# 2025-09-01 12:54:09,537 - INFO - Enhanced simulated analysis for CLLS: £126.63 (+0.00%)
# 2025-09-01 12:54:09,544 - INFO - BUY signal for CLLS: 3/7 signals
# 2025-09-01 12:54:09,544 - INFO - Simulated BUY order placed: 5 CLLS
# 2025-09-01 12:54:09,545 - INFO - SIMULATED BUY: 5 CLLS @ £126.63 (Cost: £633.15, Balance: £4853.95)
# 2025-09-01 12:54:09,545 - INFO - CLLS indicators - RSI: 52.7, MACD: 1.278, Volatility: 0.23%
# 2025-09-01 12:54:09,551 - INFO - Enhanced simulated analysis for CLRB: £427.37 (+0.00%)
# 2025-09-01 12:54:09,563 - INFO - Enhanced simulated analysis for CLSD: £170.33 (+0.00%)
# 2025-09-01 12:54:09,574 - INFO - Enhanced simulated analysis for CLYM: £193.75 (+0.00%)
# 2025-09-01 12:54:09,581 - INFO - BUY signal for CLYM: 3/7 signals
# 2025-09-01 12:54:09,582 - INFO - Simulated BUY order placed: 3 CLYM
# 2025-09-01 12:54:09,582 - INFO - SIMULATED BUY: 3 CLYM @ £193.75 (Cost: £581.25, Balance: £4272.70)
# 2025-09-01 12:54:09,582 - INFO - CLYM indicators - RSI: 30.0, MACD: -0.451, Volatility: 0.20%
# 2025-09-01 12:54:09,589 - INFO - Enhanced simulated analysis for CMPS: £477.84 (+0.00%)
# 2025-09-01 12:54:09,601 - INFO - Enhanced simulated analysis for CMPX: £322.03 (+0.00%)
# 2025-09-01 12:54:09,613 - INFO - Enhanced simulated analysis for CMTL: £398.55 (+0.00%)
# 2025-09-01 12:54:09,625 - INFO - Enhanced simulated analysis for COCP: £176.97 (+0.00%)
# 2025-09-01 12:54:09,637 - INFO - Enhanced simulated analysis for CRBU: £247.99 (+0.00%)
# 2025-09-01 12:54:09,648 - INFO - Enhanced simulated analysis for CRDF: £342.95 (+0.00%)
# 2025-09-01 12:54:09,660 - INFO - Enhanced simulated analysis for CRDL: £358.99 (+0.00%)
# 2025-09-01 12:54:09,671 - INFO - Enhanced simulated analysis for CRIS: £387.75 (+0.00%)
# 2025-09-01 12:54:09,683 - INFO - Enhanced simulated analysis for CTMX: £317.05 (+0.00%)
# 2025-09-01 12:54:09,696 - INFO - Enhanced simulated analysis for CTOR: £440.11 (+0.00%)
# 2025-09-01 12:54:09,709 - INFO - Enhanced simulated analysis for CTXR: £141.92 (+0.00%)
# 2025-09-01 12:54:09,720 - INFO - Enhanced simulated analysis for CUE: £252.99 (+0.00%)
# 2025-09-01 12:54:09,732 - INFO - Enhanced simulated analysis for CURR: £71.35 (+0.00%)
# 2025-09-01 12:54:09,744 - INFO - Enhanced simulated analysis for DARE: £115.15 (+0.00%)
# 2025-09-01 12:54:09,755 - INFO - Enhanced simulated analysis for DTIL: £362.66 (+0.00%)
# 2025-09-01 12:54:09,767 - INFO - Enhanced simulated analysis for EDIT: £111.06 (+0.00%)
# 2025-09-01 12:54:09,779 - INFO - Enhanced simulated analysis for ELDN: £440.77 (+0.00%)
# 2025-09-01 12:54:09,790 - INFO - Enhanced simulated analysis for EQ: £345.77 (+0.00%)
# 2025-09-01 12:54:09,803 - INFO - Enhanced simulated analysis for ERAS: £111.10 (+0.00%)
# 2025-09-01 12:54:09,816 - INFO - Enhanced simulated analysis for ERNA: £182.71 (+0.00%)
# 2025-09-01 12:54:09,828 - INFO - Enhanced simulated analysis for ESLA: £497.99 (+0.00%)
# 2025-09-01 12:54:09,840 - INFO - Enhanced simulated analysis for ESPR: £484.50 (+0.00%)
# 2025-09-01 12:54:09,853 - INFO - Enhanced simulated analysis for EVGN: £154.15 (+0.00%)
# 2025-09-01 12:54:09,865 - INFO - Enhanced simulated analysis for FATE: £156.43 (+0.00%)
# 2025-09-01 12:54:09,876 - INFO - Enhanced simulated analysis for FBLG: £328.18 (+0.00%)
# 2025-09-01 12:54:09,882 - INFO - Cycle completed: 8 trades executed
# 2025-09-01 12:55:09,888 - INFO - --- Cycle 2 ---
# 2025-09-01 12:55:09,929 - INFO - Enhanced simulated analysis for ABCL: £354.55 (+0.00%)
# 2025-09-01 12:55:09,947 - INFO - Enhanced simulated analysis for ALLO: £461.16 (+0.00%)
# 2025-09-01 12:55:09,961 - INFO - Enhanced simulated analysis for ANNX: £394.64 (+0.00%)
# 2025-09-01 12:55:09,975 - INFO - Enhanced simulated analysis for ANRO: £211.29 (+0.00%)
# 2025-09-01 12:55:09,988 - INFO - Enhanced simulated analysis for ANVS: £260.13 (+0.00%)
# 2025-09-01 12:55:10,000 - INFO - Enhanced simulated analysis for APLM: £356.47 (+0.00%)
# 2025-09-01 12:55:10,006 - INFO - SELL signal for APLM: 3/7 signals
# 2025-09-01 12:55:10,007 - INFO - Simulated SELL order placed: 2 APLM
# 2025-09-01 12:55:10,007 - INFO - SIMULATED SELL: 0 APLM @ £356.47 (Value: £712.94, P&L: £712.94, Balance: £4985.64)
# 2025-09-01 12:55:10,008 - INFO - APLM indicators - RSI: 42.0, MACD: -0.086, Volatility: 0.17%
# 2025-09-01 12:55:10,015 - INFO - Enhanced simulated analysis for APLT: £107.40 (+0.00%)
# 2025-09-01 12:55:10,028 - INFO - Enhanced simulated analysis for APVO: £292.46 (+0.00%)
# 2025-09-01 12:55:10,041 - INFO - Enhanced simulated analysis for ARAY: £70.57 (+0.00%)
# 2025-09-01 12:55:10,053 - INFO - Enhanced simulated analysis for ARBE: £442.87 (+0.00%)
# 2025-09-01 12:55:10,065 - INFO - Enhanced simulated analysis for ATEN: £185.97 (+0.00%)
# 2025-09-01 12:55:10,077 - INFO - Enhanced simulated analysis for ATAI: £321.19 (+0.00%)
# 2025-09-01 12:55:10,088 - INFO - Enhanced simulated analysis for ATHA: £118.62 (+0.00%)
# 2025-09-01 12:55:10,095 - INFO - BUY signal for ATHA: 4/7 signals
# 2025-09-01 12:55:10,095 - INFO - Simulated BUY order placed: 5 ATHA
# 2025-09-01 12:55:10,095 - INFO - SIMULATED BUY: 5 ATHA @ £118.62 (Cost: £593.10, Balance: £4392.54)
# 2025-09-01 12:55:10,096 - INFO - ATHA indicators - RSI: 76.6, MACD: 1.273, Volatility: 0.23%
# 2025-09-01 12:55:10,102 - INFO - Enhanced simulated analysis for AUTL: £385.81 (+0.00%)
# 2025-09-01 12:55:10,114 - INFO - Enhanced simulated analysis for AVIR: £481.28 (+0.00%)
# 2025-09-01 12:55:10,125 - INFO - Enhanced simulated analysis for CABA: £148.97 (+0.00%)
# 2025-09-01 12:55:10,137 - INFO - Enhanced simulated analysis for CAMP: £55.90 (+0.00%)
# 2025-09-01 12:55:10,149 - INFO - Enhanced simulated analysis for CARM: £119.40 (+0.00%)
# 2025-09-01 12:55:10,160 - INFO - Enhanced simulated analysis for CATX: £434.01 (+0.00%)
# 2025-09-01 12:55:10,172 - INFO - Enhanced simulated analysis for CCCC: £459.74 (+0.00%)
# 2025-09-01 12:55:10,179 - INFO - BUY signal for CCCC: 3/7 signals
# 2025-09-01 12:55:10,179 - INFO - Simulated BUY order placed: 1 CCCC
# 2025-09-01 12:55:10,179 - INFO - SIMULATED BUY: 1 CCCC @ £459.74 (Cost: £459.74, Balance: £3932.80)
# 2025-09-01 12:55:10,179 - INFO - CCCC indicators - RSI: 66.7, MACD: 0.511, Volatility: 0.21%
# 2025-09-01 12:55:10,186 - INFO - Enhanced simulated analysis for CELU: £101.08 (+0.00%)
# 2025-09-01 12:55:10,197 - INFO - Enhanced simulated analysis for CERS: £353.14 (+0.00%)
# 2025-09-01 12:55:10,209 - INFO - Enhanced simulated analysis for CGTX: £318.76 (+0.00%)
# 2025-09-01 12:55:10,220 - INFO - Enhanced simulated analysis for CHRS: £215.30 (+0.00%)
# 2025-09-01 12:55:10,232 - INFO - Enhanced simulated analysis for CLDI: £377.00 (+0.00%)
# 2025-09-01 12:55:10,238 - INFO - BUY signal for CLDI: 3/7 signals
# 2025-09-01 12:55:10,238 - INFO - Simulated BUY order placed: 1 CLDI
# 2025-09-01 12:55:10,239 - INFO - SIMULATED BUY: 1 CLDI @ £377.00 (Cost: £377.00, Balance: £3555.80)
# 2025-09-01 12:55:10,239 - INFO - CLDI indicators - RSI: 77.1, MACD: 2.100, Volatility: 0.22%
# 2025-09-01 12:55:10,246 - INFO - Enhanced simulated analysis for CLLS: £125.17 (+0.00%)
# 2025-09-01 12:55:10,258 - INFO - Enhanced simulated analysis for CLRB: £427.91 (+0.00%)
# 2025-09-01 12:55:10,269 - INFO - Enhanced simulated analysis for CLSD: £170.20 (+0.00%)
# 2025-09-01 12:55:10,281 - INFO - Enhanced simulated analysis for CLYM: £192.65 (+0.00%)
# 2025-09-01 12:55:10,292 - INFO - Enhanced simulated analysis for CMPS: £480.10 (+0.00%)
# 2025-09-01 12:55:10,304 - INFO - Enhanced simulated analysis for CMPX: £323.32 (+0.00%)
# 2025-09-01 12:55:10,316 - INFO - Enhanced simulated analysis for CMTL: £399.08 (+0.00%)
# 2025-09-01 12:55:10,328 - INFO - Enhanced simulated analysis for COCP: £175.81 (+0.00%)
# 2025-09-01 12:55:10,339 - INFO - Enhanced simulated analysis for CRBU: £250.56 (+0.00%)
# 2025-09-01 12:55:10,350 - INFO - Enhanced simulated analysis for CRDF: £342.61 (+0.00%)
# 2025-09-01 12:55:10,362 - INFO - Enhanced simulated analysis for CRDL: £359.98 (+0.00%)
# 2025-09-01 12:55:10,373 - INFO - Enhanced simulated analysis for CRIS: £385.09 (+0.00%)
# 2025-09-01 12:55:10,385 - INFO - Enhanced simulated analysis for CTMX: £315.44 (+0.00%)
# 2025-09-01 12:55:10,418 - INFO - Enhanced simulated analysis for CTOR: £436.65 (+0.00%)
# 2025-09-01 12:55:10,435 - INFO - Enhanced simulated analysis for CTXR: £143.74 (+0.00%)
# 2025-09-01 12:55:10,447 - INFO - Enhanced simulated analysis for CUE: £253.88 (+0.00%)
# 2025-09-01 12:55:10,453 - INFO - BUY signal for CUE: 3/7 signals
# 2025-09-01 12:55:10,453 - INFO - Simulated BUY order placed: 1 CUE
# 2025-09-01 12:55:10,454 - INFO - SIMULATED BUY: 1 CUE @ £253.88 (Cost: £253.88, Balance: £3301.92)
# 2025-09-01 12:55:10,454 - INFO - CUE indicators - RSI: 47.1, MACD: -0.081, Volatility: 0.21%
# 2025-09-01 12:55:10,461 - INFO - Enhanced simulated analysis for CURR: £70.30 (+0.00%)
# 2025-09-01 12:55:10,473 - INFO - Enhanced simulated analysis for DARE: £114.41 (+0.00%)
# 2025-09-01 12:55:10,485 - INFO - Enhanced simulated analysis for DTIL: £358.43 (+0.00%)
# 2025-09-01 12:55:10,497 - INFO - Enhanced simulated analysis for EDIT: £111.25 (+0.00%)
# 2025-09-01 12:55:10,509 - INFO - Enhanced simulated analysis for ELDN: £444.92 (+0.00%)
# 2025-09-01 12:55:10,521 - INFO - Enhanced simulated analysis for EQ: £348.77 (+0.00%)
# 2025-09-01 12:55:10,534 - INFO - Enhanced simulated analysis for ERAS: £111.44 (+0.00%)
# 2025-09-01 12:55:10,547 - INFO - Enhanced simulated analysis for ERNA: £181.85 (+0.00%)
# 2025-09-01 12:55:10,559 - INFO - Enhanced simulated analysis for ESLA: £497.81 (+0.00%)
# 2025-09-01 12:55:10,570 - INFO - Enhanced simulated analysis for ESPR: £484.13 (+0.00%)
# 2025-09-01 12:55:10,582 - INFO - Enhanced simulated analysis for EVGN: £155.75 (+0.00%)
# 2025-09-01 12:55:10,594 - INFO - Enhanced simulated analysis for FATE: £157.05 (+0.00%)
# 2025-09-01 12:55:10,606 - INFO - Enhanced simulated analysis for FBLG: £325.83 (+0.00%)
# 2025-09-01 12:55:10,612 - INFO - Cycle completed: 5 trades executed
# 2025-09-01 12:55:10,613 - INFO - Performance - Total Trades: 1, Win Rate: 0.0%, Total P&L: £-7.90
# 2025-09-01 12:56:10,619 - INFO - --- Cycle 3 ---
# 2025-09-01 12:56:10,651 - INFO - Enhanced simulated analysis for ABCL: £355.23 (+0.00%)
# 2025-09-01 12:56:10,669 - INFO - Enhanced simulated analysis for ALLO: £459.74 (+0.00%)
# 2025-09-01 12:56:10,686 - INFO - Enhanced simulated analysis for ANNX: £393.64 (+0.00%)
# 2025-09-01 12:56:10,700 - INFO - Enhanced simulated analysis for ANRO: £210.05 (+0.00%)
# 2025-09-01 12:56:10,707 - INFO - BUY signal for ANRO: 3/7 signals
# 2025-09-01 12:56:10,707 - INFO - Simulated BUY order placed: 1 ANRO
# 2025-09-01 12:56:10,707 - INFO - SIMULATED BUY: 1 ANRO @ £210.05 (Cost: £210.05, Balance: £3091.87)
# 2025-09-01 12:56:10,708 - INFO - ANRO indicators - RSI: 66.2, MACD: 2.658, Volatility: 0.22%
# 2025-09-01 12:56:10,716 - INFO - Enhanced simulated analysis for ANVS: £259.88 (+0.00%)
# 2025-09-01 12:56:10,728 - INFO - Enhanced simulated analysis for APLM: £360.65 (+0.00%)
# 2025-09-01 12:56:10,740 - INFO - Enhanced simulated analysis for APLT: £106.17 (+0.00%)
# 2025-09-01 12:56:10,753 - INFO - Enhanced simulated analysis for APVO: £292.00 (+0.00%)
# 2025-09-01 12:56:10,765 - INFO - Enhanced simulated analysis for ARAY: £70.56 (+0.00%)
# 2025-09-01 12:56:10,777 - INFO - Enhanced simulated analysis for ARBE: £444.88 (+0.00%)
# 2025-09-01 12:56:10,789 - INFO - Enhanced simulated analysis for ATEN: £186.21 (+0.00%)
# 2025-09-01 12:56:10,801 - INFO - Enhanced simulated analysis for ATAI: £323.37 (+0.00%)
# 2025-09-01 12:56:10,812 - INFO - Enhanced simulated analysis for ATHA: £118.83 (+0.00%)
# 2025-09-01 12:56:10,824 - INFO - Enhanced simulated analysis for AUTL: £383.61 (+0.00%)
# 2025-09-01 12:56:10,836 - INFO - Enhanced simulated analysis for AVIR: £485.83 (+0.00%)
# 2025-09-01 12:56:10,848 - INFO - Enhanced simulated analysis for CABA: £149.46 (+0.00%)
# 2025-09-01 12:56:10,859 - INFO - Enhanced simulated analysis for CAMP: £56.09 (+0.00%)
# 2025-09-01 12:56:10,871 - INFO - Enhanced simulated analysis for CARM: £118.67 (+0.00%)
# 2025-09-01 12:56:10,877 - INFO - BUY signal for CARM: 4/7 signals
# 2025-09-01 12:56:10,877 - INFO - Simulated BUY order placed: 3 CARM
# 2025-09-01 12:56:10,878 - INFO - SIMULATED BUY: 3 CARM @ £118.67 (Cost: £356.01, Balance: £2735.86)
# 2025-09-01 12:56:10,878 - INFO - CARM indicators - RSI: 71.5, MACD: 0.635, Volatility: 0.24%
# 2025-09-01 12:56:10,885 - INFO - Enhanced simulated analysis for CATX: £433.57 (+0.00%)
# 2025-09-01 12:56:10,897 - INFO - Enhanced simulated analysis for CCCC: £457.40 (+0.00%)
# 2025-09-01 12:56:10,909 - INFO - Enhanced simulated analysis for CELU: £100.24 (+0.00%)
# 2025-09-01 12:56:10,921 - INFO - Enhanced simulated analysis for CERS: £354.23 (+0.00%)
# 2025-09-01 12:56:10,932 - INFO - Enhanced simulated analysis for CGTX: £319.82 (+0.00%)
# 2025-09-01 12:56:10,944 - INFO - Enhanced simulated analysis for CHRS: £214.99 (+0.00%)
# 2025-09-01 12:56:10,955 - INFO - Enhanced simulated analysis for CLDI: £375.93 (+0.00%)
# 2025-09-01 12:56:10,968 - INFO - Enhanced simulated analysis for CLLS: £126.20 (+0.00%)
# 2025-09-01 12:56:10,980 - INFO - Enhanced simulated analysis for CLRB: £424.43 (+0.00%)
# 2025-09-01 12:56:10,991 - INFO - Enhanced simulated analysis for CLSD: £171.64 (+0.00%)
# 2025-09-01 12:56:11,003 - INFO - Enhanced simulated analysis for CLYM: £193.32 (+0.00%)
# 2025-09-01 12:56:11,009 - INFO - SELL signal for CLYM: 3/7 signals
# 2025-09-01 12:56:11,010 - INFO - Simulated SELL order placed: 3 CLYM
# 2025-09-01 12:56:11,010 - INFO - SIMULATED SELL: 0 CLYM @ £193.32 (Value: £579.96, P&L: £579.96, Balance: £3315.82)
# 2025-09-01 12:56:11,010 - INFO - CLYM indicators - RSI: 38.2, MACD: -0.528, Volatility: 0.24%
# 2025-09-01 12:56:11,017 - INFO - Enhanced simulated analysis for CMPS: £479.40 (+0.00%)
# 2025-09-01 12:56:11,032 - INFO - Enhanced simulated analysis for CMPX: £324.37 (+0.00%)
# 2025-09-01 12:56:11,049 - INFO - Enhanced simulated analysis for CMTL: £394.50 (+0.00%)
# 2025-09-01 12:56:11,057 - INFO - BUY signal for CMTL: 4/7 signals
# 2025-09-01 12:56:11,058 - INFO - Simulated BUY order placed: 1 CMTL
# 2025-09-01 12:56:11,058 - INFO - SIMULATED BUY: 1 CMTL @ £394.50 (Cost: £394.50, Balance: £2921.32)
# 2025-09-01 12:56:11,059 - INFO - CMTL indicators - RSI: 37.5, MACD: -0.222, Volatility: 0.15%
# 2025-09-01 12:56:11,066 - INFO - Enhanced simulated analysis for COCP: £173.46 (+0.00%)
# 2025-09-01 12:56:11,079 - INFO - Enhanced simulated analysis for CRBU: £247.60 (+0.00%)
# 2025-09-01 12:56:11,092 - INFO - Enhanced simulated analysis for CRDF: £343.56 (+0.00%)
# 2025-09-01 12:56:11,107 - INFO - BUY signal for CRDF: 3/7 signals
# 2025-09-01 12:56:11,113 - INFO - Simulated BUY order placed: 1 CRDF
# 2025-09-01 12:56:11,115 - INFO - SIMULATED BUY: 1 CRDF @ £343.56 (Cost: £343.56, Balance: £2577.76)
# 2025-09-01 12:56:11,117 - INFO - CRDF indicators - RSI: 67.5, MACD: 1.464, Volatility: 0.19%
# 2025-09-01 12:56:11,148 - INFO - Enhanced simulated analysis for CRDL: £358.77 (+0.00%)
# 2025-09-01 12:56:11,162 - INFO - Enhanced simulated analysis for CRIS: £379.57 (+0.00%)
# 2025-09-01 12:56:11,176 - INFO - Enhanced simulated analysis for CTMX: £316.50 (+0.00%)
# 2025-09-01 12:56:11,184 - INFO - BUY signal for CTMX: 3/7 signals
# 2025-09-01 12:56:11,184 - INFO - Simulated BUY order placed: 1 CTMX
# 2025-09-01 12:56:11,185 - INFO - SIMULATED BUY: 1 CTMX @ £316.50 (Cost: £316.50, Balance: £2261.26)
# 2025-09-01 12:56:11,185 - INFO - CTMX indicators - RSI: 67.4, MACD: 0.176, Volatility: 0.18%
# 2025-09-01 12:56:11,192 - INFO - Enhanced simulated analysis for CTOR: £435.02 (+0.00%)
# 2025-09-01 12:56:11,199 - INFO - BUY signal for CTOR: 3/7 signals
# 2025-09-01 12:56:11,199 - INFO - Simulated BUY order placed: 1 CTOR
# 2025-09-01 12:56:11,199 - INFO - SIMULATED BUY: 1 CTOR @ £435.02 (Cost: £435.02, Balance: £1826.24)
# 2025-09-01 12:56:11,200 - INFO - CTOR indicators - RSI: 71.1, MACD: 0.806, Volatility: 0.20%
# 2025-09-01 12:56:11,208 - INFO - Enhanced simulated analysis for CTXR: £145.33 (+0.00%)
# 2025-09-01 12:56:11,220 - INFO - Enhanced simulated analysis for CUE: £255.48 (+0.00%)
# 2025-09-01 12:56:11,232 - INFO - Enhanced simulated analysis for CURR: £70.83 (+0.00%)
# 2025-09-01 12:56:11,244 - INFO - Enhanced simulated analysis for DARE: £112.99 (+0.00%)
# 2025-09-01 12:56:11,257 - INFO - Enhanced simulated analysis for DTIL: £357.26 (+0.00%)
# 2025-09-01 12:56:11,269 - INFO - Enhanced simulated analysis for EDIT: £110.19 (+0.00%)
# 2025-09-01 12:56:11,281 - INFO - Enhanced simulated analysis for ELDN: £440.05 (+0.00%)
# 2025-09-01 12:56:11,293 - INFO - Enhanced simulated analysis for EQ: £347.26 (+0.00%)
# 2025-09-01 12:56:11,300 - INFO - BUY signal for EQ: 3/7 signals
# 2025-09-01 12:56:11,300 - INFO - Simulated BUY order placed: 1 EQ
# 2025-09-01 12:56:11,300 - INFO - SIMULATED BUY: 1 EQ @ £347.26 (Cost: £347.26, Balance: £1478.98)
# 2025-09-01 12:56:11,301 - INFO - EQ indicators - RSI: 29.8, MACD: -0.244, Volatility: 0.21%
# 2025-09-01 12:56:11,308 - INFO - Enhanced simulated analysis for ERAS: £110.92 (+0.00%)
# 2025-09-01 12:56:11,320 - INFO - Enhanced simulated analysis for ERNA: £183.02 (+0.00%)
# 2025-09-01 12:56:11,331 - INFO - Enhanced simulated analysis for ESLA: £499.13 (+0.00%)
# 2025-09-01 12:56:11,343 - INFO - Enhanced simulated analysis for ESPR: £487.72 (+0.00%)
# 2025-09-01 12:56:11,355 - INFO - Enhanced simulated analysis for EVGN: £154.02 (+0.00%)
# 2025-09-01 12:56:11,367 - INFO - Enhanced simulated analysis for FATE: £157.10 (+0.00%)
# 2025-09-01 12:56:11,379 - INFO - Enhanced simulated analysis for FBLG: £322.97 (+0.00%)
# 2025-09-01 12:56:11,385 - INFO - Cycle completed: 8 trades executed
# 2025-09-01 12:56:11,386 - INFO - Performance - Total Trades: 2, Win Rate: 0.0%, Total P&L: £-9.19
# 2025-09-01 12:57:11,388 - INFO - --- Cycle 4 ---
# 2025-09-01 12:57:11,427 - INFO - Enhanced simulated analysis for ABCL: £356.77 (+0.00%)
# 2025-09-01 12:57:11,438 - INFO - BUY signal for ABCL: 3/7 signals
# 2025-09-01 12:57:11,438 - INFO - Simulated BUY order placed: 1 ABCL
# 2025-09-01 12:57:11,439 - INFO - SIMULATED BUY: 1 ABCL @ £356.77 (Cost: £356.77, Balance: £1122.21)
# 2025-09-01 12:57:11,439 - INFO - ABCL indicators - RSI: 75.9, MACD: 0.743, Volatility: 0.24%
# 2025-09-01 12:57:11,452 - INFO - Enhanced simulated analysis for ALLO: £464.62 (+0.00%)
# 2025-09-01 12:57:11,461 - INFO - BUY signal for ALLO: 4/7 signals
# 2025-09-01 12:57:11,461 - INFO - Simulated BUY order placed: 1 ALLO
# 2025-09-01 12:57:11,461 - INFO - SIMULATED BUY: 1 ALLO @ £464.62 (Cost: £464.62, Balance: £657.59)
# 2025-09-01 12:57:11,462 - INFO - ALLO indicators - RSI: 65.7, MACD: -1.460, Volatility: 0.15%
# 2025-09-01 12:57:11,470 - INFO - Enhanced simulated analysis for ANNX: £392.57 (+0.00%)
# 2025-09-01 12:57:11,483 - INFO - Enhanced simulated analysis for ANRO: £213.56 (+0.00%)
# 2025-09-01 12:57:11,496 - INFO - Enhanced simulated analysis for ANVS: £260.36 (+0.00%)
# 2025-09-01 12:57:11,507 - INFO - Enhanced simulated analysis for APLM: £359.71 (+0.00%)
# 2025-09-01 12:57:11,519 - INFO - Enhanced simulated analysis for APLT: £106.37 (+0.00%)
# 2025-09-01 12:57:11,530 - INFO - Enhanced simulated analysis for APVO: £294.93 (+0.00%)
# 2025-09-01 12:57:11,542 - INFO - Enhanced simulated analysis for ARAY: £70.94 (+0.00%)
# 2025-09-01 12:57:11,554 - INFO - Enhanced simulated analysis for ARBE: £450.03 (+0.00%)
# 2025-09-01 12:57:11,566 - INFO - Enhanced simulated analysis for ATEN: £187.22 (+0.00%)
# 2025-09-01 12:57:11,579 - INFO - Enhanced simulated analysis for ATAI: £320.94 (+0.00%)
# 2025-09-01 12:57:11,585 - INFO - BUY signal for ATAI: 3/7 signals
# 2025-09-01 12:57:11,586 - INFO - Simulated BUY order placed: 1 ATAI
# 2025-09-01 12:57:11,586 - INFO - SIMULATED BUY: 1 ATAI @ £320.94 (Cost: £320.94, Balance: £336.65)
# 2025-09-01 12:57:11,586 - INFO - ATAI indicators - RSI: 33.2, MACD: -0.567, Volatility: 0.19%
# 2025-09-01 12:57:11,593 - INFO - Enhanced simulated analysis for ATHA: £117.53 (+0.00%)
# 2025-09-01 12:57:11,607 - INFO - Enhanced simulated analysis for AUTL: £383.03 (+0.00%)
# 2025-09-01 12:57:11,619 - INFO - Enhanced simulated analysis for AVIR: £478.79 (+0.00%)
# 2025-09-01 12:57:11,631 - INFO - Enhanced simulated analysis for CABA: £149.60 (+0.00%)
# 2025-09-01 12:57:11,647 - INFO - Enhanced simulated analysis for CAMP: £56.51 (+0.00%)
# 2025-09-01 12:57:11,659 - INFO - Enhanced simulated analysis for CARM: £117.59 (+0.00%)
# 2025-09-01 12:57:11,671 - INFO - Enhanced simulated analysis for CATX: £431.80 (+0.00%)
# 2025-09-01 12:57:11,682 - INFO - Enhanced simulated analysis for CCCC: £454.14 (+0.00%)
# 2025-09-01 12:57:11,694 - INFO - Enhanced simulated analysis for CELU: £102.36 (+0.00%)
# 2025-09-01 12:57:11,701 - INFO - BUY signal for CELU: 3/7 signals
# 2025-09-01 12:57:11,701 - INFO - Simulated BUY order placed: 1 CELU
# 2025-09-01 12:57:11,701 - INFO - SIMULATED BUY: 1 CELU @ £102.36 (Cost: £102.36, Balance: £234.29)
# 2025-09-01 12:57:11,701 - INFO - CELU indicators - RSI: 54.2, MACD: 0.238, Volatility: 0.21%
# 2025-09-01 12:57:11,708 - INFO - Enhanced simulated analysis for CERS: £353.17 (+0.00%)
# 2025-09-01 12:57:11,720 - INFO - Enhanced simulated analysis for CGTX: £319.00 (+0.00%)
# 2025-09-01 12:57:11,726 - INFO - BUY signal for CGTX: 3/7 signals
# 2025-09-01 12:57:11,733 - INFO - Enhanced simulated analysis for CHRS: £214.53 (+0.00%)
# 2025-09-01 12:57:11,745 - INFO - Enhanced simulated analysis for CLDI: £377.09 (+0.00%)
# 2025-09-01 12:57:11,756 - INFO - Enhanced simulated analysis for CLLS: £126.88 (+0.00%)
# 2025-09-01 12:57:11,771 - INFO - Enhanced simulated analysis for CLRB: £425.22 (+0.00%)
# 2025-09-01 12:57:11,778 - INFO - BUY signal for CLRB: 3/7 signals
# 2025-09-01 12:57:11,785 - INFO - Enhanced simulated analysis for CLSD: £170.52 (+0.00%)
# 2025-09-01 12:57:11,798 - INFO - Enhanced simulated analysis for CLYM: £194.60 (+0.00%)
# 2025-09-01 12:57:11,810 - INFO - Enhanced simulated analysis for CMPS: £473.49 (+0.00%)
# 2025-09-01 12:57:11,822 - INFO - Enhanced simulated analysis for CMPX: £330.12 (+0.00%)
# 2025-09-01 12:57:11,835 - INFO - Enhanced simulated analysis for CMTL: £392.64 (+0.00%)
# 2025-09-01 12:57:11,847 - INFO - Enhanced simulated analysis for COCP: £174.54 (+0.00%)
# 2025-09-01 12:57:11,860 - INFO - Enhanced simulated analysis for CRBU: £246.63 (+0.00%)
# 2025-09-01 12:57:11,872 - INFO - Enhanced simulated analysis for CRDF: £347.82 (+0.00%)
# 2025-09-01 12:57:11,912 - INFO - Enhanced simulated analysis for CRDL: £358.93 (+0.00%)
# 2025-09-01 12:57:11,924 - INFO - Enhanced simulated analysis for CRIS: £380.67 (+0.00%)
# 2025-09-01 12:57:11,936 - INFO - Enhanced simulated analysis for CTMX: £315.37 (+0.00%)
# 2025-09-01 12:57:11,948 - INFO - Enhanced simulated analysis for CTOR: £435.02 (+0.00%)
# 2025-09-01 12:57:11,962 - INFO - Enhanced simulated analysis for CTXR: £146.05 (+0.00%)
# 2025-09-01 12:57:11,974 - INFO - Enhanced simulated analysis for CUE: £256.29 (+0.00%)
# 2025-09-01 12:57:11,986 - INFO - Enhanced simulated analysis for CURR: £70.11 (+0.00%)
# 2025-09-01 12:57:11,994 - INFO - BUY signal for CURR: 3/7 signals
# 2025-09-01 12:57:11,994 - INFO - Simulated BUY order placed: 1 CURR
# 2025-09-01 12:57:11,994 - INFO - SIMULATED BUY: 1 CURR @ £70.11 (Cost: £70.11, Balance: £164.18)
# 2025-09-01 12:57:11,995 - INFO - CURR indicators - RSI: 60.6, MACD: -0.364, Volatility: 0.20%
# 2025-09-01 12:57:12,002 - INFO - Enhanced simulated analysis for DARE: £113.31 (+0.00%)
# 2025-09-01 12:57:12,015 - INFO - Enhanced simulated analysis for DTIL: £357.19 (+0.00%)
# 2025-09-01 12:57:12,028 - INFO - Enhanced simulated analysis for EDIT: £110.78 (+0.00%)
# 2025-09-01 12:57:12,034 - INFO - BUY signal for EDIT: 3/7 signals
# 2025-09-01 12:57:12,035 - INFO - Simulated BUY order placed: 1 EDIT
# 2025-09-01 12:57:12,035 - INFO - SIMULATED BUY: 1 EDIT @ £110.78 (Cost: £110.78, Balance: £53.40)
# 2025-09-01 12:57:12,035 - INFO - EDIT indicators - RSI: 27.5, MACD: -0.891, Volatility: 0.15%
# 2025-09-01 12:57:12,042 - INFO - Enhanced simulated analysis for ELDN: £437.68 (+0.00%)
# 2025-09-01 12:57:12,054 - INFO - Enhanced simulated analysis for EQ: £349.99 (+0.00%)
# 2025-09-01 12:57:12,067 - INFO - Enhanced simulated analysis for ERAS: £111.61 (+0.00%)
# 2025-09-01 12:57:12,078 - INFO - Enhanced simulated analysis for ERNA: £184.25 (+0.00%)
# 2025-09-01 12:57:12,084 - INFO - BUY signal for ERNA: 3/7 signals
# 2025-09-01 12:57:12,091 - INFO - Enhanced simulated analysis for ESLA: £508.08 (+0.00%)
# 2025-09-01 12:57:12,102 - INFO - Enhanced simulated analysis for ESPR: £491.70 (+0.00%)
# 2025-09-01 12:57:12,114 - INFO - Enhanced simulated analysis for EVGN: £153.97 (+0.00%)
# 2025-09-01 12:57:12,126 - INFO - Enhanced simulated analysis for FATE: £159.08 (+0.00%)
# 2025-09-01 12:57:12,137 - INFO - Enhanced simulated analysis for FBLG: £319.67 (+0.00%)
# 2025-09-01 12:57:12,144 - INFO - Cycle completed: 6 trades executed
# 2025-09-01 12:57:12,144 - INFO - Performance - Total Trades: 2, Win Rate: 0.0%, Total P&L: £-9.19
# 2025-09-01 12:58:12,145 - INFO - --- Cycle 5 ---
# 2025-09-01 12:58:12,170 - INFO - Enhanced simulated analysis for ABCL: £360.73 (+0.00%)
# 2025-09-01 12:58:12,193 - INFO - Enhanced simulated analysis for ALLO: £463.97 (+0.00%)
# 2025-09-01 12:58:12,209 - INFO - Enhanced simulated analysis for ANNX: £388.72 (+0.00%)
# 2025-09-01 12:58:12,224 - INFO - Enhanced simulated analysis for ANRO: £212.11 (+0.00%)
# 2025-09-01 12:58:12,236 - INFO - Enhanced simulated analysis for ANVS: £259.73 (+0.00%)
# 2025-09-01 12:58:12,249 - INFO - Enhanced simulated analysis for APLM: £357.90 (+0.00%)
# 2025-09-01 12:58:12,261 - INFO - Enhanced simulated analysis for APLT: £107.73 (+0.00%)
# 2025-09-01 12:58:12,272 - INFO - Enhanced simulated analysis for APVO: £294.26 (+0.00%)
# 2025-09-01 12:58:12,284 - INFO - Enhanced simulated analysis for ARAY: £70.54 (+0.00%)
# 2025-09-01 12:58:12,290 - INFO - BUY signal for ARAY: 3/7 signals
# 2025-09-01 12:58:12,297 - INFO - Enhanced simulated analysis for ARBE: £452.96 (+0.00%)
# 2025-09-01 12:58:12,308 - INFO - Enhanced simulated analysis for ATEN: £186.35 (+0.00%)
# 2025-09-01 12:58:12,320 - INFO - Enhanced simulated analysis for ATAI: £320.93 (+0.00%)
# 2025-09-01 12:58:12,327 - INFO - SELL signal for ATAI: 3/7 signals
# 2025-09-01 12:58:12,327 - INFO - Simulated SELL order placed: 1 ATAI
# 2025-09-01 12:58:12,327 - INFO - SIMULATED SELL: 0 ATAI @ £320.93 (Value: £320.93, P&L: £320.93, Balance: £374.33)
# 2025-09-01 12:58:12,327 - INFO - ATAI indicators - RSI: 27.7, MACD: -0.491, Volatility: 0.23%
# 2025-09-01 12:58:12,334 - INFO - Enhanced simulated analysis for ATHA: £117.22 (+0.00%)
# 2025-09-01 12:58:12,346 - INFO - Enhanced simulated analysis for AUTL: £385.60 (+0.00%)
# 2025-09-01 12:58:12,357 - INFO - Enhanced simulated analysis for AVIR: £473.82 (+0.00%)
# 2025-09-01 12:58:12,369 - INFO - Enhanced simulated analysis for CABA: £150.89 (+0.00%)
# 2025-09-01 12:58:12,384 - INFO - Enhanced simulated analysis for CAMP: £56.22 (+0.00%)
# 2025-09-01 12:58:12,393 - INFO - BUY signal for CAMP: 3/7 signals
# 2025-09-01 12:58:12,393 - INFO - Simulated BUY order placed: 1 CAMP
# 2025-09-01 12:58:12,393 - INFO - SIMULATED BUY: 1 CAMP @ £56.22 (Cost: £56.22, Balance: £318.11)
# 2025-09-01 12:58:12,394 - INFO - CAMP indicators - RSI: 30.8, MACD: -1.156, Volatility: 0.19%
# 2025-09-01 12:58:12,404 - INFO - Enhanced simulated analysis for CARM: £117.67 (+0.00%)
# 2025-09-01 12:58:12,417 - INFO - Enhanced simulated analysis for CATX: £436.31 (+0.00%)
# 2025-09-01 12:58:12,429 - INFO - Enhanced simulated analysis for CCCC: £458.63 (+0.00%)
# 2025-09-01 12:58:12,442 - INFO - Enhanced simulated analysis for CELU: £101.17 (+0.00%)
# 2025-09-01 12:58:12,454 - INFO - Enhanced simulated analysis for CERS: £356.23 (+0.00%)
# 2025-09-01 12:58:12,462 - INFO - BUY signal for CERS: 3/7 signals
# 2025-09-01 12:58:12,470 - INFO - Enhanced simulated analysis for CGTX: £317.80 (+0.00%)
# 2025-09-01 12:58:12,483 - INFO - Enhanced simulated analysis for CHRS: £212.36 (+0.00%)
# 2025-09-01 12:58:12,496 - INFO - Enhanced simulated analysis for CLDI: £384.69 (+0.00%)
# 2025-09-01 12:58:12,508 - INFO - Enhanced simulated analysis for CLLS: £127.27 (+0.00%)
# 2025-09-01 12:58:12,519 - INFO - Enhanced simulated analysis for CLRB: £423.45 (+0.00%)
# 2025-09-01 12:58:12,531 - INFO - Enhanced simulated analysis for CLSD: £171.01 (+0.00%)
# 2025-09-01 12:58:12,538 - INFO - BUY signal for CLSD: 3/7 signals
# 2025-09-01 12:58:12,538 - INFO - Simulated BUY order placed: 1 CLSD
# 2025-09-01 12:58:12,538 - INFO - SIMULATED BUY: 1 CLSD @ £171.01 (Cost: £171.01, Balance: £147.10)
# 2025-09-01 12:58:12,539 - INFO - CLSD indicators - RSI: 57.1, MACD: 0.710, Volatility: 0.21%
# 2025-09-01 12:58:12,546 - INFO - Enhanced simulated analysis for CLYM: £196.17 (+0.00%)
# 2025-09-01 12:58:12,562 - INFO - Enhanced simulated analysis for CMPS: £468.58 (+0.00%)
# 2025-09-01 12:58:12,573 - INFO - Enhanced simulated analysis for CMPX: £330.84 (+0.00%)
# 2025-09-01 12:58:12,585 - INFO - Enhanced simulated analysis for CMTL: £396.36 (+0.00%)
# 2025-09-01 12:58:12,597 - INFO - Enhanced simulated analysis for COCP: £175.92 (+0.00%)
# 2025-09-01 12:58:12,611 - INFO - Enhanced simulated analysis for CRBU: £245.33 (+0.00%)
# 2025-09-01 12:58:12,624 - INFO - Enhanced simulated analysis for CRDF: £347.42 (+0.00%)
# 2025-09-01 12:58:12,636 - INFO - Enhanced simulated analysis for CRDL: £359.41 (+0.00%)
# 2025-09-01 12:58:12,648 - INFO - Enhanced simulated analysis for CRIS: £378.09 (+0.00%)
# 2025-09-01 12:58:12,684 - INFO - Enhanced simulated analysis for CTMX: £314.33 (+0.00%)
# 2025-09-01 12:58:12,700 - INFO - Enhanced simulated analysis for CTOR: £437.66 (+0.00%)
# 2025-09-01 12:58:12,712 - INFO - Enhanced simulated analysis for CTXR: £145.73 (+0.00%)
# 2025-09-01 12:58:12,723 - INFO - Enhanced simulated analysis for CUE: £257.37 (+0.00%)
# 2025-09-01 12:58:12,735 - INFO - Enhanced simulated analysis for CURR: £69.64 (+0.00%)
# 2025-09-01 12:58:12,747 - INFO - Enhanced simulated analysis for DARE: £111.61 (+0.00%)
# 2025-09-01 12:58:12,758 - INFO - Enhanced simulated analysis for DTIL: £353.12 (+0.00%)
# 2025-09-01 12:58:12,770 - INFO - Enhanced simulated analysis for EDIT: £111.36 (+0.00%)
# 2025-09-01 12:58:12,782 - INFO - Enhanced simulated analysis for ELDN: £436.31 (+0.00%)
# 2025-09-01 12:58:12,793 - INFO - Enhanced simulated analysis for EQ: £345.46 (+0.00%)
# 2025-09-01 12:58:12,805 - INFO - Enhanced simulated analysis for ERAS: £110.61 (+0.00%)
# 2025-09-01 12:58:12,817 - INFO - Enhanced simulated analysis for ERNA: £185.30 (+0.00%)
# 2025-09-01 12:58:12,828 - INFO - Enhanced simulated analysis for ESLA: £504.14 (+0.00%)
# 2025-09-01 12:58:12,840 - INFO - Enhanced simulated analysis for ESPR: £488.23 (+0.00%)
# 2025-09-01 12:58:12,846 - INFO - BUY signal for ESPR: 3/7 signals
# 2025-09-01 12:58:12,852 - INFO - Enhanced simulated analysis for EVGN: £154.30 (+0.00%)
# 2025-09-01 12:58:12,864 - INFO - Enhanced simulated analysis for FATE: £158.40 (+0.00%)
# 2025-09-01 12:58:12,870 - INFO - BUY signal for FATE: 3/7 signals
# 2025-09-01 12:58:12,876 - INFO - Enhanced simulated analysis for FBLG: £320.69 (+0.00%)
# 2025-09-01 12:58:12,882 - INFO - Cycle completed: 3 trades executed
# 2025-09-01 12:58:12,883 - INFO - Performance - Total Trades: 3, Win Rate: 0.0%, Total P&L: £-9.20
# 2025-09-01 12:58:12,883 - INFO - Market Overview - Active Positions: 24, Symbols Tracked: 54
# 2025-09-01 12:59:12,889 - INFO - Reached maximum cycles (5)
# 2025-09-01 12:59:12,896 - INFO - ==================================================
# 2025-09-01 12:59:12,897 - INFO - ENHANCED TRADING SESSION SUMMARY
# 2025-09-01 12:59:12,898 - INFO - ==================================================
# 2025-09-01 12:59:12,901 - INFO - Environment: SIMULATOR
# 2025-09-01 12:59:12,902 - INFO - Duration: 0:05:03.729043
# 2025-09-01 12:59:12,903 - INFO - Total trades executed: 30
# 2025-09-01 12:59:12,904 - INFO - Strategy: Production_Enhanced
# 2025-09-01 12:59:12,904 - INFO - Win Rate: 0.0%
# 2025-09-01 12:59:12,905 - INFO - Total P&L: £-9.20
# 2025-09-01 12:59:12,907 - INFO - Profitable Trades: 0/3
# 2025-09-01 12:59:12,908 - INFO - Current Positions:
# 2025-09-01 12:59:12,951 - INFO - Enhanced simulated analysis for ANNX: £387.49 (+0.00%)
# 2025-09-01 12:59:12,951 - INFO -   ANNX: 3 shares @ £396.52 (Current: £387.49, P&L: £-27.09 -2.3%)
# 2025-09-01 12:59:12,963 - INFO - Enhanced simulated analysis for ANVS: £257.40 (+0.00%)
# 2025-09-01 12:59:12,963 - INFO -   ANVS: 4 shares @ £258.48 (Current: £257.40, P&L: £-4.32 -0.4%)
# 2025-09-01 12:59:12,964 - INFO -   APLM: No position
# 2025-09-01 12:59:12,971 - INFO - Enhanced simulated analysis for APLT: £108.05 (+0.00%)
# 2025-09-01 12:59:12,972 - INFO -   APLT: 7 shares @ £106.91 (Current: £108.05, P&L: £+7.98 +1.1%)
# 2025-09-01 12:59:12,979 - INFO - Enhanced simulated analysis for AUTL: £380.18 (+0.00%)
# 2025-09-01 12:59:12,979 - INFO -   AUTL: 1 shares @ £383.80 (Current: £380.18, P&L: £-3.62 -0.9%)
# 2025-09-01 12:59:12,986 - INFO - Enhanced simulated analysis for CATX: £432.62 (+0.00%)
# 2025-09-01 12:59:12,986 - INFO -   CATX: 1 shares @ £436.41 (Current: £432.62, P&L: £-3.79 -0.9%)
# 2025-09-01 12:59:12,994 - INFO - Enhanced simulated analysis for CLLS: £128.92 (+0.00%)
# 2025-09-01 12:59:12,994 - INFO -   CLLS: 5 shares @ £126.63 (Current: £128.92, P&L: £+11.45 +1.8%)
# 2025-09-01 12:59:12,994 - INFO -   CLYM: No position
# 2025-09-01 12:59:13,001 - INFO - Enhanced simulated analysis for ATHA: £116.77 (+0.00%)
# 2025-09-01 12:59:13,001 - INFO -   ATHA: 5 shares @ £118.62 (Current: £116.77, P&L: £-9.25 -1.6%)
# 2025-09-01 12:59:13,008 - INFO - Enhanced simulated analysis for CCCC: £464.49 (+0.00%)
# 2025-09-01 12:59:13,008 - INFO -   CCCC: 1 shares @ £459.74 (Current: £464.49, P&L: £+4.75 +1.0%)
# 2025-09-01 12:59:13,014 - INFO - Enhanced simulated analysis for CLDI: £382.26 (+0.00%)
# 2025-09-01 12:59:13,015 - INFO -   CLDI: 1 shares @ £377.00 (Current: £382.26, P&L: £+5.26 +1.4%)
# 2025-09-01 12:59:13,021 - INFO - Enhanced simulated analysis for CUE: £258.72 (+0.00%)
# 2025-09-01 12:59:13,021 - INFO -   CUE: 1 shares @ £253.88 (Current: £258.72, P&L: £+4.84 +1.9%)
# 2025-09-01 12:59:13,029 - INFO - Enhanced simulated analysis for ANRO: £214.32 (+0.00%)
# 2025-09-01 12:59:13,029 - INFO -   ANRO: 1 shares @ £210.05 (Current: £214.32, P&L: £+4.27 +2.0%)
# 2025-09-01 12:59:13,035 - INFO - Enhanced simulated analysis for CARM: £116.87 (+0.00%)
# 2025-09-01 12:59:13,035 - INFO -   CARM: 3 shares @ £118.67 (Current: £116.87, P&L: £-5.40 -1.5%)
# 2025-09-01 12:59:13,043 - INFO - Enhanced simulated analysis for CMTL: £395.87 (+0.00%)
# 2025-09-01 12:59:13,043 - INFO -   CMTL: 1 shares @ £394.50 (Current: £395.87, P&L: £+1.37 +0.3%)
# 2025-09-01 12:59:13,049 - INFO - Enhanced simulated analysis for CRDF: £347.16 (+0.00%)
# 2025-09-01 12:59:13,049 - INFO -   CRDF: 1 shares @ £343.56 (Current: £347.16, P&L: £+3.60 +1.0%)
# 2025-09-01 12:59:13,056 - INFO - Enhanced simulated analysis for CTMX: £313.62 (+0.00%)
# 2025-09-01 12:59:13,056 - INFO -   CTMX: 1 shares @ £316.50 (Current: £313.62, P&L: £-2.88 -0.9%)
# 2025-09-01 12:59:13,063 - INFO - Enhanced simulated analysis for CTOR: £435.84 (+0.00%)
# 2025-09-01 12:59:13,063 - INFO -   CTOR: 1 shares @ £435.02 (Current: £435.84, P&L: £+0.82 +0.2%)
# 2025-09-01 12:59:13,070 - INFO - Enhanced simulated analysis for EQ: £344.16 (+0.00%)
# 2025-09-01 12:59:13,070 - INFO -   EQ: 1 shares @ £347.26 (Current: £344.16, P&L: £-3.10 -0.9%)
# 2025-09-01 12:59:13,076 - INFO - Enhanced simulated analysis for ABCL: £360.20 (+0.00%)
# 2025-09-01 12:59:13,077 - INFO -   ABCL: 1 shares @ £356.77 (Current: £360.20, P&L: £+3.43 +1.0%)
# 2025-09-01 12:59:13,083 - INFO - Enhanced simulated analysis for ALLO: £469.47 (+0.00%)
# 2025-09-01 12:59:13,083 - INFO -   ALLO: 1 shares @ £464.62 (Current: £469.47, P&L: £+4.85 +1.0%)
# 2025-09-01 12:59:13,084 - INFO -   ATAI: No position
# 2025-09-01 12:59:13,091 - INFO - Enhanced simulated analysis for CELU: £100.13 (+0.00%)
# 2025-09-01 12:59:13,091 - INFO -   CELU: 1 shares @ £102.36 (Current: £100.13, P&L: £-2.23 -2.2%)
# 2025-09-01 12:59:13,097 - INFO - Enhanced simulated analysis for CURR: £69.45 (+0.00%)
# 2025-09-01 12:59:13,097 - INFO -   CURR: 1 shares @ £70.11 (Current: £69.45, P&L: £-0.66 -0.9%)
# 2025-09-01 12:59:13,104 - INFO - Enhanced simulated analysis for EDIT: £112.49 (+0.00%)
# 2025-09-01 12:59:13,104 - INFO -   EDIT: 1 shares @ £110.78 (Current: £112.49, P&L: £+1.71 +1.5%)
# 2025-09-01 12:59:13,111 - INFO - Enhanced simulated analysis for CAMP: £56.19 (+0.00%)
# 2025-09-01 12:59:13,111 - INFO -   CAMP: 1 shares @ £56.22 (Current: £56.19, P&L: £-0.03 -0.1%)
# 2025-09-01 12:59:13,118 - INFO - Enhanced simulated analysis for CLSD: £171.21 (+0.00%)
# 2025-09-01 12:59:13,118 - INFO -   CLSD: 1 shares @ £171.01 (Current: £171.21, P&L: £+0.20 +0.1%)
# 2025-09-01 12:59:13,118 - INFO - Total Position Value: £9843.70
# 2025-09-01 12:59:13,118 - INFO - Technical Indicators Summary:
# 2025-09-01 12:59:13,119 - INFO -   ABCL: RSI: 34.3, MACD: -0.580, Vol: 0.2%
# 2025-09-01 12:59:13,119 - INFO -   ALLO: RSI: 40.6, MACD: 1.070, Vol: 0.2%
# 2025-09-01 12:59:13,119 - INFO -   ANNX: RSI: 56.3, MACD: -0.017, Vol: 0.2%
# 2025-09-01 12:59:13,120 - INFO -   ANRO: RSI: 68.8, MACD: 6.471, Vol: 0.3%
# 2025-09-01 12:59:13,120 - INFO -   ANVS: RSI: 74.8, MACD: 0.283, Vol: 0.2%
# 2025-09-01 12:59:13,120 - INFO -   APLM: RSI: 54.0, MACD: -0.298, Vol: 0.2%
# 2025-09-01 12:59:13,121 - INFO -   APLT: RSI: 63.6, MACD: -0.054, Vol: 0.2%
# 2025-09-01 12:59:13,121 - INFO -   APVO: RSI: 34.8, MACD: -0.800, Vol: 0.2%
# 2025-09-01 12:59:13,121 - INFO -   ARAY: RSI: 41.5, MACD: 0.185, Vol: 0.2%
# 2025-09-01 12:59:13,122 - INFO -   ARBE: RSI: 41.8, MACD: -0.760, Vol: 0.1%
# 2025-09-01 12:59:13,122 - INFO -   ATEN: RSI: 78.9, MACD: 4.385, Vol: 0.2%
# 2025-09-01 12:59:13,122 - INFO -   ATAI: RSI: 27.7, MACD: -0.491, Vol: 0.2%
# 2025-09-01 12:59:13,123 - INFO -   ATHA: RSI: 27.9, MACD: -1.091, Vol: 0.2%
# 2025-09-01 12:59:13,123 - INFO -   AUTL: RSI: 34.9, MACD: -5.422, Vol: 0.2%
# 2025-09-01 12:59:13,123 - INFO -   AVIR: RSI: 31.2, MACD: -1.232, Vol: 0.2%
# 2025-09-01 12:59:13,123 - INFO -   CABA: RSI: 28.9, MACD: -0.203, Vol: 0.3%
# 2025-09-01 12:59:13,124 - INFO -   CAMP: RSI: 89.7, MACD: 3.083, Vol: 0.2%
# 2025-09-01 12:59:13,125 - INFO -   CARM: RSI: 55.2, MACD: 0.149, Vol: 0.3%
# 2025-09-01 12:59:13,125 - INFO -   CATX: RSI: 36.7, MACD: -1.779, Vol: 0.2%
# 2025-09-01 12:59:13,125 - INFO -   CCCC: RSI: 52.5, MACD: 0.638, Vol: 0.2%
# 2025-09-01 12:59:13,125 - INFO -   CELU: RSI: 60.8, MACD: 0.301, Vol: 0.2%
# 2025-09-01 12:59:13,125 - INFO -   CERS: RSI: 31.8, MACD: -0.565, Vol: 0.3%
# 2025-09-01 12:59:13,126 - INFO -   CGTX: RSI: 84.7, MACD: 1.633, Vol: 0.2%
# 2025-09-01 12:59:13,126 - INFO -   CHRS: RSI: 47.2, MACD: -0.406, Vol: 0.2%
# 2025-09-01 12:59:13,126 - INFO -   CLDI: RSI: 45.8, MACD: -1.002, Vol: 0.2%
# 2025-09-01 12:59:13,126 - INFO -   CLLS: RSI: 39.5, MACD: -0.316, Vol: 0.2%
# 2025-09-01 12:59:13,127 - INFO -   CLRB: RSI: 39.5, MACD: 0.182, Vol: 0.3%
# 2025-09-01 12:59:13,127 - INFO -   CLSD: RSI: 40.8, MACD: -1.489, Vol: 0.3%
# 2025-09-01 12:59:13,127 - INFO -   CLYM: RSI: 69.6, MACD: 0.291, Vol: 0.2%
# 2025-09-01 12:59:13,128 - INFO -   CMPS: RSI: 47.0, MACD: 0.351, Vol: 0.2%
# 2025-09-01 12:59:13,129 - INFO -   CMPX: RSI: 44.2, MACD: 1.613, Vol: 0.2%
# 2025-09-01 12:59:13,129 - INFO -   CMTL: RSI: 52.6, MACD: 0.201, Vol: 0.2%
# 2025-09-01 12:59:13,130 - INFO -   COCP: RSI: 62.8, MACD: 1.184, Vol: 0.2%
# 2025-09-01 12:59:13,131 - INFO -   CRBU: RSI: 49.2, MACD: -0.690, Vol: 0.2%
# 2025-09-01 12:59:13,132 - INFO -   CRDF: RSI: 66.2, MACD: 0.520, Vol: 0.2%
# 2025-09-01 12:59:13,135 - INFO -   CRDL: RSI: 48.1, MACD: -0.570, Vol: 0.2%
# 2025-09-01 12:59:13,136 - INFO -   CRIS: RSI: 73.9, MACD: 0.533, Vol: 0.2%
# 2025-09-01 12:59:13,137 - INFO -   CTMX: RSI: 34.5, MACD: -1.533, Vol: 0.2%
# 2025-09-01 12:59:13,138 - INFO -   CTOR: RSI: 48.0, MACD: 0.396, Vol: 0.2%
# 2025-09-01 12:59:13,139 - INFO -   CTXR: RSI: 52.9, MACD: -1.072, Vol: 0.2%
# 2025-09-01 12:59:13,140 - INFO -   CUE: RSI: 61.7, MACD: -1.047, Vol: 0.2%
# 2025-09-01 12:59:13,142 - INFO -   CURR: RSI: 74.4, MACD: 0.985, Vol: 0.2%
# 2025-09-01 12:59:13,144 - INFO -   DARE: RSI: 60.9, MACD: -0.359, Vol: 0.3%
# 2025-09-01 12:59:13,144 - INFO -   DTIL: RSI: 41.6, MACD: -0.344, Vol: 0.2%
# 2025-09-01 12:59:13,146 - INFO -   EDIT: RSI: 61.5, MACD: 1.109, Vol: 0.2%
# 2025-09-01 12:59:13,146 - INFO -   ELDN: RSI: 75.3, MACD: 2.415, Vol: 0.2%
# 2025-09-01 12:59:13,148 - INFO -   EQ: RSI: 56.7, MACD: -0.196, Vol: 0.1%
# 2025-09-01 12:59:13,148 - INFO -   ERAS: RSI: 51.2, MACD: 3.133, Vol: 0.2%
# 2025-09-01 12:59:13,150 - INFO -   ERNA: RSI: 65.3, MACD: 2.063, Vol: 0.2%
# 2025-09-01 12:59:13,151 - INFO -   ESLA: RSI: 63.7, MACD: 0.252, Vol: 0.2%
# 2025-09-01 12:59:13,152 - INFO -   ESPR: RSI: 29.9, MACD: -1.319, Vol: 0.2%
# 2025-09-01 12:59:13,152 - INFO -   EVGN: RSI: 78.5, MACD: 1.896, Vol: 0.2%
# 2025-09-01 12:59:13,152 - INFO -   FATE: RSI: 37.9, MACD: -2.068, Vol: 0.2%
# 2025-09-01 12:59:13,154 - INFO -   FBLG: RSI: 25.2, MACD: -1.209, Vol: 0.2%
# 2025-09-01 12:59:13,154 - INFO - ==================================================
# 2025-09-01 12:59:13,157 - INFO - Disconnected from trading simulator
# Session Results:
# Trades: 30
# Final Balance: £147.10
# ANNX: 3 shares @ £396.52
# ANVS: 4 shares @ £258.48
# APLT: 7 shares @ £106.91
# AUTL: 1 shares @ £383.80
# CATX: 1 shares @ £436.41
# CLLS: 5 shares @ £126.63
# ATHA: 5 shares @ £118.62
# CCCC: 1 shares @ £459.74
# CLDI: 1 shares @ £377.00
# CUE: 1 shares @ £253.88
# ANRO: 1 shares @ £210.05
# CARM: 3 shares @ £118.67
# CMTL: 1 shares @ £394.50
# CRDF: 1 shares @ £343.56
# CTMX: 1 shares @ £316.50
# CTOR: 1 shares @ £435.02
# EQ: 1 shares @ £347.26
# ABCL: 1 shares @ £356.77
# ALLO: 1 shares @ £464.62
# CELU: 1 shares @ £102.36
# CURR: 1 shares @ £70.11
# EDIT: 1 shares @ £110.78
# CAMP: 1 shares @ £56.22
# CLSD: 1 shares @ £171.01
#
# Session ended
#
# Demo completed
# Next: Try run_production_session('paper', 10) with TWS running
# ============================================================

# %% [markdown]
# ### Execute IB Trading Bot Simulator (Longer Session)

# %%
print("✓ IB Trading Bot Simulator Started")
run_production_session('simulator', max_cycles=20)
print("✓ IB Trading Bot Simulator Completed")
# Out:
# 2025-09-01 13:03:07,600 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 13:03:07,603 - INFO - Trading bot simulator initialised
# 2025-09-01 13:03:07,603 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:03:07,604 - INFO - Starting balance: £10,000.00
# 2025-09-01 13:03:07,604 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 13:03:07,605 - INFO - Connected to trading simulator
# 2025-09-01 13:03:07,606 - INFO - Starting automated trading...
# 2025-09-01 13:03:07,606 - INFO - Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 13:03:07,607 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:03:07,607 - INFO - Update interval: 60 seconds
# 2025-09-01 13:03:07,607 - INFO - Strategy config - Short: 20, Long: 50, Stop Loss: 5.0%, Take Profit: 15.0%
# 2025-09-01 13:03:07,608 - INFO - --- Cycle 1 ---
# 2025-09-01 13:03:07,647 - INFO - Enhanced simulated analysis for ABCL: £191.47 (+0.00%)
# 2025-09-01 13:03:07,666 - INFO - Enhanced simulated analysis for ALLO: £477.75 (+0.00%)
# 2025-09-01 13:03:07,673 - INFO - BUY signal for ALLO: 3/7 signals
# 2025-09-01 13:03:07,673 - INFO - Simulated BUY order placed: 2 ALLO
# 2025-09-01 13:03:07,673 - INFO - SIMULATED BUY: 2 ALLO @ £477.75 (Cost: £955.50, Balance: £9044.50)
# 2025-09-01 13:03:07,674 - INFO - ALLO indicators - RSI: 91.2, MACD: 1.396, Volatility: 0.25%
# 2025-09-01 13:03:07,681 - INFO - Enhanced simulated analysis for ANNX: £439.39 (+0.00%)
# 2025-09-01 13:03:07,695 - INFO - Enhanced simulated analysis for ANRO: £296.78 (+0.00%)
# 2025-09-01 13:03:07,707 - INFO - Enhanced simulated analysis for ANVS: £286.81 (+0.00%)
# 2025-09-01 13:03:07,720 - INFO - Enhanced simulated analysis for APLM: £409.05 (+0.00%)
# 2025-09-01 13:03:07,728 - INFO - BUY signal for APLM: 3/7 signals
# 2025-09-01 13:03:07,728 - INFO - Simulated BUY order placed: 2 APLM
# 2025-09-01 13:03:07,728 - INFO - SIMULATED BUY: 2 APLM @ £409.05 (Cost: £818.10, Balance: £8226.40)
# 2025-09-01 13:03:07,729 - INFO - APLM indicators - RSI: 61.8, MACD: 0.005, Volatility: 0.23%
# 2025-09-01 13:03:07,736 - INFO - Enhanced simulated analysis for APLT: £476.17 (+0.00%)
# 2025-09-01 13:03:07,748 - INFO - Enhanced simulated analysis for APVO: £209.82 (+0.00%)
# 2025-09-01 13:03:07,761 - INFO - Enhanced simulated analysis for ARAY: £295.02 (+0.00%)
# 2025-09-01 13:03:07,767 - INFO - BUY signal for ARAY: 3/7 signals
# 2025-09-01 13:03:07,767 - INFO - Simulated BUY order placed: 3 ARAY
# 2025-09-01 13:03:07,768 - INFO - SIMULATED BUY: 3 ARAY @ £295.02 (Cost: £885.06, Balance: £7341.34)
# 2025-09-01 13:03:07,768 - INFO - ARAY indicators - RSI: 67.7, MACD: 0.081, Volatility: 0.20%
# 2025-09-01 13:03:07,775 - INFO - Enhanced simulated analysis for ARBE: £305.34 (+0.00%)
# 2025-09-01 13:03:07,787 - INFO - Enhanced simulated analysis for ATEN: £366.56 (+0.00%)
# 2025-09-01 13:03:07,800 - INFO - Enhanced simulated analysis for ATAI: £416.36 (+0.00%)
# ✓ IB Trading Bot Simulator Started
# ==================================================
# PRODUCTION SESSION STARTED
# ==================================================
# Environment: SIMULATOR
# Strategy: Production_Enhanced
# Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# Cycles: 20
# ==================================================
# 2025-09-01 13:03:07,813 - INFO - Enhanced simulated analysis for ATHA: £64.71 (+0.00%)
# 2025-09-01 13:03:07,826 - INFO - Enhanced simulated analysis for AUTL: £73.65 (+0.00%)
# 2025-09-01 13:03:07,839 - INFO - Enhanced simulated analysis for AVIR: £487.04 (+0.00%)
# 2025-09-01 13:03:07,851 - INFO - Enhanced simulated analysis for CABA: £147.29 (+0.00%)
# 2025-09-01 13:03:07,863 - INFO - Enhanced simulated analysis for CAMP: £493.99 (+0.00%)
# 2025-09-01 13:03:07,876 - INFO - Enhanced simulated analysis for CARM: £396.24 (+0.00%)
# 2025-09-01 13:03:07,887 - INFO - Enhanced simulated analysis for CATX: £378.90 (+0.00%)
# 2025-09-01 13:03:07,900 - INFO - Enhanced simulated analysis for CCCC: £119.43 (+0.00%)
# 2025-09-01 13:03:07,906 - INFO - BUY signal for CCCC: 3/7 signals
# 2025-09-01 13:03:07,906 - INFO - Simulated BUY order placed: 7 CCCC
# 2025-09-01 13:03:07,907 - INFO - SIMULATED BUY: 7 CCCC @ £119.43 (Cost: £836.01, Balance: £6505.33)
# 2025-09-01 13:03:07,907 - INFO - CCCC indicators - RSI: 32.0, MACD: -1.687, Volatility: 0.24%
# 2025-09-01 13:03:07,914 - INFO - Enhanced simulated analysis for CELU: £452.38 (+0.00%)
# 2025-09-01 13:03:07,927 - INFO - Enhanced simulated analysis for CERS: £362.21 (+0.00%)
# 2025-09-01 13:03:07,938 - INFO - Enhanced simulated analysis for CGTX: £284.62 (+0.00%)
# 2025-09-01 13:03:07,951 - INFO - Enhanced simulated analysis for CHRS: £58.61 (+0.00%)
# 2025-09-01 13:03:07,963 - INFO - Enhanced simulated analysis for CLDI: £157.76 (+0.00%)
# 2025-09-01 13:03:07,970 - INFO - BUY signal for CLDI: 3/7 signals
# 2025-09-01 13:03:07,970 - INFO - Simulated BUY order placed: 4 CLDI
# 2025-09-01 13:03:07,970 - INFO - SIMULATED BUY: 4 CLDI @ £157.76 (Cost: £631.04, Balance: £5874.29)
# 2025-09-01 13:03:07,970 - INFO - CLDI indicators - RSI: 71.8, MACD: 0.291, Volatility: 0.18%
# 2025-09-01 13:03:07,978 - INFO - Enhanced simulated analysis for CLLS: £84.69 (+0.00%)
# 2025-09-01 13:03:07,990 - INFO - Enhanced simulated analysis for CLRB: £473.95 (+0.00%)
# 2025-09-01 13:03:08,003 - INFO - Enhanced simulated analysis for CLSD: £280.56 (+0.00%)
# 2025-09-01 13:03:08,016 - INFO - Enhanced simulated analysis for CLYM: £306.36 (+0.00%)
# 2025-09-01 13:03:08,028 - INFO - Enhanced simulated analysis for CMPS: £200.77 (+0.00%)
# 2025-09-01 13:03:08,061 - INFO - Enhanced simulated analysis for CMPX: £224.71 (+0.00%)
# 2025-09-01 13:03:08,080 - INFO - Enhanced simulated analysis for CMTL: £326.13 (+0.00%)
# 2025-09-01 13:03:08,093 - INFO - Enhanced simulated analysis for COCP: £408.72 (+0.00%)
# 2025-09-01 13:03:08,104 - INFO - Enhanced simulated analysis for CRBU: £188.08 (+0.00%)
# 2025-09-01 13:03:08,117 - INFO - Enhanced simulated analysis for CRDF: £173.55 (+0.00%)
# 2025-09-01 13:03:08,129 - INFO - Enhanced simulated analysis for CRDL: £310.40 (+0.00%)
# 2025-09-01 13:03:08,135 - INFO - BUY signal for CRDL: 3/7 signals
# 2025-09-01 13:03:08,136 - INFO - Simulated BUY order placed: 2 CRDL
# 2025-09-01 13:03:08,136 - INFO - SIMULATED BUY: 2 CRDL @ £310.40 (Cost: £620.80, Balance: £5253.49)
# 2025-09-01 13:03:08,136 - INFO - CRDL indicators - RSI: 61.1, MACD: 0.625, Volatility: 0.23%
# 2025-09-01 13:03:08,144 - INFO - Enhanced simulated analysis for CRIS: £153.57 (+0.00%)
# 2025-09-01 13:03:08,156 - INFO - Enhanced simulated analysis for CTMX: £480.38 (+0.00%)
# 2025-09-01 13:03:08,163 - INFO - BUY signal for CTMX: 3/7 signals
# 2025-09-01 13:03:08,163 - INFO - Simulated BUY order placed: 1 CTMX
# 2025-09-01 13:03:08,163 - INFO - SIMULATED BUY: 1 CTMX @ £480.38 (Cost: £480.38, Balance: £4773.11)
# 2025-09-01 13:03:08,163 - INFO - CTMX indicators - RSI: 60.6, MACD: -0.242, Volatility: 0.23%
# 2025-09-01 13:03:08,171 - INFO - Enhanced simulated analysis for CTOR: £266.57 (+0.00%)
# 2025-09-01 13:03:08,185 - INFO - Enhanced simulated analysis for CTXR: £371.82 (+0.00%)
# 2025-09-01 13:03:08,198 - INFO - Enhanced simulated analysis for CUE: £198.17 (+0.00%)
# 2025-09-01 13:03:08,210 - INFO - Enhanced simulated analysis for CURR: £102.87 (+0.00%)
# 2025-09-01 13:03:08,222 - INFO - Enhanced simulated analysis for DARE: £453.04 (+0.00%)
# 2025-09-01 13:03:08,234 - INFO - Enhanced simulated analysis for DTIL: £430.79 (+0.00%)
# 2025-09-01 13:03:08,246 - INFO - Enhanced simulated analysis for EDIT: £454.86 (+0.00%)
# 2025-09-01 13:03:08,258 - INFO - Enhanced simulated analysis for ELDN: £464.08 (+0.00%)
# 2025-09-01 13:03:08,270 - INFO - Enhanced simulated analysis for EQ: £250.34 (+0.00%)
# 2025-09-01 13:03:08,282 - INFO - Enhanced simulated analysis for ERAS: £83.02 (+0.00%)
# 2025-09-01 13:03:08,296 - INFO - Enhanced simulated analysis for ERNA: £445.44 (+0.00%)
# 2025-09-01 13:03:08,307 - INFO - Enhanced simulated analysis for ESLA: £362.22 (+0.00%)
# 2025-09-01 13:03:08,319 - INFO - Enhanced simulated analysis for ESPR: £95.73 (+0.00%)
# 2025-09-01 13:03:08,331 - INFO - Enhanced simulated analysis for EVGN: £180.85 (+0.00%)
# 2025-09-01 13:03:08,343 - INFO - Enhanced simulated analysis for FATE: £456.18 (+0.00%)
# 2025-09-01 13:03:08,355 - INFO - Enhanced simulated analysis for FBLG: £448.69 (+0.00%)
# 2025-09-01 13:03:08,361 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 13:04:08,360 - INFO - --- Cycle 2 ---
# 2025-09-01 13:04:08,390 - INFO - Enhanced simulated analysis for ABCL: £192.69 (+0.00%)
# 2025-09-01 13:04:08,408 - INFO - Enhanced simulated analysis for ALLO: £471.55 (+0.00%)
# 2025-09-01 13:04:08,424 - INFO - Enhanced simulated analysis for ANNX: £433.21 (+0.00%)
# 2025-09-01 13:04:08,439 - INFO - Enhanced simulated analysis for ANRO: £296.62 (+0.00%)
# 2025-09-01 13:04:08,451 - INFO - Enhanced simulated analysis for ANVS: £286.30 (+0.00%)
# 2025-09-01 13:04:08,463 - INFO - Enhanced simulated analysis for APLM: £410.54 (+0.00%)
# 2025-09-01 13:04:08,469 - INFO - SELL signal for APLM: 3/7 signals
# 2025-09-01 13:04:08,470 - INFO - Simulated SELL order placed: 2 APLM
# 2025-09-01 13:04:08,470 - INFO - SIMULATED SELL: 0 APLM @ £410.54 (Value: £821.08, P&L: £821.08, Balance: £5594.19)
# 2025-09-01 13:04:08,470 - INFO - APLM indicators - RSI: 35.2, MACD: -0.024, Volatility: 0.24%
# 2025-09-01 13:04:08,477 - INFO - Enhanced simulated analysis for APLT: £479.25 (+0.00%)
# 2025-09-01 13:04:08,488 - INFO - Enhanced simulated analysis for APVO: £212.00 (+0.00%)
# 2025-09-01 13:04:08,500 - INFO - Enhanced simulated analysis for ARAY: £297.73 (+0.00%)
# 2025-09-01 13:04:08,511 - INFO - Enhanced simulated analysis for ARBE: £305.94 (+0.00%)
# 2025-09-01 13:04:08,522 - INFO - Enhanced simulated analysis for ATEN: £367.52 (+0.00%)
# 2025-09-01 13:04:08,533 - INFO - Enhanced simulated analysis for ATAI: £419.12 (+0.00%)
# 2025-09-01 13:04:08,539 - INFO - BUY signal for ATAI: 4/7 signals
# 2025-09-01 13:04:08,539 - INFO - Simulated BUY order placed: 1 ATAI
# 2025-09-01 13:04:08,539 - INFO - SIMULATED BUY: 1 ATAI @ £419.12 (Cost: £419.12, Balance: £5175.07)
# 2025-09-01 13:04:08,539 - INFO - ATAI indicators - RSI: 58.9, MACD: 0.256, Volatility: 0.18%
# 2025-09-01 13:04:08,546 - INFO - Enhanced simulated analysis for ATHA: £65.16 (+0.00%)
# 2025-09-01 13:04:08,557 - INFO - Enhanced simulated analysis for AUTL: £74.09 (+0.00%)
# 2025-09-01 13:04:08,568 - INFO - Enhanced simulated analysis for AVIR: £481.61 (+0.00%)
# 2025-09-01 13:04:08,579 - INFO - Enhanced simulated analysis for CABA: £147.61 (+0.00%)
# 2025-09-01 13:04:08,590 - INFO - Enhanced simulated analysis for CAMP: £494.74 (+0.00%)
# 2025-09-01 13:04:08,600 - INFO - Enhanced simulated analysis for CARM: £390.62 (+0.00%)
# 2025-09-01 13:04:08,612 - INFO - Enhanced simulated analysis for CATX: £379.66 (+0.00%)
# 2025-09-01 13:04:08,622 - INFO - Enhanced simulated analysis for CCCC: £118.51 (+0.00%)
# 2025-09-01 13:04:08,633 - INFO - Enhanced simulated analysis for CELU: £454.98 (+0.00%)
# 2025-09-01 13:04:08,644 - INFO - Enhanced simulated analysis for CERS: £361.77 (+0.00%)
# 2025-09-01 13:04:08,655 - INFO - Enhanced simulated analysis for CGTX: £284.88 (+0.00%)
# 2025-09-01 13:04:08,666 - INFO - Enhanced simulated analysis for CHRS: £58.09 (+0.00%)
# 2025-09-01 13:04:08,677 - INFO - Enhanced simulated analysis for CLDI: £157.29 (+0.00%)
# 2025-09-01 13:04:08,688 - INFO - Enhanced simulated analysis for CLLS: £85.70 (+0.00%)
# 2025-09-01 13:04:08,699 - INFO - Enhanced simulated analysis for CLRB: £472.54 (+0.00%)
# 2025-09-01 13:04:08,710 - INFO - Enhanced simulated analysis for CLSD: £279.27 (+0.00%)
# 2025-09-01 13:04:08,721 - INFO - Enhanced simulated analysis for CLYM: £305.87 (+0.00%)
# 2025-09-01 13:04:08,731 - INFO - Enhanced simulated analysis for CMPS: £201.92 (+0.00%)
# 2025-09-01 13:04:08,743 - INFO - Enhanced simulated analysis for CMPX: £226.30 (+0.00%)
# 2025-09-01 13:04:08,753 - INFO - Enhanced simulated analysis for CMTL: £324.05 (+0.00%)
# 2025-09-01 13:04:08,759 - INFO - BUY signal for CMTL: 3/7 signals
# 2025-09-01 13:04:08,759 - INFO - Simulated BUY order placed: 1 CMTL
# 2025-09-01 13:04:08,760 - INFO - SIMULATED BUY: 1 CMTL @ £324.05 (Cost: £324.05, Balance: £4851.02)
# 2025-09-01 13:04:08,760 - INFO - CMTL indicators - RSI: 58.4, MACD: 1.955, Volatility: 0.23%
# 2025-09-01 13:04:08,766 - INFO - Enhanced simulated analysis for COCP: £408.60 (+0.00%)
# 2025-09-01 13:04:08,777 - INFO - Enhanced simulated analysis for CRBU: £188.89 (+0.00%)
# 2025-09-01 13:04:08,788 - INFO - Enhanced simulated analysis for CRDF: £175.91 (+0.00%)
# 2025-09-01 13:04:08,800 - INFO - Enhanced simulated analysis for CRDL: £311.40 (+0.00%)
# 2025-09-01 13:04:08,812 - INFO - Enhanced simulated analysis for CRIS: £154.62 (+0.00%)
# 2025-09-01 13:04:08,823 - INFO - Enhanced simulated analysis for CTMX: £480.98 (+0.00%)
# 2025-09-01 13:04:08,834 - INFO - Enhanced simulated analysis for CTOR: £266.05 (+0.00%)
# 2025-09-01 13:04:08,845 - INFO - Enhanced simulated analysis for CTXR: £374.06 (+0.00%)
# 2025-09-01 13:04:08,856 - INFO - Enhanced simulated analysis for CUE: £199.25 (+0.00%)
# 2025-09-01 13:04:08,867 - INFO - Enhanced simulated analysis for CURR: £103.32 (+0.00%)
# 2025-09-01 13:04:08,877 - INFO - Enhanced simulated analysis for DARE: £450.40 (+0.00%)
# 2025-09-01 13:04:08,889 - INFO - Enhanced simulated analysis for DTIL: £431.80 (+0.00%)
# 2025-09-01 13:04:08,900 - INFO - Enhanced simulated analysis for EDIT: £456.28 (+0.00%)
# 2025-09-01 13:04:08,912 - INFO - Enhanced simulated analysis for ELDN: £463.34 (+0.00%)
# 2025-09-01 13:04:08,942 - INFO - Enhanced simulated analysis for EQ: £247.70 (+0.00%)
# 2025-09-01 13:04:08,958 - INFO - Enhanced simulated analysis for ERAS: £82.79 (+0.00%)
# 2025-09-01 13:04:08,970 - INFO - Enhanced simulated analysis for ERNA: £444.53 (+0.00%)
# 2025-09-01 13:04:08,981 - INFO - Enhanced simulated analysis for ESLA: £362.46 (+0.00%)
# 2025-09-01 13:04:08,992 - INFO - Enhanced simulated analysis for ESPR: £95.54 (+0.00%)
# 2025-09-01 13:04:09,003 - INFO - Enhanced simulated analysis for EVGN: £178.62 (+0.00%)
# 2025-09-01 13:04:09,014 - INFO - Enhanced simulated analysis for FATE: £450.31 (+0.00%)
# 2025-09-01 13:04:09,025 - INFO - Enhanced simulated analysis for FBLG: £443.73 (+0.00%)
# 2025-09-01 13:04:09,031 - INFO - Cycle completed: 3 trades executed
# 2025-09-01 13:04:09,031 - INFO - Performance - Total Trades: 1, Win Rate: 100.0%, Total P&L: £2.98
# 2025-09-01 13:05:09,036 - INFO - --- Cycle 3 ---
# 2025-09-01 13:05:09,055 - INFO - Enhanced simulated analysis for ABCL: £190.00 (+0.00%)
# 2025-09-01 13:05:09,076 - INFO - Enhanced simulated analysis for ALLO: £474.27 (+0.00%)
# 2025-09-01 13:05:09,086 - INFO - SELL signal for ALLO: 3/7 signals
# 2025-09-01 13:05:09,086 - INFO - Simulated SELL order placed: 2 ALLO
# 2025-09-01 13:05:09,086 - INFO - SIMULATED SELL: 0 ALLO @ £474.27 (Value: £948.54, P&L: £948.54, Balance: £5799.56)
# 2025-09-01 13:05:09,087 - INFO - ALLO indicators - RSI: 24.1, MACD: -0.977, Volatility: 0.16%
# 2025-09-01 13:05:09,096 - INFO - Enhanced simulated analysis for ANNX: £432.19 (+0.00%)
# 2025-09-01 13:05:09,110 - INFO - Enhanced simulated analysis for ANRO: £293.84 (+0.00%)
# 2025-09-01 13:05:09,123 - INFO - Enhanced simulated analysis for ANVS: £286.36 (+0.00%)
# 2025-09-01 13:05:09,129 - INFO - BUY signal for ANVS: 4/7 signals
# 2025-09-01 13:05:09,130 - INFO - Simulated BUY order placed: 2 ANVS
# 2025-09-01 13:05:09,130 - INFO - SIMULATED BUY: 2 ANVS @ £286.36 (Cost: £572.72, Balance: £5226.84)
# 2025-09-01 13:05:09,130 - INFO - ANVS indicators - RSI: 57.2, MACD: 0.339, Volatility: 0.22%
# 2025-09-01 13:05:09,137 - INFO - Enhanced simulated analysis for APLM: £409.23 (+0.00%)
# 2025-09-01 13:05:09,148 - INFO - Enhanced simulated analysis for APLT: £475.25 (+0.00%)
# 2025-09-01 13:05:09,159 - INFO - Enhanced simulated analysis for APVO: £214.50 (+0.00%)
# 2025-09-01 13:05:09,170 - INFO - Enhanced simulated analysis for ARAY: £300.20 (+0.00%)
# 2025-09-01 13:05:09,181 - INFO - Enhanced simulated analysis for ARBE: £312.12 (+0.00%)
# 2025-09-01 13:05:09,192 - INFO - Enhanced simulated analysis for ATEN: £367.84 (+0.00%)
# 2025-09-01 13:05:09,203 - INFO - Enhanced simulated analysis for ATAI: £419.33 (+0.00%)
# 2025-09-01 13:05:09,209 - INFO - SELL signal for ATAI: 3/7 signals
# 2025-09-01 13:05:09,209 - INFO - Simulated SELL order placed: 1 ATAI
# 2025-09-01 13:05:09,210 - INFO - SIMULATED SELL: 0 ATAI @ £419.33 (Value: £419.33, P&L: £419.33, Balance: £5646.17)
# 2025-09-01 13:05:09,210 - INFO - ATAI indicators - RSI: 17.2, MACD: -0.961, Volatility: 0.19%
# 2025-09-01 13:05:09,216 - INFO - Enhanced simulated analysis for ATHA: £65.05 (+0.00%)
# 2025-09-01 13:05:09,227 - INFO - Enhanced simulated analysis for AUTL: £74.01 (+0.00%)
# 2025-09-01 13:05:09,238 - INFO - Enhanced simulated analysis for AVIR: £480.30 (+0.00%)
# 2025-09-01 13:05:09,249 - INFO - Enhanced simulated analysis for CABA: £146.28 (+0.00%)
# 2025-09-01 13:05:09,260 - INFO - Enhanced simulated analysis for CAMP: £496.39 (+0.00%)
# 2025-09-01 13:05:09,271 - INFO - Enhanced simulated analysis for CARM: £388.02 (+0.00%)
# 2025-09-01 13:05:09,282 - INFO - Enhanced simulated analysis for CATX: £374.28 (+0.00%)
# 2025-09-01 13:05:09,293 - INFO - Enhanced simulated analysis for CCCC: £117.94 (+0.00%)
# 2025-09-01 13:05:09,304 - INFO - Enhanced simulated analysis for CELU: £460.21 (+0.00%)
# 2025-09-01 13:05:09,316 - INFO - Enhanced simulated analysis for CERS: £360.08 (+0.00%)
# 2025-09-01 13:05:09,327 - INFO - Enhanced simulated analysis for CGTX: £283.93 (+0.00%)
# 2025-09-01 13:05:09,339 - INFO - Enhanced simulated analysis for CHRS: £58.18 (+0.00%)
# 2025-09-01 13:05:09,350 - INFO - Enhanced simulated analysis for CLDI: £156.13 (+0.00%)
# 2025-09-01 13:05:09,362 - INFO - Enhanced simulated analysis for CLLS: £85.93 (+0.00%)
# 2025-09-01 13:05:09,373 - INFO - Enhanced simulated analysis for CLRB: £475.26 (+0.00%)
# 2025-09-01 13:05:09,380 - INFO - BUY signal for CLRB: 3/7 signals
# 2025-09-01 13:05:09,380 - INFO - Simulated BUY order placed: 1 CLRB
# 2025-09-01 13:05:09,380 - INFO - SIMULATED BUY: 1 CLRB @ £475.26 (Cost: £475.26, Balance: £5170.91)
# 2025-09-01 13:05:09,381 - INFO - CLRB indicators - RSI: 62.9, MACD: 0.170, Volatility: 0.18%
# 2025-09-01 13:05:09,387 - INFO - Enhanced simulated analysis for CLSD: £280.29 (+0.00%)
# 2025-09-01 13:05:09,399 - INFO - Enhanced simulated analysis for CLYM: £307.28 (+0.00%)
# 2025-09-01 13:05:09,415 - INFO - Enhanced simulated analysis for CMPS: £199.26 (+0.00%)
# 2025-09-01 13:05:09,421 - INFO - BUY signal for CMPS: 3/7 signals
# 2025-09-01 13:05:09,421 - INFO - Simulated BUY order placed: 3 CMPS
# 2025-09-01 13:05:09,421 - INFO - SIMULATED BUY: 3 CMPS @ £199.26 (Cost: £597.78, Balance: £4573.13)
# 2025-09-01 13:05:09,422 - INFO - CMPS indicators - RSI: 46.8, MACD: -0.368, Volatility: 0.23%
# 2025-09-01 13:05:09,428 - INFO - Enhanced simulated analysis for CMPX: £227.36 (+0.00%)
# 2025-09-01 13:05:09,439 - INFO - Enhanced simulated analysis for CMTL: £320.44 (+0.00%)
# 2025-09-01 13:05:09,450 - INFO - Enhanced simulated analysis for COCP: £410.06 (+0.00%)
# 2025-09-01 13:05:09,461 - INFO - Enhanced simulated analysis for CRBU: £187.97 (+0.00%)
# 2025-09-01 13:05:09,472 - INFO - Enhanced simulated analysis for CRDF: £175.03 (+0.00%)
# 2025-09-01 13:05:09,483 - INFO - Enhanced simulated analysis for CRDL: £310.11 (+0.00%)
# 2025-09-01 13:05:09,494 - INFO - Enhanced simulated analysis for CRIS: £152.60 (+0.00%)
# 2025-09-01 13:05:09,505 - INFO - Enhanced simulated analysis for CTMX: £482.74 (+0.00%)
# 2025-09-01 13:05:09,516 - INFO - Enhanced simulated analysis for CTOR: £266.83 (+0.00%)
# 2025-09-01 13:05:09,527 - INFO - Enhanced simulated analysis for CTXR: £375.08 (+0.00%)
# 2025-09-01 13:05:09,538 - INFO - Enhanced simulated analysis for CUE: £199.60 (+0.00%)
# 2025-09-01 13:05:09,544 - INFO - BUY signal for CUE: 4/7 signals
# 2025-09-01 13:05:09,544 - INFO - Simulated BUY order placed: 2 CUE
# 2025-09-01 13:05:09,544 - INFO - SIMULATED BUY: 2 CUE @ £199.60 (Cost: £399.20, Balance: £4173.93)
# 2025-09-01 13:05:09,545 - INFO - CUE indicators - RSI: 63.7, MACD: 0.359, Volatility: 0.19%
# 2025-09-01 13:05:09,551 - INFO - Enhanced simulated analysis for CURR: £105.39 (+0.00%)
# 2025-09-01 13:05:09,557 - INFO - BUY signal for CURR: 3/7 signals
# 2025-09-01 13:05:09,557 - INFO - Simulated BUY order placed: 4 CURR
# 2025-09-01 13:05:09,557 - INFO - SIMULATED BUY: 4 CURR @ £105.39 (Cost: £421.56, Balance: £3752.37)
# 2025-09-01 13:05:09,558 - INFO - CURR indicators - RSI: 60.1, MACD: 0.827, Volatility: 0.24%
# 2025-09-01 13:05:09,564 - INFO - Enhanced simulated analysis for DARE: £452.64 (+0.00%)
# 2025-09-01 13:05:09,575 - INFO - Enhanced simulated analysis for DTIL: £425.76 (+0.00%)
# 2025-09-01 13:05:09,586 - INFO - Enhanced simulated analysis for EDIT: £455.47 (+0.00%)
# 2025-09-01 13:05:09,597 - INFO - Enhanced simulated analysis for ELDN: £465.56 (+0.00%)
# 2025-09-01 13:05:09,608 - INFO - Enhanced simulated analysis for EQ: £248.56 (+0.00%)
# 2025-09-01 13:05:09,619 - INFO - Enhanced simulated analysis for ERAS: £82.75 (+0.00%)
# 2025-09-01 13:05:09,630 - INFO - Enhanced simulated analysis for ERNA: £447.05 (+0.00%)
# 2025-09-01 13:05:09,640 - INFO - Enhanced simulated analysis for ESLA: £358.69 (+0.00%)
# 2025-09-01 13:05:09,651 - INFO - Enhanced simulated analysis for ESPR: £96.08 (+0.00%)
# 2025-09-01 13:05:09,662 - INFO - Enhanced simulated analysis for EVGN: £178.90 (+0.00%)
# 2025-09-01 13:05:09,673 - INFO - Enhanced simulated analysis for FATE: £447.26 (+0.00%)
# 2025-09-01 13:05:09,684 - INFO - Enhanced simulated analysis for FBLG: £447.59 (+0.00%)
# 2025-09-01 13:05:09,689 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 13:05:09,690 - INFO - Performance - Total Trades: 3, Win Rate: 66.7%, Total P&L: £-3.77
# 2025-09-01 13:06:09,694 - INFO - --- Cycle 4 ---
# 2025-09-01 13:06:09,708 - INFO - Enhanced simulated analysis for ABCL: £186.94 (+0.00%)
# 2025-09-01 13:06:09,726 - INFO - Enhanced simulated analysis for ALLO: £475.70 (+0.00%)
# 2025-09-01 13:06:09,742 - INFO - Enhanced simulated analysis for ANNX: £433.56 (+0.00%)
# 2025-09-01 13:06:09,755 - INFO - Enhanced simulated analysis for ANRO: £298.07 (+0.00%)
# 2025-09-01 13:06:09,769 - INFO - Enhanced simulated analysis for ANVS: £289.81 (+0.00%)
# 2025-09-01 13:06:09,782 - INFO - Enhanced simulated analysis for APLM: £410.98 (+0.00%)
# 2025-09-01 13:06:09,794 - INFO - Enhanced simulated analysis for APLT: £473.20 (+0.00%)
# 2025-09-01 13:06:09,800 - INFO - BUY signal for APLT: 3/7 signals
# 2025-09-01 13:06:09,800 - INFO - Simulated BUY order placed: 1 APLT
# 2025-09-01 13:06:09,801 - INFO - SIMULATED BUY: 1 APLT @ £473.20 (Cost: £473.20, Balance: £3279.17)
# 2025-09-01 13:06:09,801 - INFO - APLT indicators - RSI: 55.9, MACD: -0.086, Volatility: 0.18%
# 2025-09-01 13:06:09,809 - INFO - Enhanced simulated analysis for APVO: £215.09 (+0.00%)
# 2025-09-01 13:06:09,822 - INFO - Enhanced simulated analysis for ARAY: £300.65 (+0.00%)
# 2025-09-01 13:06:09,834 - INFO - Enhanced simulated analysis for ARBE: £309.70 (+0.00%)
# 2025-09-01 13:06:09,846 - INFO - Enhanced simulated analysis for ATEN: £367.65 (+0.00%)
# 2025-09-01 13:06:09,862 - INFO - Enhanced simulated analysis for ATAI: £417.19 (+0.00%)
# 2025-09-01 13:06:09,874 - INFO - Enhanced simulated analysis for ATHA: £64.68 (+0.00%)
# 2025-09-01 13:06:09,885 - INFO - Enhanced simulated analysis for AUTL: £73.46 (+0.00%)
# 2025-09-01 13:06:09,897 - INFO - Enhanced simulated analysis for AVIR: £474.57 (+0.00%)
# 2025-09-01 13:06:09,904 - INFO - BUY signal for AVIR: 3/7 signals
# 2025-09-01 13:06:09,904 - INFO - Simulated BUY order placed: 1 AVIR
# 2025-09-01 13:06:09,904 - INFO - SIMULATED BUY: 1 AVIR @ £474.57 (Cost: £474.57, Balance: £2804.60)
# 2025-09-01 13:06:09,905 - INFO - AVIR indicators - RSI: 63.5, MACD: 0.431, Volatility: 0.22%
# 2025-09-01 13:06:09,911 - INFO - Enhanced simulated analysis for CABA: £145.26 (+0.00%)
# 2025-09-01 13:06:09,924 - INFO - Enhanced simulated analysis for CAMP: £496.55 (+0.00%)
# 2025-09-01 13:06:09,935 - INFO - Enhanced simulated analysis for CARM: £389.91 (+0.00%)
# 2025-09-01 13:06:09,947 - INFO - Enhanced simulated analysis for CATX: £372.65 (+0.00%)
# 2025-09-01 13:06:09,959 - INFO - Enhanced simulated analysis for CCCC: £119.38 (+0.00%)
# 2025-09-01 13:06:09,970 - INFO - Enhanced simulated analysis for CELU: £459.36 (+0.00%)
# 2025-09-01 13:06:09,976 - INFO - BUY signal for CELU: 3/7 signals
# 2025-09-01 13:06:09,977 - INFO - Simulated BUY order placed: 1 CELU
# 2025-09-01 13:06:09,977 - INFO - SIMULATED BUY: 1 CELU @ £459.36 (Cost: £459.36, Balance: £2345.24)
# 2025-09-01 13:06:09,977 - INFO - CELU indicators - RSI: 37.6, MACD: 1.689, Volatility: 0.23%
# 2025-09-01 13:06:09,984 - INFO - Enhanced simulated analysis for CERS: £358.19 (+0.00%)
# 2025-09-01 13:06:09,996 - INFO - Enhanced simulated analysis for CGTX: £284.21 (+0.00%)
# 2025-09-01 13:06:10,007 - INFO - Enhanced simulated analysis for CHRS: £58.24 (+0.00%)
# 2025-09-01 13:06:10,019 - INFO - Enhanced simulated analysis for CLDI: £154.59 (+0.00%)
# 2025-09-01 13:06:10,031 - INFO - Enhanced simulated analysis for CLLS: £84.57 (+0.00%)
# 2025-09-01 13:06:10,042 - INFO - Enhanced simulated analysis for CLRB: £478.07 (+0.00%)
# 2025-09-01 13:06:10,048 - INFO - SELL signal for CLRB: 3/7 signals
# 2025-09-01 13:06:10,049 - INFO - Simulated SELL order placed: 1 CLRB
# 2025-09-01 13:06:10,049 - INFO - SIMULATED SELL: 0 CLRB @ £478.07 (Value: £478.07, P&L: £478.07, Balance: £2823.31)
# 2025-09-01 13:06:10,049 - INFO - CLRB indicators - RSI: 32.5, MACD: -0.900, Volatility: 0.18%
# 2025-09-01 13:06:10,056 - INFO - Enhanced simulated analysis for CLSD: £277.88 (+0.00%)
# 2025-09-01 13:06:10,067 - INFO - Enhanced simulated analysis for CLYM: £307.68 (+0.00%)
# 2025-09-01 13:06:10,101 - INFO - Enhanced simulated analysis for CMPS: £198.69 (+0.00%)
# 2025-09-01 13:06:10,117 - INFO - Enhanced simulated analysis for CMPX: £226.59 (+0.00%)
# 2025-09-01 13:06:10,129 - INFO - Enhanced simulated analysis for CMTL: £321.35 (+0.00%)
# 2025-09-01 13:06:10,141 - INFO - Enhanced simulated analysis for COCP: £415.28 (+0.00%)
# 2025-09-01 13:06:10,153 - INFO - Enhanced simulated analysis for CRBU: £188.08 (+0.00%)
# 2025-09-01 13:06:10,159 - INFO - BUY signal for CRBU: 3/7 signals
# 2025-09-01 13:06:10,160 - INFO - Simulated BUY order placed: 1 CRBU
# 2025-09-01 13:06:10,160 - INFO - SIMULATED BUY: 1 CRBU @ £188.08 (Cost: £188.08, Balance: £2635.23)
# 2025-09-01 13:06:10,160 - INFO - CRBU indicators - RSI: 69.2, MACD: 0.830, Volatility: 0.17%
# 2025-09-01 13:06:10,167 - INFO - Enhanced simulated analysis for CRDF: £174.59 (+0.00%)
# 2025-09-01 13:06:10,179 - INFO - Enhanced simulated analysis for CRDL: £313.15 (+0.00%)
# 2025-09-01 13:06:10,191 - INFO - Enhanced simulated analysis for CRIS: £152.11 (+0.00%)
# 2025-09-01 13:06:10,202 - INFO - Enhanced simulated analysis for CTMX: £485.09 (+0.00%)
# 2025-09-01 13:06:10,214 - INFO - Enhanced simulated analysis for CTOR: £269.13 (+0.00%)
# 2025-09-01 13:06:10,226 - INFO - Enhanced simulated analysis for CTXR: £373.59 (+0.00%)
# 2025-09-01 13:06:10,238 - INFO - Enhanced simulated analysis for CUE: £200.39 (+0.00%)
# 2025-09-01 13:06:10,249 - INFO - Enhanced simulated analysis for CURR: £106.37 (+0.00%)
# 2025-09-01 13:06:10,261 - INFO - Enhanced simulated analysis for DARE: £447.65 (+0.00%)
# 2025-09-01 13:06:10,266 - INFO - BUY signal for DARE: 3/7 signals
# 2025-09-01 13:06:10,267 - INFO - Simulated BUY order placed: 1 DARE
# 2025-09-01 13:06:10,267 - INFO - SIMULATED BUY: 1 DARE @ £447.65 (Cost: £447.65, Balance: £2187.58)
# 2025-09-01 13:06:10,267 - INFO - DARE indicators - RSI: 61.1, MACD: 0.088, Volatility: 0.23%
# 2025-09-01 13:06:10,275 - INFO - Enhanced simulated analysis for DTIL: £423.26 (+0.00%)
# 2025-09-01 13:06:10,286 - INFO - Enhanced simulated analysis for EDIT: £455.42 (+0.00%)
# 2025-09-01 13:06:10,298 - INFO - Enhanced simulated analysis for ELDN: £459.45 (+0.00%)
# 2025-09-01 13:06:10,310 - INFO - Enhanced simulated analysis for EQ: £251.85 (+0.00%)
# 2025-09-01 13:06:10,322 - INFO - Enhanced simulated analysis for ERAS: £83.18 (+0.00%)
# 2025-09-01 13:06:10,328 - INFO - BUY signal for ERAS: 3/7 signals
# 2025-09-01 13:06:10,328 - INFO - Simulated BUY order placed: 3 ERAS
# 2025-09-01 13:06:10,329 - INFO - SIMULATED BUY: 3 ERAS @ £83.18 (Cost: £249.54, Balance: £1938.04)
# 2025-09-01 13:06:10,329 - INFO - ERAS indicators - RSI: 69.5, MACD: 0.382, Volatility: 0.15%
# 2025-09-01 13:06:10,337 - INFO - Enhanced simulated analysis for ERNA: £445.49 (+0.00%)
# 2025-09-01 13:06:10,351 - INFO - Enhanced simulated analysis for ESLA: £362.18 (+0.00%)
# 2025-09-01 13:06:10,365 - INFO - Enhanced simulated analysis for ESPR: £96.53 (+0.00%)
# 2025-09-01 13:06:10,378 - INFO - Enhanced simulated analysis for EVGN: £179.45 (+0.00%)
# 2025-09-01 13:06:10,391 - INFO - Enhanced simulated analysis for FATE: £449.60 (+0.00%)
# 2025-09-01 13:06:10,402 - INFO - Enhanced simulated analysis for FBLG: £445.31 (+0.00%)
# 2025-09-01 13:06:10,408 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 13:06:10,409 - INFO - Performance - Total Trades: 4, Win Rate: 75.0%, Total P&L: £-0.96
# 2025-09-01 13:07:10,411 - INFO - --- Cycle 5 ---
# 2025-09-01 13:07:10,431 - INFO - Enhanced simulated analysis for ABCL: £186.51 (+0.00%)
# 2025-09-01 13:07:10,449 - INFO - Enhanced simulated analysis for ALLO: £478.58 (+0.00%)
# 2025-09-01 13:07:10,464 - INFO - Enhanced simulated analysis for ANNX: £436.56 (+0.00%)
# 2025-09-01 13:07:10,478 - INFO - Enhanced simulated analysis for ANRO: £297.28 (+0.00%)
# 2025-09-01 13:07:10,490 - INFO - Enhanced simulated analysis for ANVS: £288.49 (+0.00%)
# 2025-09-01 13:07:10,503 - INFO - Enhanced simulated analysis for APLM: £405.26 (+0.00%)
# 2025-09-01 13:07:10,515 - INFO - Enhanced simulated analysis for APLT: £470.98 (+0.00%)
# 2025-09-01 13:07:10,521 - INFO - SELL signal for APLT: 3/7 signals
# 2025-09-01 13:07:10,521 - INFO - Simulated SELL order placed: 1 APLT
# 2025-09-01 13:07:10,522 - INFO - SIMULATED SELL: 0 APLT @ £470.98 (Value: £470.98, P&L: £470.98, Balance: £2409.02)
# 2025-09-01 13:07:10,522 - INFO - APLT indicators - RSI: 31.6, MACD: -0.233, Volatility: 0.20%
# 2025-09-01 13:07:10,529 - INFO - Enhanced simulated analysis for APVO: £216.33 (+0.00%)
# 2025-09-01 13:07:10,540 - INFO - Enhanced simulated analysis for ARAY: £301.95 (+0.00%)
# 2025-09-01 13:07:10,552 - INFO - Enhanced simulated analysis for ARBE: £311.27 (+0.00%)
# 2025-09-01 13:07:10,564 - INFO - Enhanced simulated analysis for ATEN: £368.09 (+0.00%)
# 2025-09-01 13:07:10,575 - INFO - Enhanced simulated analysis for ATAI: £419.27 (+0.00%)
# 2025-09-01 13:07:10,587 - INFO - Enhanced simulated analysis for ATHA: £63.63 (+0.00%)
# 2025-09-01 13:07:10,599 - INFO - Enhanced simulated analysis for AUTL: £74.06 (+0.00%)
# 2025-09-01 13:07:10,611 - INFO - Enhanced simulated analysis for AVIR: £470.39 (+0.00%)
# 2025-09-01 13:07:10,622 - INFO - Enhanced simulated analysis for CABA: £145.50 (+0.00%)
# 2025-09-01 13:07:10,634 - INFO - Enhanced simulated analysis for CAMP: £497.76 (+0.00%)
# 2025-09-01 13:07:10,646 - INFO - Enhanced simulated analysis for CARM: £389.34 (+0.00%)
# 2025-09-01 13:07:10,657 - INFO - Enhanced simulated analysis for CATX: £369.68 (+0.00%)
# 2025-09-01 13:07:10,669 - INFO - Enhanced simulated analysis for CCCC: £120.58 (+0.00%)
# 2025-09-01 13:07:10,681 - INFO - Enhanced simulated analysis for CELU: £456.72 (+0.00%)
# 2025-09-01 13:07:10,692 - INFO - Enhanced simulated analysis for CERS: £361.87 (+0.00%)
# 2025-09-01 13:07:10,708 - INFO - Enhanced simulated analysis for CGTX: £284.06 (+0.00%)
# 2025-09-01 13:07:10,720 - INFO - Enhanced simulated analysis for CHRS: £58.28 (+0.00%)
# 2025-09-01 13:07:10,732 - INFO - Enhanced simulated analysis for CLDI: £153.93 (+0.00%)
# 2025-09-01 13:07:10,744 - INFO - Enhanced simulated analysis for CLLS: £84.56 (+0.00%)
# 2025-09-01 13:07:10,756 - INFO - Enhanced simulated analysis for CLRB: £480.95 (+0.00%)
# 2025-09-01 13:07:10,767 - INFO - Enhanced simulated analysis for CLSD: £276.63 (+0.00%)
# 2025-09-01 13:07:10,779 - INFO - Enhanced simulated analysis for CLYM: £310.66 (+0.00%)
# 2025-09-01 13:07:10,790 - INFO - Enhanced simulated analysis for CMPS: £195.65 (+0.00%)
# 2025-09-01 13:07:10,796 - INFO - SELL signal for CMPS: 3/7 signals
# 2025-09-01 13:07:10,797 - INFO - Simulated SELL order placed: 3 CMPS
# 2025-09-01 13:07:10,797 - INFO - SIMULATED SELL: 0 CMPS @ £195.65 (Value: £586.95, P&L: £586.95, Balance: £2995.97)
# 2025-09-01 13:07:10,797 - INFO - CMPS indicators - RSI: 21.9, MACD: -0.361, Volatility: 0.22%
# 2025-09-01 13:07:10,804 - INFO - Enhanced simulated analysis for CMPX: £228.11 (+0.00%)
# 2025-09-01 13:07:10,815 - INFO - Enhanced simulated analysis for CMTL: £321.48 (+0.00%)
# 2025-09-01 13:07:10,827 - INFO - Enhanced simulated analysis for COCP: £418.90 (+0.00%)
# 2025-09-01 13:07:10,839 - INFO - Enhanced simulated analysis for CRBU: £188.19 (+0.00%)
# 2025-09-01 13:07:10,850 - INFO - Enhanced simulated analysis for CRDF: £173.90 (+0.00%)
# 2025-09-01 13:07:10,862 - INFO - Enhanced simulated analysis for CRDL: £312.06 (+0.00%)
# 2025-09-01 13:07:10,873 - INFO - Enhanced simulated analysis for CRIS: £152.21 (+0.00%)
# 2025-09-01 13:07:10,908 - INFO - Enhanced simulated analysis for CTMX: £482.83 (+0.00%)
# 2025-09-01 13:07:10,924 - INFO - Enhanced simulated analysis for CTOR: £269.15 (+0.00%)
# 2025-09-01 13:07:10,930 - INFO - BUY signal for CTOR: 3/7 signals
# 2025-09-01 13:07:10,931 - INFO - Simulated BUY order placed: 1 CTOR
# 2025-09-01 13:07:10,931 - INFO - SIMULATED BUY: 1 CTOR @ £269.15 (Cost: £269.15, Balance: £2726.82)
# 2025-09-01 13:07:10,931 - INFO - CTOR indicators - RSI: 64.5, MACD: 0.626, Volatility: 0.19%
# 2025-09-01 13:07:10,938 - INFO - Enhanced simulated analysis for CTXR: £374.11 (+0.00%)
# 2025-09-01 13:07:10,950 - INFO - Enhanced simulated analysis for CUE: £200.59 (+0.00%)
# 2025-09-01 13:07:10,956 - INFO - SELL signal for CUE: 3/7 signals
# 2025-09-01 13:07:10,957 - INFO - Simulated SELL order placed: 2 CUE
# 2025-09-01 13:07:10,957 - INFO - SIMULATED SELL: 0 CUE @ £200.59 (Value: £401.18, P&L: £401.18, Balance: £3128.00)
# 2025-09-01 13:07:10,957 - INFO - CUE indicators - RSI: 37.5, MACD: -0.120, Volatility: 0.20%
# 2025-09-01 13:07:10,964 - INFO - Enhanced simulated analysis for CURR: £104.61 (+0.00%)
# 2025-09-01 13:07:10,976 - INFO - Enhanced simulated analysis for DARE: £450.21 (+0.00%)
# 2025-09-01 13:07:10,988 - INFO - Enhanced simulated analysis for DTIL: £427.57 (+0.00%)
# 2025-09-01 13:07:10,994 - INFO - BUY signal for DTIL: 3/7 signals
# 2025-09-01 13:07:10,994 - INFO - Simulated BUY order placed: 1 DTIL
# 2025-09-01 13:07:10,995 - INFO - SIMULATED BUY: 1 DTIL @ £427.57 (Cost: £427.57, Balance: £2700.43)
# 2025-09-01 13:07:10,995 - INFO - DTIL indicators - RSI: 69.9, MACD: 1.098, Volatility: 0.17%
# 2025-09-01 13:07:11,002 - INFO - Enhanced simulated analysis for EDIT: £460.72 (+0.00%)
# 2025-09-01 13:07:11,013 - INFO - Enhanced simulated analysis for ELDN: £456.52 (+0.00%)
# 2025-09-01 13:07:11,020 - INFO - BUY signal for ELDN: 3/7 signals
# 2025-09-01 13:07:11,020 - INFO - Simulated BUY order placed: 1 ELDN
# 2025-09-01 13:07:11,020 - INFO - SIMULATED BUY: 1 ELDN @ £456.52 (Cost: £456.52, Balance: £2243.91)
# 2025-09-01 13:07:11,020 - INFO - ELDN indicators - RSI: 55.1, MACD: -0.561, Volatility: 0.18%
# 2025-09-01 13:07:11,027 - INFO - Enhanced simulated analysis for EQ: £251.44 (+0.00%)
# 2025-09-01 13:07:11,033 - INFO - BUY signal for EQ: 3/7 signals
# 2025-09-01 13:07:11,033 - INFO - Simulated BUY order placed: 1 EQ
# 2025-09-01 13:07:11,034 - INFO - SIMULATED BUY: 1 EQ @ £251.44 (Cost: £251.44, Balance: £1992.47)
# 2025-09-01 13:07:11,034 - INFO - EQ indicators - RSI: 65.7, MACD: 1.210, Volatility: 0.18%
# 2025-09-01 13:07:11,041 - INFO - Enhanced simulated analysis for ERAS: £82.41 (+0.00%)
# 2025-09-01 13:07:11,052 - INFO - Enhanced simulated analysis for ERNA: £446.99 (+0.00%)
# 2025-09-01 13:07:11,064 - INFO - Enhanced simulated analysis for ESLA: £362.15 (+0.00%)
# 2025-09-01 13:07:11,076 - INFO - Enhanced simulated analysis for ESPR: £96.64 (+0.00%)
# 2025-09-01 13:07:11,088 - INFO - Enhanced simulated analysis for EVGN: £181.06 (+0.00%)
# 2025-09-01 13:07:11,099 - INFO - Enhanced simulated analysis for FATE: £451.27 (+0.00%)
# 2025-09-01 13:07:11,111 - INFO - Enhanced simulated analysis for FBLG: £440.86 (+0.00%)
# 2025-09-01 13:07:11,117 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 13:07:11,117 - INFO - Performance - Total Trades: 7, Win Rate: 57.1%, Total P&L: £-12.03
# 2025-09-01 13:07:11,118 - INFO - Market Overview - Active Positions: 17, Symbols Tracked: 54
# 2025-09-01 13:08:11,125 - INFO - --- Cycle 6 ---
# 2025-09-01 13:08:11,188 - INFO - Enhanced simulated analysis for ABCL: £185.93 (+0.00%)
# 2025-09-01 13:08:11,210 - INFO - Enhanced simulated analysis for ALLO: £479.66 (+0.00%)
# 2025-09-01 13:08:11,221 - INFO - BUY signal for ALLO: 3/7 signals
# 2025-09-01 13:08:11,222 - INFO - Simulated BUY order placed: 1 ALLO
# 2025-09-01 13:08:11,222 - INFO - SIMULATED BUY: 1 ALLO @ £479.66 (Cost: £479.66, Balance: £1512.81)
# 2025-09-01 13:08:11,223 - INFO - ALLO indicators - RSI: 77.6, MACD: 1.603, Volatility: 0.21%
# 2025-09-01 13:08:11,232 - INFO - Enhanced simulated analysis for ANNX: £435.45 (+0.00%)
# 2025-09-01 13:08:11,249 - INFO - Enhanced simulated analysis for ANRO: £297.08 (+0.00%)
# 2025-09-01 13:08:11,263 - INFO - Enhanced simulated analysis for ANVS: £290.17 (+0.00%)
# 2025-09-01 13:08:11,277 - INFO - Enhanced simulated analysis for APLM: £407.67 (+0.00%)
# 2025-09-01 13:08:11,290 - INFO - Enhanced simulated analysis for APLT: £477.55 (+0.00%)
# 2025-09-01 13:08:11,302 - INFO - Enhanced simulated analysis for APVO: £214.56 (+0.00%)
# 2025-09-01 13:08:11,314 - INFO - Enhanced simulated analysis for ARAY: £303.78 (+0.00%)
# 2025-09-01 13:08:11,328 - INFO - Enhanced simulated analysis for ARBE: £310.36 (+0.00%)
# 2025-09-01 13:08:11,340 - INFO - Enhanced simulated analysis for ATEN: £368.71 (+0.00%)
# 2025-09-01 13:08:11,352 - INFO - Enhanced simulated analysis for ATAI: £418.10 (+0.00%)
# 2025-09-01 13:08:11,363 - INFO - Enhanced simulated analysis for ATHA: £63.24 (+0.00%)
# 2025-09-01 13:08:11,375 - INFO - Enhanced simulated analysis for AUTL: £73.92 (+0.00%)
# 2025-09-01 13:08:11,387 - INFO - Enhanced simulated analysis for AVIR: £468.41 (+0.00%)
# 2025-09-01 13:08:11,399 - INFO - Enhanced simulated analysis for CABA: £145.95 (+0.00%)
# 2025-09-01 13:08:11,411 - INFO - Enhanced simulated analysis for CAMP: £492.22 (+0.00%)
# 2025-09-01 13:08:11,422 - INFO - Enhanced simulated analysis for CARM: £389.84 (+0.00%)
# 2025-09-01 13:08:11,434 - INFO - Enhanced simulated analysis for CATX: £370.35 (+0.00%)
# 2025-09-01 13:08:11,445 - INFO - Enhanced simulated analysis for CCCC: £120.80 (+0.00%)
# 2025-09-01 13:08:11,457 - INFO - Enhanced simulated analysis for CELU: £453.82 (+0.00%)
# 2025-09-01 13:08:11,468 - INFO - Enhanced simulated analysis for CERS: £362.77 (+0.00%)
# 2025-09-01 13:08:11,484 - INFO - Enhanced simulated analysis for CGTX: £286.70 (+0.00%)
# 2025-09-01 13:08:11,496 - INFO - Enhanced simulated analysis for CHRS: £58.47 (+0.00%)
# 2025-09-01 13:08:11,508 - INFO - Enhanced simulated analysis for CLDI: £154.30 (+0.00%)
# 2025-09-01 13:08:11,519 - INFO - Enhanced simulated analysis for CLLS: £83.76 (+0.00%)
# 2025-09-01 13:08:11,531 - INFO - Enhanced simulated analysis for CLRB: £487.66 (+0.00%)
# 2025-09-01 13:08:11,542 - INFO - Enhanced simulated analysis for CLSD: £273.61 (+0.00%)
# 2025-09-01 13:08:11,554 - INFO - Enhanced simulated analysis for CLYM: £310.16 (+0.00%)
# 2025-09-01 13:08:11,566 - INFO - Enhanced simulated analysis for CMPS: £196.08 (+0.00%)
# 2025-09-01 13:08:11,577 - INFO - Enhanced simulated analysis for CMPX: £227.80 (+0.00%)
# 2025-09-01 13:08:11,589 - INFO - Enhanced simulated analysis for CMTL: £317.00 (+0.00%)
# 2025-09-01 13:08:11,601 - INFO - Enhanced simulated analysis for COCP: £419.88 (+0.00%)
# 2025-09-01 13:08:11,633 - INFO - Enhanced simulated analysis for CRBU: £188.40 (+0.00%)
# 2025-09-01 13:08:11,649 - INFO - Enhanced simulated analysis for CRDF: £173.61 (+0.00%)
# 2025-09-01 13:08:11,661 - INFO - Enhanced simulated analysis for CRDL: £313.66 (+0.00%)
# 2025-09-01 13:08:11,672 - INFO - Enhanced simulated analysis for CRIS: £152.43 (+0.00%)
# 2025-09-01 13:08:11,684 - INFO - Enhanced simulated analysis for CTMX: £483.46 (+0.00%)
# 2025-09-01 13:08:11,696 - INFO - Enhanced simulated analysis for CTOR: £268.97 (+0.00%)
# 2025-09-01 13:08:11,707 - INFO - Enhanced simulated analysis for CTXR: £371.42 (+0.00%)
# 2025-09-01 13:08:11,718 - INFO - Enhanced simulated analysis for CUE: £201.33 (+0.00%)
# 2025-09-01 13:08:11,730 - INFO - Enhanced simulated analysis for CURR: £104.76 (+0.00%)
# 2025-09-01 13:08:11,741 - INFO - Enhanced simulated analysis for DARE: £446.47 (+0.00%)
# 2025-09-01 13:08:11,753 - INFO - Enhanced simulated analysis for DTIL: £423.64 (+0.00%)
# 2025-09-01 13:08:11,764 - INFO - Enhanced simulated analysis for EDIT: £465.09 (+0.00%)
# 2025-09-01 13:08:11,776 - INFO - Enhanced simulated analysis for ELDN: £457.31 (+0.00%)
# 2025-09-01 13:08:11,787 - INFO - Enhanced simulated analysis for EQ: £251.15 (+0.00%)
# 2025-09-01 13:08:11,799 - INFO - Enhanced simulated analysis for ERAS: £83.23 (+0.00%)
# 2025-09-01 13:08:11,810 - INFO - Enhanced simulated analysis for ERNA: £445.47 (+0.00%)
# 2025-09-01 13:08:11,822 - INFO - Enhanced simulated analysis for ESLA: £361.24 (+0.00%)
# 2025-09-01 13:08:11,828 - INFO - BUY signal for ESLA: 3/7 signals
# 2025-09-01 13:08:11,828 - INFO - Simulated BUY order placed: 1 ESLA
# 2025-09-01 13:08:11,829 - INFO - SIMULATED BUY: 1 ESLA @ £361.24 (Cost: £361.24, Balance: £1151.57)
# 2025-09-01 13:08:11,829 - INFO - ESLA indicators - RSI: 51.3, MACD: 0.251, Volatility: 0.16%
# 2025-09-01 13:08:11,835 - INFO - Enhanced simulated analysis for ESPR: £95.69 (+0.00%)
# 2025-09-01 13:08:11,847 - INFO - Enhanced simulated analysis for EVGN: £180.95 (+0.00%)
# 2025-09-01 13:08:11,859 - INFO - Enhanced simulated analysis for FATE: £448.76 (+0.00%)
# 2025-09-01 13:08:11,870 - INFO - Enhanced simulated analysis for FBLG: £444.24 (+0.00%)
# 2025-09-01 13:08:11,876 - INFO - Cycle completed: 2 trades executed
# 2025-09-01 13:08:11,877 - INFO - Performance - Total Trades: 7, Win Rate: 57.1%, Total P&L: £-12.03
# 2025-09-01 13:09:11,881 - INFO - --- Cycle 7 ---
# 2025-09-01 13:09:11,901 - INFO - Enhanced simulated analysis for ABCL: £185.06 (+0.00%)
# 2025-09-01 13:09:11,910 - INFO - BUY signal for ABCL: 3/7 signals
# 2025-09-01 13:09:11,911 - INFO - Simulated BUY order placed: 1 ABCL
# 2025-09-01 13:09:11,911 - INFO - SIMULATED BUY: 1 ABCL @ £185.06 (Cost: £185.06, Balance: £966.51)
# 2025-09-01 13:09:11,911 - INFO - ABCL indicators - RSI: 68.8, MACD: 1.230, Volatility: 0.20%
# 2025-09-01 13:09:11,921 - INFO - Enhanced simulated analysis for ALLO: £474.17 (+0.00%)
# 2025-09-01 13:09:11,936 - INFO - Enhanced simulated analysis for ANNX: £435.92 (+0.00%)
# 2025-09-01 13:09:11,951 - INFO - Enhanced simulated analysis for ANRO: £298.07 (+0.00%)
# 2025-09-01 13:09:11,964 - INFO - Enhanced simulated analysis for ANVS: £289.46 (+0.00%)
# 2025-09-01 13:09:11,982 - INFO - Enhanced simulated analysis for APLM: £404.81 (+0.00%)
# 2025-09-01 13:09:11,997 - INFO - Enhanced simulated analysis for APLT: £474.25 (+0.00%)
# 2025-09-01 13:09:12,012 - INFO - Enhanced simulated analysis for APVO: £215.07 (+0.00%)
# 2025-09-01 13:09:12,025 - INFO - Enhanced simulated analysis for ARAY: £302.44 (+0.00%)
# 2025-09-01 13:09:12,037 - INFO - Enhanced simulated analysis for ARBE: £309.40 (+0.00%)
# 2025-09-01 13:09:12,043 - INFO - BUY signal for ARBE: 3/7 signals
# 2025-09-01 13:09:12,043 - INFO - Simulated BUY order placed: 1 ARBE
# 2025-09-01 13:09:12,044 - INFO - SIMULATED BUY: 1 ARBE @ £309.40 (Cost: £309.40, Balance: £657.11)
# 2025-09-01 13:09:12,044 - INFO - ARBE indicators - RSI: 83.1, MACD: 4.503, Volatility: 0.18%
# 2025-09-01 13:09:12,051 - INFO - Enhanced simulated analysis for ATEN: £367.66 (+0.00%)
# 2025-09-01 13:09:12,057 - INFO - BUY signal for ATEN: 3/7 signals
# 2025-09-01 13:09:12,058 - INFO - Simulated BUY order placed: 1 ATEN
# 2025-09-01 13:09:12,058 - INFO - SIMULATED BUY: 1 ATEN @ £367.66 (Cost: £367.66, Balance: £289.45)
# 2025-09-01 13:09:12,058 - INFO - ATEN indicators - RSI: 39.7, MACD: 0.684, Volatility: 0.19%
# 2025-09-01 13:09:12,067 - INFO - Enhanced simulated analysis for ATAI: £416.86 (+0.00%)
# 2025-09-01 13:09:12,082 - INFO - Enhanced simulated analysis for ATHA: £63.81 (+0.00%)
# 2025-09-01 13:09:12,099 - INFO - Enhanced simulated analysis for AUTL: £74.17 (+0.00%)
# 2025-09-01 13:09:12,113 - INFO - Enhanced simulated analysis for AVIR: £467.29 (+0.00%)
# 2025-09-01 13:09:12,120 - INFO - SELL signal for AVIR: 3/7 signals
# 2025-09-01 13:09:12,120 - INFO - Simulated SELL order placed: 1 AVIR
# 2025-09-01 13:09:12,120 - INFO - SIMULATED SELL: 0 AVIR @ £467.29 (Value: £467.29, P&L: £467.29, Balance: £756.74)
# 2025-09-01 13:09:12,121 - INFO - AVIR indicators - RSI: 49.5, MACD: 0.743, Volatility: 0.20%
# 2025-09-01 13:09:12,128 - INFO - Enhanced simulated analysis for CABA: £145.60 (+0.00%)
# 2025-09-01 13:09:12,136 - INFO - BUY signal for CABA: 3/7 signals
# 2025-09-01 13:09:12,136 - INFO - Simulated BUY order placed: 1 CABA
# 2025-09-01 13:09:12,136 - INFO - SIMULATED BUY: 1 CABA @ £145.60 (Cost: £145.60, Balance: £611.14)
# 2025-09-01 13:09:12,137 - INFO - CABA indicators - RSI: 46.9, MACD: -0.415, Volatility: 0.28%
# 2025-09-01 13:09:12,143 - INFO - Enhanced simulated analysis for CAMP: £490.58 (+0.00%)
# 2025-09-01 13:09:12,156 - INFO - Enhanced simulated analysis for CARM: £392.38 (+0.00%)
# 2025-09-01 13:09:12,169 - INFO - Enhanced simulated analysis for CATX: £371.26 (+0.00%)
# 2025-09-01 13:09:12,181 - INFO - Enhanced simulated analysis for CCCC: £121.06 (+0.00%)
# 2025-09-01 13:09:12,194 - INFO - Enhanced simulated analysis for CELU: £453.48 (+0.00%)
# 2025-09-01 13:09:12,206 - INFO - Enhanced simulated analysis for CERS: £365.20 (+0.00%)
# 2025-09-01 13:09:12,219 - INFO - Enhanced simulated analysis for CGTX: £286.59 (+0.00%)
# 2025-09-01 13:09:12,225 - INFO - BUY signal for CGTX: 3/7 signals
# 2025-09-01 13:09:12,226 - INFO - Simulated BUY order placed: 1 CGTX
# 2025-09-01 13:09:12,226 - INFO - SIMULATED BUY: 1 CGTX @ £286.59 (Cost: £286.59, Balance: £324.55)
# 2025-09-01 13:09:12,226 - INFO - CGTX indicators - RSI: 41.1, MACD: -3.875, Volatility: 0.18%
# 2025-09-01 13:09:12,233 - INFO - Enhanced simulated analysis for CHRS: £59.26 (+0.00%)
# 2025-09-01 13:09:12,245 - INFO - Enhanced simulated analysis for CLDI: £153.87 (+0.00%)
# 2025-09-01 13:09:12,257 - INFO - Enhanced simulated analysis for CLLS: £84.17 (+0.00%)
# 2025-09-01 13:09:12,269 - INFO - Enhanced simulated analysis for CLRB: £489.90 (+0.00%)
# 2025-09-01 13:09:12,278 - INFO - BUY signal for CLRB: 3/7 signals
# 2025-09-01 13:09:12,285 - INFO - Enhanced simulated analysis for CLSD: £274.62 (+0.00%)
# 2025-09-01 13:09:12,297 - INFO - Enhanced simulated analysis for CLYM: £308.61 (+0.00%)
# 2025-09-01 13:09:12,304 - INFO - BUY signal for CLYM: 3/7 signals
# 2025-09-01 13:09:12,304 - INFO - Simulated BUY order placed: 1 CLYM
# 2025-09-01 13:09:12,304 - INFO - SIMULATED BUY: 1 CLYM @ £308.61 (Cost: £308.61, Balance: £15.94)
# 2025-09-01 13:09:12,305 - INFO - CLYM indicators - RSI: 55.5, MACD: 0.320, Volatility: 0.19%
# ...
# 2025-09-01 13:22:21,534 - INFO - Enhanced simulated analysis for CARM: £378.73 (+0.00%)
# 2025-09-01 13:22:21,546 - INFO - Enhanced simulated analysis for CATX: £369.19 (+0.00%)
# 2025-09-01 13:22:21,558 - INFO - Enhanced simulated analysis for CCCC: £124.36 (+0.00%)
# 2025-09-01 13:22:21,569 - INFO - Enhanced simulated analysis for CELU: £462.98 (+0.00%)
# 2025-09-01 13:22:21,581 - INFO - Enhanced simulated analysis for CERS: £378.39 (+0.00%)
# 2025-09-01 13:22:21,593 - INFO - Enhanced simulated analysis for CGTX: £281.90 (+0.00%)
# 2025-09-01 13:22:21,604 - INFO - Enhanced simulated analysis for CHRS: £57.34 (+0.00%)
# 2025-09-01 13:22:21,616 - INFO - Enhanced simulated analysis for CLDI: £152.73 (+0.00%)
# 2025-09-01 13:22:21,627 - INFO - Enhanced simulated analysis for CLLS: £82.13 (+0.00%)
# 2025-09-01 13:22:21,639 - INFO - Enhanced simulated analysis for CLRB: £479.98 (+0.00%)
# 2025-09-01 13:22:21,651 - INFO - Enhanced simulated analysis for CLSD: £280.58 (+0.00%)
# 2025-09-01 13:22:21,662 - INFO - Enhanced simulated analysis for CLYM: £327.35 (+0.00%)
# 2025-09-01 13:22:21,674 - INFO - Enhanced simulated analysis for CMPS: £201.10 (+0.00%)
# 2025-09-01 13:22:21,685 - INFO - Enhanced simulated analysis for CMPX: £234.33 (+0.00%)
# 2025-09-01 13:22:21,696 - INFO - Enhanced simulated analysis for CMTL: £314.24 (+0.00%)
# 2025-09-01 13:22:21,708 - INFO - Enhanced simulated analysis for COCP: £425.57 (+0.00%)
# 2025-09-01 13:22:21,720 - INFO - Enhanced simulated analysis for CRBU: £183.07 (+0.00%)
# 2025-09-01 13:22:21,732 - INFO - Enhanced simulated analysis for CRDF: £175.71 (+0.00%)
# 2025-09-01 13:22:21,744 - INFO - Enhanced simulated analysis for CRDL: £316.52 (+0.00%)
# 2025-09-01 13:22:21,755 - INFO - Enhanced simulated analysis for CRIS: £152.45 (+0.00%)
# 2025-09-01 13:22:21,771 - INFO - Enhanced simulated analysis for CTMX: £507.51 (+0.00%)
# 2025-09-01 13:22:21,782 - INFO - Enhanced simulated analysis for CTOR: £273.67 (+0.00%)
# 2025-09-01 13:22:21,793 - INFO - Enhanced simulated analysis for CTXR: £373.71 (+0.00%)
# 2025-09-01 13:22:21,805 - INFO - Enhanced simulated analysis for CUE: £201.66 (+0.00%)
# 2025-09-01 13:22:21,817 - INFO - Enhanced simulated analysis for CURR: £106.51 (+0.00%)
# 2025-09-01 13:22:21,828 - INFO - Enhanced simulated analysis for DARE: £424.85 (+0.00%)
# 2025-09-01 13:22:21,840 - INFO - Enhanced simulated analysis for DTIL: £430.09 (+0.00%)
# 2025-09-01 13:22:21,852 - INFO - Enhanced simulated analysis for EDIT: £470.52 (+0.00%)
# 2025-09-01 13:22:21,863 - INFO - Enhanced simulated analysis for ELDN: £449.96 (+0.00%)
# 2025-09-01 13:22:21,896 - INFO - Enhanced simulated analysis for EQ: £255.76 (+0.00%)
# 2025-09-01 13:22:21,912 - INFO - Enhanced simulated analysis for ERAS: £86.19 (+0.00%)
# 2025-09-01 13:22:21,924 - INFO - Enhanced simulated analysis for ERNA: £453.31 (+0.00%)
# 2025-09-01 13:22:21,936 - INFO - Enhanced simulated analysis for ESLA: £346.49 (+0.00%)
# 2025-09-01 13:22:21,948 - INFO - Enhanced simulated analysis for ESPR: £95.53 (+0.00%)
# 2025-09-01 13:22:21,959 - INFO - Enhanced simulated analysis for EVGN: £181.82 (+0.00%)
# 2025-09-01 13:22:21,971 - INFO - Enhanced simulated analysis for FATE: £450.44 (+0.00%)
# 2025-09-01 13:22:21,983 - INFO - Enhanced simulated analysis for FBLG: £428.43 (+0.00%)
# 2025-09-01 13:22:21,990 - INFO - Cycle completed: 1 trades executed
# 2025-09-01 13:22:21,990 - INFO - Performance - Total Trades: 15, Win Rate: 46.7%, Total P&L: £-84.11
# 2025-09-01 13:22:21,991 - INFO - Market Overview - Active Positions: 32, Symbols Tracked: 54
# 2025-09-01 13:23:21,996 - INFO - Reached maximum cycles (20)
# 2025-09-01 13:23:22,000 - INFO - ==================================================
# 2025-09-01 13:23:22,001 - INFO - ENHANCED TRADING SESSION SUMMARY
# 2025-09-01 13:23:22,002 - INFO - ==================================================
# 2025-09-01 13:23:22,003 - INFO - Environment: SIMULATOR
# 2025-09-01 13:23:22,004 - INFO - Duration: 0:20:14.394504
# 2025-09-01 13:23:22,006 - INFO - Total trades executed: 62
# 2025-09-01 13:23:22,007 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:23:22,008 - INFO - Win Rate: 46.7%
# 2025-09-01 13:23:22,009 - INFO - Total P&L: £-84.11
# 2025-09-01 13:23:22,009 - INFO - Profitable Trades: 7/15
# 2025-09-01 13:23:22,010 - INFO - Current Positions:
# 2025-09-01 13:23:22,011 - INFO -   ALLO: No position
# 2025-09-01 13:23:22,011 - INFO -   APLM: No position
# 2025-09-01 13:23:22,012 - INFO -   ARAY: No position
# 2025-09-01 13:23:22,013 - INFO -   CCCC: No position
# 2025-09-01 13:23:22,035 - INFO - Enhanced simulated analysis for CLDI: £153.01 (+0.00%)
# 2025-09-01 13:23:22,036 - INFO -   CLDI: 1 shares @ £148.68 (Current: £153.01, P&L: £+4.33 +2.9%)
# 2025-09-01 13:23:22,046 - INFO - Enhanced simulated analysis for CRDL: £316.17 (+0.00%)
# 2025-09-01 13:23:22,046 - INFO -   CRDL: 2 shares @ £310.40 (Current: £316.17, P&L: £+11.54 +1.9%)
# 2025-09-01 13:23:22,056 - INFO - Enhanced simulated analysis for CTMX: £496.19 (+0.00%)
# 2025-09-01 13:23:22,057 - INFO -   CTMX: 1 shares @ £480.38 (Current: £496.19, P&L: £+15.81 +3.3%)
# 2025-09-01 13:23:22,057 - INFO -   ATAI: No position
# 2025-09-01 13:23:22,066 - INFO - Enhanced simulated analysis for CMTL: £311.68 (+0.00%)
# 2025-09-01 13:23:22,067 - INFO -   CMTL: 1 shares @ £324.05 (Current: £311.68, P&L: £-12.37 -3.8%)
# 2025-09-01 13:23:22,075 - INFO - Enhanced simulated analysis for ANVS: £278.72 (+0.00%)
# 2025-09-01 13:23:22,075 - INFO -   ANVS: 2 shares @ £286.36 (Current: £278.72, P&L: £-15.28 -2.7%)
# 2025-09-01 13:23:22,083 - INFO - Enhanced simulated analysis for CLRB: £478.79 (+0.00%)
# 2025-09-01 13:23:22,083 - INFO -   CLRB: 1 shares @ £489.85 (Current: £478.79, P&L: £-11.06 -2.3%)
# 2025-09-01 13:23:22,090 - INFO - Enhanced simulated analysis for CMPS: £202.43 (+0.00%)
# 2025-09-01 13:23:22,090 - INFO -   CMPS: 1 shares @ £202.62 (Current: £202.43, P&L: £-0.19 -0.1%)
# 2025-09-01 13:23:22,090 - INFO -   CUE: No position
# 2025-09-01 13:23:22,098 - INFO - Enhanced simulated analysis for CURR: £107.57 (+0.00%)
# 2025-09-01 13:23:22,098 - INFO -   CURR: 4 shares @ £105.39 (Current: £107.57, P&L: £+8.72 +2.1%)
# 2025-09-01 13:23:22,105 - INFO - Enhanced simulated analysis for APLT: £462.43 (+0.00%)
# 2025-09-01 13:23:22,105 - INFO -   APLT: 1 shares @ £460.17 (Current: £462.43, P&L: £+2.26 +0.5%)
# 2025-09-01 13:23:22,105 - INFO -   AVIR: No position
# 2025-09-01 13:23:22,112 - INFO - Enhanced simulated analysis for CELU: £464.80 (+0.00%)
# 2025-09-01 13:23:22,113 - INFO -   CELU: 1 shares @ £459.36 (Current: £464.80, P&L: £+5.44 +1.2%)
# 2025-09-01 13:23:22,119 - INFO - Enhanced simulated analysis for CRBU: £183.34 (+0.00%)
# 2025-09-01 13:23:22,120 - INFO -   CRBU: 1 shares @ £188.08 (Current: £183.34, P&L: £-4.74 -2.5%)
# 2025-09-01 13:23:22,120 - INFO -   DARE: No position
# 2025-09-01 13:23:22,127 - INFO - Enhanced simulated analysis for ERAS: £85.86 (+0.00%)
# 2025-09-01 13:23:22,127 - INFO -   ERAS: 3 shares @ £83.18 (Current: £85.86, P&L: £+8.04 +3.2%)
# 2025-09-01 13:23:22,134 - INFO - Enhanced simulated analysis for CTOR: £275.19 (+0.00%)
# 2025-09-01 13:23:22,135 - INFO -   CTOR: 1 shares @ £269.15 (Current: £275.19, P&L: £+6.04 +2.2%)
# 2025-09-01 13:23:22,141 - INFO - Enhanced simulated analysis for DTIL: £431.62 (+0.00%)
# 2025-09-01 13:23:22,141 - INFO -   DTIL: 1 shares @ £427.57 (Current: £431.62, P&L: £+4.05 +0.9%)
# 2025-09-01 13:23:22,148 - INFO - Enhanced simulated analysis for ELDN: £446.71 (+0.00%)
# 2025-09-01 13:23:22,149 - INFO -   ELDN: 1 shares @ £456.52 (Current: £446.71, P&L: £-9.81 -2.1%)
# 2025-09-01 13:23:22,149 - INFO -   EQ: No position
# 2025-09-01 13:23:22,156 - INFO - Enhanced simulated analysis for ESLA: £346.61 (+0.00%)
# 2025-09-01 13:23:22,156 - INFO -   ESLA: 1 shares @ £361.24 (Current: £346.61, P&L: £-14.63 -4.0%)
# 2025-09-01 13:23:22,162 - INFO - Enhanced simulated analysis for ABCL: £170.58 (+0.00%)
# 2025-09-01 13:23:22,163 - INFO -   ABCL: 1 shares @ £172.61 (Current: £170.58, P&L: £-2.03 -1.2%)
# 2025-09-01 13:23:22,170 - INFO - Enhanced simulated analysis for ARBE: £317.58 (+0.00%)
# 2025-09-01 13:23:22,170 - INFO -   ARBE: 1 shares @ £309.40 (Current: £317.58, P&L: £+8.18 +2.6%)
# 2025-09-01 13:23:22,176 - INFO - Enhanced simulated analysis for ATEN: £381.32 (+0.00%)
# 2025-09-01 13:23:22,177 - INFO -   ATEN: 1 shares @ £367.66 (Current: £381.32, P&L: £+13.66 +3.7%)
# 2025-09-01 13:23:22,184 - INFO - Enhanced simulated analysis for CABA: £146.26 (+0.00%)
# 2025-09-01 13:23:22,184 - INFO -   CABA: 1 shares @ £145.60 (Current: £146.26, P&L: £+0.66 +0.5%)
# 2025-09-01 13:23:22,190 - INFO - Enhanced simulated analysis for CGTX: £282.64 (+0.00%)
# 2025-09-01 13:23:22,191 - INFO -   CGTX: 1 shares @ £286.59 (Current: £282.64, P&L: £-3.95 -1.4%)
# 2025-09-01 13:23:22,219 - INFO - Enhanced simulated analysis for CLYM: £327.55 (+0.00%)
# 2025-09-01 13:23:22,219 - INFO -   CLYM: 1 shares @ £308.61 (Current: £327.55, P&L: £+18.94 +6.1%)
# 2025-09-01 13:23:22,230 - INFO - Enhanced simulated analysis for CHRS: £57.33 (+0.00%)
# 2025-09-01 13:23:22,231 - INFO -   CHRS: 1 shares @ £59.04 (Current: £57.33, P&L: £-1.71 -2.9%)
# 2025-09-01 13:23:22,240 - INFO - Enhanced simulated analysis for CRDF: £174.62 (+0.00%)
# 2025-09-01 13:23:22,241 - INFO -   CRDF: 1 shares @ £175.50 (Current: £174.62, P&L: £-0.88 -0.5%)
# 2025-09-01 13:23:22,248 - INFO - Enhanced simulated analysis for CLLS: £81.55 (+0.00%)
# 2025-09-01 13:23:22,249 - INFO -   CLLS: 1 shares @ £82.42 (Current: £81.55, P&L: £-0.87 -1.1%)
# 2025-09-01 13:23:22,255 - INFO - Enhanced simulated analysis for CMPX: £233.14 (+0.00%)
# 2025-09-01 13:23:22,256 - INFO -   CMPX: 1 shares @ £229.99 (Current: £233.14, P&L: £+3.15 +1.4%)
# 2025-09-01 13:23:22,262 - INFO - Enhanced simulated analysis for EDIT: £470.69 (+0.00%)
# 2025-09-01 13:23:22,262 - INFO -   EDIT: 1 shares @ £459.05 (Current: £470.69, P&L: £+11.64 +2.5%)
# 2025-09-01 13:23:22,269 - INFO - Enhanced simulated analysis for ATHA: £63.46 (+0.00%)
# 2025-09-01 13:23:22,270 - INFO -   ATHA: 1 shares @ £64.35 (Current: £63.46, P&L: £-0.89 -1.4%)
# 2025-09-01 13:23:22,276 - INFO - Enhanced simulated analysis for ANRO: £293.12 (+0.00%)
# 2025-09-01 13:23:22,276 - INFO -   ANRO: 1 shares @ £292.95 (Current: £293.12, P&L: £+0.17 +0.1%)
# 2025-09-01 13:23:22,283 - INFO - Enhanced simulated analysis for CRIS: £151.91 (+0.00%)
# 2025-09-01 13:23:22,283 - INFO -   CRIS: 1 shares @ £151.99 (Current: £151.91, P&L: £-0.08 -0.1%)
# 2025-09-01 13:23:22,290 - INFO - Enhanced simulated analysis for ESPR: £96.22 (+0.00%)
# 2025-09-01 13:23:22,290 - INFO -   ESPR: 1 shares @ £93.06 (Current: £96.22, P&L: £+3.16 +3.4%)
# 2025-09-01 13:23:22,297 - INFO - Enhanced simulated analysis for CTXR: £375.02 (+0.00%)
# 2025-09-01 13:23:22,297 - INFO -   CTXR: 1 shares @ £379.35 (Current: £375.02, P&L: £-4.33 -1.1%)
# 2025-09-01 13:23:22,297 - INFO - Total Position Value: £9710.46
# 2025-09-01 13:23:22,298 - INFO - Technical Indicators Summary:
# 2025-09-01 13:23:22,298 - INFO -   ABCL: RSI: 44.0, MACD: -1.215, Vol: 0.2%
# 2025-09-01 13:23:22,299 - INFO -   ALLO: RSI: 50.0, MACD: 3.438, Vol: 0.2%
# 2025-09-01 13:23:22,299 - INFO -   ANNX: RSI: 42.2, MACD: -0.780, Vol: 0.2%
# 2025-09-01 13:23:22,300 - INFO -   ANRO: RSI: 67.4, MACD: 19.406, Vol: 0.2%
# 2025-09-01 13:23:22,300 - INFO -   ANVS: RSI: 50.3, MACD: 20.423, Vol: 0.2%
# 2025-09-01 13:23:22,301 - INFO -   APLM: RSI: 37.1, MACD: -4.601, Vol: 0.2%
# 2025-09-01 13:23:22,301 - INFO -   APLT: RSI: 26.2, MACD: -7.097, Vol: 0.2%
# 2025-09-01 13:23:22,302 - INFO -   APVO: RSI: 44.9, MACD: -0.419, Vol: 0.2%
# 2025-09-01 13:23:22,302 - INFO -   ARAY: RSI: 23.7, MACD: -1.507, Vol: 0.2%
# 2025-09-01 13:23:22,302 - INFO -   ARBE: RSI: 61.9, MACD: 15.711, Vol: 0.2%
# 2025-09-01 13:23:22,303 - INFO -   ATEN: RSI: 40.3, MACD: -0.226, Vol: 0.2%
# 2025-09-01 13:23:22,303 - INFO -   ATAI: RSI: 45.7, MACD: 5.970, Vol: 0.2%
# 2025-09-01 13:23:22,304 - INFO -   ATHA: RSI: 52.9, MACD: -0.796, Vol: 0.2%
# 2025-09-01 13:23:22,304 - INFO -   AUTL: RSI: 63.3, MACD: 8.963, Vol: 0.2%
# 2025-09-01 13:23:22,304 - INFO -   AVIR: RSI: 37.3, MACD: 0.845, Vol: 0.2%
# 2025-09-01 13:23:22,305 - INFO -   CABA: RSI: 43.0, MACD: 3.368, Vol: 0.3%
# 2025-09-01 13:23:22,305 - INFO -   CAMP: RSI: 58.5, MACD: 2.976, Vol: 0.2%
# 2025-09-01 13:23:22,305 - INFO -   CARM: RSI: 46.0, MACD: 1.345, Vol: 0.2%
# 2025-09-01 13:23:22,306 - INFO -   CATX: RSI: 12.2, MACD: -3.967, Vol: 0.2%
# 2025-09-01 13:23:22,306 - INFO -   CCCC: RSI: 53.7, MACD: 17.243, Vol: 0.2%
# 2025-09-01 13:23:22,307 - INFO -   CELU: RSI: 57.6, MACD: -2.949, Vol: 0.2%
# 2025-09-01 13:23:22,308 - INFO -   CERS: RSI: 68.2, MACD: 2.871, Vol: 0.2%
# 2025-09-01 13:23:22,309 - INFO -   CGTX: RSI: 60.5, MACD: 10.736, Vol: 0.2%
# 2025-09-01 13:23:22,310 - INFO -   CHRS: RSI: 54.8, MACD: 2.047, Vol: 0.2%
# 2025-09-01 13:23:22,310 - INFO -   CLDI: RSI: 65.8, MACD: 4.422, Vol: 0.2%
# 2025-09-01 13:23:22,311 - INFO -   CLLS: RSI: 37.7, MACD: -33.882, Vol: 0.2%
# 2025-09-01 13:23:22,311 - INFO -   CLRB: RSI: 57.3, MACD: -2.675, Vol: 0.2%
# 2025-09-01 13:23:22,312 - INFO -   CLSD: RSI: 59.7, MACD: 10.222, Vol: 0.2%
# 2025-09-01 13:23:22,312 - INFO -   CLYM: RSI: 44.3, MACD: 2.949, Vol: 0.2%
# 2025-09-01 13:23:22,313 - INFO -   CMPS: RSI: 50.6, MACD: -3.897, Vol: 0.2%
# 2025-09-01 13:23:22,321 - INFO -   CMPX: RSI: 71.7, MACD: 12.761, Vol: 0.3%
# 2025-09-01 13:23:22,341 - INFO -   CMTL: RSI: 44.9, MACD: 17.446, Vol: 0.2%
# 2025-09-01 13:23:22,343 - INFO -   COCP: RSI: 34.0, MACD: -1.192, Vol: 0.2%
# 2025-09-01 13:23:22,344 - INFO -   CRBU: RSI: 60.7, MACD: -0.140, Vol: 0.2%
# 2025-09-01 13:23:22,347 - INFO -   CRDF: RSI: 64.8, MACD: 20.379, Vol: 0.2%
# 2025-09-01 13:23:22,348 - INFO -   CRDL: RSI: 38.4, MACD: -12.712, Vol: 0.2%
# 2025-09-01 13:23:22,349 - INFO -   CRIS: RSI: 70.1, MACD: 2.646, Vol: 0.2%
# 2025-09-01 13:23:22,349 - INFO -   CTMX: RSI: 42.8, MACD: -5.316, Vol: 0.2%
# 2025-09-01 13:23:22,349 - INFO -   CTOR: RSI: 61.3, MACD: -5.359, Vol: 0.2%
# 2025-09-01 13:23:22,349 - INFO -   CTXR: RSI: 47.6, MACD: -3.942, Vol: 0.2%
# 2025-09-01 13:23:22,350 - INFO -   CUE: RSI: 33.5, MACD: 1.916, Vol: 0.2%
# 2025-09-01 13:23:22,350 - INFO -   CURR: RSI: 59.0, MACD: 2.247, Vol: 0.2%
# 2025-09-01 13:23:22,351 - INFO -   DARE: RSI: 21.5, MACD: -9.186, Vol: 0.3%
# 2025-09-01 13:23:22,351 - INFO -   DTIL: RSI: 44.5, MACD: -12.479, Vol: 0.2%
# 2025-09-01 13:23:22,360 - INFO -   EDIT: RSI: 70.8, MACD: 9.031, Vol: 0.2%
# 2025-09-01 13:23:22,361 - INFO -   ELDN: RSI: 69.3, MACD: 17.153, Vol: 0.2%
# 2025-09-01 13:23:22,362 - INFO -   EQ: RSI: 68.0, MACD: -4.063, Vol: 0.2%
# 2025-09-01 13:23:22,362 - INFO -   ERAS: RSI: 24.0, MACD: -13.180, Vol: 0.2%
# 2025-09-01 13:23:22,363 - INFO -   ERNA: RSI: 54.5, MACD: 1.095, Vol: 0.2%
# 2025-09-01 13:23:22,364 - INFO -   ESLA: RSI: 78.6, MACD: 3.199, Vol: 0.1%
# 2025-09-01 13:23:22,365 - INFO -   ESPR: RSI: 96.4, MACD: 8.422, Vol: 0.2%
# 2025-09-01 13:23:22,366 - INFO -   EVGN: RSI: 47.9, MACD: 3.582, Vol: 0.2%
# 2025-09-01 13:23:22,366 - INFO -   FATE: RSI: 55.6, MACD: 1.072, Vol: 0.2%
# 2025-09-01 13:23:22,366 - INFO -   FBLG: RSI: 58.9, MACD: -0.596, Vol: 0.1%
# 2025-09-01 13:23:22,367 - INFO - ==================================================
# 2025-09-01 13:23:22,368 - INFO - Disconnected from trading simulator
# Session Results:
# Trades: 62
# Final Balance: £205.43
# CLDI: 1 shares @ £148.68
# CRDL: 2 shares @ £310.40
# CTMX: 1 shares @ £480.38
# CMTL: 1 shares @ £324.05
# ANVS: 2 shares @ £286.36
# CLRB: 1 shares @ £489.85
# CMPS: 1 shares @ £202.62
# CURR: 4 shares @ £105.39
# APLT: 1 shares @ £460.17
# CELU: 1 shares @ £459.36
# CRBU: 1 shares @ £188.08
# ERAS: 3 shares @ £83.18
# CTOR: 1 shares @ £269.15
# DTIL: 1 shares @ £427.57
# ELDN: 1 shares @ £456.52
# ESLA: 1 shares @ £361.24
# ABCL: 1 shares @ £172.61
# ARBE: 1 shares @ £309.40
# ATEN: 1 shares @ £367.66
# CABA: 1 shares @ £145.60
# CGTX: 1 shares @ £286.59
# CLYM: 1 shares @ £308.61
# CHRS: 1 shares @ £59.04
# CRDF: 1 shares @ £175.50
# CLLS: 1 shares @ £82.42
# CMPX: 1 shares @ £229.99
# EDIT: 1 shares @ £459.05
# ATHA: 1 shares @ £64.35
# ANRO: 1 shares @ £292.95
# CRIS: 1 shares @ £151.99
# ESPR: 1 shares @ £93.06
# CTXR: 1 shares @ £379.35
#
# Session ended
# ✓ IB Trading Bot Simulator Completed

# %% [markdown]
# ### Execution IB Trading Bot - Paper Trading (needs TWS running)

# %%
print("✓ IB Trading Bot Started")
run_production_session('paper', max_cycles=5)
print("✓ IB Trading Bot Completed")
# Out:
# 2025-09-01 13:23:40,354 - INFO - Initialised for Paper Trading (Demo Account)
# 2025-09-01 13:23:40,355 - INFO - Trading bot initialised for paper trading
# 2025-09-01 13:23:40,356 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:23:40,357 - INFO - Updated trading symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# ✓ IB Trading Bot Started
# 2025-09-01 13:23:40,875 - INFO - ✓ Connected to IB on port 7497
# 2025-09-01 13:23:40,875 - INFO - Account: DUM797459
# 2025-09-01 13:23:40,876 - INFO - Data handlers configured for enhanced analysis
# 2025-09-01 13:23:40,876 - INFO - Trading bot connected successfully
# 2025-09-01 13:23:41,101 - INFO - Account Net Liquidation: £1000093.76
# 2025-09-01 13:23:41,102 - INFO - Buying Power: £4000000.00
# 2025-09-01 13:23:41,103 - INFO - Starting automated trading...
# 2025-09-01 13:23:41,104 - INFO - Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# 2025-09-01 13:23:41,104 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:23:41,105 - INFO - Update interval: 60 seconds
# 2025-09-01 13:23:41,105 - INFO - Strategy config - Short: 20, Long: 50, Stop Loss: 5.0%, Take Profit: 15.0%
# 2025-09-01 13:23:41,106 - INFO - --- Cycle 1 ---
# ==================================================
# PRODUCTION SESSION STARTED
# ==================================================
# Environment: PAPER
# Strategy: Production_Enhanced
# Symbols: ['ABCL', 'ALLO', 'ANNX', 'ANRO', 'ANVS', 'APLM', 'APLT', 'APVO', 'ARAY', 'ARBE', 'ATEN', 'ATAI', 'ATHA', 'AUTL', 'AVIR', 'CABA', 'CAMP', 'CARM', 'CATX', 'CCCC', 'CELU', 'CERS', 'CGTX', 'CHRS', 'CLDI', 'CLLS', 'CLRB', 'CLSD', 'CLYM', 'CMPS', 'CMPX', 'CMTL', 'COCP', 'CRBU', 'CRDF', 'CRDL', 'CRIS', 'CTMX', 'CTOR', 'CTXR', 'CUE', 'CURR', 'DARE', 'DTIL', 'EDIT', 'ELDN', 'EQ', 'ERAS', 'ERNA', 'ESLA', 'ESPR', 'EVGN', 'FATE', 'FBLG']
# Cycles: 5
# ==================================================
# 2025-09-01 13:23:42,527 - INFO - Retrieved 1170 historical bars for ABCL
# 2025-09-01 13:23:42,866 - INFO - Retrieved 22 historical bars for ABCL
# 2025-09-01 13:23:44,870 - WARNING - No valid market data for ABCL
# 2025-09-01 13:23:44,872 - INFO - Enhanced analysis for ABCL: £4.17 (+0.00%)
# 2025-09-01 13:23:45,363 - INFO - Retrieved 1170 historical bars for ABCL
# 2025-09-01 13:23:45,699 - INFO - Retrieved 22 historical bars for ABCL
# 2025-09-01 13:23:47,703 - WARNING - No valid market data for ABCL
# 2025-09-01 13:23:48,208 - INFO - Retrieved 1170 historical bars for ALLO
# 2025-09-01 13:23:48,539 - INFO - Retrieved 22 historical bars for ALLO
# 2025-09-01 13:23:50,542 - WARNING - No valid market data for ALLO
# 2025-09-01 13:23:50,544 - INFO - Enhanced analysis for ALLO: £1.14 (+0.00%)
# 2025-09-01 13:23:51,033 - INFO - Retrieved 1170 historical bars for ALLO
# 2025-09-01 13:23:51,357 - INFO - Retrieved 22 historical bars for ALLO
# 2025-09-01 13:23:53,360 - WARNING - No valid market data for ALLO
# 2025-09-01 13:23:53,362 - INFO - BUY signal for ALLO: 3/7 signals
# 2025-09-01 13:23:53,364 - INFO - ✓ Market order placed: BUY 422907 ALLO
# 2025-09-01 13:23:53,364 - INFO - BUY executed: 422907 shares of ALLO
# 2025-09-01 13:23:53,365 - INFO - ALLO indicators - RSI: 62.5, MACD: 0.005, Volatility: 0.34%
# 2025-09-01 13:23:54,119 - INFO - Retrieved 1170 historical bars for ANNX
# 2025-09-01 13:23:54,461 - INFO - Retrieved 22 historical bars for ANNX
# 2025-09-01 13:23:56,464 - WARNING - No valid market data for ANNX
# 2025-09-01 13:23:56,467 - INFO - Enhanced analysis for ANNX: £2.06 (+0.00%)
# 2025-09-01 13:23:56,995 - INFO - Retrieved 1170 historical bars for ANNX
# 2025-09-01 13:23:57,316 - INFO - Retrieved 22 historical bars for ANNX
# 2025-09-01 13:23:59,321 - WARNING - No valid market data for ANNX
# 2025-09-01 13:23:59,949 - INFO - Retrieved 1170 historical bars for ANRO
# 2025-09-01 13:24:00,266 - INFO - Retrieved 22 historical bars for ANRO
# 2025-09-01 13:24:02,270 - WARNING - No valid market data for ANRO
# 2025-09-01 13:24:02,272 - INFO - Enhanced analysis for ANRO: £3.68 (+0.00%)
# 2025-09-01 13:24:02,731 - INFO - Retrieved 1170 historical bars for ANRO
# 2025-09-01 13:24:03,055 - INFO - Retrieved 22 historical bars for ANRO
# 2025-09-01 13:24:05,059 - WARNING - No valid market data for ANRO
# 2025-09-01 13:24:05,681 - INFO - Retrieved 1170 historical bars for ANVS
# 2025-09-01 13:24:06,001 - INFO - Retrieved 22 historical bars for ANVS
# 2025-09-01 13:24:08,005 - WARNING - No valid market data for ANVS
# 2025-09-01 13:24:08,007 - INFO - Enhanced analysis for ANVS: £2.31 (+0.00%)
# 2025-09-01 13:24:08,524 - INFO - Retrieved 1170 historical bars for ANVS
# 2025-09-01 13:24:08,854 - INFO - Retrieved 22 historical bars for ANVS
# 2025-09-01 13:24:10,857 - WARNING - No valid market data for ANVS
# 2025-09-01 13:24:11,589 - INFO - Retrieved 1170 historical bars for APLM
# 2025-09-01 13:24:11,965 - INFO - Retrieved 22 historical bars for APLM
# 2025-09-01 13:24:13,969 - WARNING - No valid market data for APLM
# 2025-09-01 13:24:13,971 - INFO - Enhanced analysis for APLM: £3.93 (+0.00%)
# 2025-09-01 13:24:14,436 - INFO - Retrieved 1170 historical bars for APLM
# 2025-09-01 13:24:14,760 - INFO - Retrieved 22 historical bars for APLM
# 2025-09-01 13:24:16,764 - WARNING - No valid market data for APLM
# 2025-09-01 13:24:17,411 - INFO - Retrieved 1170 historical bars for APLT
# 2025-09-01 13:24:17,739 - INFO - Retrieved 22 historical bars for APLT
# 2025-09-01 13:24:19,742 - WARNING - No valid market data for APLT
# 2025-09-01 13:24:19,744 - INFO - Enhanced analysis for APLT: £0.50 (+0.00%)
# 2025-09-01 13:24:20,295 - INFO - Retrieved 1170 historical bars for APLT
# 2025-09-01 13:24:20,618 - INFO - Retrieved 22 historical bars for APLT
# 2025-09-01 13:24:22,621 - WARNING - No valid market data for APLT
# 2025-09-01 13:24:22,623 - INFO - BUY signal for APLT: 3/7 signals
# 2025-09-01 13:24:22,626 - INFO - ✓ Market order placed: BUY 958275 APLT
# 2025-09-01 13:24:22,627 - INFO - BUY executed: 958275 shares of APLT
# 2025-09-01 13:24:22,628 - INFO - APLT indicators - RSI: 70.0, MACD: 0.001, Volatility: 0.58%
# 2025-09-01 13:24:23,214 - ERROR - Error 201, reqId 91: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 499500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:24:23,215 - WARNING - Canceled order: Trade(contract=Stock(symbol='APLT', exchange='SMART', currency='USD'), order=MarketOrder(orderId=91, clientId=1, permId=542815544, action='BUY', totalQuantity=958275.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=91, status='Cancelled', filled=0.0, remaining=958275.0, avgFillPrice=0.0, permId=542815544, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 22, 625435, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 23, 170838, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 23, 214909, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 91: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 499500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:24:23,373 - INFO - Retrieved 1170 historical bars for APVO
# 2025-09-01 13:24:23,714 - INFO - Retrieved 22 historical bars for APVO
# 2025-09-01 13:24:25,717 - WARNING - No valid market data for APVO
# 2025-09-01 13:24:25,721 - INFO - Enhanced analysis for APVO: £1.63 (+0.00%)
# 2025-09-01 13:24:26,195 - INFO - Retrieved 1170 historical bars for APVO
# 2025-09-01 13:24:26,567 - INFO - Retrieved 22 historical bars for APVO
# 2025-09-01 13:24:28,571 - WARNING - No valid market data for APVO
# 2025-09-01 13:24:29,220 - INFO - Retrieved 1170 historical bars for ARAY
# 2025-09-01 13:24:29,542 - INFO - Retrieved 22 historical bars for ARAY
# 2025-09-01 13:24:31,545 - WARNING - No valid market data for ARAY
# 2025-09-01 13:24:31,547 - INFO - Enhanced analysis for ARAY: £1.52 (+0.00%)
# 2025-09-01 13:24:32,055 - INFO - Retrieved 1170 historical bars for ARAY
# 2025-09-01 13:24:32,376 - INFO - Retrieved 22 historical bars for ARAY
# 2025-09-01 13:24:34,379 - WARNING - No valid market data for ARAY
# 2025-09-01 13:24:34,381 - INFO - BUY signal for ARAY: 4/7 signals
# 2025-09-01 13:24:34,382 - INFO - ✓ Market order placed: BUY 314754 ARAY
# 2025-09-01 13:24:34,383 - INFO - BUY executed: 314754 shares of ARAY
# 2025-09-01 13:24:34,383 - INFO - ARAY indicators - RSI: 66.7, MACD: 0.000, Volatility: 0.15%
# 2025-09-01 13:24:34,926 - ERROR - Error 201, reqId 104: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 276500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:24:34,927 - WARNING - Canceled order: Trade(contract=Stock(symbol='ARAY', exchange='SMART', currency='USD'), order=MarketOrder(orderId=104, clientId=1, permId=542815545, action='BUY', totalQuantity=314754.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=104, status='Cancelled', filled=0.0, remaining=314754.0, avgFillPrice=0.0, permId=542815545, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 34, 381948, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 34, 923082, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 24, 34, 926360, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 104: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 276500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:24:35,132 - INFO - Retrieved 1170 historical bars for ARBE
# 2025-09-01 13:24:35,461 - INFO - Retrieved 22 historical bars for ARBE
# 2025-09-01 13:24:37,464 - WARNING - No valid market data for ARBE
# 2025-09-01 13:24:37,466 - INFO - Enhanced analysis for ARBE: £1.30 (+0.00%)
# 2025-09-01 13:24:37,972 - INFO - Retrieved 1170 historical bars for ARBE
# 2025-09-01 13:24:38,291 - INFO - Retrieved 22 historical bars for ARBE
# 2025-09-01 13:24:40,295 - WARNING - No valid market data for ARBE
# 2025-09-01 13:24:41,032 - INFO - Retrieved 1170 historical bars for ATEN
# 2025-09-01 13:24:41,346 - INFO - Retrieved 22 historical bars for ATEN
# 2025-09-01 13:24:43,348 - WARNING - No valid market data for ATEN
# 2025-09-01 13:24:43,350 - INFO - Enhanced analysis for ATEN: £17.72 (+0.00%)
# 2025-09-01 13:24:43,949 - INFO - Retrieved 1170 historical bars for ATEN
# 2025-09-01 13:24:44,281 - INFO - Retrieved 22 historical bars for ATEN
# 2025-09-01 13:24:46,284 - WARNING - No valid market data for ATEN
# 2025-09-01 13:24:46,287 - INFO - BUY signal for ATEN: 3/7 signals
# 2025-09-01 13:24:46,288 - INFO - ✓ Market order placed: BUY 27088 ATEN
# 2025-09-01 13:24:46,289 - INFO - BUY executed: 27088 shares of ATEN
# 2025-09-01 13:24:46,291 - INFO - ATEN indicators - RSI: 73.3, MACD: 0.028, Volatility: 0.07%
# 2025-09-01 13:24:47,055 - INFO - Retrieved 1170 historical bars for ATAI
# 2025-09-01 13:24:47,375 - INFO - Retrieved 22 historical bars for ATAI
# 2025-09-01 13:24:49,379 - WARNING - No valid market data for ATAI
# 2025-09-01 13:24:49,381 - INFO - Enhanced analysis for ATAI: £4.57 (+0.00%)
# 2025-09-01 13:24:49,879 - INFO - Retrieved 1170 historical bars for ATAI
# 2025-09-01 13:24:50,210 - INFO - Retrieved 22 historical bars for ATAI
# 2025-09-01 13:24:52,213 - WARNING - No valid market data for ATAI
# 2025-09-01 13:24:52,216 - INFO - BUY signal for ATAI: 3/7 signals
# 2025-09-01 13:24:52,217 - INFO - ✓ Market order placed: BUY 105032 ATAI
# 2025-09-01 13:24:52,218 - INFO - BUY executed: 105032 shares of ATAI
# 2025-09-01 13:24:52,220 - INFO - ATAI indicators - RSI: 47.1, MACD: 0.003, Volatility: 0.16%
# 2025-09-01 13:24:52,937 - INFO - Retrieved 1170 historical bars for ATHA
# 2025-09-01 13:24:53,259 - INFO - Retrieved 22 historical bars for ATHA
# 2025-09-01 13:24:55,262 - WARNING - No valid market data for ATHA
# 2025-09-01 13:24:55,264 - INFO - Enhanced analysis for ATHA: £0.39 (+0.00%)
# 2025-09-01 13:24:55,727 - INFO - Retrieved 1170 historical bars for ATHA
# 2025-09-01 13:24:56,060 - INFO - Retrieved 22 historical bars for ATHA
# 2025-09-01 13:24:58,064 - WARNING - No valid market data for ATHA
# 2025-09-01 13:24:58,816 - INFO - Retrieved 1170 historical bars for AUTL
# 2025-09-01 13:24:59,131 - INFO - Retrieved 22 historical bars for AUTL
# 2025-09-01 13:25:01,136 - WARNING - No valid market data for AUTL
# 2025-09-01 13:25:01,138 - INFO - Enhanced analysis for AUTL: £1.50 (+0.00%)
# 2025-09-01 13:25:01,638 - INFO - Retrieved 1170 historical bars for AUTL
# 2025-09-01 13:25:01,989 - INFO - Retrieved 22 historical bars for AUTL
# 2025-09-01 13:25:03,992 - WARNING - No valid market data for AUTL
# 2025-09-01 13:25:04,701 - INFO - Retrieved 1170 historical bars for AVIR
# 2025-09-01 13:25:05,014 - INFO - Retrieved 22 historical bars for AVIR
# 2025-09-01 13:25:07,018 - WARNING - No valid market data for AVIR
# 2025-09-01 13:25:07,019 - INFO - Enhanced analysis for AVIR: £3.36 (+0.00%)
# 2025-09-01 13:25:07,494 - INFO - Retrieved 1170 historical bars for AVIR
# 2025-09-01 13:25:07,816 - INFO - Retrieved 22 historical bars for AVIR
# 2025-09-01 13:25:09,819 - WARNING - No valid market data for AVIR
# 2025-09-01 13:25:10,564 - INFO - Retrieved 1170 historical bars for CABA
# 2025-09-01 13:25:10,903 - INFO - Retrieved 22 historical bars for CABA
# 2025-09-01 13:25:12,906 - WARNING - No valid market data for CABA
# 2025-09-01 13:25:12,908 - INFO - Enhanced analysis for CABA: £1.45 (+0.00%)
# 2025-09-01 13:25:13,390 - INFO - Retrieved 1170 historical bars for CABA
# 2025-09-01 13:25:13,700 - INFO - Retrieved 22 historical bars for CABA
# 2025-09-01 13:25:15,702 - WARNING - No valid market data for CABA
# 2025-09-01 13:25:16,405 - INFO - Retrieved 1170 historical bars for CAMP
# 2025-09-01 13:25:16,721 - INFO - Retrieved 22 historical bars for CAMP
# 2025-09-01 13:25:18,725 - WARNING - No valid market data for CAMP
# 2025-09-01 13:25:18,727 - INFO - Enhanced analysis for CAMP: £1.56 (+0.00%)
# 2025-09-01 13:25:19,275 - INFO - Retrieved 1170 historical bars for CAMP
# 2025-09-01 13:25:19,593 - INFO - Retrieved 22 historical bars for CAMP
# 2025-09-01 13:25:21,596 - WARNING - No valid market data for CAMP
# 2025-09-01 13:25:22,466 - INFO - Retrieved 1170 historical bars for CARM
# 2025-09-01 13:25:22,796 - INFO - Retrieved 22 historical bars for CARM
# 2025-09-01 13:25:24,800 - WARNING - No valid market data for CARM
# 2025-09-01 13:25:24,802 - INFO - Enhanced analysis for CARM: £0.21 (+0.00%)
# 2025-09-01 13:25:25,305 - INFO - Retrieved 1170 historical bars for CARM
# 2025-09-01 13:25:25,630 - INFO - Retrieved 22 historical bars for CARM
# 2025-09-01 13:25:27,633 - WARNING - No valid market data for CARM
# 2025-09-01 13:25:28,585 - INFO - Retrieved 1170 historical bars for CATX
# 2025-09-01 13:25:28,924 - INFO - Retrieved 22 historical bars for CATX
# 2025-09-01 13:25:29,566 - ERROR - Error 10089, reqId 163: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.Delayed market data is available.CATX AMEX/TOP/ALL, contract: Stock(symbol='CATX', exchange='SMART', currency='USD')
# 2025-09-01 13:25:30,926 - WARNING - No valid market data for CATX
# 2025-09-01 13:25:30,928 - INFO - Enhanced analysis for CATX: £3.35 (+0.00%)
# 2025-09-01 13:25:30,934 - ERROR - Error 300, reqId 163: Can't find EId with tickerId:163
# 2025-09-01 13:25:31,512 - INFO - Retrieved 1170 historical bars for CATX
# 2025-09-01 13:25:31,836 - INFO - Retrieved 22 historical bars for CATX
# 2025-09-01 13:25:32,191 - ERROR - Error 10089, reqId 166: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.Delayed market data is available.CATX AMEX/TOP/ALL, contract: Stock(symbol='CATX', exchange='SMART', currency='USD')
# 2025-09-01 13:25:33,840 - WARNING - No valid market data for CATX
# 2025-09-01 13:25:33,843 - ERROR - Error 300, reqId 166: Can't find EId with tickerId:166
# 2025-09-01 13:25:34,566 - INFO - Retrieved 1170 historical bars for CCCC
# 2025-09-01 13:25:34,880 - INFO - Retrieved 22 historical bars for CCCC
# 2025-09-01 13:25:36,882 - WARNING - No valid market data for CCCC
# 2025-09-01 13:25:36,884 - INFO - Enhanced analysis for CCCC: £2.60 (+0.00%)
# 2025-09-01 13:25:37,372 - INFO - Retrieved 1170 historical bars for CCCC
# 2025-09-01 13:25:37,694 - INFO - Retrieved 22 historical bars for CCCC
# 2025-09-01 13:25:39,697 - WARNING - No valid market data for CCCC
# 2025-09-01 13:25:39,699 - INFO - BUY signal for CCCC: 3/7 signals
# 2025-09-01 13:25:39,701 - INFO - ✓ Market order placed: BUY 184615 CCCC
# 2025-09-01 13:25:39,703 - INFO - BUY executed: 184615 shares of CCCC
# 2025-09-01 13:25:39,704 - INFO - CCCC indicators - RSI: 75.0, MACD: 0.014, Volatility: 0.30%
# 2025-09-01 13:25:40,422 - INFO - Retrieved 1147 historical bars for CELU
# 2025-09-01 13:25:40,744 - INFO - Retrieved 22 historical bars for CELU
# 2025-09-01 13:25:42,747 - WARNING - No valid market data for CELU
# 2025-09-01 13:25:42,751 - INFO - Enhanced analysis for CELU: £3.94 (+0.00%)
# 2025-09-01 13:25:43,209 - INFO - Retrieved 1147 historical bars for CELU
# 2025-09-01 13:25:43,534 - INFO - Retrieved 22 historical bars for CELU
# 2025-09-01 13:25:45,538 - WARNING - No valid market data for CELU
# 2025-09-01 13:25:46,270 - INFO - Retrieved 1170 historical bars for CERS
# 2025-09-01 13:25:46,586 - INFO - Retrieved 22 historical bars for CERS
# 2025-09-01 13:25:48,590 - WARNING - No valid market data for CERS
# 2025-09-01 13:25:48,592 - INFO - Enhanced analysis for CERS: £1.30 (+0.00%)
# 2025-09-01 13:25:49,061 - INFO - Retrieved 1170 historical bars for CERS
# 2025-09-01 13:25:49,396 - INFO - Retrieved 22 historical bars for CERS
# 2025-09-01 13:25:51,400 - WARNING - No valid market data for CERS
# 2025-09-01 13:25:52,150 - INFO - Retrieved 1170 historical bars for CGTX
# 2025-09-01 13:25:52,478 - INFO - Retrieved 22 historical bars for CGTX
# 2025-09-01 13:25:54,482 - WARNING - No valid market data for CGTX
# 2025-09-01 13:25:54,484 - INFO - Enhanced analysis for CGTX: £2.42 (+0.00%)
# 2025-09-01 13:25:54,994 - INFO - Retrieved 1170 historical bars for CGTX
# 2025-09-01 13:25:55,319 - INFO - Retrieved 22 historical bars for CGTX
# 2025-09-01 13:25:57,323 - WARNING - No valid market data for CGTX
# 2025-09-01 13:25:57,325 - INFO - BUY signal for CGTX: 3/7 signals
# 2025-09-01 13:25:57,329 - INFO - ✓ Market order placed: BUY 198347 CGTX
# 2025-09-01 13:25:57,330 - INFO - BUY executed: 198347 shares of CGTX
# 2025-09-01 13:25:57,331 - INFO - CGTX indicators - RSI: 30.1, MACD: -0.003, Volatility: 0.21%
# 2025-09-01 13:25:58,099 - INFO - Retrieved 1170 historical bars for CHRS
# 2025-09-01 13:25:58,410 - INFO - Retrieved 22 historical bars for CHRS
# 2025-09-01 13:26:00,413 - WARNING - No valid market data for CHRS
# 2025-09-01 13:26:00,415 - INFO - Enhanced analysis for CHRS: £1.16 (+0.00%)
# 2025-09-01 13:26:00,880 - INFO - Retrieved 1170 historical bars for CHRS
# 2025-09-01 13:26:01,195 - INFO - Retrieved 22 historical bars for CHRS
# 2025-09-01 13:26:03,198 - WARNING - No valid market data for CHRS
# 2025-09-01 13:26:03,959 - INFO - Retrieved 1170 historical bars for CLDI
# 2025-09-01 13:26:04,464 - INFO - Retrieved 21 historical bars for CLDI
# 2025-09-01 13:26:05,028 - ERROR - Error 10089, reqId 201: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.Delayed market data is available.CLDI AMEX/TOP/ALL, contract: Stock(symbol='CLDI', exchange='SMART', currency='USD')
# 2025-09-01 13:26:06,469 - WARNING - No valid market data for CLDI
# 2025-09-01 13:26:06,471 - INFO - Enhanced analysis for CLDI: £1.64 (+0.00%)
# 2025-09-01 13:26:06,491 - ERROR - Error 300, reqId 201: Can't find EId with tickerId:201
# 2025-09-01 13:26:07,152 - INFO - Retrieved 1170 historical bars for CLDI
# 2025-09-01 13:26:07,782 - INFO - Retrieved 21 historical bars for CLDI
# 2025-09-01 13:26:08,349 - ERROR - Error 10089, reqId 204: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.Delayed market data is available.CLDI AMEX/TOP/ALL, contract: Stock(symbol='CLDI', exchange='SMART', currency='USD')
# 2025-09-01 13:26:09,785 - WARNING - No valid market data for CLDI
# 2025-09-01 13:26:09,789 - ERROR - Error 300, reqId 204: Can't find EId with tickerId:204
# 2025-09-01 13:26:10,527 - INFO - Retrieved 1170 historical bars for CLLS
# 2025-09-01 13:26:10,849 - INFO - Retrieved 22 historical bars for CLLS
# 2025-09-01 13:26:12,853 - WARNING - No valid market data for CLLS
# 2025-09-01 13:26:12,855 - INFO - Enhanced analysis for CLLS: £2.57 (+0.00%)
# 2025-09-01 13:26:13,319 - INFO - Retrieved 1170 historical bars for CLLS
# 2025-09-01 13:26:13,635 - INFO - Retrieved 22 historical bars for CLLS
# 2025-09-01 13:26:15,638 - WARNING - No valid market data for CLLS
# 2025-09-01 13:26:16,376 - INFO - Retrieved 1170 historical bars for CLRB
# 2025-09-01 13:26:16,701 - INFO - Retrieved 22 historical bars for CLRB
# 2025-09-01 13:26:18,703 - WARNING - No valid market data for CLRB
# 2025-09-01 13:26:18,705 - INFO - Enhanced analysis for CLRB: £4.96 (+0.00%)
# 2025-09-01 13:26:19,164 - INFO - Retrieved 1170 historical bars for CLRB
# 2025-09-01 13:26:19,509 - INFO - Retrieved 22 historical bars for CLRB
# 2025-09-01 13:26:21,511 - WARNING - No valid market data for CLRB
# 2025-09-01 13:26:21,514 - INFO - BUY signal for CLRB: 4/7 signals
# 2025-09-01 13:26:21,515 - INFO - ✓ Market order placed: BUY 96774 CLRB
# 2025-09-01 13:26:21,517 - INFO - BUY executed: 96774 shares of CLRB
# 2025-09-01 13:26:21,517 - INFO - CLRB indicators - RSI: 65.1, MACD: 0.009, Volatility: 0.30%
# 2025-09-01 13:26:22,068 - ERROR - Error 201, reqId 217: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 49000), or convert your order to an algorithmic Order (IBALGO). This is a control designed to ensure<br> that we comply with our regulatory obligations to avoid submitting disruptive orders to the marketplace.
# 2025-09-01 13:26:22,069 - WARNING - Canceled order: Trade(contract=Stock(symbol='CLRB', exchange='SMART', currency='USD'), order=MarketOrder(orderId=217, clientId=1, permId=542815550, action='BUY', totalQuantity=96774.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=217, status='Cancelled', filled=0.0, remaining=96774.0, avgFillPrice=0.0, permId=542815550, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 26, 21, 515400, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 26, 22, 66181, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 26, 22, 68116, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 217: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 49000), or convert your order to an algorithmic Order (IBALGO). This is a control designed to ensure<br> that we comply with our regulatory obligations to avoid submitting disruptive orders to the marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:26:22,337 - INFO - Retrieved 1170 historical bars for CLSD
# 2025-09-01 13:26:22,661 - INFO - Retrieved 22 historical bars for CLSD
# 2025-09-01 13:26:24,666 - WARNING - No valid market data for CLSD
# 2025-09-01 13:26:24,668 - INFO - Enhanced analysis for CLSD: £0.37 (+0.00%)
# 2025-09-01 13:26:25,148 - INFO - Retrieved 1170 historical bars for CLSD
# 2025-09-01 13:26:25,466 - INFO - Retrieved 22 historical bars for CLSD
# 2025-09-01 13:26:27,470 - WARNING - No valid market data for CLSD
# 2025-09-01 13:26:28,219 - INFO - Retrieved 1170 historical bars for CLYM
# 2025-09-01 13:26:28,573 - INFO - Retrieved 22 historical bars for CLYM
# 2025-09-01 13:26:30,577 - WARNING - No valid market data for CLYM
# 2025-09-01 13:26:30,581 - INFO - Enhanced analysis for CLYM: £2.25 (+0.00%)
# 2025-09-01 13:26:31,050 - INFO - Retrieved 1170 historical bars for CLYM
# 2025-09-01 13:26:31,373 - INFO - Retrieved 22 historical bars for CLYM
# 2025-09-01 13:26:33,376 - WARNING - No valid market data for CLYM
# 2025-09-01 13:26:33,379 - INFO - BUY signal for CLYM: 3/7 signals
# 2025-09-01 13:26:33,381 - INFO - ✓ Market order placed: BUY 213808 CLYM
# 2025-09-01 13:26:33,383 - INFO - BUY executed: 213808 shares of CLYM
# 2025-09-01 13:26:33,384 - INFO - CLYM indicators - RSI: 38.5, MACD: -0.004, Volatility: 0.31%
# 2025-09-01 13:26:34,150 - INFO - Retrieved 1170 historical bars for CMPS
# 2025-09-01 13:26:34,481 - INFO - Retrieved 22 historical bars for CMPS
# 2025-09-01 13:26:36,485 - WARNING - No valid market data for CMPS
# 2025-09-01 13:26:36,486 - INFO - Enhanced analysis for CMPS: £4.41 (+0.00%)
# 2025-09-01 13:26:37,064 - INFO - Retrieved 1170 historical bars for CMPS
# 2025-09-01 13:26:37,387 - INFO - Retrieved 22 historical bars for CMPS
# 2025-09-01 13:26:39,391 - WARNING - No valid market data for CMPS
# 2025-09-01 13:26:39,393 - INFO - BUY signal for CMPS: 3/7 signals
# 2025-09-01 13:26:39,394 - INFO - ✓ Market order placed: BUY 108843 CMPS
# 2025-09-01 13:26:39,397 - INFO - BUY executed: 108843 shares of CMPS
# 2025-09-01 13:26:39,400 - INFO - CMPS indicators - RSI: 46.2, MACD: -0.004, Volatility: 0.33%
# 2025-09-01 13:26:40,214 - INFO - Retrieved 1170 historical bars for CMPX
# 2025-09-01 13:26:40,544 - INFO - Retrieved 22 historical bars for CMPX
# 2025-09-01 13:26:42,547 - WARNING - No valid market data for CMPX
# 2025-09-01 13:26:42,549 - INFO - Enhanced analysis for CMPX: £3.48 (+0.00%)
# 2025-09-01 13:26:43,069 - INFO - Retrieved 1170 historical bars for CMPX
# 2025-09-01 13:26:43,401 - INFO - Retrieved 22 historical bars for CMPX
# 2025-09-01 13:26:45,405 - WARNING - No valid market data for CMPX
# 2025-09-01 13:26:45,407 - INFO - BUY signal for CMPX: 4/7 signals
# 2025-09-01 13:26:45,410 - INFO - ✓ Market order placed: BUY 137733 CMPX
# 2025-09-01 13:26:45,410 - INFO - BUY executed: 137733 shares of CMPX
# 2025-09-01 13:26:45,413 - INFO - CMPX indicators - RSI: 84.6, MACD: 0.021, Volatility: 0.33%
# 2025-09-01 13:26:46,203 - INFO - Retrieved 1168 historical bars for CMTL
# 2025-09-01 13:26:46,526 - INFO - Retrieved 22 historical bars for CMTL
# 2025-09-01 13:26:48,528 - WARNING - No valid market data for CMTL
# 2025-09-01 13:26:48,531 - INFO - Enhanced analysis for CMTL: £1.95 (+0.00%)
# 2025-09-01 13:26:49,010 - INFO - Retrieved 1168 historical bars for CMTL
# 2025-09-01 13:26:49,337 - INFO - Retrieved 22 historical bars for CMTL
# 2025-09-01 13:26:51,341 - WARNING - No valid market data for CMTL
# 2025-09-01 13:26:52,031 - INFO - Retrieved 1129 historical bars for COCP
# 2025-09-01 13:26:52,351 - INFO - Retrieved 22 historical bars for COCP
# 2025-09-01 13:26:54,355 - WARNING - No valid market data for COCP
# 2025-09-01 13:26:54,357 - INFO - Enhanced analysis for COCP: £1.50 (+0.00%)
# 2025-09-01 13:26:54,910 - INFO - Retrieved 1129 historical bars for COCP
# 2025-09-01 13:26:55,253 - INFO - Retrieved 22 historical bars for COCP
# 2025-09-01 13:26:57,256 - WARNING - No valid market data for COCP
# 2025-09-01 13:26:57,950 - INFO - Retrieved 1170 historical bars for CRBU
# 2025-09-01 13:26:58,276 - INFO - Retrieved 22 historical bars for CRBU
# 2025-09-01 13:27:00,280 - WARNING - No valid market data for CRBU
# 2025-09-01 13:27:00,282 - INFO - Enhanced analysis for CRBU: £1.86 (+0.00%)
# 2025-09-01 13:27:00,786 - INFO - Retrieved 1170 historical bars for CRBU
# 2025-09-01 13:27:01,107 - INFO - Retrieved 22 historical bars for CRBU
# 2025-09-01 13:27:03,111 - WARNING - No valid market data for CRBU
# 2025-09-01 13:27:03,860 - INFO - Retrieved 1170 historical bars for CRDF
# 2025-09-01 13:27:04,267 - INFO - Retrieved 22 historical bars for CRDF
# 2025-09-01 13:27:06,270 - WARNING - No valid market data for CRDF
# 2025-09-01 13:27:06,274 - INFO - Enhanced analysis for CRDF: £2.10 (+0.00%)
# 2025-09-01 13:27:06,766 - INFO - Retrieved 1170 historical bars for CRDF
# 2025-09-01 13:27:07,100 - INFO - Retrieved 22 historical bars for CRDF
# 2025-09-01 13:27:09,105 - WARNING - No valid market data for CRDF
# 2025-09-01 13:27:09,921 - INFO - Retrieved 1170 historical bars for CRDL
# 2025-09-01 13:27:10,247 - INFO - Retrieved 22 historical bars for CRDL
# 2025-09-01 13:27:12,250 - WARNING - No valid market data for CRDL
# 2025-09-01 13:27:12,253 - INFO - Enhanced analysis for CRDL: £1.07 (+0.00%)
# 2025-09-01 13:27:12,742 - INFO - Retrieved 1170 historical bars for CRDL
# 2025-09-01 13:27:13,068 - INFO - Retrieved 22 historical bars for CRDL
# 2025-09-01 13:27:15,072 - WARNING - No valid market data for CRDL
# 2025-09-01 13:27:15,796 - INFO - Retrieved 1170 historical bars for CRIS
# /var/folders/c6/kph1v5p51lqf1036zbvfjz6r0000gn/T/ipykernel_78130/2750766155.py:106: RuntimeWarning: invalid value encountered in scalar divide
#   indicators['volume_ratio'] = df['volume'].iloc[-1] / indicators['volume_sma']
# /var/folders/c6/kph1v5p51lqf1036zbvfjz6r0000gn/T/ipykernel_78130/2750766155.py:133: RuntimeWarning: invalid value encountered in scalar divide
#   indicators['williams_r'] = ((highest_high - current_close) / (highest_high - lowest_low)) * -100
# 2025-09-01 13:27:16,117 - INFO - Retrieved 22 historical bars for CRIS
# 2025-09-01 13:27:18,120 - WARNING - No valid market data for CRIS
# 2025-09-01 13:27:18,123 - INFO - Enhanced analysis for CRIS: £1.68 (+0.00%)
# 2025-09-01 13:27:18,582 - INFO - Retrieved 1170 historical bars for CRIS
# /var/folders/c6/kph1v5p51lqf1036zbvfjz6r0000gn/T/ipykernel_78130/2750766155.py:106: RuntimeWarning: invalid value encountered in scalar divide
#   indicators['volume_ratio'] = df['volume'].iloc[-1] / indicators['volume_sma']
# /var/folders/c6/kph1v5p51lqf1036zbvfjz6r0000gn/T/ipykernel_78130/2750766155.py:133: RuntimeWarning: invalid value encountered in scalar divide
#   indicators['williams_r'] = ((highest_high - current_close) / (highest_high - lowest_low)) * -100
# 2025-09-01 13:27:18,903 - INFO - Retrieved 22 historical bars for CRIS
# 2025-09-01 13:27:20,906 - WARNING - No valid market data for CRIS
# 2025-09-01 13:27:21,653 - INFO - Retrieved 1170 historical bars for CTMX
# 2025-09-01 13:27:21,984 - INFO - Retrieved 22 historical bars for CTMX
# 2025-09-01 13:27:23,987 - WARNING - No valid market data for CTMX
# 2025-09-01 13:27:23,990 - INFO - Enhanced analysis for CTMX: £2.05 (+0.00%)
# 2025-09-01 13:27:24,478 - INFO - Retrieved 1170 historical bars for CTMX
# 2025-09-01 13:27:24,793 - INFO - Retrieved 22 historical bars for CTMX
# 2025-09-01 13:27:26,797 - WARNING - No valid market data for CTMX
# 2025-09-01 13:27:27,506 - INFO - Retrieved 1170 historical bars for CTOR
# 2025-09-01 13:27:27,832 - INFO - Retrieved 22 historical bars for CTOR
# 2025-09-01 13:27:29,836 - WARNING - No valid market data for CTOR
# 2025-09-01 13:27:29,838 - INFO - Enhanced analysis for CTOR: £2.15 (+0.00%)
# 2025-09-01 13:27:30,305 - INFO - Retrieved 1170 historical bars for CTOR
# 2025-09-01 13:27:30,626 - INFO - Retrieved 22 historical bars for CTOR
# 2025-09-01 13:27:32,630 - WARNING - No valid market data for CTOR
# 2025-09-01 13:27:32,633 - INFO - BUY signal for CTOR: 4/7 signals
# 2025-09-01 13:27:32,636 - INFO - ✓ Market order placed: BUY 223776 CTOR
# 2025-09-01 13:27:32,639 - INFO - BUY executed: 223776 shares of CTOR
# 2025-09-01 13:27:32,640 - INFO - CTOR indicators - RSI: 81.0, MACD: 0.004, Volatility: 0.13%
# 2025-09-01 13:27:33,410 - INFO - Retrieved 1170 historical bars for CTXR
# 2025-09-01 13:27:33,838 - INFO - Retrieved 22 historical bars for CTXR
# 2025-09-01 13:27:35,840 - WARNING - No valid market data for CTXR
# 2025-09-01 13:27:35,842 - INFO - Enhanced analysis for CTXR: £1.33 (+0.00%)
# 2025-09-01 13:27:36,343 - INFO - Retrieved 1170 historical bars for CTXR
# 2025-09-01 13:27:36,661 - INFO - Retrieved 22 historical bars for CTXR
# 2025-09-01 13:27:38,664 - WARNING - No valid market data for CTXR
# 2025-09-01 13:27:38,666 - INFO - BUY signal for CTXR: 3/7 signals
# 2025-09-01 13:27:38,667 - INFO - ✓ Market order placed: BUY 361065 CTXR
# 2025-09-01 13:27:38,667 - INFO - BUY executed: 361065 shares of CTXR
# 2025-09-01 13:27:38,668 - INFO - CTXR indicators - RSI: 55.9, MACD: 0.001, Volatility: 0.36%
# 2025-09-01 13:27:39,383 - INFO - Retrieved 1170 historical bars for CUE
# 2025-09-01 13:27:39,700 - INFO - Retrieved 22 historical bars for CUE
# 2025-09-01 13:27:41,704 - WARNING - No valid market data for CUE
# 2025-09-01 13:27:41,707 - INFO - Enhanced analysis for CUE: £0.79 (+0.00%)
# 2025-09-01 13:27:42,163 - INFO - Retrieved 1170 historical bars for CUE
# 2025-09-01 13:27:42,488 - INFO - Retrieved 22 historical bars for CUE
# 2025-09-01 13:27:44,491 - WARNING - No valid market data for CUE
# 2025-09-01 13:27:45,209 - INFO - Retrieved 1170 historical bars for CURR
# 2025-09-01 13:27:45,529 - INFO - Retrieved 22 historical bars for CURR
# 2025-09-01 13:27:47,532 - WARNING - No valid market data for CURR
# 2025-09-01 13:27:47,534 - INFO - Enhanced analysis for CURR: £1.74 (+0.00%)
# 2025-09-01 13:27:47,984 - INFO - Retrieved 1170 historical bars for CURR
# 2025-09-01 13:27:48,305 - INFO - Retrieved 22 historical bars for CURR
# 2025-09-01 13:27:50,309 - WARNING - No valid market data for CURR
# 2025-09-01 13:27:50,936 - INFO - Retrieved 1170 historical bars for DARE
# 2025-09-01 13:27:51,254 - INFO - Retrieved 22 historical bars for DARE
# 2025-09-01 13:27:53,258 - WARNING - No valid market data for DARE
# 2025-09-01 13:27:53,260 - INFO - Enhanced analysis for DARE: £2.04 (+0.00%)
# 2025-09-01 13:27:53,726 - INFO - Retrieved 1170 historical bars for DARE
# 2025-09-01 13:27:54,044 - INFO - Retrieved 22 historical bars for DARE
# 2025-09-01 13:27:56,048 - WARNING - No valid market data for DARE
# 2025-09-01 13:27:56,786 - INFO - Retrieved 1143 historical bars for DTIL
# 2025-09-01 13:27:57,104 - INFO - Retrieved 22 historical bars for DTIL
# 2025-09-01 13:27:59,106 - WARNING - No valid market data for DTIL
# 2025-09-01 13:27:59,109 - INFO - Enhanced analysis for DTIL: £4.85 (+0.00%)
# 2025-09-01 13:27:59,561 - INFO - Retrieved 1143 historical bars for DTIL
# 2025-09-01 13:27:59,892 - INFO - Retrieved 22 historical bars for DTIL
# 2025-09-01 13:28:01,896 - WARNING - No valid market data for DTIL
# 2025-09-01 13:28:02,660 - INFO - Retrieved 1170 historical bars for EDIT
# 2025-09-01 13:28:02,981 - INFO - Retrieved 22 historical bars for EDIT
# 2025-09-01 13:28:04,985 - WARNING - No valid market data for EDIT
# 2025-09-01 13:28:04,988 - INFO - Enhanced analysis for EDIT: £2.56 (+0.00%)
# 2025-09-01 13:28:05,457 - INFO - Retrieved 1170 historical bars for EDIT
# 2025-09-01 13:28:05,768 - INFO - Retrieved 22 historical bars for EDIT
# 2025-09-01 13:28:07,771 - WARNING - No valid market data for EDIT
# 2025-09-01 13:28:08,400 - INFO - Retrieved 1170 historical bars for ELDN
# 2025-09-01 13:28:08,719 - INFO - Retrieved 22 historical bars for ELDN
# 2025-09-01 13:28:10,723 - WARNING - No valid market data for ELDN
# 2025-09-01 13:28:10,725 - INFO - Enhanced analysis for ELDN: £2.59 (+0.00%)
# 2025-09-01 13:28:11,206 - INFO - Retrieved 1170 historical bars for ELDN
# 2025-09-01 13:28:11,527 - INFO - Retrieved 22 historical bars for ELDN
# 2025-09-01 13:28:13,530 - WARNING - No valid market data for ELDN
# 2025-09-01 13:28:14,185 - INFO - Retrieved 1170 historical bars for EQ
# 2025-09-01 13:28:14,506 - INFO - Retrieved 22 historical bars for EQ
# 2025-09-01 13:28:16,510 - WARNING - No valid market data for EQ
# 2025-09-01 13:28:16,512 - INFO - Enhanced analysis for EQ: £1.75 (+0.00%)
# 2025-09-01 13:28:17,002 - INFO - Retrieved 1170 historical bars for EQ
# 2025-09-01 13:28:17,319 - INFO - Retrieved 22 historical bars for EQ
# 2025-09-01 13:28:19,322 - WARNING - No valid market data for EQ
# 2025-09-01 13:28:20,081 - INFO - Retrieved 1170 historical bars for ERAS
# 2025-09-01 13:28:20,406 - INFO - Retrieved 22 historical bars for ERAS
# 2025-09-01 13:28:22,410 - WARNING - No valid market data for ERAS
# 2025-09-01 13:28:22,413 - INFO - Enhanced analysis for ERAS: £1.57 (+0.00%)
# 2025-09-01 13:28:22,914 - INFO - Retrieved 1170 historical bars for ERAS
# 2025-09-01 13:28:23,231 - INFO - Retrieved 22 historical bars for ERAS
# 2025-09-01 13:28:25,234 - WARNING - No valid market data for ERAS
# 2025-09-01 13:28:25,236 - INFO - BUY signal for ERAS: 3/7 signals
# 2025-09-01 13:28:25,238 - INFO - ✓ Market order placed: BUY 304761 ERAS
# 2025-09-01 13:28:25,240 - INFO - BUY executed: 304761 shares of ERAS
# 2025-09-01 13:28:25,241 - INFO - ERAS indicators - RSI: 50.0, MACD: 0.002, Volatility: 0.23%
# 2025-09-01 13:28:25,769 - ERROR - Error 201, reqId 349: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 208500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:28:25,771 - WARNING - Canceled order: Trade(contract=Stock(symbol='ERAS', exchange='SMART', currency='USD'), order=MarketOrder(orderId=349, clientId=1, permId=542815556, action='BUY', totalQuantity=304761.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=349, status='Cancelled', filled=0.0, remaining=304761.0, avgFillPrice=0.0, permId=542815556, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 25, 238316, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 25, 767738, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 25, 769604, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 349: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 208500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:28:25,959 - INFO - Retrieved 1170 historical bars for ERNA
# 2025-09-01 13:28:26,301 - INFO - Retrieved 22 historical bars for ERNA
# 2025-09-01 13:28:28,305 - WARNING - No valid market data for ERNA
# 2025-09-01 13:28:28,310 - INFO - Enhanced analysis for ERNA: £1.33 (+0.00%)
# 2025-09-01 13:28:28,774 - INFO - Retrieved 1170 historical bars for ERNA
# 2025-09-01 13:28:29,102 - INFO - Retrieved 22 historical bars for ERNA
# 2025-09-01 13:28:31,105 - WARNING - No valid market data for ERNA
# 2025-09-01 13:28:31,814 - INFO - Retrieved 948 historical bars for ESLA
# 2025-09-01 13:28:32,190 - INFO - Retrieved 22 historical bars for ESLA
# 2025-09-01 13:28:34,194 - WARNING - No valid market data for ESLA
# 2025-09-01 13:28:34,196 - INFO - Enhanced analysis for ESLA: £1.05 (+0.00%)
# 2025-09-01 13:28:34,642 - INFO - Retrieved 948 historical bars for ESLA
# 2025-09-01 13:28:34,966 - INFO - Retrieved 22 historical bars for ESLA
# 2025-09-01 13:28:36,969 - WARNING - No valid market data for ESLA
# 2025-09-01 13:28:36,971 - INFO - BUY signal for ESLA: 4/7 signals
# 2025-09-01 13:28:36,973 - INFO - ✓ Market order placed: BUY 457142 ESLA
# 2025-09-01 13:28:36,975 - INFO - BUY executed: 457142 shares of ESLA
# 2025-09-01 13:28:36,976 - INFO - ESLA indicators - RSI: 100.0, MACD: 0.002, Volatility: 0.70%
# 2025-09-01 13:28:37,495 - ERROR - Error 201, reqId 362: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 258500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:28:37,496 - WARNING - Canceled order: Trade(contract=Stock(symbol='ESLA', exchange='SMART', currency='USD'), order=MarketOrder(orderId=362, clientId=1, permId=542815557, action='BUY', totalQuantity=457142.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=362, status='Cancelled', filled=0.0, remaining=457142.0, avgFillPrice=0.0, permId=542815557, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 36, 972764, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 37, 494405, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 28, 37, 495021, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 362: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 258500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:28:37,734 - INFO - Retrieved 1170 historical bars for ESPR
# 2025-09-01 13:28:38,087 - INFO - Retrieved 22 historical bars for ESPR
# 2025-09-01 13:28:40,091 - WARNING - No valid market data for ESPR
# 2025-09-01 13:28:40,093 - INFO - Enhanced analysis for ESPR: £2.22 (+0.00%)
# 2025-09-01 13:28:40,599 - INFO - Retrieved 1170 historical bars for ESPR
# 2025-09-01 13:28:40,930 - INFO - Retrieved 22 historical bars for ESPR
# 2025-09-01 13:28:42,933 - WARNING - No valid market data for ESPR
# 2025-09-01 13:28:43,645 - INFO - Retrieved 1117 historical bars for EVGN
# 2025-09-01 13:28:43,970 - INFO - Retrieved 22 historical bars for EVGN
# 2025-09-01 13:28:45,973 - WARNING - No valid market data for EVGN
# 2025-09-01 13:28:45,975 - INFO - Enhanced analysis for EVGN: £1.29 (+0.00%)
# 2025-09-01 13:28:46,429 - INFO - Retrieved 1117 historical bars for EVGN
# 2025-09-01 13:28:46,750 - INFO - Retrieved 22 historical bars for EVGN
# 2025-09-01 13:28:48,754 - WARNING - No valid market data for EVGN
# 2025-09-01 13:28:49,483 - INFO - Retrieved 1170 historical bars for FATE
# 2025-09-01 13:28:49,825 - INFO - Retrieved 22 historical bars for FATE
# 2025-09-01 13:28:51,827 - WARNING - No valid market data for FATE
# 2025-09-01 13:28:51,832 - INFO - Enhanced analysis for FATE: £1.04 (+0.00%)
# 2025-09-01 13:28:52,352 - INFO - Retrieved 1170 historical bars for FATE
# 2025-09-01 13:28:52,670 - INFO - Retrieved 22 historical bars for FATE
# 2025-09-01 13:28:54,674 - WARNING - No valid market data for FATE
# 2025-09-01 13:28:55,403 - INFO - Retrieved 1170 historical bars for FBLG
# 2025-09-01 13:28:55,719 - INFO - Retrieved 22 historical bars for FBLG
# 2025-09-01 13:28:57,723 - WARNING - No valid market data for FBLG
# 2025-09-01 13:28:57,728 - INFO - Enhanced analysis for FBLG: £0.60 (+0.00%)
# 2025-09-01 13:28:58,221 - INFO - Retrieved 1170 historical bars for FBLG
# 2025-09-01 13:28:58,541 - INFO - Retrieved 22 historical bars for FBLG
# 2025-09-01 13:29:00,545 - WARNING - No valid market data for FBLG
# 2025-09-01 13:29:00,548 - INFO - BUY signal for FBLG: 3/7 signals
# 2025-09-01 13:29:00,550 - INFO - ✓ Market order placed: BUY 670690 FBLG
# 2025-09-01 13:29:00,552 - INFO - BUY executed: 670690 shares of FBLG
# 2025-09-01 13:29:00,553 - INFO - FBLG indicators - RSI: 45.6, MACD: -0.002, Volatility: 1.35%
# 2025-09-01 13:29:00,554 - INFO - Cycle completed: 16 trades executed
# 2025-09-01 13:30:00,562 - INFO - --- Cycle 2 ---
# 2025-09-01 13:30:00,576 - ERROR - Error 201, reqId 387: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 132000), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:30:00,578 - WARNING - Canceled order: Trade(contract=Stock(symbol='FBLG', exchange='SMART', currency='USD'), order=MarketOrder(orderId=387, clientId=1, permId=542815558, action='BUY', totalQuantity=670690.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=387, status='Cancelled', filled=0.0, remaining=670690.0, avgFillPrice=0.0, permId=542815558, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 29, 0, 550065, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 30, 0, 574941, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 30, 0, 574941, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 387: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 132000), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:30:01,276 - INFO - Retrieved 1170 historical bars for ABCL
# 2025-09-01 13:30:01,603 - INFO - Retrieved 22 historical bars for ABCL
# 2025-09-01 13:30:03,609 - WARNING - No valid market data for ABCL
# 2025-09-01 13:30:03,611 - INFO - Enhanced analysis for ABCL: £4.17 (+0.00%)
# 2025-09-01 13:30:04,141 - INFO - Retrieved 1170 historical bars for ABCL
# 2025-09-01 13:30:04,466 - INFO - Retrieved 22 historical bars for ABCL
# 2025-09-01 13:30:06,470 - WARNING - No valid market data for ABCL
# 2025-09-01 13:30:07,055 - INFO - Retrieved 1170 historical bars for ALLO
# 2025-09-01 13:30:07,374 - INFO - Retrieved 22 historical bars for ALLO
# 2025-09-01 13:30:09,377 - WARNING - No valid market data for ALLO
# 2025-09-01 13:30:09,378 - INFO - Enhanced analysis for ALLO: £1.14 (+0.00%)
# 2025-09-01 13:30:09,862 - INFO - Retrieved 1170 historical bars for ALLO
# ...
# 2025-09-01 13:53:14,177 - INFO - ESLA indicators - RSI: 100.0, MACD: 0.002, Volatility: 0.70%
# 2025-09-01 13:53:14,565 - ERROR - Error 201, reqId 1687: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 258500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.
# 2025-09-01 13:53:14,566 - WARNING - Canceled order: Trade(contract=Stock(symbol='ESLA', exchange='SMART', currency='USD'), order=MarketOrder(orderId=1687, clientId=1, permId=542815586, action='BUY', totalQuantity=457142.0, lmtPrice=0.0, auxPrice=0.0), orderStatus=OrderStatus(orderId=1687, status='Cancelled', filled=0.0, remaining=457142.0, avgFillPrice=0.0, permId=542815586, parentId=0, lastFillPrice=0.0, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 53, 14, 174738, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 53, 14, 562321, tzinfo=datetime.timezone.utc), status='Inactive', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2025, 9, 1, 12, 53, 14, 565051, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 201, reqId 1687: Order rejected - reason:Your order is too large for us to accept for a non-algorithmic order. Please submit a smaller order (not <br>exceeding 258500), or convert your order to an algorithmic Order (IBALGO). This is a control designed to <br>ensure that we comply with our regulatory obligations to avoid submitting disruptive orders to the <br>marketplace.', errorCode=201)], advancedError='')
# 2025-09-01 13:53:14,787 - INFO - Retrieved 1170 historical bars for ESPR
# 2025-09-01 13:53:15,099 - INFO - Retrieved 22 historical bars for ESPR
# 2025-09-01 13:53:17,101 - WARNING - No valid market data for ESPR
# 2025-09-01 13:53:17,103 - INFO - Enhanced analysis for ESPR: £2.22 (+0.00%)
# 2025-09-01 13:53:17,634 - INFO - Retrieved 1170 historical bars for ESPR
# 2025-09-01 13:53:17,946 - INFO - Retrieved 22 historical bars for ESPR
# 2025-09-01 13:53:19,949 - WARNING - No valid market data for ESPR
# 2025-09-01 13:53:20,439 - INFO - Retrieved 1117 historical bars for EVGN
# 2025-09-01 13:53:20,797 - INFO - Retrieved 22 historical bars for EVGN
# 2025-09-01 13:53:22,801 - WARNING - No valid market data for EVGN
# 2025-09-01 13:53:22,803 - INFO - Enhanced analysis for EVGN: £1.29 (+0.00%)
# 2025-09-01 13:53:23,258 - INFO - Retrieved 1117 historical bars for EVGN
# 2025-09-01 13:53:23,574 - INFO - Retrieved 22 historical bars for EVGN
# 2025-09-01 13:53:25,578 - WARNING - No valid market data for EVGN
# 2025-09-01 13:53:26,112 - INFO - Retrieved 1170 historical bars for FATE
# 2025-09-01 13:53:26,432 - INFO - Retrieved 22 historical bars for FATE
# 2025-09-01 13:53:28,435 - WARNING - No valid market data for FATE
# 2025-09-01 13:53:28,439 - INFO - Enhanced analysis for FATE: £1.04 (+0.00%)
# 2025-09-01 13:53:28,943 - INFO - Retrieved 1170 historical bars for FATE
# 2025-09-01 13:53:29,256 - INFO - Retrieved 22 historical bars for FATE
# 2025-09-01 13:53:31,260 - WARNING - No valid market data for FATE
# 2025-09-01 13:53:31,771 - INFO - Retrieved 1170 historical bars for FBLG
# 2025-09-01 13:53:32,089 - INFO - Retrieved 22 historical bars for FBLG
# 2025-09-01 13:53:34,092 - WARNING - No valid market data for FBLG
# 2025-09-01 13:53:34,095 - INFO - Enhanced analysis for FBLG: £0.60 (+0.00%)
# 2025-09-01 13:53:34,600 - INFO - Retrieved 1170 historical bars for FBLG
# 2025-09-01 13:53:34,918 - INFO - Retrieved 22 historical bars for FBLG
# 2025-09-01 13:53:36,921 - WARNING - No valid market data for FBLG
# 2025-09-01 13:53:36,923 - INFO - Cycle completed: 7 trades executed
# 2025-09-01 13:53:36,924 - INFO - Performance - Total Trades: 14, Win Rate: 0.0%, Total P&L: £0.00
# 2025-09-01 13:53:36,926 - INFO - Market Overview - Active Positions: 16, Symbols Tracked: 54
# 2025-09-01 13:54:36,928 - INFO - Reached maximum cycles (5)
# 2025-09-01 13:54:36,932 - INFO - ==================================================
# 2025-09-01 13:54:36,933 - INFO - ENHANCED TRADING SESSION SUMMARY
# 2025-09-01 13:54:36,934 - INFO - ==================================================
# 2025-09-01 13:54:36,935 - INFO - Environment: PAPER
# 2025-09-01 13:54:36,936 - INFO - Duration: 0:30:55.828986
# 2025-09-01 13:54:36,938 - INFO - Total trades executed: 44
# 2025-09-01 13:54:36,938 - INFO - Strategy: Production_Enhanced
# 2025-09-01 13:54:36,939 - INFO - Win Rate: 0.0%
# 2025-09-01 13:54:36,940 - INFO - Total P&L: £0.00
# 2025-09-01 13:54:36,940 - INFO - Profitable Trades: 0/14
# 2025-09-01 13:54:36,941 - INFO - Current Positions:
# 2025-09-01 13:54:37,446 - INFO - Retrieved 1170 historical bars for ALLO
# 2025-09-01 13:54:37,816 - INFO - Retrieved 22 historical bars for ALLO
# 2025-09-01 13:54:39,820 - WARNING - No valid market data for ALLO
# 2025-09-01 13:54:39,822 - INFO - Enhanced analysis for ALLO: £1.14 (+0.00%)
# 2025-09-01 13:54:39,823 - INFO -   ALLO: 422907 shares @ £1.14 (Current: £1.14, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:40,312 - INFO - Retrieved 1170 historical bars for APLT
# 2025-09-01 13:54:40,633 - INFO - Retrieved 22 historical bars for APLT
# 2025-09-01 13:54:42,636 - WARNING - No valid market data for APLT
# 2025-09-01 13:54:42,639 - INFO - Enhanced analysis for APLT: £0.50 (+0.00%)
# 2025-09-01 13:54:42,640 - INFO -   APLT: 958275 shares @ £0.50 (Current: £0.50, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:43,135 - INFO - Retrieved 1170 historical bars for ARAY
# 2025-09-01 13:54:43,449 - INFO - Retrieved 22 historical bars for ARAY
# 2025-09-01 13:54:45,453 - WARNING - No valid market data for ARAY
# 2025-09-01 13:54:45,455 - INFO - Enhanced analysis for ARAY: £1.52 (+0.00%)
# 2025-09-01 13:54:45,456 - INFO -   ARAY: 314754 shares @ £1.52 (Current: £1.52, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:45,972 - INFO - Retrieved 1170 historical bars for ATEN
# 2025-09-01 13:54:46,285 - INFO - Retrieved 22 historical bars for ATEN
# 2025-09-01 13:54:48,289 - WARNING - No valid market data for ATEN
# 2025-09-01 13:54:48,291 - INFO - Enhanced analysis for ATEN: £17.72 (+0.00%)
# 2025-09-01 13:54:48,292 - INFO -   ATEN: 27088 shares @ £17.72 (Current: £17.72, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:48,836 - INFO - Retrieved 1170 historical bars for ATAI
# 2025-09-01 13:54:49,151 - INFO - Retrieved 22 historical bars for ATAI
# 2025-09-01 13:54:51,155 - WARNING - No valid market data for ATAI
# 2025-09-01 13:54:51,157 - INFO - Enhanced analysis for ATAI: £4.57 (+0.00%)
# 2025-09-01 13:54:51,158 - INFO -   ATAI: 105032 shares @ £4.57 (Current: £4.57, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:51,654 - INFO - Retrieved 1170 historical bars for CCCC
# 2025-09-01 13:54:51,974 - INFO - Retrieved 22 historical bars for CCCC
# 2025-09-01 13:54:53,977 - WARNING - No valid market data for CCCC
# 2025-09-01 13:54:53,980 - INFO - Enhanced analysis for CCCC: £2.60 (+0.00%)
# 2025-09-01 13:54:53,980 - INFO -   CCCC: 184615 shares @ £2.60 (Current: £2.60, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:54,516 - INFO - Retrieved 1170 historical bars for CGTX
# 2025-09-01 13:54:54,904 - INFO - Retrieved 22 historical bars for CGTX
# 2025-09-01 13:54:56,908 - WARNING - No valid market data for CGTX
# 2025-09-01 13:54:56,910 - INFO - Enhanced analysis for CGTX: £2.42 (+0.00%)
# 2025-09-01 13:54:56,911 - INFO -   CGTX: 198347 shares @ £2.42 (Current: £2.42, P&L: £+0.00 +0.0%)
# 2025-09-01 13:54:57,448 - INFO - Retrieved 1170 historical bars for CLRB
# 2025-09-01 13:54:57,770 - INFO - Retrieved 22 historical bars for CLRB
# 2025-09-01 13:54:59,774 - WARNING - No valid market data for CLRB
# 2025-09-01 13:54:59,776 - INFO - Enhanced analysis for CLRB: £4.96 (+0.00%)
# 2025-09-01 13:54:59,778 - INFO -   CLRB: 96774 shares @ £4.96 (Current: £4.96, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:00,277 - INFO - Retrieved 1170 historical bars for CLYM
# 2025-09-01 13:55:00,594 - INFO - Retrieved 22 historical bars for CLYM
# 2025-09-01 13:55:02,597 - WARNING - No valid market data for CLYM
# 2025-09-01 13:55:02,599 - INFO - Enhanced analysis for CLYM: £2.25 (+0.00%)
# 2025-09-01 13:55:02,600 - INFO -   CLYM: 213808 shares @ £2.25 (Current: £2.25, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:03,096 - INFO - Retrieved 1170 historical bars for CMPS
# 2025-09-01 13:55:03,406 - INFO - Retrieved 22 historical bars for CMPS
# 2025-09-01 13:55:05,408 - WARNING - No valid market data for CMPS
# 2025-09-01 13:55:05,412 - INFO - Enhanced analysis for CMPS: £4.41 (+0.00%)
# 2025-09-01 13:55:05,413 - INFO -   CMPS: 108843 shares @ £4.41 (Current: £4.41, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:06,011 - INFO - Retrieved 1170 historical bars for CMPX
# 2025-09-01 13:55:06,326 - INFO - Retrieved 22 historical bars for CMPX
# 2025-09-01 13:55:08,329 - WARNING - No valid market data for CMPX
# 2025-09-01 13:55:08,331 - INFO - Enhanced analysis for CMPX: £3.48 (+0.00%)
# 2025-09-01 13:55:08,334 - INFO -   CMPX: 137733 shares @ £3.48 (Current: £3.48, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:08,818 - INFO - Retrieved 1170 historical bars for CTOR
# 2025-09-01 13:55:09,133 - INFO - Retrieved 22 historical bars for CTOR
# 2025-09-01 13:55:11,136 - WARNING - No valid market data for CTOR
# 2025-09-01 13:55:11,139 - INFO - Enhanced analysis for CTOR: £2.15 (+0.00%)
# 2025-09-01 13:55:11,140 - INFO -   CTOR: 223776 shares @ £2.15 (Current: £2.15, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:11,625 - INFO - Retrieved 1170 historical bars for CTXR
# 2025-09-01 13:55:11,946 - INFO - Retrieved 22 historical bars for CTXR
# 2025-09-01 13:55:13,950 - WARNING - No valid market data for CTXR
# 2025-09-01 13:55:13,952 - INFO - Enhanced analysis for CTXR: £1.33 (+0.00%)
# 2025-09-01 13:55:13,953 - INFO -   CTXR: 361065 shares @ £1.33 (Current: £1.33, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:14,424 - INFO - Retrieved 1170 historical bars for ERAS
# 2025-09-01 13:55:14,738 - INFO - Retrieved 22 historical bars for ERAS
# 2025-09-01 13:55:16,742 - WARNING - No valid market data for ERAS
# 2025-09-01 13:55:16,745 - INFO - Enhanced analysis for ERAS: £1.57 (+0.00%)
# 2025-09-01 13:55:16,746 - INFO -   ERAS: 304761 shares @ £1.57 (Current: £1.57, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:17,213 - INFO - Retrieved 948 historical bars for ESLA
# 2025-09-01 13:55:17,527 - INFO - Retrieved 22 historical bars for ESLA
# 2025-09-01 13:55:19,531 - WARNING - No valid market data for ESLA
# 2025-09-01 13:55:19,533 - INFO - Enhanced analysis for ESLA: £1.05 (+0.00%)
# 2025-09-01 13:55:19,537 - INFO -   ESLA: 457142 shares @ £1.05 (Current: £1.05, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:20,020 - INFO - Retrieved 1170 historical bars for FBLG
# 2025-09-01 13:55:20,337 - INFO - Retrieved 22 historical bars for FBLG
# 2025-09-01 13:55:22,341 - WARNING - No valid market data for FBLG
# 2025-09-01 13:55:22,342 - INFO - Enhanced analysis for FBLG: £0.60 (+0.00%)
# 2025-09-01 13:55:22,343 - INFO -   FBLG: 670690 shares @ £0.60 (Current: £0.60, P&L: £+0.00 +0.0%)
# 2025-09-01 13:55:22,344 - INFO - Total Position Value: £7599985.24
# 2025-09-01 13:55:22,345 - INFO - Technical Indicators Summary:
# 2025-09-01 13:55:22,346 - INFO -   ABCL: RSI: 46.2, MACD: 0.001, Vol: 0.1%
# 2025-09-01 13:55:22,348 - INFO -   ALLO: RSI: 62.5, MACD: 0.005, Vol: 0.3%
# 2025-09-01 13:55:22,349 - INFO -   ANNX: RSI: 22.9, MACD: -0.008, Vol: 0.3%
# 2025-09-01 13:55:22,350 - INFO -   ANRO: RSI: 9.5, MACD: -0.007, Vol: 0.2%
# 2025-09-01 13:55:22,351 - INFO -   ANVS: RSI: 0.0, MACD: -0.003, Vol: 0.1%
# 2025-09-01 13:55:22,352 - INFO -   APLM: RSI: 23.5, MACD: -0.025, Vol: 0.8%
# 2025-09-01 13:55:22,353 - INFO -   APLT: RSI: 70.0, MACD: 0.001, Vol: 0.6%
# 2025-09-01 13:55:22,354 - INFO -   APVO: RSI: 20.0, MACD: -0.001, Vol: 0.2%
# 2025-09-01 13:55:22,354 - INFO -   ARAY: RSI: 66.7, MACD: 0.000, Vol: 0.2%
# 2025-09-01 13:55:22,355 - INFO -   ARBE: RSI: 23.8, MACD: -0.002, Vol: 0.3%
# 2025-09-01 13:55:22,355 - INFO -   ATEN: RSI: 73.3, MACD: 0.028, Vol: 0.1%
# 2025-09-01 13:55:22,356 - INFO -   ATAI: RSI: 47.1, MACD: 0.003, Vol: 0.2%
# 2025-09-01 13:55:22,361 - INFO -   ATHA: RSI: 44.4, MACD: 0.000, Vol: 0.4%
# 2025-09-01 13:55:22,379 - INFO -   AUTL: RSI: 42.8, MACD: -0.004, Vol: 0.4%
# 2025-09-01 13:55:22,381 - INFO -   AVIR: RSI: 66.7, MACD: 0.004, Vol: 0.1%
# 2025-09-01 13:55:22,382 - INFO -   CABA: RSI: 80.1, MACD: 0.008, Vol: 0.4%
# 2025-09-01 13:55:22,383 - INFO -   CAMP: RSI: 72.7, MACD: 0.013, Vol: 0.7%
# 2025-09-01 13:55:22,385 - INFO -   CARM: RSI: 35.0, MACD: -0.000, Vol: 0.6%
# 2025-09-01 13:55:22,387 - INFO -   CATX: RSI: 56.1, MACD: 0.004, Vol: 0.2%
# 2025-09-01 13:55:22,388 - INFO -   CCCC: RSI: 75.0, MACD: 0.014, Vol: 0.3%
# 2025-09-01 13:55:22,389 - INFO -   CELU: RSI: 54.1, MACD: 0.031, Vol: 1.6%
# 2025-09-01 13:55:22,390 - INFO -   CERS: RSI: 50.0, MACD: 0.001, Vol: 0.2%
# 2025-09-01 13:55:22,390 - INFO -   CGTX: RSI: 30.1, MACD: -0.003, Vol: 0.2%
# 2025-09-01 13:55:22,391 - INFO -   CHRS: RSI: 42.2, MACD: -0.001, Vol: 0.3%
# 2025-09-01 13:55:22,392 - INFO -   CLDI: RSI: 53.3, MACD: 0.001, Vol: 0.4%
# 2025-09-01 13:55:22,393 - INFO -   CLLS: RSI: 100.0, MACD: -0.008, Vol: 0.3%
# 2025-09-01 13:55:22,395 - INFO -   CLRB: RSI: 65.1, MACD: 0.009, Vol: 0.3%
# 2025-09-01 13:55:22,396 - INFO -   CLSD: RSI: 57.3, MACD: 0.001, Vol: 0.6%
# 2025-09-01 13:55:22,396 - INFO -   CLYM: RSI: 38.5, MACD: -0.004, Vol: 0.3%
# 2025-09-01 13:55:22,397 - INFO -   CMPS: RSI: 46.2, MACD: -0.004, Vol: 0.3%
# 2025-09-01 13:55:22,398 - INFO -   CMPX: RSI: 84.6, MACD: 0.021, Vol: 0.3%
# 2025-09-01 13:55:22,398 - INFO -   CMTL: RSI: 45.9, MACD: 0.006, Vol: 0.3%
# 2025-09-01 13:55:22,399 - INFO -   COCP: RSI: 0.0, MACD: 0.002, Vol: 0.8%
# 2025-09-01 13:55:22,399 - INFO -   CRBU: RSI: 58.5, MACD: 0.003, Vol: 0.2%
# 2025-09-01 13:55:22,399 - INFO -   CRDF: RSI: 65.1, MACD: 0.007, Vol: 0.3%
# 2025-09-01 13:55:22,399 - INFO -   CRDL: RSI: 50.0, MACD: 0.001, Vol: 0.3%
# 2025-09-01 13:55:22,399 - INFO -   CRIS: RSI: nan, MACD: 0.004, Vol: 0.3%
# 2025-09-01 13:55:22,400 - INFO -   CTMX: RSI: 75.0, MACD: 0.004, Vol: 0.2%
# 2025-09-01 13:55:22,400 - INFO -   CTOR: RSI: 81.0, MACD: 0.004, Vol: 0.1%
# 2025-09-01 13:55:22,400 - INFO -   CTXR: RSI: 55.9, MACD: 0.001, Vol: 0.4%
# 2025-09-01 13:55:22,400 - INFO -   CUE: RSI: 75.0, MACD: 0.001, Vol: 0.3%
# 2025-09-01 13:55:22,400 - INFO -   CURR: RSI: 71.4, MACD: 0.008, Vol: 0.4%
# 2025-09-01 13:55:22,401 - INFO -   DARE: RSI: 33.3, MACD: -0.000, Vol: 0.1%
# 2025-09-01 13:55:22,401 - INFO -   DTIL: RSI: 27.3, MACD: -0.021, Vol: 0.4%
# 2025-09-01 13:55:22,401 - INFO -   EDIT: RSI: 64.3, MACD: 0.007, Vol: 0.3%
# 2025-09-01 13:55:22,402 - INFO -   ELDN: RSI: 21.4, MACD: -0.002, Vol: 0.3%
# 2025-09-01 13:55:22,402 - INFO -   EQ: RSI: 58.6, MACD: 0.044, Vol: 1.9%
# 2025-09-01 13:55:22,403 - INFO -   ERAS: RSI: 50.0, MACD: 0.002, Vol: 0.2%
# 2025-09-01 13:55:22,405 - INFO -   ERNA: RSI: 27.7, MACD: -0.005, Vol: 0.7%
# 2025-09-01 13:55:22,405 - INFO -   ESLA: RSI: 100.0, MACD: 0.002, Vol: 0.7%
# 2025-09-01 13:55:22,406 - INFO -   ESPR: RSI: 54.4, MACD: 0.001, Vol: 0.2%
# 2025-09-01 13:55:22,406 - INFO -   EVGN: RSI: 100.0, MACD: 0.004, Vol: 0.7%
# 2025-09-01 13:55:22,407 - INFO -   FATE: RSI: 60.1, MACD: 0.001, Vol: 0.3%
# 2025-09-01 13:55:22,408 - INFO -   FBLG: RSI: 45.6, MACD: -0.002, Vol: 1.3%
# 2025-09-01 13:55:22,409 - INFO - ==================================================
# 2025-09-01 13:55:22,410 - INFO - All market data subscriptions cancelled
# 2025-09-01 13:55:22,411 - INFO - Disconnected from IB
# 2025-09-01 13:55:22,412 - INFO - Trading bot disconnected
# Session Results:
# Trades: 44
# ALLO: 422907 shares @ £1.14
# APLT: 958275 shares @ £0.50
# ARAY: 314754 shares @ £1.52
# ATEN: 27088 shares @ £17.72
# ATAI: 105032 shares @ £4.57
# CCCC: 184615 shares @ £2.60
# CGTX: 198347 shares @ £2.42
# CLRB: 96774 shares @ £4.96
# CLYM: 213808 shares @ £2.25
# CMPS: 108843 shares @ £4.41
# CMPX: 137733 shares @ £3.48
# CTOR: 223776 shares @ £2.15
# CTXR: 361065 shares @ £1.33
# ERAS: 304761 shares @ £1.57
# ESLA: 457142 shares @ £1.05
# FBLG: 670690 shares @ £0.60
#
# Session ended
# ✓ IB Trading Bot Completed

# %% [markdown]
# ### Live Trading Notes
#
# Trader Workstation (TWS) Configuration for Live Trading:
#
# 1. Open TWS (not IB Gateway for first time)
# 2. Switch to LIVE account (not paper)
# 3. Go to Configure → API → Settings
# 4. Enable "Enable ActiveX and Socket Clients"
# 5. Set Socket port to 7496
# 6. Disable "Read-Only API"
# 7. Add 127.0.0.1 to trusted IPs
# 8. Restart TWS
#
# **Remember**: Live trading = real money. Never rush into it. The simulator and paper trading are there for a reason! 🎯

# %% [markdown]
# ### Execution IB Trading Bot - Live Trading (needs TWS running)

# %%
# 💰 Recommended Live Trading Progression 💰

# Week 1: Extensive simulator testing
# run_production_session('simulator', max_cycles=100)

# Week 2: Extensive paper trading
# run_production_session('paper', max_cycles=100)

# Week 3: Micro live trading
run_production_session('live', max_cycles=2)     # Double cycle
# run_production_session('live', max_cycles=5)   # If successful

# Week 4+: Gradual scale-up
# run_production_session('live', max_cycles=10)  # If consistently profitable
